# %%
import pandas as pd

returns_df = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Returns_2018-2023.csv')

# %%
returns_df.head()
# Out:
#    Unnamed: 0        Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 0           0  2018-01-12       0.029327      -0.044570            0.045761
# 1           1  2018-01-19       0.013632       0.040736            0.022956
# 2           2  2018-01-26       0.004538      -0.007576            0.013324
# 3           3  2018-02-02      -0.027427      -0.033079           -0.046367
# 4           4  2018-02-09      -0.044646      -0.072697           -0.066763
#
#    Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 0          0.032797              0.072444                    0.012517
# 1          0.131214             -0.021934                    0.067308
# 2         -0.006357              0.078472                    0.019305
# 3         -0.024787             -0.030991                   -0.015783
# 4         -0.023502              0.006656                   -0.042976
#
#    Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 0                                   0.032906                     0.040625
# 1                                  -0.031857                    -0.025826
# 2                                   0.011312                     0.029593
# 3                                  -0.073208                    -0.042515
# 4                                   0.036753                     0.003752
#
#    ...  Snam 2018-2023  Stellantis 2018-2023  Stmicroeletronics 2018-2023  \
# 0  ...       -0.017408              0.067525                     0.028307
# 1  ...        0.002461              0.021955                     0.023023
# 2  ...       -0.016200              0.012786                    -0.067025
# 3  ...       -0.044411             -0.050907                    -0.030414
# 4  ...       -0.069191             -0.073222                    -0.070308
#
#    Telecom 2018-2023  Tenaris 2018-2023  Terna 2018-2023  Unicredit 2018-2023  \
# 0           0.006770           0.043350        -0.023228             0.075077
# 1          -0.030262           0.002817         0.008200            -0.004007
# 2          -0.000693           0.021067        -0.002440             0.031609
# 3          -0.015406          -0.054333        -0.035671            -0.021170
# 4          -0.014942          -0.069818        -0.050518             0.010700
#
#    Unipol 2018-2023    BOT 3m  Risk Premium
# 0          0.052374 -0.008654      0.037980
# 1          0.011628 -0.008673      0.022305
# 2          0.031724 -0.009000      0.013538
# 3         -0.032308 -0.008923     -0.018504
# 4         -0.034769 -0.008865     -0.035781
#
# [5 rows x 43 columns]

# %%
returns_df.drop(columns='Unnamed: 0', inplace = True)

# %%
# Convert 'Date' column to datetime format
returns_df['Date'] = pd.to_datetime(returns_df['Date'])

# Extract year from 'Date' column
returns_df['Year'] = returns_df['Date'].dt.year

# Filter DataFrame to include only the data from 2020
returns_2020 = returns_df[returns_df['Year'] == 2020].copy()

# Drop the 'Year' column as it's no longer needed
returns_2020.drop(columns='Year', inplace=True)

# %%
returns_2020.columns = returns_2020.columns.str.replace('2018-2023', '2020')

# %%
import numpy as np

# Copy the 2020 data to avoid modifying the original DataFrame
returns_2020_excess = returns_2020.copy()

# Calculate excess returns for each stock by subtracting the risk-free rate
risk_free_rate = returns_2020_excess['BOT 3m'].values  # Convert Series to NumPy array
returns_2020_excess.iloc[:, 2:-2] -= risk_free_rate[:, np.newaxis]

# Display the first few rows of the new DataFrame
returns_2020_excess.head()
# Out:
#           Date  FTSEMIB Index  A2A 2020  Amplifon 2020  Azimut 2020  \
# 103 2020-01-03      -0.002326 -0.012606       0.004611     0.008655
# 104 2020-01-10       0.013461  0.042732       0.029638     0.122851
# 105 2020-01-17       0.004982  0.043359       0.016006     0.008480
# 106 2020-01-24      -0.007122  0.018893       0.016927     0.003737
# 107 2020-01-31      -0.030543  0.006361      -0.033166    -0.052553
#
#      BPER banca 2020  Banca Mediolanum 2020  \
# 103         0.038692              -0.010196
# 104         0.013978               0.033506
# 105         0.002870              -0.006254
# 106        -0.022895              -0.024997
# 107        -0.062303              -0.044030
#
#      Banca Monte dei Paschi di Siena 2020  Banca pop Sondrio 2020  \
# 103                              0.012034               -0.006426
# 104                              0.241722                0.019338
# 105                              0.000079                0.006689
# 106                              0.055737               -0.034512
# 107                             -0.045880               -0.033282
#
#      Banco Bpm 2020  ...  Snam 2020  Stellantis 2020  Stmicroeletronics 2020  \
# 103        0.008655  ...   0.000052        -0.018499                0.018398
# 104        0.122851  ...   0.031450        -0.011094                0.012745
# 105        0.008480  ...   0.046596        -0.023393                0.025441
# 106        0.003737  ...  -0.009417        -0.016205                0.110495
# 107       -0.052553  ...  -0.001213        -0.026574               -0.081817
#
#      Telecom 2020  Tenaris 2020  Terna 2020  Unicredit 2020  Unipol 2020  \
# 103     -0.000116      0.022082   -0.008950        0.023720    -0.026653
# 104     -0.051306      0.022521    0.032942        0.013268     0.007865
# 105     -0.015998     -0.001513    0.032097       -0.011022    -0.013915
# 106     -0.008500      0.001770    0.027122       -0.046573    -0.014101
# 107     -0.027509     -0.081425    0.003080       -0.021898    -0.042560
#
#        BOT 3m  Risk Premium
# 103 -0.007712      0.005386
# 104 -0.007865      0.021326
# 105 -0.007635      0.012616
# 106 -0.007115     -0.000007
# 107 -0.007192     -0.023351
#
# [5 rows x 42 columns]

# %%
import statsmodels.api as sm

# Create an empty DataFrame to store the beta values
beta_df = pd.DataFrame(index=returns_2020.columns[1:-2], columns=['Beta'])

# Iterate over each asset
for asset in returns_2020_excess.columns[1:-2]:
    # Extract excess returns of the asset and the market portfolio
    x = returns_2020['FTSEMIB Index'] - returns_2020['BOT 3m']  # Market excess return
    y = returns_2020[asset] - returns_2020['BOT 3m']  # Asset excess return
    
    # Add a constant to the independent variable (market excess return)
    x = sm.add_constant(x)
    
    # Fit OLS model
    model = sm.OLS(y, x)
    results = model.fit()

    print(results.summary())
    
    # Extract the beta coefficient (slope)
    beta = results.params[0]  # Index 0 corresponds to the coefficient of the independent variable
    
    # Store the beta coefficient in the DataFrame
    beta_df.loc[asset, 'Beta'] = beta

# Display the DataFrame with beta values
beta_df
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 8.638e+32
# Date:                Sat, 04 May 2024   Prob (F-statistic):               0.00
# Time:                        10:32:03   Log-Likelihood:                 1949.0
# No. Observations:                  52   AIC:                            -3894.
# Df Residuals:                      50   BIC:                            -3890.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -2.277e-18   1.82e-18     -1.251      0.217   -5.93e-18    1.38e-18
# 0              1.0000    3.4e-17   2.94e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                       39.773   Durbin-Watson:                   1.667
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.784
# Skew:                          -1.950   Prob(JB):                     3.31e-35
# Kurtosis:                      10.621   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.686
# Model:                            OLS   Adj. R-squared:                  0.680
# Method:                 Least Squares   F-statistic:                     109.3
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.51e-14
# Time:                        10:32:03   Log-Likelihood:                 102.23
# No. Observations:                  52   AIC:                            -200.5
# Df Residuals:                      50   BIC:                            -196.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0033      0.005     -0.683      0.498      -0.013       0.006
# 0              0.9434      0.090     10.456      0.000       0.762       1.125
# ==============================================================================
# Omnibus:                        3.811   Durbin-Watson:                   2.628
# Prob(Omnibus):                  0.149   Jarque-Bera (JB):                3.417
# Skew:                           0.221   Prob(JB):                        0.181
# Kurtosis:                       4.176   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.468
# Model:                            OLS   Adj. R-squared:                  0.457
# Method:                 Least Squares   F-statistic:                     43.97
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.27e-08
# Time:                        10:32:03   Log-Likelihood:                 91.316
# No. Observations:                  52   AIC:                            -178.6
# Df Residuals:                      50   BIC:                            -174.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0082      0.006      1.381      0.173      -0.004       0.020
# 0              0.7380      0.111      6.631      0.000       0.514       0.962
# ==============================================================================
# Omnibus:                        8.520   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):               18.547
# Skew:                           0.020   Prob(JB):                     9.39e-05
# Kurtosis:                       5.925   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.645
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     90.67
# Date:                Sat, 04 May 2024   Prob (F-statistic):           8.14e-13
# Time:                        10:32:03   Log-Likelihood:                 84.953
# No. Observations:                  52   AIC:                            -165.9
# Df Residuals:                      50   BIC:                            -162.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.007     -0.228      0.821      -0.015       0.012
# 0              1.1978      0.126      9.522      0.000       0.945       1.450
# ==============================================================================
# Omnibus:                       15.868   Durbin-Watson:                   2.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.510
# Skew:                          -0.532   Prob(JB):                     3.96e-12
# Kurtosis:                       7.807   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.544
# Model:                            OLS   Adj. R-squared:                  0.535
# Method:                 Least Squares   F-statistic:                     59.63
# Date:                Sat, 04 May 2024   Prob (F-statistic):           4.48e-10
# Time:                        10:32:03   Log-Likelihood:                 75.916
# No. Observations:                  52   AIC:                            -147.8
# Df Residuals:                      50   BIC:                            -143.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0113      0.008     -1.415      0.163      -0.027       0.005
# 0              1.1557      0.150      7.722      0.000       0.855       1.456
# ==============================================================================
# Omnibus:                        4.014   Durbin-Watson:                   1.832
# Prob(Omnibus):                  0.134   Jarque-Bera (JB):                2.995
# Skew:                           0.544   Prob(JB):                        0.224
# Kurtosis:                       3.445   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.662
# Model:                            OLS   Adj. R-squared:                  0.655
# Method:                 Least Squares   F-statistic:                     97.86
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.31e-13
# Time:                        10:32:03   Log-Likelihood:                 89.955
# No. Observations:                  52   AIC:                            -175.9
# Df Residuals:                      50   BIC:                            -172.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.006     -0.452      0.653      -0.015       0.010
# 0              1.1302      0.114      9.892      0.000       0.901       1.360
# ==============================================================================
# Omnibus:                       33.787   Durbin-Watson:                   3.123
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              197.572
# Skew:                          -1.357   Prob(JB):                     1.25e-43
# Kurtosis:                      12.155   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.359
# Model:                            OLS   Adj. R-squared:                  0.346
# Method:                 Least Squares   F-statistic:                     27.95
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.74e-06
# Time:                        10:32:03   Log-Likelihood:                 63.118
# No. Observations:                  52   AIC:                            -122.2
# Df Residuals:                      50   BIC:                            -118.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0016      0.010     -0.154      0.878      -0.022       0.019
# 0              1.0121      0.191      5.287      0.000       0.628       1.397
# ==============================================================================
# Omnibus:                       16.644   Durbin-Watson:                   2.320
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.101
# Skew:                           1.093   Prob(JB):                     9.63e-06
# Kurtosis:                       5.425   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.588
# Model:                            OLS   Adj. R-squared:                  0.579
# Method:                 Least Squares   F-statistic:                     71.28
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.46e-11
# Time:                        10:32:03   Log-Likelihood:                 78.380
# No. Observations:                  52   AIC:                            -152.8
# Df Residuals:                      50   BIC:                            -148.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.008      0.334      0.740      -0.013       0.018
# 0              1.2051      0.143      8.443      0.000       0.918       1.492
# ==============================================================================
# Omnibus:                        1.668   Durbin-Watson:                   2.168
# Prob(Omnibus):                  0.434   Jarque-Bera (JB):                0.980
# Skew:                           0.308   Prob(JB):                        0.613
# Kurtosis:                       3.268   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.645
# Model:                            OLS   Adj. R-squared:                  0.637
# Method:                 Least Squares   F-statistic:                     90.67
# Date:                Sat, 04 May 2024   Prob (F-statistic):           8.14e-13
# Time:                        10:32:03   Log-Likelihood:                 84.953
# No. Observations:                  52   AIC:                            -165.9
# Df Residuals:                      50   BIC:                            -162.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0015      0.007     -0.228      0.821      -0.015       0.012
# 0              1.1978      0.126      9.522      0.000       0.945       1.450
# ==============================================================================
# Omnibus:                       15.868   Durbin-Watson:                   2.906
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               52.510
# Skew:                          -0.532   Prob(JB):                     3.96e-12
# Kurtosis:                       7.807   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.337
# Model:                            OLS   Adj. R-squared:                  0.324
# Method:                 Least Squares   F-statistic:                     25.44
# Date:                Sat, 04 May 2024   Prob (F-statistic):           6.38e-06
# Time:                        10:32:03   Log-Likelihood:                 82.518
# No. Observations:                  52   AIC:                            -161.0
# Df Residuals:                      50   BIC:                            -157.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0060      0.007      0.857      0.396      -0.008       0.020
# 0              0.6649      0.132      5.044      0.000       0.400       0.930
# ==============================================================================
# Omnibus:                        2.048   Durbin-Watson:                   1.968
# Prob(Omnibus):                  0.359   Jarque-Bera (JB):                1.885
# Skew:                           0.452   Prob(JB):                        0.390
# Kurtosis:                       2.768   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.483
# Method:                 Least Squares   F-statistic:                     48.67
# Date:                Sat, 04 May 2024   Prob (F-statistic):           6.54e-09
# Time:                        10:32:03   Log-Likelihood:                 99.145
# No. Observations:                  52   AIC:                            -194.3
# Df Residuals:                      50   BIC:                            -190.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0055      0.005      1.072      0.289      -0.005       0.016
# 0              0.6679      0.096      6.976      0.000       0.476       0.860
# ==============================================================================
# Omnibus:                        1.722   Durbin-Watson:                   2.427
# Prob(Omnibus):                  0.423   Jarque-Bera (JB):                0.912
# Skew:                           0.196   Prob(JB):                        0.634
# Kurtosis:                       3.517   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.7486
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.391
# Time:                        10:32:03   Log-Likelihood:                 71.891
# No. Observations:                  52   AIC:                            -139.8
# Df Residuals:                      50   BIC:                            -135.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0164      0.009      1.895      0.064      -0.001       0.034
# 0             -0.1399      0.162     -0.865      0.391      -0.465       0.185
# ==============================================================================
# Omnibus:                        1.574   Durbin-Watson:                   1.714
# Prob(Omnibus):                  0.455   Jarque-Bera (JB):                0.801
# Skew:                           0.038   Prob(JB):                        0.670
# Kurtosis:                       3.603   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.788
# Model:                            OLS   Adj. R-squared:                  0.784
# Method:                 Least Squares   F-statistic:                     185.8
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.83e-18
# Time:                        10:32:03   Log-Likelihood:                 111.64
# No. Observations:                  52   AIC:                            -219.3
# Df Residuals:                      50   BIC:                            -215.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0046      0.004      1.142      0.259      -0.003       0.013
# 0              1.0263      0.075     13.630      0.000       0.875       1.178
# ==============================================================================
# Omnibus:                       11.577   Durbin-Watson:                   2.670
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               12.421
# Skew:                           0.907   Prob(JB):                      0.00201
# Kurtosis:                       4.563   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.715
# Model:                            OLS   Adj. R-squared:                  0.709
# Method:                 Least Squares   F-statistic:                     125.2
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.20e-15
# Time:                        10:32:03   Log-Likelihood:                 91.573
# No. Observations:                  52   AIC:                            -179.1
# Df Residuals:                      50   BIC:                            -175.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0078      0.006     -1.319      0.193      -0.020       0.004
# 0              1.2393      0.111     11.190      0.000       1.017       1.462
# ==============================================================================
# Omnibus:                       28.183   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               69.181
# Skew:                           1.495   Prob(JB):                     9.50e-16
# Kurtosis:                       7.795   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.411
# Model:                            OLS   Adj. R-squared:                  0.399
# Method:                 Least Squares   F-statistic:                     34.86
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.08e-07
# Time:                        10:32:03   Log-Likelihood:                 86.559
# No. Observations:                  52   AIC:                            -169.1
# Df Residuals:                      50   BIC:                            -165.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0060      0.007      0.927      0.359      -0.007       0.019
# 0              0.7201      0.122      5.905      0.000       0.475       0.965
# ==============================================================================
# Omnibus:                        6.823   Durbin-Watson:                   2.170
# Prob(Omnibus):                  0.033   Jarque-Bera (JB):                7.620
# Skew:                          -0.455   Prob(JB):                       0.0222
# Kurtosis:                       4.640   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.447
# Method:                 Least Squares   F-statistic:                     42.26
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.63e-08
# Time:                        10:32:03   Log-Likelihood:                 105.86
# No. Observations:                  52   AIC:                            -207.7
# Df Residuals:                      50   BIC:                            -203.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0077      0.005      1.720      0.092      -0.001       0.017
# 0              0.5469      0.084      6.501      0.000       0.378       0.716
# ==============================================================================
# Omnibus:                        3.139   Durbin-Watson:                   2.225
# Prob(Omnibus):                  0.208   Jarque-Bera (JB):                2.147
# Skew:                           0.430   Prob(JB):                        0.342
# Kurtosis:                       3.501   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.501
# Model:                            OLS   Adj. R-squared:                  0.491
# Method:                 Least Squares   F-statistic:                     50.23
# Date:                Sat, 04 May 2024   Prob (F-statistic):           4.38e-09
# Time:                        10:32:03   Log-Likelihood:                 98.879
# No. Observations:                  52   AIC:                            -193.8
# Df Residuals:                      50   BIC:                            -189.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0073      0.005      1.414      0.163      -0.003       0.018
# 0              0.6821      0.096      7.088      0.000       0.489       0.875
# ==============================================================================
# Omnibus:                        1.624   Durbin-Watson:                   2.271
# Prob(Omnibus):                  0.444   Jarque-Bera (JB):                0.995
# Skew:                           0.322   Prob(JB):                        0.608
# Kurtosis:                       3.209   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.843
# Model:                            OLS   Adj. R-squared:                  0.840
# Method:                 Least Squares   F-statistic:                     268.9
# Date:                Sat, 04 May 2024   Prob (F-statistic):           9.32e-22
# Time:                        10:32:03   Log-Likelihood:                 122.44
# No. Observations:                  52   AIC:                            -240.9
# Df Residuals:                      50   BIC:                            -237.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0035      0.003     -1.072      0.289      -0.010       0.003
# 0              1.0031      0.061     16.397      0.000       0.880       1.126
# ==============================================================================
# Omnibus:                        9.230   Durbin-Watson:                   2.631
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               20.158
# Skew:                          -0.207   Prob(JB):                     4.20e-05
# Kurtosis:                       6.022   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.560
# Model:                            OLS   Adj. R-squared:                  0.551
# Method:                 Least Squares   F-statistic:                     63.59
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.82e-10
# Time:                        10:32:04   Log-Likelihood:                 106.58
# No. Observations:                  52   AIC:                            -209.2
# Df Residuals:                      50   BIC:                            -205.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0025      0.004     -0.569      0.572      -0.011       0.006
# 0              0.6618      0.083      7.974      0.000       0.495       0.829
# ==============================================================================
# Omnibus:                        0.373   Durbin-Watson:                   2.624
# Prob(Omnibus):                  0.830   Jarque-Bera (JB):                0.544
# Skew:                          -0.102   Prob(JB):                        0.762
# Kurtosis:                       2.542   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.401
# Model:                            OLS   Adj. R-squared:                  0.389
# Method:                 Least Squares   F-statistic:                     33.53
# Date:                Sat, 04 May 2024   Prob (F-statistic):           4.62e-07
# Time:                        10:32:04   Log-Likelihood:                 93.795
# No. Observations:                  52   AIC:                            -183.6
# Df Residuals:                      50   BIC:                            -179.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0102      0.006      1.804      0.077      -0.001       0.022
# 0              0.6145      0.106      5.791      0.000       0.401       0.828
# ==============================================================================
# Omnibus:                        0.767   Durbin-Watson:                   2.179
# Prob(Omnibus):                  0.681   Jarque-Bera (JB):                0.869
# Skew:                          -0.217   Prob(JB):                        0.648
# Kurtosis:                       2.538   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.841
# Method:                 Least Squares   F-statistic:                     270.6
# Date:                Sat, 04 May 2024   Prob (F-statistic):           8.13e-22
# Time:                        10:32:04   Log-Likelihood:                 113.65
# No. Observations:                  52   AIC:                            -223.3
# Df Residuals:                      50   BIC:                            -219.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0030      0.004     -0.766      0.447      -0.011       0.005
# 0              1.1916      0.072     16.450      0.000       1.046       1.337
# ==============================================================================
# Omnibus:                       26.520   Durbin-Watson:                   2.092
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               78.265
# Skew:                          -1.280   Prob(JB):                     1.01e-17
# Kurtosis:                       8.437   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.139
# Model:                            OLS   Adj. R-squared:                  0.121
# Method:                 Least Squares   F-statistic:                     8.040
# Date:                Sat, 04 May 2024   Prob (F-statistic):            0.00659
# Time:                        10:32:04   Log-Likelihood:                 77.328
# No. Observations:                  52   AIC:                            -150.7
# Df Residuals:                      50   BIC:                            -146.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0078      0.008      1.005      0.320      -0.008       0.023
# 0              0.4130      0.146      2.835      0.007       0.120       0.706
# ==============================================================================
# Omnibus:                        8.842   Durbin-Watson:                   2.959
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):               10.894
# Skew:                           0.577   Prob(JB):                      0.00431
# Kurtosis:                       4.922   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.531
# Model:                            OLS   Adj. R-squared:                  0.521
# Method:                 Least Squares   F-statistic:                     56.55
# Date:                Sat, 04 May 2024   Prob (F-statistic):           9.25e-10
# Time:                        10:32:04   Log-Likelihood:                 110.63
# No. Observations:                  52   AIC:                            -217.3
# Df Residuals:                      50   BIC:                            -213.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.004      0.436      0.665      -0.006       0.010
# 0              0.5773      0.077      7.520      0.000       0.423       0.731
# ==============================================================================
# Omnibus:                        3.083   Durbin-Watson:                   2.513
# Prob(Omnibus):                  0.214   Jarque-Bera (JB):                2.649
# Skew:                           0.028   Prob(JB):                        0.266
# Kurtosis:                       4.104   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.660
# Model:                            OLS   Adj. R-squared:                  0.654
# Method:                 Least Squares   F-statistic:                     97.21
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.58e-13
# Time:                        10:32:04   Log-Likelihood:                 71.517
# No. Observations:                  52   AIC:                            -139.0
# Df Residuals:                      50   BIC:                            -135.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0098      0.009     -1.121      0.268      -0.027       0.008
# 0              1.6059      0.163      9.860      0.000       1.279       1.933
# ==============================================================================
# Omnibus:                        5.337   Durbin-Watson:                   2.433
# Prob(Omnibus):                  0.069   Jarque-Bera (JB):                6.122
# Skew:                           0.262   Prob(JB):                       0.0469
# Kurtosis:                       4.597   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.776
# Method:                 Least Squares   F-statistic:                     177.7
# Date:                Sat, 04 May 2024   Prob (F-statistic):           4.37e-18
# Time:                        10:32:04   Log-Likelihood:                 94.031
# No. Observations:                  52   AIC:                            -184.1
# Df Residuals:                      50   BIC:                            -180.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0044      0.006     -0.774      0.442      -0.016       0.007
# 0              1.4084      0.106     13.332      0.000       1.196       1.621
# ==============================================================================
# Omnibus:                       13.519   Durbin-Watson:                   2.544
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               33.018
# Skew:                          -0.541   Prob(JB):                     6.76e-08
# Kurtosis:                       6.751   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.483
# Model:                            OLS   Adj. R-squared:                  0.472
# Method:                 Least Squares   F-statistic:                     46.64
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.11e-08
# Time:                        10:32:04   Log-Likelihood:                 97.899
# No. Observations:                  52   AIC:                            -191.8
# Df Residuals:                      50   BIC:                            -187.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0066      0.005      1.265      0.212      -0.004       0.017
# 0              0.6697      0.098      6.829      0.000       0.473       0.867
# ==============================================================================
# Omnibus:                        5.181   Durbin-Watson:                   2.207
# Prob(Omnibus):                  0.075   Jarque-Bera (JB):                4.101
# Skew:                           0.633   Prob(JB):                        0.129
# Kurtosis:                       3.536   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# ...
# Df Residuals:                      50   BIC:                            -221.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0024      0.004      0.625      0.535      -0.005       0.010
# 0              0.7445      0.071     10.476      0.000       0.602       0.887
# ==============================================================================
# Omnibus:                        2.324   Durbin-Watson:                   2.740
# Prob(Omnibus):                  0.313   Jarque-Bera (JB):                1.528
# Skew:                           0.144   Prob(JB):                        0.466
# Kurtosis:                       3.789   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.590
# Model:                            OLS   Adj. R-squared:                  0.582
# Method:                 Least Squares   F-statistic:                     72.05
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.95e-11
# Time:                        10:32:04   Log-Likelihood:                 84.286
# No. Observations:                  52   AIC:                            -164.6
# Df Residuals:                      50   BIC:                            -160.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0040      0.007      0.581      0.564      -0.010       0.018
# 0              1.0815      0.127      8.488      0.000       0.826       1.337
# ==============================================================================
# Omnibus:                       55.152   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              461.710
# Skew:                          -2.538   Prob(JB):                    5.51e-101
# Kurtosis:                      16.687   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.661
# Method:                 Least Squares   F-statistic:                     100.6
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.46e-13
# Time:                        10:32:04   Log-Likelihood:                 86.440
# No. Observations:                  52   AIC:                            -168.9
# Df Residuals:                      50   BIC:                            -165.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0058      0.007      0.893      0.376      -0.007       0.019
# 0              1.2260      0.122     10.029      0.000       0.980       1.471
# ==============================================================================
# Omnibus:                        5.187   Durbin-Watson:                   2.409
# Prob(Omnibus):                  0.075   Jarque-Bera (JB):                6.728
# Skew:                           0.090   Prob(JB):                       0.0346
# Kurtosis:                       4.753   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.425
# Model:                            OLS   Adj. R-squared:                  0.413
# Method:                 Least Squares   F-statistic:                     36.96
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.65e-07
# Time:                        10:32:04   Log-Likelihood:                 79.061
# No. Observations:                  52   AIC:                            -154.1
# Df Residuals:                      50   BIC:                            -150.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0041      0.008     -0.544      0.589      -0.019       0.011
# 0              0.8564      0.141      6.079      0.000       0.573       1.139
# ==============================================================================
# Omnibus:                        2.187   Durbin-Watson:                   2.464
# Prob(Omnibus):                  0.335   Jarque-Bera (JB):                1.366
# Skew:                           0.354   Prob(JB):                        0.505
# Kurtosis:                       3.358   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.757
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     155.9
# Date:                Sat, 04 May 2024   Prob (F-statistic):           5.50e-17
# Time:                        10:32:04   Log-Likelihood:                 90.413
# No. Observations:                  52   AIC:                            -176.8
# Df Residuals:                      50   BIC:                            -172.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0067      0.006     -1.105      0.274      -0.019       0.005
# 0              1.4141      0.113     12.486      0.000       1.187       1.642
# ==============================================================================
# Omnibus:                        2.115   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.347   Jarque-Bera (JB):                1.468
# Skew:                           0.403   Prob(JB):                        0.480
# Kurtosis:                       3.170   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.595
# Model:                            OLS   Adj. R-squared:                  0.587
# Method:                 Least Squares   F-statistic:                     73.34
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.26e-11
# Time:                        10:32:04   Log-Likelihood:                 113.90
# No. Observations:                  52   AIC:                            -223.8
# Df Residuals:                      50   BIC:                            -219.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0039      0.004      1.001      0.322      -0.004       0.012
# 0              0.6173      0.072      8.564      0.000       0.473       0.762
# ==============================================================================
# Omnibus:                        2.945   Durbin-Watson:                   2.563
# Prob(Omnibus):                  0.229   Jarque-Bera (JB):                2.007
# Skew:                           0.311   Prob(JB):                        0.367
# Kurtosis:                       3.734   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.694
# Method:                 Least Squares   F-statistic:                     116.6
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.13e-14
# Time:                        10:32:04   Log-Likelihood:                 86.229
# No. Observations:                  52   AIC:                            -168.5
# Df Residuals:                      50   BIC:                            -164.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0089      0.007     -1.357      0.181      -0.022       0.004
# 0              1.3256      0.123     10.800      0.000       1.079       1.572
# ==============================================================================
# Omnibus:                        1.192   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.551   Jarque-Bera (JB):                0.483
# Skew:                          -0.043   Prob(JB):                        0.785
# Kurtosis:                       3.464   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.785
# Model:                            OLS   Adj. R-squared:                  0.780
# Method:                 Least Squares   F-statistic:                     182.2
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.67e-18
# Time:                        10:32:04   Log-Likelihood:                 104.14
# No. Observations:                  52   AIC:                            -204.3
# Df Residuals:                      50   BIC:                            -200.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0045      0.005     -0.960      0.342      -0.014       0.005
# 0              1.1741      0.087     13.499      0.000       0.999       1.349
# ==============================================================================
# Omnibus:                        6.076   Durbin-Watson:                   2.206
# Prob(Omnibus):                  0.048   Jarque-Bera (JB):                5.224
# Skew:                           0.757   Prob(JB):                       0.0734
# Kurtosis:                       3.345   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                           Beta
# FTSEMIB Index                              1.0
# A2A 2020                               0.94338
# Amplifon 2020                         0.738002
# Azimut 2020                           1.197755
# BPER banca 2020                       1.155734
# Banca Mediolanum 2020                 1.130218
# Banca Monte dei Paschi di Siena 2020  1.012127
# Banca pop Sondrio 2020                1.205108
# Banco Bpm 2020                        1.197755
# Brunello cucinelli 2020               0.664913
# Campari 2020                          0.667943
# Diasorin 2020                        -0.139913
# Enel 2020                             1.026329
# Eni 2020                              1.239297
# Erg 2020                              0.720143
# Ferrari 2020                          0.546943
# Fineco 2020                            0.68207
# Generali Ass 2020                     1.003072
# Hera 2020                             0.661816
# Interpump 2020                        0.614499
# Intesa San Paolo 2020                 1.191645
# Inwit 2020                            0.412998
# Italgas 2020                          0.577299
# Leonardo 2020                         1.605905
# Mediobanca 2020                       1.408351
# Moncler 2020                          0.669733
# Pirelli 2020                          0.756518
# Poste Italiane 2020                   1.136797
# Prysmian 2020                         0.837578
# Recordati 2020                        0.416276
# Saipem 2020                           1.161933
# Snam 2020                             0.744483
# Stellantis 2020                       1.081512
# Stmicroeletronics 2020                1.225969
# Telecom 2020                          0.856433
# Tenaris 2020                           1.41411
# Terna 2020                             0.61734
# Unicredit 2020                        1.325598
# Unipol 2020                           1.174126

# %%
beta_df.drop(index='FTSEMIB Index', inplace=True)

# %%
beta_df.head()
# Out:
#                            Beta
# A2A 2020                0.94338
# Amplifon 2020          0.738002
# Azimut 2020            1.197755
# BPER banca 2020        1.155734
# Banca Mediolanum 2020  1.130218

# %%
beta_df.sort_values(by="Beta")
# Out:
#                                           Beta
# Diasorin 2020                        -0.139913
# Inwit 2020                            0.412998
# Recordati 2020                        0.416276
# Ferrari 2020                          0.546943
# Italgas 2020                          0.577299
# Interpump 2020                        0.614499
# Terna 2020                             0.61734
# Hera 2020                             0.661816
# Brunello cucinelli 2020               0.664913
# Campari 2020                          0.667943
# Moncler 2020                          0.669733
# Fineco 2020                            0.68207
# Erg 2020                              0.720143
# Amplifon 2020                         0.738002
# Snam 2020                             0.744483
# Pirelli 2020                          0.756518
# Prysmian 2020                         0.837578
# Telecom 2020                          0.856433
# A2A 2020                               0.94338
# Generali Ass 2020                     1.003072
# Banca Monte dei Paschi di Siena 2020  1.012127
# Enel 2020                             1.026329
# Stellantis 2020                       1.081512
# Banca Mediolanum 2020                 1.130218
# Poste Italiane 2020                   1.136797
# BPER banca 2020                       1.155734
# Saipem 2020                           1.161933
# Unipol 2020                           1.174126
# Intesa San Paolo 2020                 1.191645
# Banco Bpm 2020                        1.197755
# Azimut 2020                           1.197755
# Banca pop Sondrio 2020                1.205108
# Stmicroeletronics 2020                1.225969
# Eni 2020                              1.239297
# Unicredit 2020                        1.325598
# Mediobanca 2020                       1.408351
# Tenaris 2020                           1.41411
# Leonardo 2020                         1.605905

# %%
# Sort stocks based on beta values
sorted_df = beta_df.sort_values(by='Beta')

# Divide stocks into four portfolios
portfolio_1 = sorted_df.head(10)
portfolio_2 = sorted_df.iloc[10:19]
portfolio_3 = sorted_df.iloc[19:28]
portfolio_4 = sorted_df.tail(10)

# %%
print("Portfolio 1 (Lowest Beta):")
portfolio_1.to_csv("p1-3.csv")
portfolio_1
# Out:
# Portfolio 1 (Lowest Beta):
#                              Beta
# Diasorin 2020           -0.139913
# Inwit 2020               0.412998
# Recordati 2020           0.416276
# Ferrari 2020             0.546943
# Italgas 2020             0.577299
# Interpump 2020           0.614499
# Terna 2020                0.61734
# Hera 2020                0.661816
# Brunello cucinelli 2020  0.664913
# Campari 2020             0.667943

# %%
print("Portfolio 2:")
portfolio_2.to_csv("p2-3.csv")
portfolio_2
# Out:
# Portfolio 2:
#                    Beta
# Moncler 2020   0.669733
# Fineco 2020     0.68207
# Erg 2020       0.720143
# Amplifon 2020  0.738002
# Snam 2020      0.744483
# Pirelli 2020   0.756518
# Prysmian 2020  0.837578
# Telecom 2020   0.856433
# A2A 2020        0.94338

# %%
print("Portfolio 3:")
portfolio_3.to_csv("p3-3.csv")
portfolio_3
# Out:
# Portfolio 3:
#                                           Beta
# Generali Ass 2020                     1.003072
# Banca Monte dei Paschi di Siena 2020  1.012127
# Enel 2020                             1.026329
# Stellantis 2020                       1.081512
# Banca Mediolanum 2020                 1.130218
# Poste Italiane 2020                   1.136797
# BPER banca 2020                       1.155734
# Saipem 2020                           1.161933
# Unipol 2020                           1.174126

# %%
print("Portfolio 4 (Highest Beta):")
portfolio_4.to_csv("p4-3.csv")
portfolio_4
# Out:
# Portfolio 4 (Highest Beta):
#                             Beta
# Intesa San Paolo 2020   1.191645
# Banco Bpm 2020          1.197755
# Azimut 2020             1.197755
# Banca pop Sondrio 2020  1.205108
# Stmicroeletronics 2020  1.225969
# Eni 2020                1.239297
# Unicredit 2020          1.325598
# Mediobanca 2020         1.408351
# Tenaris 2020             1.41411
# Leonardo 2020           1.605905

# %% [markdown]
# # ESTIMATION #

# %%
# Convert 'Date' column to datetime format
returns_df['Date'] = pd.to_datetime(returns_df['Date'])

# Extract year from 'Date' column
returns_df['Year'] = returns_df['Date'].dt.year

# Filter DataFrame to include only the data from 2021
returns_2021 = returns_df[returns_df['Year'] == 2021].copy()

# Drop the 'Year' column as it's no longer needed
returns_2021.drop(columns='Year', inplace=True)

# %%
returns_2021.head()
# Out:
#           Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 155 2021-01-01       0.004642       0.029597            0.024067
# 156 2021-01-08       0.025235       0.025297           -0.005875
# 157 2021-01-15      -0.018101      -0.018318            0.004728
# 158 2021-01-22      -0.013091       0.025514           -0.012353
# 159 2021-01-29      -0.023353      -0.004827           -0.025313
#
#      Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 155         -0.006430              0.003378                    0.006378
# 156          0.003658              0.097643                   -0.004930
# 157          0.032240             -0.012883                    0.041047
# 158         -0.028246             -0.020820                   -0.039429
# 159         -0.029625             -0.035544                   -0.073602
#
#      Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 155                                  -0.006669                     0.011960
# 156                                   0.093001                     0.057273
# 157                                  -0.057017                    -0.059329
# 158                                   0.001857                    -0.024680
# 159                                  -0.041780                    -0.050609
#
#      Banco Bpm 2018-2023  ...  Snam 2018-2023  Stellantis 2018-2023  \
# 155            -0.006430  ...       -0.000217             -0.002181
# 156             0.003658  ...        0.010650             -0.009960
# 157             0.032240  ...       -0.018710             -0.133941
# 158            -0.028246  ...       -0.045803              0.053307
# 159            -0.029625  ...       -0.005972             -0.053627
#
#      Stmicroeletronics 2018-2023  Telecom 2018-2023  Tenaris 2018-2023  \
# 155                     0.007254          -0.011524          -0.013405
# 156                     0.080196           0.045310           0.069143
# 157                    -0.003030          -0.054499          -0.037278
# 158                    -0.009119          -0.041019          -0.077442
# 159                     0.020552          -0.012021           0.022258
#
#      Terna 2018-2023  Unicredit 2018-2023  Unipol 2018-2023    BOT 3m  \
# 155         0.013952            -0.005720          0.008252 -0.012519
# 156        -0.006720             0.069299          0.029156 -0.010904
# 157        -0.018686            -0.058327         -0.029324 -0.010077
# 158        -0.017728             0.006233         -0.034818 -0.009308
# 159         0.001671            -0.024777         -0.038727 -0.008865
#
#      Risk Premium
# 155      0.017161
# 156      0.036139
# 157     -0.008024
# 158     -0.003783
# 159     -0.014488
#
# [5 rows x 42 columns]

# %%
returns_2021.columns = returns_2021.columns.str.replace('2018-2023', '')

# %%
import numpy as np

# Copy the 2021 data to avoid modifying the original DataFrame
returns_2021_excess = returns_2021.copy()

# Calculate excess returns for each stock by subtracting the risk-free rate
risk_free_rate = returns_2021_excess['BOT 3m'].values  # Convert Series to NumPy array
returns_2021_excess.iloc[:, 2:-2] -= risk_free_rate[:, np.newaxis]

# Set 'Date' column as the index
returns_2021_excess.set_index('Date', inplace=True)

# Display the DataFrame with 'Date' as the index
returns_2021_excess.head()
# Out:
#             FTSEMIB Index      A2A   Amplifon    Azimut   BPER banca   \
# Date
# 2021-01-01       0.004642  0.042117   0.036587  0.006089     0.015898
# 2021-01-08       0.025235  0.036201   0.005028  0.014562     0.108547
# 2021-01-15      -0.018101 -0.008241   0.014805  0.042317    -0.002807
# 2021-01-22      -0.013091  0.034822  -0.003045 -0.018938    -0.011513
# 2021-01-29      -0.023353  0.004038  -0.016447 -0.020760    -0.026679
#
#             Banca Mediolanum   Banca Monte dei Paschi di Siena   \
# Date
# 2021-01-01           0.018898                          0.005851
# 2021-01-08           0.005974                          0.103905
# 2021-01-15           0.051124                         -0.046940
# 2021-01-22          -0.030121                          0.011165
# 2021-01-29          -0.064737                         -0.032915
#
#             Banca pop Sondrio   Banco Bpm   Brunello cucinelli   ...  \
# Date                                                             ...
# 2021-01-01            0.024479    0.006089            -0.004010  ...
# 2021-01-08            0.068177    0.014562            -0.029993  ...
# 2021-01-15           -0.049252    0.042317             0.008325  ...
# 2021-01-22           -0.015372   -0.018938             0.015159  ...
# 2021-01-29           -0.041744   -0.020760            -0.030111  ...
#
#                Snam   Stellantis   Stmicroeletronics   Telecom   Tenaris   \
# Date
# 2021-01-01  0.012302     0.010338            0.019773  0.000995 -0.000886
# 2021-01-08  0.021554     0.000944            0.091100  0.056214  0.080046
# 2021-01-15 -0.008633    -0.123864            0.007047 -0.044422 -0.027201
# 2021-01-22 -0.036496     0.062615            0.000189 -0.031711 -0.068134
# 2021-01-29  0.002894    -0.044762            0.029418 -0.003156  0.031123
#
#               Terna   Unicredit    Unipol     BOT 3m  Risk Premium
# Date
# 2021-01-01  0.026471    0.006799  0.020771 -0.012519      0.017161
# 2021-01-08  0.004184    0.080203  0.040060 -0.010904      0.036139
# 2021-01-15 -0.008609   -0.048250 -0.019247 -0.010077     -0.008024
# 2021-01-22 -0.008420    0.015541 -0.025511 -0.009308     -0.003783
# 2021-01-29  0.010537   -0.015912 -0.029861 -0.008865     -0.014488
#
# [5 rows x 41 columns]

# %%
portfolio_1
# Out:
#                              Beta
# Diasorin 2020           -0.139913
# Inwit 2020               0.412998
# Recordati 2020           0.416276
# Ferrari 2020             0.546943
# Italgas 2020             0.577299
# Interpump 2020           0.614499
# Terna 2020                0.61734
# Hera 2020                0.661816
# Brunello cucinelli 2020  0.664913
# Campari 2020             0.667943

# %%
# Remove '2019' from the stock names
portfolio_1.index = portfolio_1.index.str.replace(' 2020', '')

# Rename the index to 'Stock'
portfolio_1.index.name = 'Stock'

# Print the modified DataFrame
portfolio_1
# Out:
#                         Beta
# Stock
# Diasorin           -0.139913
# Inwit               0.412998
# Recordati           0.416276
# Ferrari             0.546943
# Italgas             0.577299
# Interpump           0.614499
# Terna                0.61734
# Hera                0.661816
# Brunello cucinelli  0.664913
# Campari             0.667943

# %%
# Remove '2019' from the stock names
portfolio_2.index = portfolio_2.index.str.replace(' 2020', '')

# Rename the index to 'Stock'
portfolio_2.index.name = 'Stock'

# %%
# Remove '2019' from the stock names
portfolio_3.index = portfolio_3.index.str.replace(' 2020', '')

# Rename the index to 'Stock'
portfolio_3.index.name = 'Stock'

# %%
# Remove '2019' from the stock names
portfolio_4.index = portfolio_4.index.str.replace(' 2020', '')

# Rename the index to 'Stock'
portfolio_4.index.name = 'Stock'

# %%
portfolio_1.index
# Out:
# Index(['Diasorin', 'Inwit', 'Recordati', 'Ferrari', 'Italgas', 'Interpump',
#        'Terna', 'Hera', 'Brunello cucinelli', 'Campari'],
#       dtype='object', name='Stock')

# %%
returns_2021_excess.columns = returns_2021_excess.columns.str.strip()

# %%
returns_2021_excess.columns
# Out:
# Index(['FTSEMIB Index', 'A2A', 'Amplifon', 'Azimut', 'BPER banca',
#        'Banca Mediolanum', 'Banca Monte dei Paschi di Siena',
#        'Banca pop Sondrio', 'Banco Bpm', 'Brunello cucinelli', 'Campari',
#        'Diasorin', 'Enel', 'Eni', 'Erg', 'Ferrari', 'Fineco', 'Generali Ass',
#        'Hera', 'Interpump', 'Intesa San Paolo', 'Inwit', 'Italgas', 'Leonardo',
#        'Mediobanca', 'Moncler', 'Pirelli', 'Poste Italiane', 'Prysmian',
#        'Recordati', 'Saipem', 'Snam', 'Stellantis', 'Stmicroeletronics',
#        'Telecom', 'Tenaris', 'Terna', 'Unicredit', 'Unipol', 'BOT 3m',
#        'Risk Premium'],
#       dtype='object')

# %%
returns_2021_excess['Inwit']
# Out:
# Date
# 2021-01-01    0.011011
# 2021-01-08   -0.032903
# 2021-01-15   -0.014146
# 2021-01-22    0.017403
# 2021-01-29   -0.041991
# 2021-02-05    0.030413
# 2021-02-12    0.034194
# 2021-02-19   -0.052172
# 2021-02-26   -0.001484
# 2021-03-05   -0.038306
# 2021-03-12    0.074500
# 2021-03-19    0.046920
# 2021-03-26    0.037892
# 2021-04-02    0.023607
# 2021-04-09    0.012158
# 2021-04-16    0.009365
# 2021-04-23    0.030672
# 2021-04-30    0.016493
# 2021-05-07   -0.007501
# 2021-05-14   -0.003280
# 2021-05-21    0.004951
# 2021-05-28   -0.007265
# 2021-06-04    0.015121
# 2021-06-11    0.048241
# 2021-06-18    0.034744
# 2021-06-25    0.002986
# 2021-07-02   -0.012085
# 2021-07-09    0.031119
# 2021-07-16    0.032164
# 2021-07-23    0.022890
# 2021-07-30   -0.038873
# 2021-08-06    0.026761
# 2021-08-13    0.037692
# 2021-08-20    0.022085
# 2021-08-27    0.013215
# 2021-09-03    0.001037
# 2021-09-10   -0.012984
# 2021-09-17    0.018815
# 2021-09-24    0.003894
# 2021-10-01   -0.005681
# 2021-10-08   -0.003882
# 2021-10-15    0.049280
# 2021-10-22   -0.016205
# 2021-10-29    0.010095
# 2021-11-05    0.032387
# 2021-11-12    0.039905
# 2021-11-19    0.024905
# 2021-11-26    0.034846
# 2021-12-03   -0.001947
# 2021-12-10    0.018865
# 2021-12-17    0.040978
# 2021-12-24    0.021108
# 2021-12-31    0.030387
# Name: Inwit, dtype: float64

# %%
p_1 = returns_2021_excess[portfolio_1.index]
p_1.head()
# Out:
#             Diasorin     Inwit  Recordati   Ferrari   Italgas  Interpump  \
# Date
# 2021-01-01  0.028648  0.011011   0.036001  0.023234  0.028144   0.033785
# 2021-01-08 -0.037891 -0.032903  -0.045130 -0.033623  0.001288   0.004954
# 2021-01-15  0.015021 -0.014146   0.030642 -0.013224 -0.003515   0.015064
# 2021-01-22  0.085568  0.017403  -0.007638  0.002491 -0.019826  -0.001114
# 2021-01-29  0.040865 -0.041991   0.003974 -0.006005  0.012921  -0.062348
#
#                Terna      Hera  Brunello cucinelli   Campari
# Date
# 2021-01-01  0.026471  0.026815           -0.004010  0.028178
# 2021-01-08  0.004184  0.027011           -0.029993 -0.040916
# 2021-01-15 -0.008609  0.020645            0.008325 -0.004828
# 2021-01-22 -0.008420 -0.060627            0.015159  0.019624
# 2021-01-29  0.010537  0.022217           -0.030111  0.015900

# %%
p_2 = returns_2021_excess[portfolio_2.index]
p_2.head()
# Out:
#              Moncler    Fineco       Erg  Amplifon      Snam   Pirelli  \
# Date
# 2021-01-01  0.052552  0.024986  0.064678  0.036587  0.012302  0.019333
# 2021-01-08 -0.030580  0.026202  0.080989  0.005028  0.021554  0.013836
# 2021-01-15 -0.004696  0.015957  0.021259  0.014805 -0.008633 -0.014215
# 2021-01-22  0.037185 -0.018460  0.068549 -0.003045 -0.036496 -0.001527
# 2021-01-29 -0.033460 -0.023453 -0.052283 -0.016447  0.002894  0.013293
#
#             Prysmian   Telecom       A2A
# Date
# 2021-01-01  0.043725  0.000995  0.042117
# 2021-01-08  0.054920  0.056214  0.036201
# 2021-01-15 -0.074245 -0.044422 -0.008241
# 2021-01-22  0.016502 -0.031711  0.034822
# 2021-01-29 -0.039706 -0.003156  0.004038

# %%
p_3 = returns_2021_excess[portfolio_3.index]
p_3.head()
# Out:
#             Generali Ass  Banca Monte dei Paschi di Siena      Enel  \
# Date
# 2021-01-01      0.011119                         0.005851  0.013124
# 2021-01-08      0.027734                         0.103905  0.090894
# 2021-01-15      0.000767                        -0.046940  0.001238
# 2021-01-22      0.019402                         0.011165 -0.048712
# 2021-01-29     -0.020080                        -0.032915 -0.009589
#
#             Stellantis  Banca Mediolanum  Poste Italiane  BPER banca  \
# Date
# 2021-01-01    0.010338          0.018898        0.006783    0.015898
# 2021-01-08    0.000944          0.005974        0.043837    0.108547
# 2021-01-15   -0.123864          0.051124       -0.018082   -0.002807
# 2021-01-22    0.062615         -0.030121       -0.000750   -0.011513
# 2021-01-29   -0.044762         -0.064737       -0.014357   -0.026679
#
#               Saipem    Unipol
# Date
# 2021-01-01  0.031462  0.020771
# 2021-01-08  0.114300  0.040060
# 2021-01-15 -0.033494 -0.019247
# 2021-01-22 -0.078363 -0.025511
# 2021-01-29  0.030070 -0.029861

# %%
p_4 = returns_2021_excess[portfolio_4.index]
p_4.head()
# Out:
#             Intesa San Paolo  Banco Bpm    Azimut  Banca pop Sondrio  \
# Date
# 2021-01-01          0.012310   0.006089  0.006089           0.024479
# 2021-01-08          0.033073   0.014562  0.014562           0.068177
# 2021-01-15         -0.017033   0.042317  0.042317          -0.049252
# 2021-01-22         -0.000051  -0.018938 -0.018938          -0.015372
# 2021-01-29         -0.033062  -0.020760 -0.020760          -0.041744
#
#             Stmicroeletronics       Eni  Unicredit  Mediobanca   Tenaris  \
# Date
# 2021-01-01           0.019773  0.008325   0.006799    0.013581 -0.000886
# 2021-01-08           0.091100  0.067291   0.080203    0.011965  0.080046
# 2021-01-15           0.007047 -0.011961  -0.048250   -0.000257 -0.027201
# 2021-01-22           0.000189 -0.023418   0.015541    0.001543 -0.068134
# 2021-01-29           0.029418 -0.013378  -0.015912    0.002389  0.031123
#
#             Leonardo
# Date
# 2021-01-01  0.017621
# 2021-01-08  0.011919
# 2021-01-15  0.000611
# 2021-01-22 -0.026528
# 2021-01-29  0.024087

# %%
returns_2021.head()
# Out:
#           Date  FTSEMIB Index      A2A   Amplifon    Azimut   BPER banca   \
# 155 2021-01-01       0.004642  0.029597   0.024067 -0.006430     0.003378
# 156 2021-01-08       0.025235  0.025297  -0.005875  0.003658     0.097643
# 157 2021-01-15      -0.018101 -0.018318   0.004728  0.032240    -0.012883
# 158 2021-01-22      -0.013091  0.025514  -0.012353 -0.028246    -0.020820
# 159 2021-01-29      -0.023353 -0.004827  -0.025313 -0.029625    -0.035544
#
#      Banca Mediolanum   Banca Monte dei Paschi di Siena   Banca pop Sondrio   \
# 155           0.006378                         -0.006669            0.011960
# 156          -0.004930                          0.093001            0.057273
# 157           0.041047                         -0.057017           -0.059329
# 158          -0.039429                          0.001857           -0.024680
# 159          -0.073602                         -0.041780           -0.050609
#
#      Banco Bpm   ...     Snam   Stellantis   Stmicroeletronics   Telecom   \
# 155   -0.006430  ... -0.000217    -0.002181            0.007254 -0.011524
# 156    0.003658  ...  0.010650    -0.009960            0.080196  0.045310
# 157    0.032240  ... -0.018710    -0.133941           -0.003030 -0.054499
# 158   -0.028246  ... -0.045803     0.053307           -0.009119 -0.041019
# 159   -0.029625  ... -0.005972    -0.053627            0.020552 -0.012021
#
#      Tenaris     Terna   Unicredit    Unipol     BOT 3m  Risk Premium
# 155 -0.013405  0.013952   -0.005720  0.008252 -0.012519      0.017161
# 156  0.069143 -0.006720    0.069299  0.029156 -0.010904      0.036139
# 157 -0.037278 -0.018686   -0.058327 -0.029324 -0.010077     -0.008024
# 158 -0.077442 -0.017728    0.006233 -0.034818 -0.009308     -0.003783
# 159  0.022258  0.001671   -0.024777 -0.038727 -0.008865     -0.014488
#
# [5 rows x 42 columns]

# %%
returns_2021 = returns_2021.set_index('Date')

# %% [markdown]
# # P1 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_1.index:
    # Extract market excess return for the date
    x = returns_2021.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_1.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2021-01-01              0.017161                 0.023828
# 2021-01-08              0.036139                -0.018302
# 2021-01-15             -0.008024                 0.004538
# 2021-01-22             -0.003783                 0.004262
# 2021-01-29             -0.014488                -0.003404

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.0021842992464677197
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.061
# Model:                                 OLS   Adj. R-squared:                 -0.252
# Method:                      Least Squares   F-statistic:                    0.1954
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.688
# Time:                             10:32:14   Log-Likelihood:                 14.540
# No. Observations:                        5   AIC:                            -25.08
# Df Residuals:                            3   BIC:                            -25.86
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0032      0.008      0.398      0.717      -0.022       0.028
# Market Excess Return    -0.1805      0.408     -0.442      0.688      -1.480       1.119
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.076
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.603
# Skew:                           0.809   Prob(JB):                        0.740
# Kurtosis:                       2.470   Cond. No.                         53.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.006725085021587314
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.858
# Model:                                 OLS   Adj. R-squared:                  0.787
# Method:                      Least Squares   F-statistic:                     12.07
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0738
# Time:                             10:32:14   Log-Likelihood:                 12.349
# No. Observations:                        4   AIC:                            -20.70
# Df Residuals:                            2   BIC:                            -21.93
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0130      0.010     -1.346      0.311      -0.055       0.029
# Market Excess Return     0.8125      0.234      3.474      0.074      -0.194       1.819
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.873
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.876
# Skew:                           1.089   Prob(JB):                        0.645
# Kurtosis:                       2.285   Cond. No.                         30.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.027143116443961383
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.869
# Model:                                 OLS   Adj. R-squared:                  0.804
# Method:                      Least Squares   F-statistic:                     13.30
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0676
# Time:                             10:32:14   Log-Likelihood:                 14.047
# No. Observations:                        4   AIC:                            -24.09
# Df Residuals:                            2   BIC:                            -25.32
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0017      0.009      0.192      0.865      -0.036       0.039
# Market Excess Return     0.9631      0.264      3.647      0.068      -0.173       2.099
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.793
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.251
# Skew:                          -0.328   Prob(JB):                        0.882
# Kurtosis:                       1.962   Cond. No.                         51.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01495400516497539
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.350
# Model:                                 OLS   Adj. R-squared:                  0.133
# Method:                      Least Squares   F-statistic:                     1.615
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.293
# Time:                             10:32:14   Log-Likelihood:                 15.214
# No. Observations:                        5   AIC:                            -26.43
# Df Residuals:                            3   BIC:                            -27.21
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0093      0.008      1.167      0.328      -0.016       0.035
# Market Excess Return     0.6865      0.540      1.271      0.293      -1.033       2.406
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.895
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.516
# Skew:                           0.289   Prob(JB):                        0.773
# Kurtosis:                       1.536   Cond. No.                         81.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01703452982882131
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.004
# Model:                                 OLS   Adj. R-squared:                 -0.495
# Method:                      Least Squares   F-statistic:                  0.007095
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.941
# Time:                             10:32:14   Log-Likelihood:                 10.956
# No. Observations:                        4   AIC:                            -17.91
# Df Residuals:                            2   BIC:                            -19.14
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0206      0.044      0.466      0.687      -0.170       0.211
# Market Excess Return    -0.1752      2.080     -0.084      0.941      -9.125       8.775
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.051
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.683
# Skew:                           0.923   Prob(JB):                        0.711
# Kurtosis:                       2.170   Cond. No.                         188.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.02085107058490715
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.016
# Model:                                 OLS   Adj. R-squared:                 -0.476
# Method:                      Least Squares   F-statistic:                   0.03231
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.874
# Time:                             10:32:14   Log-Likelihood:                 13.381
# No. Observations:                        4   AIC:                            -22.76
# Df Residuals:                            2   BIC:                            -23.99
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0197      0.009      2.266      0.152      -0.018       0.057
# Market Excess Return     0.0802      0.446      0.180      0.874      -1.839       2.000
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.825
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.593
# Skew:                          -0.790   Prob(JB):                        0.744
# Kurtosis:                       1.972   Cond. No.                         74.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.020335706337825554
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.490
# Model:                                 OLS   Adj. R-squared:                  0.320
# Method:                      Least Squares   F-statistic:                     2.883
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.188
# Time:                             10:32:14   Log-Likelihood:                 19.367
# No. Observations:                        5   AIC:                            -34.73
# Df Residuals:                            3   BIC:                            -35.52
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0157      0.004      3.925      0.029       0.003       0.028
# Market Excess Return     0.4835      0.285      1.698      0.188      -0.423       1.390
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.108
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.187
# Skew:                          -0.312   Prob(JB):                        0.911
# Kurtosis:                       2.288   Cond. No.                         98.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01890248441409215
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.646
# Model:                                 OLS   Adj. R-squared:                  0.468
# Method:                      Least Squares   F-statistic:                     3.644
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.196
# Time:                             10:32:14   Log-Likelihood:                 12.914
# No. Observations:                        4   AIC:                            -21.83
# Df Residuals:                            2   BIC:                            -23.06
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0086      0.009      0.986      0.428      -0.029       0.046
# Market Excess Return     0.5997      0.314      1.909      0.196      -0.752       1.951
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.649
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.419
# Skew:                          -0.511   Prob(JB):                        0.811
# Kurtosis:                       1.789   Cond. No.                         46.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.007452278129701659
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.434
# Model:                                 OLS   Adj. R-squared:                  0.150
# Method:                      Least Squares   F-statistic:                     1.531
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.341
# Time:                             10:32:14   Log-Likelihood:                 16.344
# No. Observations:                        4   AIC:                            -28.69
# Df Residuals:                            2   BIC:                            -29.92
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0033      0.004      0.759      0.527      -0.016       0.022
# Market Excess Return     0.3967      0.321      1.238      0.341      -0.982       1.776
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.239
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.666
# Skew:                           0.913   Prob(JB):                        0.717
# Kurtosis:                       2.188   Cond. No.                         111.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01640449515177898
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.607
# Model:                                 OLS   Adj. R-squared:                  0.476
# Method:                      Least Squares   F-statistic:                     4.634
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.120
# Time:                             10:32:14   Log-Likelihood:                 14.289
# No. Observations:                        5   AIC:                            -24.58
# Df Residuals:                            3   BIC:                            -25.36
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0104      0.015     -0.702      0.533      -0.058       0.037
# Market Excess Return     1.5062      0.700      2.153      0.120      -0.720       3.733
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.605
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.352
# Skew:                           0.028   Prob(JB):                        0.839
# Kurtosis:                       1.702   Cond. No.                         87.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.018853898899051896
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.936
# Model:                                 OLS   Adj. R-squared:                  0.903
# Method:                      Least Squares   F-statistic:                     29.08
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0327
# Time:                             10:32:14   Log-Likelihood:                 14.037
# No. Observations:                        4   AIC:                            -24.07
# Df Residuals:                            2   BIC:                            -25.30
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0145      0.005      2.793      0.108      -0.008       0.037
# Market Excess Return     0.8886      0.165      5.393      0.033       0.180       1.598
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.958
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.845
# Skew:                          -1.062   Prob(JB):                        0.655
# Kurtosis:                       2.251   Cond. No.                         32.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.022789794517973028
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.689
# Model:                                 OLS   Adj. R-squared:                  0.585
# Method:                      Least Squares   F-statistic:                     6.642
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0820
# Time:                             10:32:14   Log-Likelihood:                 17.703
# No. Observations:                        5   AIC:                            -31.41
# Df Residuals:                            3   BIC:                            -32.19
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0004      0.010     -0.043      0.968      -0.032       0.031
# Market Excess Return     0.8976      0.348      2.577      0.082      -0.211       2.006
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.914
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.538
# Skew:                           1.358   Prob(JB):                        0.463
# Kurtosis:                       3.047   Cond. No.                         86.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.002184 -0.180523       0.212984
# 1     02                 0.006725  0.812464       0.874976
# 2     03                 0.027143  0.963060       0.975374
# 3     04                 0.014954  0.686483       0.790989
# 4     05                 0.017035 -0.175208       0.216528
# 5     06                 0.020851  0.080193       0.386795
# 6     07                 0.020336  0.483503       0.655669
# 7     08                 0.018902  0.599738       0.733159
# 8     09                 0.007452  0.396673       0.597782
# 9     10                 0.016404  1.506183       1.337455
# 10    11                 0.018854  0.888586       0.925724
# 11    12                 0.022790  0.897563       0.931709

# %%
coefficients_df.to_csv('coefficients_df_p1_3.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.016060214252520653

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (53, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.449
# Model:                            OLS   Adj. R-squared:                  0.438
# Method:                 Least Squares   F-statistic:                     41.54
# Date:                Sat, 04 May 2024   Prob (F-statistic):           4.10e-08
# Time:                        10:32:34   Log-Likelihood:                 151.18
# No. Observations:                  53   AIC:                            -298.4
# Df Residuals:                      51   BIC:                            -294.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0062      0.002      2.515      0.015       0.001       0.011
# x1             0.6458      0.100      6.445      0.000       0.445       0.847
# ==============================================================================
# Omnibus:                        9.072   Durbin-Watson:                   1.788
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                8.714
# Skew:                          -0.783   Prob(JB):                       0.0128
# Kurtosis:                       4.223   Cond. No.                         51.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 0.6458231995108562
# P-value: 4.0972099584555754e-08
# Std. error: 0.10020733791250411
# Adj. R-squared: 0.43805860959400234
# F-statistic: 41.53634077822681
# T-statistic for X1: 6.444869337560447

# %% [markdown]
# # P2 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_2.index:
    # Extract market excess return for the date
    x = returns_2021.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_2.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2021-01-01              0.017161                 0.033030
# 2021-01-08              0.036139                 0.029374
# 2021-01-15             -0.008024                -0.011381
# 2021-01-22             -0.003783                 0.007313
# 2021-01-29             -0.014488                -0.016476

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.008372175332495312
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.810
# Model:                                 OLS   Adj. R-squared:                  0.747
# Method:                      Least Squares   F-statistic:                     12.79
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0374
# Time:                             10:33:04   Log-Likelihood:                 16.546
# No. Observations:                        5   AIC:                            -29.09
# Df Residuals:                            3   BIC:                            -29.87
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0031      0.005      0.582      0.602      -0.014       0.020
# Market Excess Return     0.9779      0.273      3.576      0.037       0.108       1.848
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.272
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.695
# Skew:                           0.458   Prob(JB):                        0.706
# Kurtosis:                       1.420   Cond. No.                         53.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.021937040536806406
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       1.000
# Model:                                 OLS   Adj. R-squared:                  0.999
# Method:                      Least Squares   F-statistic:                     5255.
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000190
# Time:                             10:33:04   Log-Likelihood:                 22.909
# No. Observations:                        4   AIC:                            -41.82
# Df Residuals:                            2   BIC:                            -43.05
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0074      0.001    -10.770      0.009      -0.010      -0.004
# Market Excess Return     1.2098      0.017     72.491      0.000       1.138       1.282
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.396
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.850
# Skew:                           1.069   Prob(JB):                        0.654
# Kurtosis:                       2.270   Cond. No.                         30.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.019947365222986957
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.782
# Model:                                 OLS   Adj. R-squared:                  0.673
# Method:                      Least Squares   F-statistic:                     7.172
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.116
# Time:                             10:33:04   Log-Likelihood:                 11.264
# No. Observations:                        4   AIC:                            -18.53
# Df Residuals:                            2   BIC:                            -19.75
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0176      0.017     -1.013      0.418      -0.092       0.057
# Market Excess Return     1.4182      0.530      2.678      0.116      -0.860       3.697
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.438
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.611
# Skew:                           0.847   Prob(JB):                        0.737
# Kurtosis:                       2.109   Cond. No.                         51.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.012929035245445105
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.784
# Model:                                 OLS   Adj. R-squared:                  0.712
# Method:                      Least Squares   F-statistic:                     10.89
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0458
# Time:                             10:33:04   Log-Likelihood:                 18.465
# No. Observations:                        5   AIC:                            -32.93
# Df Residuals:                            3   BIC:                            -33.71
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0053      0.004      1.272      0.293      -0.008       0.019
# Market Excess Return     0.9303      0.282      3.299      0.046       0.033       1.828
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.655
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.606
# Skew:                           0.290   Prob(JB):                        0.739
# Kurtosis:                       1.396   Cond. No.                         81.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.02056227814314886
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.358
# Model:                                 OLS   Adj. R-squared:                  0.038
# Method:                      Least Squares   F-statistic:                     1.118
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.401
# Time:                             10:33:04   Log-Likelihood:                 14.038
# No. Observations:                        4   AIC:                            -24.08
# Df Residuals:                            2   BIC:                            -25.30
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0416      0.021      2.027      0.180      -0.047       0.130
# Market Excess Return    -1.0178      0.963     -1.057      0.401      -5.160       3.125
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.582
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.211
# Skew:                          -0.028   Prob(JB):                        0.900
# Kurtosis:                       1.875   Cond. No.                         188.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.017987142944915446
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.344
# Model:                                 OLS   Adj. R-squared:                  0.016
# Method:                      Least Squares   F-statistic:                     1.049
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.413
# Time:                             10:33:04   Log-Likelihood:                 15.055
# No. Observations:                        4   AIC:                            -26.11
# Df Residuals:                            2   BIC:                            -27.34
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0138      0.006      2.403      0.138      -0.011       0.038
# Market Excess Return     0.3006      0.294      1.024      0.413      -0.962       1.564
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.598
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.274
# Skew:                           0.212   Prob(JB):                        0.872
# Kurtosis:                       1.790   Cond. No.                         74.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.011527757158612451
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.591
# Model:                                 OLS   Adj. R-squared:                  0.454
# Method:                      Least Squares   F-statistic:                     4.326
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.129
# Time:                             10:33:04   Log-Likelihood:                 17.561
# No. Observations:                        5   AIC:                            -31.12
# Df Residuals:                            3   BIC:                            -31.90
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0033      0.006      0.583      0.601      -0.015       0.022
# Market Excess Return     0.8499      0.409      2.080      0.129      -0.450       2.150
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.243
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.495
# Skew:                          -0.730   Prob(JB):                        0.781
# Kurtosis:                       2.509   Cond. No.                         98.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014066385662065955
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.835
# Model:                                 OLS   Adj. R-squared:                  0.752
# Method:                      Least Squares   F-statistic:                     10.10
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0864
# Time:                             10:33:04   Log-Likelihood:                 13.750
# No. Observations:                        4   AIC:                            -23.50
# Df Residuals:                            2   BIC:                            -24.73
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                 8.945e-05      0.007      0.013      0.991      -0.030       0.030
# Market Excess Return     0.8101      0.255      3.178      0.086      -0.287       1.907
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.932
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.410
# Skew:                           0.145   Prob(JB):                        0.815
# Kurtosis:                       1.458   Cond. No.                         46.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.009782403795608005
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.624
# Model:                                 OLS   Adj. R-squared:                  0.436
# Method:                      Least Squares   F-statistic:                     3.321
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.210
# Time:                             10:33:04   Log-Likelihood:                 15.546
# No. Observations:                        4   AIC:                            -27.09
# Df Residuals:                            2   BIC:                            -28.32
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0024      0.005      0.444      0.701      -0.021       0.025
# Market Excess Return     0.7132      0.391      1.822      0.210      -0.971       2.397
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.329
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.496
# Skew:                           0.052   Prob(JB):                        0.780
# Kurtosis:                       1.277   Cond. No.                         111.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.016852526087940495
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.499
# Model:                                 OLS   Adj. R-squared:                  0.332
# Method:                      Least Squares   F-statistic:                     2.992
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.182
# Time:                             10:33:04   Log-Likelihood:                 13.599
# No. Observations:                        5   AIC:                            -23.20
# Df Residuals:                            3   BIC:                            -23.98
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0079      0.017     -0.463      0.675      -0.062       0.046
# Market Excess Return     1.3893      0.803      1.730      0.182      -1.167       3.945
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.057
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.892
# Skew:                           0.993   Prob(JB):                        0.640
# Kurtosis:                       2.415   Cond. No.                         87.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.02393441577429953
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.643
# Model:                                 OLS   Adj. R-squared:                  0.465
# Method:                      Least Squares   F-statistic:                     3.605
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.198
# Time:                             10:33:04   Log-Likelihood:                 12.051
# No. Observations:                        4   AIC:                            -20.10
# Df Residuals:                            2   BIC:                            -21.33
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0214      0.009      2.513      0.128      -0.015       0.058
# Market Excess Return     0.5140      0.271      1.899      0.198      -0.651       1.679
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.080
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.541
# Skew:                          -0.138   Prob(JB):                        0.763
# Kurtosis:                       1.219   Cond. No.                         32.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.019378702578318394
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.695
# Model:                                 OLS   Adj. R-squared:                  0.594
# Method:                      Least Squares   F-statistic:                     6.845
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0793
# Time:                             10:33:04   Log-Likelihood:                 19.005
# No. Observations:                        5   AIC:                            -34.01
# Df Residuals:                            3   BIC:                            -34.79
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0012      0.008      0.159      0.884      -0.023       0.025
# Market Excess Return     0.7023      0.268      2.616      0.079      -0.152       1.557
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.093
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.409
# Skew:                           0.132   Prob(JB):                        0.815
# Kurtosis:                       1.624   Cond. No.                         86.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.008372  0.977855       0.985237
# 1     02                 0.021937  1.209752       1.139835
# 2     03                 0.019947  1.418228       1.278818
# 3     04                 0.012929  0.930279       0.953520
# 4     05                 0.020562 -1.017808      -0.345205
# 5     06                 0.017987  0.300621       0.533747
# 6     07                 0.011528  0.849932       0.899954
# 7     08                 0.014066  0.810093       0.873395
# 8     09                 0.009782  0.713151       0.808767
# 9     10                 0.016853  1.389277       1.259518
# 10    11                 0.023934  0.514022       0.676015
# 11    12                 0.019379  0.702268       0.801512

# %%
coefficients_df.to_csv('coefficients_df_p2_3.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.016191870006290254

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (53, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.625
# Model:                            OLS   Adj. R-squared:                  0.617
# Method:                 Least Squares   F-statistic:                     84.85
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.97e-12
# Time:                        10:33:14   Log-Likelihood:                 157.14
# No. Observations:                  53   AIC:                            -310.3
# Df Residuals:                      51   BIC:                            -306.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0036      0.002      1.644      0.106      -0.001       0.008
# x1             0.8249      0.090      9.211      0.000       0.645       1.005
# ==============================================================================
# Omnibus:                        4.292   Durbin-Watson:                   2.138
# Prob(Omnibus):                  0.117   Jarque-Bera (JB):                3.306
# Skew:                           0.445   Prob(JB):                        0.192
# Kurtosis:                       3.839   Cond. No.                         51.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 0.8248766547019702
# P-value: 1.965046347770722e-12
# Std. error: 0.08954898627774344
# Adj. R-squared: 0.6172275396705282
# F-statistic: 84.8509438093873
# T-statistic for X1: 9.211457203362956

# %% [markdown]
# # P3 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_3.index:
    # Extract market excess return for the date
    x = returns_2021.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_3.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2021-01-01              0.017161                 0.014916
# 2021-01-08              0.036139                 0.059577
# 2021-01-15             -0.008024                -0.021256
# 2021-01-22             -0.003783                -0.011310
# 2021-01-29             -0.014488                -0.023657

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.0036541369542397208
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.973
# Model:                                 OLS   Adj. R-squared:                  0.964
# Method:                      Least Squares   F-statistic:                     107.7
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00191
# Time:                             10:33:25   Log-Likelihood:                 19.274
# No. Observations:                        5   AIC:                            -34.55
# Df Residuals:                            3   BIC:                            -35.33
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0052      0.003     -1.697      0.188      -0.015       0.005
# Market Excess Return     1.6443      0.158     10.377      0.002       1.140       2.149
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.171
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.434
# Skew:                          -0.352   Prob(JB):                        0.805
# Kurtosis:                       1.740   Cond. No.                         53.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.037922346566750434
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.980
# Model:                                 OLS   Adj. R-squared:                  0.969
# Method:                      Least Squares   F-statistic:                     96.34
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0102
# Time:                             10:33:25   Log-Likelihood:                 13.773
# No. Observations:                        4   AIC:                            -23.55
# Df Residuals:                            2   BIC:                            -24.77
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0011      0.007     -0.161      0.887      -0.030       0.028
# Market Excess Return     1.6078      0.164      9.815      0.010       0.903       2.313
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.960
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.365
# Skew:                           0.489   Prob(JB):                        0.833
# Kurtosis:                       1.889   Cond. No.                         30.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.027074502494498606
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.784
# Model:                                 OLS   Adj. R-squared:                  0.676
# Method:                      Least Squares   F-statistic:                     7.246
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.115
# Time:                             10:33:25   Log-Likelihood:                 12.704
# No. Observations:                        4   AIC:                            -21.41
# Df Residuals:                            2   BIC:                            -22.64
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0008      0.012      0.063      0.956      -0.051       0.053
# Market Excess Return     0.9945      0.369      2.692      0.115      -0.595       2.584
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.826
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.203
# Skew:                           0.196   Prob(JB):                        0.904
# Kurtosis:                       1.970   Cond. No.                         51.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0035184546458995936
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.953
# Model:                                 OLS   Adj. R-squared:                  0.937
# Method:                      Least Squares   F-statistic:                     60.37
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00444
# Time:                             10:33:25   Log-Likelihood:                 20.899
# No. Observations:                        5   AIC:                            -37.80
# Df Residuals:                            3   BIC:                            -38.58
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0075      0.003     -2.926      0.061      -0.016       0.001
# Market Excess Return     1.3463      0.173      7.770      0.004       0.795       1.898
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.661
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.819
# Skew:                          -0.977   Prob(JB):                        0.664
# Kurtosis:                       2.660   Cond. No.                         81.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.022718556355649084
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.874
# Model:                                 OLS   Adj. R-squared:                  0.811
# Method:                      Least Squares   F-statistic:                     13.84
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0653
# Time:                             10:33:25   Log-Likelihood:                 15.273
# No. Observations:                        4   AIC:                            -26.55
# Df Residuals:                            2   BIC:                            -27.77
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0315      0.015     -2.093      0.171      -0.096       0.033
# Market Excess Return     2.6299      0.707      3.720      0.065      -0.412       5.672
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.332
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.282
# Skew:                          -0.441   Prob(JB):                        0.869
# Kurtosis:                       2.043   Cond. No.                         188.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010331569109733476
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.902
# Model:                                 OLS   Adj. R-squared:                  0.853
# Method:                      Least Squares   F-statistic:                     18.47
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0501
# Time:                             10:33:25   Log-Likelihood:                 14.839
# No. Observations:                        4   AIC:                            -25.68
# Df Residuals:                            2   BIC:                            -26.91
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0084      0.006     -1.389      0.299      -0.034       0.018
# Market Excess Return     1.3317      0.310      4.298      0.050      -0.001       2.665
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.169
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.205
# Skew:                          -0.226   Prob(JB):                        0.903
# Kurtosis:                       1.989   Cond. No.                         74.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0037089743648576574
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.988
# Model:                                 OLS   Adj. R-squared:                  0.985
# Method:                      Least Squares   F-statistic:                     256.4
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000530
# Time:                             10:33:25   Log-Likelihood:                 25.317
# No. Observations:                        5   AIC:                            -46.63
# Df Residuals:                            3   BIC:                            -47.42
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0097      0.001     -7.943      0.004      -0.014      -0.006
# Market Excess Return     1.3870      0.087     16.013      0.001       1.111       1.663
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.750
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.185
# Skew:                          -0.137   Prob(JB):                        0.912
# Kurtosis:                       2.098   Cond. No.                         98.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.02155338451200507
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.926
# Model:                                 OLS   Adj. R-squared:                  0.889
# Method:                      Least Squares   F-statistic:                     25.10
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0376
# Time:                             10:33:25   Log-Likelihood:                 14.441
# No. Observations:                        4   AIC:                            -24.88
# Df Residuals:                            2   BIC:                            -26.11
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0030      0.006      0.509      0.661      -0.022       0.029
# Market Excess Return     1.0744      0.214      5.010      0.038       0.152       1.997
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.049
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.460
# Skew:                          -0.314   Prob(JB):                        0.794
# Kurtosis:                       1.462   Cond. No.                         46.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.011573879964340127
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.834
# Model:                                 OLS   Adj. R-squared:                  0.750
# Method:                      Least Squares   F-statistic:                     10.02
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0870
# Time:                             10:33:25   Log-Likelihood:                 15.845
# No. Observations:                        4   AIC:                            -27.69
# Df Residuals:                            2   BIC:                            -28.92
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0004      0.005     -0.071      0.950      -0.022       0.021
# Market Excess Return     1.1495      0.363      3.166      0.087      -0.413       2.712
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.105
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.415
# Skew:                          -0.081   Prob(JB):                        0.813
# Kurtosis:                       1.431   Cond. No.                         111.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010689070237995322
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.003
# Model:                                 OLS   Adj. R-squared:                 -0.329
# Method:                      Least Squares   F-statistic:                  0.009601
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.928
# Time:                             10:33:25   Log-Likelihood:                 12.942
# No. Observations:                        5   AIC:                            -21.88
# Df Residuals:                            3   BIC:                            -22.66
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0123      0.019      0.634      0.571      -0.049       0.074
# Market Excess Return    -0.0898      0.916     -0.098      0.928      -3.005       2.826
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.660
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.436
# Skew:                          -0.123   Prob(JB):                        0.804
# Kurtosis:                       1.575   Cond. No.                         87.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.007974884481157025
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.919
# Model:                                 OLS   Adj. R-squared:                  0.879
# Method:                      Least Squares   F-statistic:                     22.81
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0412
# Time:                             10:33:25   Log-Likelihood:                 13.568
# No. Observations:                        4   AIC:                            -23.14
# Df Residuals:                            2   BIC:                            -24.36
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0123      0.006     -2.116      0.169      -0.037       0.013
# Market Excess Return     0.8848      0.185      4.776      0.041       0.088       1.682
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.241
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.198
# Skew:                           0.079   Prob(JB):                        0.906
# Kurtosis:                       1.922   Cond. No.                         32.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.024364451128938123
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.652
# Model:                                 OLS   Adj. R-squared:                  0.536
# Method:                      Least Squares   F-statistic:                     5.614
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0986
# Time:                             10:33:25   Log-Likelihood:                 23.658
# No. Observations:                        5   AIC:                            -43.32
# Df Residuals:                            3   BIC:                            -44.10
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0179      0.003      5.955      0.009       0.008       0.027
# Market Excess Return     0.2508      0.106      2.369      0.099      -0.086       0.588
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.882
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.342
# Skew:                           0.310   Prob(JB):                        0.843
# Kurtosis:                       1.879   Cond. No.                         86.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.003654  1.644307       1.429538
# 1     02                 0.037922  1.607796       1.405197
# 2     03                 0.027075  0.994487       0.996324
# 3     04                 0.003518  1.346348       1.230899
# 4     05                 0.022719  2.629898       2.086599
# 5     06                 0.010332  1.331738       1.221159
# 6     07                 0.003709  1.387020       1.258013
# 7     08                 0.021553  1.074424       1.049616
# 8     09                 0.011574  1.149456       1.099637
# 9     10                 0.010689 -0.089762       0.273492
# 10    11                -0.007975  0.884835       0.923223
# 11    12                 0.024364  0.250782       0.500522

# %%
coefficients_df.to_csv('coefficients_df_p3_3.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.013631563297111906

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (53, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.784
# Model:                            OLS   Adj. R-squared:                  0.779
# Method:                 Least Squares   F-statistic:                     184.7
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.39e-18
# Time:                        10:33:35   Log-Likelihood:                 156.65
# No. Observations:                  53   AIC:                            -309.3
# Df Residuals:                      51   BIC:                            -305.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0051      0.002     -2.261      0.028      -0.010      -0.001
# x1             1.2283      0.090     13.591      0.000       1.047       1.410
# ==============================================================================
# Omnibus:                        3.650   Durbin-Watson:                   1.551
# Prob(Omnibus):                  0.161   Jarque-Bera (JB):                3.615
# Skew:                          -0.014   Prob(JB):                        0.164
# Kurtosis:                       4.279   Cond. No.                         51.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 1.228325462847509
# P-value: 1.3938293274352057e-18
# Std. error: 0.09037953427791429
# Adj. R-squared: 0.7793884566467909
# F-statistic: 184.70842762631708
# T-statistic for X1: 13.590747868543405

# %% [markdown]
# # P4 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_4.index:
    # Extract market excess return for the date
    x = returns_2021.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_4.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2021-01-01              0.017161                 0.011418
# 2021-01-08              0.036139                 0.047290
# 2021-01-15             -0.008024                -0.006166
# 2021-01-22             -0.003783                -0.015411
# 2021-01-29             -0.014488                -0.005860

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.006254208815119786
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.860
# Model:                                 OLS   Adj. R-squared:                  0.813
# Method:                      Least Squares   F-statistic:                     18.45
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0232
# Time:                             10:33:45   Log-Likelihood:                 16.844
# No. Observations:                        5   AIC:                            -29.69
# Df Residuals:                            3   BIC:                            -30.47
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0003      0.005      0.056      0.959      -0.016       0.016
# Market Excess Return     1.1064      0.258      4.295      0.023       0.287       1.926
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.577
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.589
# Skew:                          -0.234   Prob(JB):                        0.745
# Kurtosis:                       1.384   Cond. No.                         53.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.04444704014225836
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.997
# Model:                                 OLS   Adj. R-squared:                  0.995
# Method:                      Least Squares   F-statistic:                     607.5
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00164
# Time:                             10:33:45   Log-Likelihood:                 19.186
# No. Observations:                        4   AIC:                            -34.37
# Df Residuals:                            2   BIC:                            -35.60
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0191      0.002     10.949      0.008       0.012       0.027
# Market Excess Return     1.0434      0.042     24.647      0.002       0.861       1.226
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.695
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.205
# Skew:                           0.215   Prob(JB):                        0.903
# Kurtosis:                       1.978   Cond. No.                         30.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.026693228978676924
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.574
# Model:                                 OLS   Adj. R-squared:                  0.361
# Method:                      Least Squares   F-statistic:                     2.694
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.242
# Time:                             10:33:45   Log-Likelihood:                 12.553
# No. Observations:                        4   AIC:                            -21.11
# Df Residuals:                            2   BIC:                            -22.33
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0100      0.013      0.798      0.508      -0.044       0.064
# Market Excess Return     0.6296      0.384      1.641      0.242      -1.021       2.280
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.842
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.189
# Skew:                           0.142   Prob(JB):                        0.910
# Kurtosis:                       1.974   Cond. No.                         51.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.012618298085629248
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.298
# Model:                                 OLS   Adj. R-squared:                  0.064
# Method:                      Least Squares   F-statistic:                     1.274
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.341
# Time:                             10:33:45   Log-Likelihood:                 13.922
# No. Observations:                        5   AIC:                            -23.84
# Df Residuals:                            3   BIC:                            -24.62
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0062      0.010      0.594      0.594      -0.027       0.039
# Market Excess Return     0.7897      0.700      1.129      0.341      -1.437       3.016
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.837
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.011
# Skew:                           1.093   Prob(JB):                        0.603
# Kurtosis:                       2.721   Cond. No.                         81.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.02439107503375948
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.345
# Model:                                 OLS   Adj. R-squared:                  0.018
# Method:                      Least Squares   F-statistic:                     1.055
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.412
# Time:                             10:33:45   Log-Likelihood:                 12.125
# No. Observations:                        4   AIC:                            -20.25
# Df Residuals:                            2   BIC:                            -21.48
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0085      0.033     -0.257      0.821      -0.151       0.134
# Market Excess Return     1.5952      1.553      1.027      0.412      -5.087       8.277
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.357
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.310
# Skew:                           0.308   Prob(JB):                        0.856
# Kurtosis:                       1.783   Cond. No.                         188.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010732694507429415
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.965
# Model:                                 OLS   Adj. R-squared:                  0.948
# Method:                      Least Squares   F-statistic:                     55.60
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0175
# Time:                             10:33:45   Log-Likelihood:                 16.596
# No. Observations:                        4   AIC:                            -29.19
# Df Residuals:                            2   BIC:                            -30.42
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0102      0.004     -2.620      0.120      -0.027       0.007
# Market Excess Return     1.4891      0.200      7.457      0.018       0.630       2.348
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.875
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.538
# Skew:                           0.723   Prob(JB):                        0.764
# Kurtosis:                       1.933   Cond. No.                         74.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010350120657621658
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.934
# Model:                                 OLS   Adj. R-squared:                  0.912
# Method:                      Least Squares   F-statistic:                     42.62
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00730
# Time:                             10:33:45   Log-Likelihood:                 19.624
# No. Observations:                        5   AIC:                            -35.25
# Df Residuals:                            3   BIC:                            -36.03
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0067      0.004     -1.755      0.177      -0.019       0.005
# Market Excess Return     1.7660      0.270      6.529      0.007       0.905       2.627
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.326
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.376
# Skew:                          -0.504   Prob(JB):                        0.829
# Kurtosis:                       2.112   Cond. No.                         98.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.022742642409186463
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.698
# Model:                                 OLS   Adj. R-squared:                  0.547
# Method:                      Least Squares   F-statistic:                     4.627
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.164
# Time:                             10:33:46   Log-Likelihood:                 11.706
# No. Observations:                        4   AIC:                            -19.41
# Df Residuals:                            2   BIC:                            -20.64
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0070      0.012      0.594      0.613      -0.044       0.057
# Market Excess Return     0.9141      0.425      2.151      0.164      -0.914       2.742
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.513
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.756
# Skew:                           0.982   Prob(JB):                        0.685
# Kurtosis:                       2.177   Cond. No.                         46.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01459549635843254
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.843
# Model:                                 OLS   Adj. R-squared:                  0.765
# Method:                      Least Squares   F-statistic:                     10.74
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0818
# Time:                             10:33:46   Log-Likelihood:                 15.976
# No. Observations:                        4   AIC:                            -27.95
# Df Residuals:                            2   BIC:                            -29.18
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0026      0.005      0.548      0.639      -0.018       0.023
# Market Excess Return     1.1519      0.351      3.278      0.082      -0.360       2.664
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.944
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.470
# Skew:                           0.715   Prob(JB):                        0.790
# Kurtosis:                       2.117   Cond. No.                         111.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.018194785508154506
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.633
# Model:                                 OLS   Adj. R-squared:                  0.510
# Method:                      Least Squares   F-statistic:                     5.164
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.108
# Time:                             10:33:46   Log-Likelihood:                 22.000
# No. Observations:                        5   AIC:                            -40.00
# Df Residuals:                            3   BIC:                            -40.78
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0242      0.003      7.654      0.005       0.014       0.034
# Market Excess Return    -0.3401      0.150     -2.272      0.108      -0.816       0.136
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.712
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.526
# Skew:                          -0.024   Prob(JB):                        0.769
# Kurtosis:                       1.411   Cond. No.                         87.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0003986867179537248
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.964
# Model:                                 OLS   Adj. R-squared:                  0.946
# Method:                      Least Squares   F-statistic:                     53.90
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0181
# Time:                             10:33:46   Log-Likelihood:                 14.033
# No. Observations:                        4   AIC:                            -24.07
# Df Residuals:                            2   BIC:                            -25.29
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0064      0.005     -1.227      0.345      -0.029       0.016
# Market Excess Return     1.2111      0.165      7.342      0.018       0.501       1.921
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.020
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.744
# Skew:                          -0.978   Prob(JB):                        0.689
# Kurtosis:                       2.201   Cond. No.                         32.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.028356122976308323
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.736
# Model:                                 OLS   Adj. R-squared:                  0.648
# Method:                      Least Squares   F-statistic:                     8.370
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0629
# Time:                             10:33:46   Log-Likelihood:                 20.544
# No. Observations:                        5   AIC:                            -37.09
# Df Residuals:                            3   BIC:                            -37.87
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0136      0.006      2.428      0.093      -0.004       0.031
# Market Excess Return     0.5708      0.197      2.893      0.063      -0.057       1.199
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.688
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.459
# Skew:                           0.630   Prob(JB):                        0.795
# Kurtosis:                       2.215   Cond. No.                         86.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.006254  1.106403       1.070935
# 1     02                 0.044447  1.043406       1.028937
# 2     03                 0.026693  0.629612       0.753075
# 3     04                 0.012618  0.789708       0.859805
# 4     05                 0.024391  1.595168       1.396779
# 5     06                 0.010733  1.489081       1.326054
# 6     07                 0.010350  1.765953       1.510635
# 7     08                 0.022743  0.914101       0.942734
# 8     09                 0.014595  1.151878       1.101252
# 9     10                 0.018195 -0.340087       0.106609
# 10    11                -0.000399  1.211073       1.140716
# 11    12                 0.028356  0.570833       0.713889

# %%
coefficients_df.to_csv('coefficients_df_p4_3.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.017956257416251425

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (53, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.741
# Model:                            OLS   Adj. R-squared:                  0.736
# Method:                 Least Squares   F-statistic:                     146.0
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.39e-16
# Time:                        10:33:58   Log-Likelihood:                 158.85
# No. Observations:                  53   AIC:                            -313.7
# Df Residuals:                      51   BIC:                            -309.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0020      0.002      0.940      0.351      -0.002       0.006
# x1             1.0477      0.087     12.084      0.000       0.874       1.222
# ==============================================================================
# Omnibus:                        4.091   Durbin-Watson:                   1.786
# Prob(Omnibus):                  0.129   Jarque-Bera (JB):                3.713
# Skew:                           0.647   Prob(JB):                        0.156
# Kurtosis:                       2.918   Cond. No.                         51.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 1.0477131109038165
# P-value: 1.3856220180246136e-16
# Std. error: 0.08670531158701897
# Adj. R-squared: 0.7360588493725818
# F-statistic: 146.01361411962506
# T-statistic for X1: 12.0836093167408
