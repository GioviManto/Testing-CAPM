# %%
import pandas as pd

returns = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Returns_2018-2023.csv')

portfolio_1 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-3/p1-3.csv', usecols=[0])
portfolio_2 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-3/p2-3.csv', usecols=[0])
portfolio_3 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-3/p3-3.csv', usecols=[0])
portfolio_4 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-3/p4-3.csv', usecols=[0])

# %%
# Rename the column
portfolio_1 = portfolio_1.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2019' from the values in the 'Stock' column
portfolio_1['Stock'] = portfolio_1['Stock'].str.replace(' 2020', '')

# %%
portfolio_1
# Out:
#                 Stock
# 0            Diasorin
# 1               Inwit
# 2           Recordati
# 3             Ferrari
# 4             Italgas
# 5           Interpump
# 6               Terna
# 7                Hera
# 8  Brunello cucinelli
# 9             Campari

# %%
# Rename the column
portfolio_2 = portfolio_2.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2019' from the values in the 'Stock' column
portfolio_2['Stock'] = portfolio_2['Stock'].str.replace(' 2020', '')

# %%
# Rename the column
portfolio_3 = portfolio_3.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2019' from the values in the 'Stock' column
portfolio_3['Stock'] = portfolio_3['Stock'].str.replace(' 2020', '')

# %%
# Rename the column
portfolio_4 = portfolio_4.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2019' from the values in the 'Stock' column
portfolio_4['Stock'] = portfolio_4['Stock'].str.replace(' 2020', '')

# %%
# Convert 'Date' column to datetime format
returns['Date'] = pd.to_datetime(returns['Date'])

# Extract year from 'Date' column
returns['Year'] = returns['Date'].dt.year

# Filter DataFrame to include only the data from 2022
returns_2022 = returns[returns['Year'] == 2022].copy()

# Drop the 'Year' column as it's no longer needed
returns_2022.drop(columns='Year', inplace=True)

# %%
returns_2022.drop(columns='Unnamed: 0', inplace=True)

# %%
returns_2022.head()
# Out:
#           Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 208 2022-01-07       0.009933      -0.031977           -0.081560
# 209 2022-01-14      -0.002698       0.000300           -0.070216
# 210 2022-01-21      -0.017520      -0.010507           -0.044423
# 211 2022-01-28      -0.018328       0.023968           -0.073605
# 212 2022-02-04       0.001437      -0.028148            0.012267
#
#      Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 208          0.005267              0.047449                    0.018894
# 209          0.051189              0.023828                    0.030303
# 210         -0.033742             -0.037340                   -0.041045
# 211         -0.082143             -0.022051                   -0.035706
# 212          0.022914              0.063298                    0.027771
#
#      Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 208                                   0.038791                     0.024878
# 209                                  -0.025689                     0.043799
# 210                                   0.001329                    -0.056117
# 211                                  -0.006636                    -0.012319
# 212                                   0.030067                     0.033080
#
#      Banco Bpm 2018-2023  ...  Snam 2018-2023  Stellantis 2018-2023  \
# 208             0.005267  ...       -0.023774              0.078869
# 209             0.051189  ...       -0.011983              0.053994
# 210            -0.033742  ...       -0.005477             -0.044587
# 211            -0.082143  ...       -0.035405             -0.058473
# 212             0.022914  ...       -0.015090             -0.035505
#
#      Stmicroeletronics 2018-2023  Telecom 2018-2023  Tenaris 2018-2023  \
# 208                     0.014282           0.046753           0.063844
# 209                    -0.031993          -0.007041           0.047152
# 210                    -0.053881          -0.070906           0.009747
# 211                    -0.016113          -0.029573           0.049228
# 212                    -0.028879           0.024576           0.050598
#
#      Terna 2018-2023  Unicredit 2018-2023  Unipol 2018-2023    BOT 3m  \
# 208        -0.035423             0.051979          0.015484 -0.013154
# 209        -0.002040            -0.049691          0.028230 -0.011635
# 210         0.012850            -0.026588         -0.013026 -0.011019
# 211        -0.007497             0.042944         -0.003858 -0.011519
# 212        -0.018303             0.089044         -0.012434 -0.010481
#
#      Risk Premium
# 208      0.023087
# 209      0.008937
# 210     -0.006500
# 211     -0.006809
# 212      0.011918
#
# [5 rows x 42 columns]

# %%
risk_premium_2022 = returns_2022[['Date','Risk Premium']]

# %%
risk_premium_2022.head()
# Out:
#           Date  Risk Premium
# 208 2022-01-07      0.023087
# 209 2022-01-14      0.008937
# 210 2022-01-21     -0.006500
# 211 2022-01-28     -0.006809
# 212 2022-02-04      0.011918

# %%
risk_premium_2022['Risk Premium'].mean()
# Out:
# -0.00405960011397478

# %%
returns_2022.columns = returns_2022.columns.str.replace('2018-2023', '')

# %%
import numpy as np

# Copy the 2022 data to avoid modifying the original DataFrame
returns_2022_excess = returns_2022.copy()

# Calculate excess returns for each stock by subtracting the risk-free rate
risk_free_rate = returns_2022_excess['BOT 3m'].values  # Convert Series to NumPy array
returns_2022_excess.iloc[:, 2:-2] -= risk_free_rate[:, np.newaxis]

# Set 'Date' column as the index
returns_2022_excess.set_index('Date', inplace=True)

# Display the DataFrame with 'Date' as the index
returns_2022_excess.head()
# Out:
#             FTSEMIB Index      A2A   Amplifon    Azimut   BPER banca   \
# Date
# 2022-01-07       0.009933 -0.018823  -0.068406  0.018421     0.060603
# 2022-01-14      -0.002698  0.011935  -0.058581  0.062824     0.035463
# 2022-01-21      -0.017520  0.000512  -0.033403 -0.022723    -0.026321
# 2022-01-28      -0.018328  0.035488  -0.062086 -0.070624    -0.010532
# 2022-02-04       0.001437 -0.017667   0.022747  0.033395     0.073779
#
#             Banca Mediolanum   Banca Monte dei Paschi di Siena   \
# Date
# 2022-01-07           0.032048                          0.051945
# 2022-01-14           0.041938                         -0.014055
# 2022-01-21          -0.030026                          0.012348
# 2022-01-28          -0.024187                          0.004883
# 2022-02-04           0.038252                          0.040548
#
#             Banca pop Sondrio   Banco Bpm   Brunello cucinelli   ...  \
# Date                                                             ...
# 2022-01-07            0.038032    0.018421             0.014801  ...
# 2022-01-14            0.055434    0.062824            -0.098563  ...
# 2022-01-21           -0.045098   -0.022723             0.006398  ...
# 2022-01-28           -0.000800   -0.070624            -0.041406  ...
# 2022-02-04            0.043561    0.033395             0.039893  ...
#
#                Snam   Stellantis   Stmicroeletronics   Telecom   Tenaris   \
# Date
# 2022-01-07 -0.010620     0.092022            0.027436  0.059906  0.076997
# 2022-01-14 -0.000348     0.065629           -0.020358  0.004594  0.058787
# 2022-01-21  0.005542    -0.033568           -0.042862 -0.059887  0.020766
# 2022-01-28 -0.023886    -0.046954           -0.004594 -0.018054  0.060747
# 2022-02-04 -0.004609    -0.025024           -0.018398  0.035057  0.061079
#
#               Terna   Unicredit    Unipol     BOT 3m  Risk Premium
# Date
# 2022-01-07 -0.022269    0.065133  0.028638 -0.013154      0.023087
# 2022-01-14  0.009594   -0.038057  0.039865 -0.011635      0.008937
# 2022-01-21  0.023870   -0.015569 -0.002007 -0.011019     -0.006500
# 2022-01-28  0.004022    0.054463  0.007661 -0.011519     -0.006809
# 2022-02-04 -0.007823    0.099525 -0.001953 -0.010481      0.011918
#
# [5 rows x 41 columns]

# %%
portfolio_1['Stock']
# Out:
# 0              Diasorin
# 1                 Inwit
# 2             Recordati
# 3               Ferrari
# 4               Italgas
# 5             Interpump
# 6                 Terna
# 7                  Hera
# 8    Brunello cucinelli
# 9               Campari
# Name: Stock, dtype: object

# %%
returns_2022_excess.columns = returns_2022_excess.columns.str.strip()

# %%
p_1 = returns_2022_excess[portfolio_1['Stock'].values]
p_1.head()
# Out:
#             Diasorin     Inwit  Recordati   Ferrari   Italgas  Interpump  \
# Date
# 2022-01-07 -0.062391 -0.045835  -0.024722  0.002604 -0.033442  -0.026412
# 2022-01-14 -0.044567 -0.036525   0.003908 -0.040342  0.033818  -0.062679
# 2022-01-21 -0.011226  0.018128  -0.034216 -0.016160  0.000846  -0.018649
# 2022-01-28 -0.042733 -0.023980  -0.027122 -0.022681  0.014260  -0.034344
# 2022-02-04 -0.015426  0.002947  -0.033147  0.007987 -0.018218  -0.004599
#
#                Terna      Hera  Brunello cucinelli   Campari
# Date
# 2022-01-07 -0.022269 -0.011156            0.014801 -0.050246
# 2022-01-14  0.009594  0.000996           -0.098563 -0.034462
# 2022-01-21  0.023870 -0.004261            0.006398  0.003183
# 2022-01-28  0.004022  0.054623           -0.041406 -0.038064
# 2022-02-04 -0.007823  0.008552            0.039893  0.028948

# %%
p_2 = returns_2022_excess[portfolio_2['Stock'].values]
p_2.head()
# Out:
#              Moncler    Fineco       Erg  Amplifon      Snam   Pirelli  \
# Date
# 2022-01-07 -0.030270  0.024168 -0.017788 -0.068406 -0.010620  0.065217
# 2022-01-14 -0.059887  0.024451 -0.057306 -0.058581 -0.000348  0.050539
# 2022-01-21  0.030013 -0.018402  0.004004 -0.033403  0.005542 -0.024331
# 2022-01-28 -0.031629 -0.037699 -0.004964 -0.062086 -0.023886 -0.031959
# 2022-02-04  0.056657  0.033107  0.003298  0.022747 -0.004609 -0.009000
#
#             Prysmian   Telecom       A2A
# Date
# 2022-01-07  0.012550  0.059906 -0.018823
# 2022-01-14  0.017679  0.004594  0.011935
# 2022-01-21 -0.059272 -0.059887  0.000512
# 2022-01-28 -0.062148 -0.018054  0.035488
# 2022-02-04 -0.004866  0.035057 -0.017667

# %%
p_3 = returns_2022_excess[portfolio_3['Stock'].values]
p_3.head()
# Out:
#             Generali Ass  Banca Monte dei Paschi di Siena      Enel  \
# Date
# 2022-01-07      0.009933                         0.051945 -0.006290
# 2022-01-14      0.004634                        -0.014055 -0.003129
# 2022-01-21      0.001800                         0.012348  0.025416
# 2022-01-28      0.011246                         0.004883 -0.010639
# 2022-02-04      0.018146                         0.040548 -0.006255
#
#             Stellantis  Banca Mediolanum  Poste Italiane  BPER banca  \
# Date
# 2022-01-07    0.092022          0.032048        0.014454    0.060603
# 2022-01-14    0.065629          0.041938        0.015529    0.035463
# 2022-01-21   -0.033568         -0.030026        0.001105   -0.026321
# 2022-01-28   -0.046954         -0.024187        0.004554   -0.010532
# 2022-02-04   -0.025024          0.038252       -0.007932    0.073779
#
#               Saipem    Unipol
# Date
# 2022-01-07  0.074411  0.028638
# 2022-01-14  0.035114  0.039865
# 2022-01-21  0.007779 -0.002007
# 2022-01-28 -0.019773  0.007661
# 2022-02-04 -0.372724 -0.001953

# %%
p_4 = returns_2022_excess[portfolio_4['Stock'].values]
p_4.head()
# Out:
#             Intesa San Paolo  Banco Bpm    Azimut  Banca pop Sondrio  \
# Date
# 2022-01-07          0.091210   0.018421  0.018421           0.038032
# 2022-01-14          0.056709   0.062824  0.062824           0.055434
# 2022-01-21          0.007116  -0.022723 -0.022723          -0.045098
# 2022-01-28          0.029152  -0.070624 -0.070624          -0.000800
# 2022-02-04          0.037435   0.033395  0.033395           0.043561
#
#             Stmicroeletronics       Eni  Unicredit  Mediobanca   Tenaris  \
# Date
# 2022-01-07           0.027436  0.059799   0.065133    0.040355  0.076997
# 2022-01-14          -0.020358  0.040563  -0.038057    0.011635  0.058787
# 2022-01-21          -0.042862  0.006916  -0.015569   -0.015461  0.020766
# 2022-01-28          -0.004594  0.047228   0.054463    0.004101  0.060747
# 2022-02-04          -0.018398  0.003556   0.099525    0.009484  0.061079
#
#             Leonardo
# Date
# 2022-01-07  0.021090
# 2022-01-14  0.076517
# 2022-01-21  0.016639
# 2022-01-28 -0.038481
# 2022-02-04 -0.038126

# %%
returns_2022 = returns_2022.set_index('Date')

# %% [markdown]
# # P1 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_1.index:
    # Extract market excess return for the date
    x = returns_2022.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_1.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2022-01-07              0.023087                -0.025907
# 2022-01-14              0.008937                -0.026882
# 2022-01-21             -0.006500                -0.003209
# 2022-01-28             -0.006809                -0.015743
# 2022-02-04              0.011918                 0.000912

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 1': monthly_portfolio_excess_return, 'Beta 1': x1_coefficient, 'Adjusted Beta 1': adj, "Residual Variance 1": residual_variance})

# Convert the list to a DataFrame
coefficients_df_port1 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port1
# Out:
# -0.017934995181044383
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.626
# Model:                                 OLS   Adj. R-squared:                  0.439
# Method:                      Least Squares   F-statistic:                     3.347
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.209
# Time:                             11:08:57   Log-Likelihood:                 14.893
# No. Observations:                        4   AIC:                            -25.79
# Df Residuals:                            2   BIC:                            -27.01
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0151      0.004     -3.414      0.076      -0.034       0.004
# Market Excess Return    -0.6103      0.334     -1.829      0.209      -2.046       0.825
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.347
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.495
# Skew:                           0.201   Prob(JB):                        0.781
# Kurtosis:                       1.324   Cond. No.                         80.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.042118245639792e-10
# 0.00033854006914564583
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.841
# Model:                                 OLS   Adj. R-squared:                  0.762
# Method:                      Least Squares   F-statistic:                     10.59
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0829
# Time:                             11:08:57   Log-Likelihood:                 14.847
# No. Observations:                        4   AIC:                            -25.69
# Df Residuals:                            2   BIC:                            -26.92
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0040      0.004      0.914      0.457      -0.015       0.023
# Market Excess Return    -0.8743      0.269     -3.254      0.083      -2.030       0.282
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.902
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.385
# Skew:                          -0.112   Prob(JB):                        0.825
# Kurtosis:                       1.496   Cond. No.                         64.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.080077317212006e-10
# 0.018194889941904966
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.829
# Model:                                 OLS   Adj. R-squared:                  0.744
# Method:                      Least Squares   F-statistic:                     9.699
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0895
# Time:                             11:08:57   Log-Likelihood:                 10.244
# No. Observations:                        4   AIC:                            -16.49
# Df Residuals:                            2   BIC:                            -17.71
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0161      0.013      1.220      0.347      -0.041       0.073
# Market Excess Return     0.5837      0.187      3.114      0.089      -0.223       1.390
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.971
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.338
# Skew:                           0.259   Prob(JB):                        0.845
# Kurtosis:                       1.675   Cond. No.                         14.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.0969797221611388e-07
# 0.014455371348260604
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.561
# Model:                                 OLS   Adj. R-squared:                  0.415
# Method:                      Least Squares   F-statistic:                     3.838
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.145
# Time:                             11:08:57   Log-Likelihood:                 14.521
# No. Observations:                        5   AIC:                            -25.04
# Df Residuals:                            3   BIC:                            -25.82
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0058      0.009      0.650      0.562      -0.022       0.034
# Market Excess Return     0.9210      0.470      1.959      0.145      -0.575       2.417
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.977
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.430
# Skew:                           0.374   Prob(JB):                        0.806
# Kurtosis:                       1.773   Cond. No.                         61.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.984673764283076e-08
# 0.006919191689761218
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.928
# Model:                                 OLS   Adj. R-squared:                  0.893
# Method:                      Least Squares   F-statistic:                     25.93
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0365
# Time:                             11:08:57   Log-Likelihood:                 14.024
# No. Observations:                        4   AIC:                            -24.05
# Df Residuals:                            2   BIC:                            -25.28
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0121      0.006     -1.909      0.197      -0.039       0.015
# Market Excess Return     1.1283      0.222      5.093      0.036       0.175       2.082
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.517
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.752
# Skew:                           0.980   Prob(JB):                        0.686
# Kurtosis:                       2.181   Cond. No.                         43.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.380044743490171e-09
# -0.005020291726430497
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.957
# Model:                                 OLS   Adj. R-squared:                  0.936
# Method:                      Least Squares   F-statistic:                     44.94
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0215
# Time:                             11:08:57   Log-Likelihood:                 14.206
# No. Observations:                        4   AIC:                            -24.41
# Df Residuals:                            2   BIC:                            -25.64
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0163      0.006      2.785      0.108      -0.009       0.041
# Market Excess Return     1.1191      0.167      6.704      0.022       0.401       1.837
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.961
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.620
# Skew:                          -0.848   Prob(JB):                        0.733
# Kurtosis:                       2.080   Cond. No.                         34.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.34063103917618e-09
# 0.019193184755944958
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.769
# Model:                                 OLS   Adj. R-squared:                  0.692
# Method:                      Least Squares   F-statistic:                     9.975
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0509
# Time:                             11:08:57   Log-Likelihood:                 16.891
# No. Observations:                        5   AIC:                            -29.78
# Df Residuals:                            3   BIC:                            -30.56
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0154      0.005      3.137      0.052      -0.000       0.031
# Market Excess Return     0.4639      0.147      3.158      0.051      -0.004       0.931
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.789
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.437
# Skew:                          -0.013   Prob(JB):                        0.804
# Kurtosis:                       1.551   Cond. No.                         30.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.1992053740434954e-09
# -0.013708313617732622
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.219
# Model:                                 OLS   Adj. R-squared:                 -0.171
# Method:                      Least Squares   F-statistic:                    0.5611
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.532
# Time:                             11:08:57   Log-Likelihood:                 10.856
# No. Observations:                        4   AIC:                            -17.71
# Df Residuals:                            2   BIC:                            -18.94
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0100      0.012     -0.805      0.505      -0.063       0.043
# Market Excess Return     0.4518      0.603      0.749      0.532      -2.143       3.047
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.987
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.501
# Skew:                           0.139   Prob(JB):                        0.779
# Kurtosis:                       1.289   Cond. No.                         53.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.5520719882509358e-08
# -0.034444374181956526
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.489
# Model:                                 OLS   Adj. R-squared:                  0.319
# Method:                      Least Squares   F-statistic:                     2.871
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.189
# Time:                             11:08:57   Log-Likelihood:                 14.516
# No. Observations:                        5   AIC:                            -25.03
# Df Residuals:                            3   BIC:                            -25.81
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0207      0.011     -1.848      0.162      -0.056       0.015
# Market Excess Return     0.5794      0.342      1.694      0.189      -0.509       1.668
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.833
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.865
# Skew:                           0.966   Prob(JB):                        0.649
# Kurtosis:                       2.350   Cond. No.                         44.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.234694262265712e-08
# 0.0056973596110024526
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.669
# Model:                                 OLS   Adj. R-squared:                  0.504
# Method:                      Least Squares   F-statistic:                     4.044
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.182
# Time:                             11:08:58   Log-Likelihood:                 11.051
# No. Observations:                        4   AIC:                            -18.10
# Df Residuals:                            2   BIC:                            -19.33
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0057      0.012     -0.468      0.686      -0.058       0.047
# Market Excess Return     1.6119      0.802      2.011      0.182      -1.837       5.061
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.800
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.644
# Skew:                           0.009   Prob(JB):                        0.725
# Kurtosis:                       1.035   Cond. No.                         74.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.5092485909140457e-09
# -0.008748328949284592
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.662
# Model:                                 OLS   Adj. R-squared:                  0.493
# Method:                      Least Squares   F-statistic:                     3.920
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.186
# Time:                             11:08:58   Log-Likelihood:                 11.014
# No. Observations:                        4   AIC:                            -18.03
# Df Residuals:                            2   BIC:                            -19.25
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0051      0.011     -0.463      0.689      -0.053       0.042
# Market Excess Return     1.1511      0.581      1.980      0.186      -1.350       3.653
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.617
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.514
# Skew:                          -0.200   Prob(JB):                        0.773
# Kurtosis:                       1.290   Cond. No.                         53.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.1822088553557485e-08
# -0.03799539379934583
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.356
# Model:                                 OLS   Adj. R-squared:                  0.141
# Method:                      Least Squares   F-statistic:                     1.658
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.288
# Time:                             11:08:58   Log-Likelihood:                 14.894
# No. Observations:                        5   AIC:                            -25.79
# Df Residuals:                            3   BIC:                            -26.57
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0058      0.026     -0.222      0.839      -0.089       0.077
# Market Excess Return     0.7920      0.615      1.288      0.288      -1.165       2.749
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.788
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.562
# Skew:                           0.194   Prob(JB):                        0.755
# Kurtosis:                       1.404   Cond. No.                         86.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.1585745876490806e-08
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 1    Beta 1  Adjusted Beta 1  \
# 0     01                  -0.017935 -0.610253        -0.073502
# 1     02                   0.000339 -0.874277        -0.249518
# 2     03                   0.018195  0.583665         0.722444
# 3     04                   0.014455  0.920994         0.947329
# 4     05                   0.006919  1.128327         1.085551
# 5     06                  -0.005020  1.119065         1.079376
# 6     07                   0.019193  0.463931         0.642621
# 7     08                  -0.013708  0.451837         0.634558
# 8     09                  -0.034444  0.579429         0.719619
# 9     10                   0.005697  1.611939         1.407959
# 10    11                  -0.008748  1.151125         1.100750
# 11    12                  -0.037995  0.792006         0.861337
#
#     Residual Variance 1
# 0          5.042118e-10
# 1          8.080077e-10
# 2          1.096980e-07
# 3          2.984674e-08
# 4          4.380045e-09
# 5          3.340631e-09
# 6          3.199205e-09
# 7          2.552072e-08
# 8          5.234694e-08
# 9          2.509249e-09
# 10         2.182209e-08
# 11         1.158575e-08

# %% [markdown]
# # P2 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_2.index:
    # Extract market excess return for the date
    x = returns_2022.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_2.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2022-01-07              0.023087                 0.001770
# 2022-01-14              0.008937                -0.007436
# 2022-01-21             -0.006500                -0.017247
# 2022-01-28             -0.006809                -0.026326
# 2022-02-04              0.011918                 0.012747

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 2': monthly_portfolio_excess_return, 'Beta 2': x1_coefficient, 'Adjusted Beta 2': adj, "Residual Variance 2": residual_variance})

# Convert the list to a DataFrame
coefficients_df_port2 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port2
# Out:
# -0.012309780915600137
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.905
# Model:                                 OLS   Adj. R-squared:                  0.858
# Method:                      Least Squares   F-statistic:                     19.15
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0484
# Time:                             11:08:58   Log-Likelihood:                 17.259
# No. Observations:                        4   AIC:                            -30.52
# Df Residuals:                            2   BIC:                            -31.74
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0161      0.002     -6.580      0.022      -0.027      -0.006
# Market Excess Return     0.8082      0.185      4.376      0.048       0.014       1.603
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.150
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.285
# Skew:                          -0.257   Prob(JB):                        0.867
# Kurtosis:                       1.798   Cond. No.                         80.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.165917638933991e-10
# 0.007647688125093893
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.149
# Model:                                 OLS   Adj. R-squared:                 -0.277
# Method:                      Least Squares   F-statistic:                    0.3497
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.614
# Time:                             11:08:58   Log-Likelihood:                 16.914
# No. Observations:                        4   AIC:                            -29.83
# Df Residuals:                            2   BIC:                            -31.05
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0080      0.003      3.116      0.089      -0.003       0.019
# Market Excess Return    -0.0948      0.160     -0.591      0.614      -0.784       0.595
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.827
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.620
# Skew:                           0.860   Prob(JB):                        0.734
# Kurtosis:                       2.127   Cond. No.                         64.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.3255259610934915e-10
# 0.010142559038890511
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.913
# Model:                                 OLS   Adj. R-squared:                  0.869
# Method:                      Least Squares   F-statistic:                     20.94
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0446
# Time:                             11:08:58   Log-Likelihood:                 10.002
# No. Observations:                        4   AIC:                            -16.00
# Df Residuals:                            2   BIC:                            -17.23
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0069      0.014      0.494      0.670      -0.054       0.067
# Market Excess Return     0.9111      0.199      4.576      0.045       0.054       1.768
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.385
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.670
# Skew:                           0.896   Prob(JB):                        0.715
# Kurtosis:                       2.099   Cond. No.                         14.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.2759332817098733e-07
# 0.013844752927668996
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.880
# Model:                                 OLS   Adj. R-squared:                  0.840
# Method:                      Least Squares   F-statistic:                     22.04
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0183
# Time:                             11:08:58   Log-Likelihood:                 18.375
# No. Observations:                        5   AIC:                            -32.75
# Df Residuals:                            3   BIC:                            -33.53
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0042      0.004      1.026      0.381      -0.009       0.017
# Market Excess Return     1.0212      0.218      4.695      0.018       0.329       1.713
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.538
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.632
# Skew:                          -0.625   Prob(JB):                        0.729
# Kurtosis:                       1.787   Cond. No.                         61.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.3935378070813367e-09
# 0.0035573540954300974
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.964
# Model:                                 OLS   Adj. R-squared:                  0.946
# Method:                      Least Squares   F-statistic:                     53.33
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0182
# Time:                             11:08:58   Log-Likelihood:                 15.242
# No. Observations:                        4   AIC:                            -26.48
# Df Residuals:                            2   BIC:                            -27.71
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0166      0.005     -3.539      0.071      -0.037       0.004
# Market Excess Return     1.1932      0.163      7.302      0.018       0.490       1.896
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.516
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.911
# Skew:                           1.116   Prob(JB):                        0.634
# Kurtosis:                       2.301   Cond. No.                         43.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.4272830945058945e-09
# -0.017150377699218407
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.991
# Model:                                 OLS   Adj. R-squared:                  0.987
# Method:                      Least Squares   F-statistic:                     232.2
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00428
# Time:                             11:08:58   Log-Likelihood:                 16.976
# No. Observations:                        4   AIC:                            -29.95
# Df Residuals:                            2   BIC:                            -31.18
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0071      0.003      2.418      0.137      -0.006       0.020
# Market Excess Return     1.2724      0.084     15.237      0.004       0.913       1.632
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.588
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.309
# Skew:                          -0.401   Prob(JB):                        0.857
# Kurtosis:                       1.900   Cond. No.                         34.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.743523240892172e-10
# 0.01232758459353008
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.882
# Model:                                 OLS   Adj. R-squared:                  0.842
# Method:                      Least Squares   F-statistic:                     22.33
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0180
# Time:                             11:08:58   Log-Likelihood:                 15.665
# No. Observations:                        5   AIC:                            -27.33
# Df Residuals:                            3   BIC:                            -28.11
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0051      0.006      0.812      0.476      -0.015       0.025
# Market Excess Return     0.8869      0.188      4.725      0.018       0.290       1.484
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.907
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.230
# Skew:                          -0.279   Prob(JB):                        0.892
# Kurtosis:                       2.112   Cond. No.                         30.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.719595340247062e-08
# -0.015246697698169671
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.992
# Model:                                 OLS   Adj. R-squared:                  0.988
# Method:                      Least Squares   F-statistic:                     252.7
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00393
# Time:                             11:08:58   Log-Likelihood:                 18.421
# No. Observations:                        4   AIC:                            -32.84
# Df Residuals:                            2   BIC:                            -34.07
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0033      0.002     -1.761      0.220      -0.011       0.005
# Market Excess Return     1.4466      0.091     15.896      0.004       1.055       1.838
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.119
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.352
# Skew:                           0.546   Prob(JB):                        0.839
# Kurtosis:                       2.042   Cond. No.                         53.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.759706017672543e-11
# -0.02653849214928709
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.650
# Model:                                 OLS   Adj. R-squared:                  0.533
# Method:                      Least Squares   F-statistic:                     5.574
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0993
# Time:                             11:08:58   Log-Likelihood:                 16.057
# No. Observations:                        5   AIC:                            -28.11
# Df Residuals:                            3   BIC:                            -28.90
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0124      0.008     -1.513      0.227      -0.039       0.014
# Market Excess Return     0.5932      0.251      2.361      0.099      -0.206       1.393
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.999
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.474
# Skew:                           0.430   Prob(JB):                        0.789
# Kurtosis:                       1.761   Cond. No.                         44.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.598654672190327e-09
# 0.0035600846991676116
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.970
# Model:                                 OLS   Adj. R-squared:                  0.954
# Method:                      Least Squares   F-statistic:                     63.86
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0153
# Time:                             11:08:58   Log-Likelihood:                 17.539
# No. Observations:                        4   AIC:                            -31.08
# Df Residuals:                            2   BIC:                            -32.31
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0054      0.002     -2.240      0.154      -0.016       0.005
# Market Excess Return     1.2653      0.158      7.991      0.015       0.584       1.947
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.873
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.474
# Skew:                          -0.140   Prob(JB):                        0.789
# Kurtosis:                       1.337   Cond. No.                         74.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.716213155146296e-11
# -0.005217839546518133
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.858
# Model:                                 OLS   Adj. R-squared:                  0.787
# Method:                      Least Squares   F-statistic:                     12.07
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0738
# Time:                             11:08:58   Log-Likelihood:                 12.621
# No. Observations:                        4   AIC:                            -21.24
# Df Residuals:                            2   BIC:                            -22.47
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0010      0.007     -0.130      0.909      -0.033       0.031
# Market Excess Return     1.3516      0.389      3.475      0.074      -0.322       3.025
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.898
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.509
# Skew:                           0.027   Prob(JB):                        0.775
# Kurtosis:                       1.253   Cond. No.                         53.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.815894048939902e-09
# -0.03614807854828182
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.945
# Model:                                 OLS   Adj. R-squared:                  0.927
# Method:                      Least Squares   F-statistic:                     51.83
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00552
# Time:                             11:08:58   Log-Likelihood:                 22.877
# No. Observations:                        5   AIC:                            -41.75
# Df Residuals:                            3   BIC:                            -42.54
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0004      0.005      0.068      0.950      -0.016       0.017
# Market Excess Return     0.8971      0.125      7.200      0.006       0.501       1.294
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.682
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.055
# Skew:                           1.121   Prob(JB):                        0.590
# Kurtosis:                       2.823   Cond. No.                         86.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.797357981141856e-11
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 2    Beta 2  Adjusted Beta 2  \
# 0     01                  -0.012310  0.808159         0.872106
# 1     02                   0.007648 -0.094758         0.270161
# 2     03                   0.010143  0.911127         0.940752
# 3     04                   0.013845  1.021176         1.014118
# 4     05                   0.003557  1.193212         1.128808
# 5     06                  -0.017150  1.272440         1.181627
# 6     07                   0.012328  0.886927         0.924618
# 7     08                  -0.015247  1.446604         1.297736
# 8     09                  -0.026538  0.593208         0.728805
# 9     10                   0.003560  1.265279         1.176853
# 10    11                  -0.005218  1.351594         1.234396
# 11    12                  -0.036148  0.897091         0.931394
#
#     Residual Variance 2
# 0          1.165918e-10
# 1          2.325526e-10
# 2          2.275933e-07
# 3          1.393538e-09
# 4          1.427283e-09
# 5          1.743523e-10
# 6          1.719595e-08
# 7          4.759706e-11
# 8          8.598655e-09
# 9          3.716213e-11
# 10         3.815894e-09
# 11         8.797358e-11

# %% [markdown]
# # P3 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_3.index:
    # Extract market excess return for the date
    x = returns_2022.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_3.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2022-01-07              0.023087                 0.039752
# 2022-01-14              0.008937                 0.024554
# 2022-01-21             -0.006500                -0.004830
# 2022-01-28             -0.006809                -0.009304
# 2022-02-04              0.011918                -0.027018

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 3': monthly_portfolio_excess_return, 'Beta 3': x1_coefficient, 'Adjusted Beta 3': adj, "Residual Variance 3" : residual_variance})

# Convert the list to a DataFrame
coefficients_df_port3 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port3
# Out:
# 0.012542764144978121
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.974
# Model:                                 OLS   Adj. R-squared:                  0.960
# Method:                      Least Squares   F-statistic:                     73.66
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0133
# Time:                             11:08:58   Log-Likelihood:                 17.160
# No. Observations:                        4   AIC:                            -30.32
# Df Residuals:                            2   BIC:                            -31.55
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0049      0.003      1.972      0.187      -0.006       0.016
# Market Excess Return     1.6243      0.189      8.582      0.013       0.810       2.439
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.160
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.479
# Skew:                           0.554   Prob(JB):                        0.787
# Kurtosis:                       1.716   Cond. No.                         80.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.1545387019932775e-10
# -0.011750139518285463
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.601
# Model:                                 OLS   Adj. R-squared:                  0.402
# Method:                      Least Squares   F-statistic:                     3.015
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.225
# Time:                             11:08:58   Log-Likelihood:                 10.680
# No. Observations:                        4   AIC:                            -17.36
# Df Residuals:                            2   BIC:                            -18.59
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0172      0.012     -1.404      0.295      -0.070       0.036
# Market Excess Return     1.3219      0.761      1.736      0.225      -1.954       4.598
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.730
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.462
# Skew:                          -0.520   Prob(JB):                        0.794
# Kurtosis:                       1.700   Cond. No.                         64.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 7.354932049593747e-08
# 0.01388288472004524
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.988
# Model:                                 OLS   Adj. R-squared:                  0.982
# Method:                      Least Squares   F-statistic:                     167.9
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00590
# Time:                             11:08:58   Log-Likelihood:                 13.004
# No. Observations:                        4   AIC:                            -22.01
# Df Residuals:                            2   BIC:                            -23.23
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0096      0.007      1.447      0.285      -0.019       0.038
# Market Excess Return     1.2181      0.094     12.958      0.006       0.814       1.623
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.355
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.615
# Skew:                          -0.862   Prob(JB):                        0.735
# Kurtosis:                       2.150   Cond. No.                         14.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.184155328933225e-08
# 0.003873500852890353
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.626
# Model:                                 OLS   Adj. R-squared:                  0.502
# Method:                      Least Squares   F-statistic:                     5.027
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.111
# Time:                             11:08:58   Log-Likelihood:                 14.389
# No. Observations:                        5   AIC:                            -24.78
# Df Residuals:                            3   BIC:                            -25.56
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0063      0.009     -0.699      0.535      -0.035       0.023
# Market Excess Return     1.0824      0.483      2.242      0.111      -0.454       2.619
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.619
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.611
# Skew:                           0.312   Prob(JB):                        0.737
# Kurtosis:                       1.405   Cond. No.                         61.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.740935407570881e-08
# 0.020647283037077357
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.863
# Model:                                 OLS   Adj. R-squared:                  0.794
# Method:                      Least Squares   F-statistic:                     12.57
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0712
# Time:                             11:08:58   Log-Likelihood:                 13.890
# No. Observations:                        4   AIC:                            -23.78
# Df Residuals:                            2   BIC:                            -25.01
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0069      0.007      1.056      0.402      -0.021       0.035
# Market Excess Return     0.8124      0.229      3.546      0.071      -0.173       1.798
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.529
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.251
# Skew:                           0.312   Prob(JB):                        0.882
# Kurtosis:                       1.944   Cond. No.                         43.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.0061244359446955e-09
# -0.03451798698625579
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.374
# Model:                                 OLS   Adj. R-squared:                  0.061
# Method:                      Least Squares   F-statistic:                     1.194
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.389
# Time:                             11:08:58   Log-Likelihood:                 10.039
# No. Observations:                        4   AIC:                            -16.08
# Df Residuals:                            2   BIC:                            -17.30
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0247      0.017     -1.489      0.275      -0.096       0.047
# Market Excess Return     0.5171      0.473      1.093      0.389      -1.519       2.553
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.003
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.666
# Skew:                           0.000   Prob(JB):                        0.717
# Kurtosis:                       1.001   Cond. No.                         34.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.756123961562365e-10
# 0.001368177697812964
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.184
# Model:                                 OLS   Adj. R-squared:                 -0.088
# Method:                      Least Squares   F-statistic:                    0.6751
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.471
# Time:                             11:08:58   Log-Likelihood:                 5.8409
# No. Observations:                        5   AIC:                            -7.682
# Df Residuals:                            3   BIC:                            -8.463
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0076      0.045     -0.170      0.876      -0.150       0.135
# Market Excess Return     1.1002      1.339      0.822      0.471      -3.161       5.361
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.232
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.139
# Skew:                           0.192   Prob(JB):                        0.933
# Kurtosis:                       2.280   Cond. No.                         30.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.12780347117538e-05
# -0.008215538259377967
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.893
# Model:                                 OLS   Adj. R-squared:                  0.839
# Method:                      Least Squares   F-statistic:                     16.62
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0552
# Time:                             11:08:58   Log-Likelihood:                 11.657
# No. Observations:                        4   AIC:                            -19.31
# Df Residuals:                            2   BIC:                            -20.54
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0084      0.010      0.830      0.494      -0.035       0.052
# Market Excess Return     2.0126      0.494      4.077      0.055      -0.111       4.136
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.929
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.436
# Skew:                           0.509   Prob(JB):                        0.804
# Kurtosis:                       1.744   Cond. No.                         53.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.941352276676163e-08
# -0.027474926005700933
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.810
# Model:                                 OLS   Adj. R-squared:                  0.747
# Method:                      Least Squares   F-statistic:                     12.80
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0373
# Time:                             11:08:58   Log-Likelihood:                 14.309
# No. Observations:                        5   AIC:                            -24.62
# Df Residuals:                            3   BIC:                            -25.40
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0029      0.012      0.247      0.821      -0.034       0.040
# Market Excess Return     1.2755      0.356      3.578      0.037       0.141       2.410
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.265
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.210
# Skew:                           1.201   Prob(JB):                        0.546
# Kurtosis:                       2.788   Cond. No.                         44.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.184288669704145e-08
# 0.0009620706907077364
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.917
# Model:                                 OLS   Adj. R-squared:                  0.876
# Method:                      Least Squares   F-statistic:                     22.20
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0422
# Time:                             11:08:58   Log-Likelihood:                 11.406
# No. Observations:                        4   AIC:                            -18.81
# Df Residuals:                            2   BIC:                            -20.04
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0235      0.011     -2.106      0.170      -0.072       0.025
# Market Excess Return     3.4565      0.734      4.712      0.042       0.300       6.613
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.885
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.516
# Skew:                           0.725   Prob(JB):                        0.773
# Kurtosis:                       2.004   Cond. No.                         74.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.107859836352007e-08
# -0.00916105218199511
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.651
# Model:                                 OLS   Adj. R-squared:                  0.477
# Method:                      Least Squares   F-statistic:                     3.735
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.193
# Time:                             11:08:58   Log-Likelihood:                 12.092
# No. Observations:                        4   AIC:                            -20.18
# Df Residuals:                            2   BIC:                            -21.41
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0065      0.008     -0.765      0.524      -0.043       0.030
# Market Excess Return     0.8580      0.444      1.933      0.193      -1.052       2.768
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.863
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.469
# Skew:                          -0.508   Prob(JB):                        0.791
# Kurtosis:                       1.666   Cond. No.                         53.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.7055269696071052e-08
# -0.03405475332498503
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.886
# Model:                                 OLS   Adj. R-squared:                  0.848
# Method:                      Least Squares   F-statistic:                     23.38
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0169
# Time:                             11:08:58   Log-Likelihood:                 18.411
# No. Observations:                        5   AIC:                            -32.82
# Df Residuals:                            3   BIC:                            -33.60
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0258      0.013      2.007      0.138      -0.015       0.067
# Market Excess Return     1.4718      0.304      4.835      0.017       0.503       2.441
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.355
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.695
# Skew:                          -0.300   Prob(JB):                        0.707
# Kurtosis:                       1.275   Cond. No.                         86.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.731678595846044e-10
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 3    Beta 3  Adjusted Beta 3  \
# 0     01                   0.012543  1.624277         1.416185
# 1     02                  -0.011750  1.321946         1.214630
# 2     03                   0.013883  1.218083         1.145389
# 3     04                   0.003874  1.082356         1.054904
# 4     05                   0.020647  0.812432         0.874955
# 5     06                  -0.034518  0.517105         0.678070
# 6     07                   0.001368  1.100167         1.066778
# 7     08                  -0.008216  2.012564         1.675043
# 8     09                  -0.027475  1.275518         1.183679
# 9     10                   0.000962  3.456508         2.637672
# 10    11                  -0.009161  0.858046         0.905364
# 11    12                  -0.034055  1.471829         1.314553
#
#     Residual Variance 3
# 0          1.154539e-10
# 1          7.354932e-08
# 2          1.184155e-08
# 3          1.740935e-08
# 4          4.006124e-09
# 5          1.756124e-10
# 6          5.127803e-05
# 7          2.941352e-08
# 8          8.184289e-08
# 9          5.107860e-08
# 10         1.705527e-08
# 11         4.731679e-10

# %% [markdown]
# # P4 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_4.index:
    # Extract market excess return for the date
    x = returns_2022.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_4.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2022-01-07              0.023087                 0.045689
# 2022-01-14              0.008937                 0.036688
# 2022-01-21             -0.006500                -0.011300
# 2022-01-28             -0.006809                 0.001057
# 2022-02-04              0.011918                 0.026491

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 4': monthly_portfolio_excess_return, 'Beta 4': x1_coefficient, 'Adjusted Beta 4': adj, "Residual Variance 4" : residual_variance})

# Convert the list to a DataFrame
coefficients_df_port4 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port4
# Out:
# 0.01803355959208274
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.890
# Model:                                 OLS   Adj. R-squared:                  0.835
# Method:                      Least Squares   F-statistic:                     16.14
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0567
# Time:                             11:08:58   Log-Likelihood:                 13.691
# No. Observations:                        4   AIC:                            -23.38
# Df Residuals:                            2   BIC:                            -24.61
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0096      0.006      1.603      0.250      -0.016       0.035
# Market Excess Return     1.8104      0.451      4.018      0.057      -0.128       3.749
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.388
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.435
# Skew:                           0.220   Prob(JB):                        0.804
# Kurtosis:                       1.445   Cond. No.                         80.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.3022596519117093e-09
# 0.006733730001716221
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.992
# Model:                                 OLS   Adj. R-squared:                  0.988
# Method:                      Least Squares   F-statistic:                     258.3
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00385
# Time:                             11:08:58   Log-Likelihood:                 17.707
# No. Observations:                        4   AIC:                            -31.41
# Df Residuals:                            2   BIC:                            -32.64
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0020      0.002     -0.945      0.444      -0.011       0.007
# Market Excess Return     2.1118      0.131     16.072      0.004       1.546       2.677
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.823
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.636
# Skew:                           0.036   Prob(JB):                        0.727
# Kurtosis:                       1.047   Cond. No.                         64.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.411538316111162e-12
# 0.017196947600755668
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.984
# Model:                                 OLS   Adj. R-squared:                  0.977
# Method:                      Least Squares   F-statistic:                     125.8
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00786
# Time:                             11:08:58   Log-Likelihood:                 13.232
# No. Observations:                        4   AIC:                            -22.46
# Df Residuals:                            2   BIC:                            -23.69
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0137      0.006      2.185      0.161      -0.013       0.041
# Market Excess Return     0.9959      0.089     11.216      0.008       0.614       1.378
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.341
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.674
# Skew:                           0.898   Prob(JB):                        0.714
# Kurtosis:                       2.093   Cond. No.                         14.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.958874207543128e-09
# 0.010942611730595856
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.398
# Model:                                 OLS   Adj. R-squared:                  0.197
# Method:                      Least Squares   F-statistic:                     1.981
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.254
# Time:                             11:08:58   Log-Likelihood:                 15.194
# No. Observations:                        5   AIC:                            -26.39
# Df Residuals:                            3   BIC:                            -27.17
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0055      0.008      0.709      0.530      -0.019       0.030
# Market Excess Return     0.5783      0.411      1.407      0.254      -0.729       1.886
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.345
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.219
# Skew:                          -0.185   Prob(JB):                        0.896
# Kurtosis:                       2.044   Cond. No.                         61.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.3539571231298966e-08
# 0.02416775480882627
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.973
# Model:                                 OLS   Adj. R-squared:                  0.959
# Method:                      Least Squares   F-statistic:                     70.81
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0138
# Time:                             11:08:58   Log-Likelihood:                 16.158
# No. Observations:                        4   AIC:                            -28.32
# Df Residuals:                            2   BIC:                            -29.54
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0057      0.004      1.531      0.265      -0.010       0.022
# Market Excess Return     1.0938      0.130      8.415      0.014       0.535       1.653
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.531
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.352
# Skew:                           0.373   Prob(JB):                        0.839
# Kurtosis:                       1.753   Cond. No.                         43.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.30705946781418e-10
# -0.025420402493567366
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.950
# Model:                                 OLS   Adj. R-squared:                  0.925
# Method:                      Least Squares   F-statistic:                     38.22
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0252
# Time:                             11:08:58   Log-Likelihood:                 14.308
# No. Observations:                        4   AIC:                            -24.62
# Df Residuals:                            2   BIC:                            -25.84
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0063      0.006     -1.100      0.386      -0.031       0.018
# Market Excess Return     1.0060      0.163      6.183      0.025       0.306       1.706
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.991
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.799
# Skew:                           1.022   Prob(JB):                        0.671
# Kurtosis:                       2.213   Cond. No.                         34.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.386781956517146e-09
# 0.005668277009456456
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.973
# Model:                                 OLS   Adj. R-squared:                  0.964
# Method:                      Least Squares   F-statistic:                     108.2
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00190
# Time:                             11:08:58   Log-Likelihood:                 18.515
# No. Observations:                        5   AIC:                            -33.03
# Df Residuals:                            3   BIC:                            -33.81
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0033      0.004     -0.938      0.417      -0.015       0.008
# Market Excess Return     1.1041      0.106     10.402      0.002       0.766       1.442
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.244
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.292
# Skew:                           0.404   Prob(JB):                        0.864
# Kurtosis:                       2.133   Cond. No.                         30.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.7927325831588977e-09
# -0.010110046822006167
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.888
# Model:                                 OLS   Adj. R-squared:                  0.832
# Method:                      Least Squares   F-statistic:                     15.82
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0578
# Time:                             11:08:58   Log-Likelihood:                 14.702
# No. Observations:                        4   AIC:                            -25.40
# Df Residuals:                            2   BIC:                            -26.63
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0025      0.005     -0.534      0.646      -0.023       0.018
# Market Excess Return     0.9171      0.231      3.978      0.058      -0.075       1.909
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.943
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.332
# Skew:                          -0.420   Prob(JB):                        0.847
# Kurtosis:                       1.866   Cond. No.                         53.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.6317011111110893e-09
# -0.01844627923633712
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.988
# Model:                                 OLS   Adj. R-squared:                  0.983
# Method:                      Least Squares   F-statistic:                     237.1
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000595
# Time:                             11:08:58   Log-Likelihood:                 21.976
# No. Observations:                        5   AIC:                            -39.95
# Df Residuals:                            3   BIC:                            -40.73
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0097      0.003      3.873      0.030       0.002       0.018
# Market Excess Return     1.1846      0.077     15.399      0.001       0.940       1.429
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.769
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.543
# Skew:                           0.312   Prob(JB):                        0.762
# Kurtosis:                       1.510   Cond. No.                         44.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.063868694244465e-11
# 0.013741697368641441
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.735
# Model:                                 OLS   Adj. R-squared:                  0.603
# Method:                      Least Squares   F-statistic:                     5.549
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.143
# Time:                             11:08:58   Log-Likelihood:                 12.281
# No. Observations:                        4   AIC:                            -20.56
# Df Residuals:                            2   BIC:                            -21.79
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0039      0.009      0.436      0.705      -0.035       0.043
# Market Excess Return     1.3884      0.589      2.356      0.143      -1.148       3.924
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.801
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.644
# Skew:                          -0.010   Prob(JB):                        0.725
# Kurtosis:                       1.034   Cond. No.                         74.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 7.299864428947088e-10
# -0.0028775973870851833
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.801
# Model:                                 OLS   Adj. R-squared:                  0.702
# Method:                      Least Squares   F-statistic:                     8.061
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.105
# Time:                             11:08:58   Log-Likelihood:                 13.499
# No. Observations:                        4   AIC:                            -23.00
# Df Residuals:                            2   BIC:                            -24.22
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -8.305e-05      0.006     -0.014      0.990      -0.026       0.025
# Market Excess Return     0.8869      0.312      2.839      0.105      -0.457       2.231
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.899
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.485
# Skew:                          -0.018   Prob(JB):                        0.785
# Kurtosis:                       1.295   Cond. No.                         53.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.8483033561340293e-09
# -0.03416709205491718
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.332
# Model:                                 OLS   Adj. R-squared:                  0.109
# Method:                      Least Squares   F-statistic:                     1.488
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.310
# Time:                             11:08:58   Log-Likelihood:                 15.859
# No. Observations:                        5   AIC:                            -27.72
# Df Residuals:                            3   BIC:                            -28.50
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0090      0.021     -0.419      0.703      -0.077       0.059
# Market Excess Return     0.6185      0.507      1.220      0.310      -0.995       2.232
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.661
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.280
# Skew:                           0.055   Prob(JB):                        0.870
# Kurtosis:                       1.847   Cond. No.                         86.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.1208749688615046e-08
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 4    Beta 4  Adjusted Beta 4  \
# 0     01                   0.018034  1.810403         1.540269
# 1     02                   0.006734  2.111801         1.741200
# 2     03                   0.017197  0.995866         0.997244
# 3     04                   0.010943  0.578274         0.718849
# 4     05                   0.024168  1.093778         1.062519
# 5     06                  -0.025420  1.006020         1.004013
# 6     07                   0.005668  1.104081         1.069387
# 7     08                  -0.010110  0.917124         0.944750
# 8     09                  -0.018446  1.184586         1.123057
# 9     10                   0.013742  1.388426         1.258950
# 10    11                  -0.002878  0.886870         0.924580
# 11    12                  -0.034167  0.618498         0.745665
#
#     Residual Variance 4
# 0          2.302260e-09
# 1          4.411538e-12
# 2          8.958874e-09
# 3          2.353957e-08
# 4          3.307059e-10
# 5          3.386782e-09
# 6          1.792733e-09
# 7          1.631701e-09
# 8          5.063869e-11
# 9          7.299864e-10
# 10         1.848303e-09
# 11         1.120875e-08

# %%
merged_df = pd.merge(coefficients_df_port1, coefficients_df_port2, on="Month", how="inner")
merged_df = pd.merge(merged_df, coefficients_df_port3, on="Month", how="inner")
merged_df = pd.merge(merged_df, coefficients_df_port4, on="Month", how="inner")
merged_df
# Out:
#    Month  Portfolio Excess Return 1    Beta 1  Adjusted Beta 1  \
# 0     01                  -0.017935 -0.610253        -0.073502
# 1     02                   0.000339 -0.874277        -0.249518
# 2     03                   0.018195  0.583665         0.722444
# 3     04                   0.014455  0.920994         0.947329
# 4     05                   0.006919  1.128327         1.085551
# 5     06                  -0.005020  1.119065         1.079376
# 6     07                   0.019193  0.463931         0.642621
# 7     08                  -0.013708  0.451837         0.634558
# 8     09                  -0.034444  0.579429         0.719619
# 9     10                   0.005697  1.611939         1.407959
# 10    11                  -0.008748  1.151125         1.100750
# 11    12                  -0.037995  0.792006         0.861337
#
#     Residual Variance 1  Portfolio Excess Return 2    Beta 2  Adjusted Beta 2  \
# 0          5.042118e-10                  -0.012310  0.808159         0.872106
# 1          8.080077e-10                   0.007648 -0.094758         0.270161
# 2          1.096980e-07                   0.010143  0.911127         0.940752
# 3          2.984674e-08                   0.013845  1.021176         1.014118
# 4          4.380045e-09                   0.003557  1.193212         1.128808
# 5          3.340631e-09                  -0.017150  1.272440         1.181627
# 6          3.199205e-09                   0.012328  0.886927         0.924618
# 7          2.552072e-08                  -0.015247  1.446604         1.297736
# 8          5.234694e-08                  -0.026538  0.593208         0.728805
# 9          2.509249e-09                   0.003560  1.265279         1.176853
# 10         2.182209e-08                  -0.005218  1.351594         1.234396
# 11         1.158575e-08                  -0.036148  0.897091         0.931394
#
#     Residual Variance 2  Portfolio Excess Return 3    Beta 3  Adjusted Beta 3  \
# 0          1.165918e-10                   0.012543  1.624277         1.416185
# 1          2.325526e-10                  -0.011750  1.321946         1.214630
# 2          2.275933e-07                   0.013883  1.218083         1.145389
# 3          1.393538e-09                   0.003874  1.082356         1.054904
# 4          1.427283e-09                   0.020647  0.812432         0.874955
# 5          1.743523e-10                  -0.034518  0.517105         0.678070
# 6          1.719595e-08                   0.001368  1.100167         1.066778
# 7          4.759706e-11                  -0.008216  2.012564         1.675043
# 8          8.598655e-09                  -0.027475  1.275518         1.183679
# 9          3.716213e-11                   0.000962  3.456508         2.637672
# 10         3.815894e-09                  -0.009161  0.858046         0.905364
# 11         8.797358e-11                  -0.034055  1.471829         1.314553
#
#     Residual Variance 3  Portfolio Excess Return 4    Beta 4  Adjusted Beta 4  \
# 0          1.154539e-10                   0.018034  1.810403         1.540269
# 1          7.354932e-08                   0.006734  2.111801         1.741200
# 2          1.184155e-08                   0.017197  0.995866         0.997244
# 3          1.740935e-08                   0.010943  0.578274         0.718849
# 4          4.006124e-09                   0.024168  1.093778         1.062519
# 5          1.756124e-10                  -0.025420  1.006020         1.004013
# 6          5.127803e-05                   0.005668  1.104081         1.069387
# 7          2.941352e-08                  -0.010110  0.917124         0.944750
# 8          8.184289e-08                  -0.018446  1.184586         1.123057
# 9          5.107860e-08                   0.013742  1.388426         1.258950
# 10         1.705527e-08                  -0.002878  0.886870         0.924580
# 11         4.731679e-10                  -0.034167  0.618498         0.745665
#
#     Residual Variance 4
# 0          2.302260e-09
# 1          4.411538e-12
# 2          8.958874e-09
# 3          2.353957e-08
# 4          3.307059e-10
# 5          3.386782e-09
# 6          1.792733e-09
# 7          1.631701e-09
# 8          5.063869e-11
# 9          7.299864e-10
# 10         1.848303e-09
# 11         1.120875e-08

# %%
# Assuming your DataFrame is named df
new_df = merged_df[['Portfolio Excess Return 1', 'Adjusted Beta 1','Beta 1','Residual Variance 1']].copy()  # Selecting columns for Portfolio 1
new_df.columns = ['Portfolio Excess Return', 'Adjusted Beta','Beta','Residual Variance']  # Renaming columns

# Concatenating data for other portfolios
for i in range(2, 5):
    temp_df = merged_df[['Portfolio Excess Return {}'.format(i), 'Adjusted Beta {}'.format(i), 'Beta {}'.format(i), 'Residual Variance {}'.format(i) ]].copy()
    temp_df.columns = ['Portfolio Excess Return', 'Adjusted Beta','Beta', 'Residual Variance']
    new_df = pd.concat([new_df, temp_df], ignore_index=True)

new_df
# Out:
#     Portfolio Excess Return  Adjusted Beta      Beta  Residual Variance
# 0                 -0.017935      -0.073502 -0.610253       5.042118e-10
# 1                  0.000339      -0.249518 -0.874277       8.080077e-10
# 2                  0.018195       0.722444  0.583665       1.096980e-07
# 3                  0.014455       0.947329  0.920994       2.984674e-08
# 4                  0.006919       1.085551  1.128327       4.380045e-09
# 5                 -0.005020       1.079376  1.119065       3.340631e-09
# 6                  0.019193       0.642621  0.463931       3.199205e-09
# 7                 -0.013708       0.634558  0.451837       2.552072e-08
# 8                 -0.034444       0.719619  0.579429       5.234694e-08
# 9                  0.005697       1.407959  1.611939       2.509249e-09
# 10                -0.008748       1.100750  1.151125       2.182209e-08
# 11                -0.037995       0.861337  0.792006       1.158575e-08
# 12                -0.012310       0.872106  0.808159       1.165918e-10
# 13                 0.007648       0.270161 -0.094758       2.325526e-10
# 14                 0.010143       0.940752  0.911127       2.275933e-07
# 15                 0.013845       1.014118  1.021176       1.393538e-09
# 16                 0.003557       1.128808  1.193212       1.427283e-09
# 17                -0.017150       1.181627  1.272440       1.743523e-10
# 18                 0.012328       0.924618  0.886927       1.719595e-08
# 19                -0.015247       1.297736  1.446604       4.759706e-11
# 20                -0.026538       0.728805  0.593208       8.598655e-09
# 21                 0.003560       1.176853  1.265279       3.716213e-11
# 22                -0.005218       1.234396  1.351594       3.815894e-09
# 23                -0.036148       0.931394  0.897091       8.797358e-11
# 24                 0.012543       1.416185  1.624277       1.154539e-10
# 25                -0.011750       1.214630  1.321946       7.354932e-08
# 26                 0.013883       1.145389  1.218083       1.184155e-08
# 27                 0.003874       1.054904  1.082356       1.740935e-08
# 28                 0.020647       0.874955  0.812432       4.006124e-09
# 29                -0.034518       0.678070  0.517105       1.756124e-10
# 30                 0.001368       1.066778  1.100167       5.127803e-05
# 31                -0.008216       1.675043  2.012564       2.941352e-08
# 32                -0.027475       1.183679  1.275518       8.184289e-08
# 33                 0.000962       2.637672  3.456508       5.107860e-08
# 34                -0.009161       0.905364  0.858046       1.705527e-08
# 35                -0.034055       1.314553  1.471829       4.731679e-10
# 36                 0.018034       1.540269  1.810403       2.302260e-09
# 37                 0.006734       1.741200  2.111801       4.411538e-12
# 38                 0.017197       0.997244  0.995866       8.958874e-09
# 39                 0.010943       0.718849  0.578274       2.353957e-08
# 40                 0.024168       1.062519  1.093778       3.307059e-10
# 41                -0.025420       1.004013  1.006020       3.386782e-09
# 42                 0.005668       1.069387  1.104081       1.792733e-09
# 43                -0.010110       0.944750  0.917124       1.631701e-09
# 44                -0.018446       1.123057  1.184586       5.063869e-11
# 45                 0.013742       1.258950  1.388426       7.299864e-10
# 46                -0.002878       0.924580  0.886870       1.848303e-09
# 47                -0.034167       0.745665  0.618498       1.120875e-08

# %%
# Normalize residual variance
residual_variance_mean = new_df['Residual Variance'].mean()
residual_variance_std = new_df['Residual Variance'].std()
normalized_residual_variance = (new_df['Residual Variance'] - residual_variance_mean) / residual_variance_std

# Replace the original column with the normalized values
new_df['Normalized Residual Variance'] = normalized_residual_variance

# %%
merged_df.columns
# Out:
# Index(['Month', 'Portfolio Excess Return 1', 'Beta 1', 'Adjusted Beta 1',
#        'Residual Variance 1', 'Portfolio Excess Return 2', 'Beta 2',
#        'Adjusted Beta 2', 'Residual Variance 2', 'Portfolio Excess Return 3',
#        'Beta 3', 'Adjusted Beta 3', 'Residual Variance 3',
#        'Portfolio Excess Return 4', 'Beta 4', 'Adjusted Beta 4',
#        'Residual Variance 4'],
#       dtype='object')

# %%
new_df.head()
# Out:
#    Portfolio Excess Return  Adjusted Beta      Beta  Residual Variance  \
# 0                -0.017935      -0.073502 -0.610253       5.042118e-10
# 1                 0.000339      -0.249518 -0.874277       8.080077e-10
# 2                 0.018195       0.722444  0.583665       1.096980e-07
# 3                 0.014455       0.947329  0.920994       2.984674e-08
# 4                 0.006919       1.085551  1.128327       4.380045e-09
#
#    Normalized Residual Variance
# 0                     -0.146767
# 1                     -0.146725
# 2                     -0.132008
# 3                     -0.142801
# 4                     -0.146243

# %% [markdown]
# # SML #

# %%
import statsmodels.api as sm
import pandas as pd

x = new_df['Adjusted Beta'].values # Monthly  est. Adj Beta 2022

y = new_df['Portfolio Excess Return'].values # Monthly Portfolio excess return
    
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
inter = results.params[0]
risk_premium = results.params[1]  # Coefficient
p_value_1 = results.pvalues[1]  # P-value
p_value_2 = results.pvalues[0]
std_error_1 = results.bse[1]  # Standard error
std_error_2 = results.bse[0]
t_stat_x1 = results.tvalues[1]
t_stat_const = results.tvalues[0]

# Print the retrieved values
print("Intercept:", inter)
print("Risk premium (Coefficient):", risk_premium)
print("P-value x1:", p_value_1)
print("P-value const:", p_value_2)
print("Std. error x1:", std_error_1)
print("Std. error const :", std_error_2)
print("T-statistic for X1:", t_stat_x1)
print("T-statistic for const:", t_stat_const)
# Out:
# (48, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.016
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.7621
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.387
# Time:                        11:08:58   Log-Likelihood:                 126.25
# No. Observations:                  48   AIC:                            -248.5
# Df Residuals:                      46   BIC:                            -244.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0091      0.007     -1.376      0.176      -0.022       0.004
# x1             0.0052      0.006      0.873      0.387      -0.007       0.017
# ==============================================================================
# Omnibus:                        5.481   Durbin-Watson:                   1.987
# Prob(Omnibus):                  0.065   Jarque-Bera (JB):                2.945
# Skew:                          -0.375   Prob(JB):                        0.229
# Kurtosis:                       2.046   Cond. No.                         4.95
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept: -0.009073515776283694
# Risk premium (Coefficient): 0.005207084402758777
# P-value x1: 0.38722141279936084
# P-value const: 0.17558915532666267
# Std. error x1: 0.0059648888451625465
# Std. error const : 0.006595759640573974
# T-statistic for X1: 0.8729558149238036
# T-statistic for const: -1.3756589491933187

# %% [markdown]
# # NON-Linearity #

# %%
import statsmodels.api as sm
import pandas as pd

# Assuming new_df contains the required data

# Calculate adjusted beta squared
raw_beta_sqr = new_df['Beta'].values ** 2
adjusted_beta_sqr = 0.67 * raw_beta_sqr + 0.33 * 1.0

# Prepare the data
x = new_df['Adjusted Beta'].values
x_squared = adjusted_beta_sqr
y = new_df['Portfolio Excess Return'].values

# Prepare the independent variables matrix
X = sm.add_constant(pd.DataFrame({'Adjusted Beta': x, 'Adjusted Beta Squared': x_squared}))

# Fit the nonlinear OLS model
model = sm.OLS(y, X)
results = model.fit()

# Print the summary of results
print(results.summary())

# Retrieve specific values from the model summary
intercept = results.params[0]
gamma1 = results.params[1]  # Coefficient for adjusted beta
gamma2 = results.params[2]  # Coefficient for adjusted beta squared
p_value_int = results.pvalues[0]
p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
std_error_int = results.bse[0] 
std_error_gamma1 = results.bse[1]  # Standard error for gamma1
std_error_gamma2 = results.bse[2]  # Standard error for gamma2
t_stat_int = results.tvalues[0]
t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2

# Print the retrieved values
print("Intercept:", intercept)
print("Coefficient for adjusted beta (γ1):", gamma1)
print("Coefficient for adjusted beta squared (γ2):", gamma2)
print("Std. error for intercept:", std_error_int)
print("Std. error for γ1:", std_error_gamma1)
print("Std. error for γ2:", std_error_gamma2)
print("T-statistic for intercept:", t_stat_int)
print("T-statistic for γ1:", t_stat_gamma1)
print("T-statistic for γ2:", t_stat_gamma2)
print("P-value for intercept:", p_value_int)
print("P-value for γ1:", p_value_gamma1)
print("P-value for γ2:", p_value_gamma2)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                 -0.027
# Method:                 Least Squares   F-statistic:                    0.3789
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.687
# Time:                        11:08:58   Log-Likelihood:                 126.25
# No. Observations:                  48   AIC:                            -246.5
# Df Residuals:                      45   BIC:                            -240.9
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.0087      0.008     -1.132      0.264      -0.024       0.007
# Adjusted Beta             0.0043      0.010      0.408      0.686      -0.017       0.025
# Adjusted Beta Squared     0.0004      0.004      0.110      0.913      -0.007       0.008
# ==============================================================================
# Omnibus:                        5.530   Durbin-Watson:                   1.985
# Prob(Omnibus):                  0.063   Jarque-Bera (JB):                2.915
# Skew:                          -0.366   Prob(JB):                        0.233
# Kurtosis:                       2.040   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept: -0.008660726231434601
# Coefficient for adjusted beta (γ1): 0.004265714278090856
# Coefficient for adjusted beta squared (γ2): 0.0004143052787143745
# Std. error for intercept: 0.007650502898710516
# Std. error for γ1: 0.01046622948118234
# Std. error for γ2: 0.003764954755919193
# T-statistic for intercept: -1.1320466570758843
# T-statistic for γ1: 0.4075693434546183
# T-statistic for γ2: 0.11004256507014097
# P-value for intercept: 0.26361124729162183
# P-value for γ1: 0.6855223973988853
# P-value for γ2: 0.9128649176066856
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:26: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept = results.params[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma1 = results.params[1]  # Coefficient for adjusted beta
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma2 = results.params[2]  # Coefficient for adjusted beta squared
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_int = results.pvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_int = results.bse[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma1 = results.bse[1]  # Standard error for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma2 = results.bse[2]  # Standard error for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_int = results.tvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/2626776032.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2

# %% [markdown]
# # Non-systematic risk

# %%
import statsmodels.api as sm
import pandas as pd

# Assuming new_df contains the required data

# Calculate adjusted beta squared
raw_beta_sqr = new_df['Beta'].values ** 2
adjusted_beta_sqr = 0.67 * raw_beta_sqr + 0.33 * 1.0

# Prepare the data
x = new_df['Adjusted Beta'].values
x_squared = adjusted_beta_sqr
residual_variance = new_df['Normalized Residual Variance'].values
y = new_df['Portfolio Excess Return'].values

# Prepare the independent variables matrix
X = sm.add_constant(pd.DataFrame({'Adjusted Beta': x, 'Adjusted Beta Squared': x_squared, 'Residual Variance': residual_variance}))

# Fit the nonlinear OLS model
model = sm.OLS(y, X)
results = model.fit()

# Print the summary of results
print(results.summary())

# Retrieve specific values from the model summary
intercept = results.params[0]
gamma1 = results.params[1]  # Coefficient for adjusted beta
gamma2 = results.params[2]  # Coefficient for adjusted beta squared
gamma3 = results.params[3]  # Coefficient for residual variance
p_value_int = results.pvalues[0]
p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
p_value_gamma3 = results.pvalues[3]  # P-value for gamma3
std_error_int = results.bse[0] 
std_error_gamma1 = results.bse[1]  # Standard error for gamma1
std_error_gamma2 = results.bse[2]  # Standard error for gamma2
std_error_gamma3 = results.bse[3]  # Standard error for gamma3
t_stat_int = results.tvalues[0]
t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2
t_stat_gamma3 = results.tvalues[3]  # T-statistic for gamma3

# Function to round the values
def round_to_six_decimals(value):
    return round(value, 6)

# Print the retrieved values rounded to the sixth decimal point
print("Intercept:", round_to_six_decimals(intercept))
print("Coefficient for adjusted beta (γ1):", round_to_six_decimals(gamma1))
print("Coefficient for adjusted beta squared (γ2):", round_to_six_decimals(gamma2))
print("Coefficient for residual variance (γ3):", round_to_six_decimals(gamma3))
print("Std. error for intercept:", round_to_six_decimals(std_error_int))
print("Std. error for γ1:", round_to_six_decimals(std_error_gamma1))
print("Std. error for γ2:", round_to_six_decimals(std_error_gamma2))
print("Std. error for γ3:", round_to_six_decimals(std_error_gamma3))
print("T-statistic for intercept:", round_to_six_decimals(t_stat_int))
print("T-statistic for γ1:", round_to_six_decimals(t_stat_gamma1))
print("T-statistic for γ2:", round_to_six_decimals(t_stat_gamma2))
print("T-statistic for γ3:", round_to_six_decimals(t_stat_gamma3))
print("P-value for intercept:", round_to_six_decimals(p_value_int))
print("P-value for γ1:", round_to_six_decimals(p_value_gamma1))
print("P-value for γ2:", round_to_six_decimals(p_value_gamma2))
print("P-value for γ3:", round_to_six_decimals(p_value_gamma3))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                 -0.049
# Method:                 Least Squares   F-statistic:                    0.2737
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.844
# Time:                        11:08:58   Log-Likelihood:                 126.29
# No. Observations:                  48   AIC:                            -244.6
# Df Residuals:                      44   BIC:                            -237.1
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.0086      0.008     -1.107      0.274      -0.024       0.007
# Adjusted Beta             0.0041      0.011      0.386      0.701      -0.017       0.025
# Adjusted Beta Squared     0.0005      0.004      0.126      0.901      -0.007       0.008
# Residual Variance         0.0007      0.003      0.281      0.780      -0.005       0.006
# ==============================================================================
# Omnibus:                        5.456   Durbin-Watson:                   1.958
# Prob(Omnibus):                  0.065   Jarque-Bera (JB):                2.822
# Skew:                          -0.348   Prob(JB):                        0.244
# Kurtosis:                       2.037   Cond. No.                         11.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept: -0.008567
# Coefficient for adjusted beta (γ1): 0.00409
# Coefficient for adjusted beta squared (γ2): 0.000479
# Coefficient for residual variance (γ3): 0.000747
# Std. error for intercept: 0.007737
# Std. error for γ1: 0.010594
# Std. error for γ2: 0.003811
# Std. error for γ3: 0.002659
# T-statistic for intercept: -1.107264
# T-statistic for γ1: 0.386092
# T-statistic for γ2: 0.125695
# T-statistic for γ3: 0.280726
# P-value for intercept: 0.274196
# P-value for γ1: 0.701289
# P-value for γ2: 0.900546
# P-value for γ3: 0.780236
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept = results.params[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma1 = results.params[1]  # Coefficient for adjusted beta
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma2 = results.params[2]  # Coefficient for adjusted beta squared
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma3 = results.params[3]  # Coefficient for residual variance
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_int = results.pvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma3 = results.pvalues[3]  # P-value for gamma3
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_int = results.bse[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma1 = results.bse[1]  # Standard error for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma2 = results.bse[2]  # Standard error for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma3 = results.bse[3]  # Standard error for gamma3
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_int = results.tvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30966/3466800342.py:42: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma3 = results.tvalues[3]  # T-statistic for gamma3
