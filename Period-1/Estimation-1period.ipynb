# %%
import pandas as pd

returns = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Returns_2018-2023.csv')

portfolio_1 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/p1-1.csv', usecols=[1])
portfolio_2 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/p2-1.csv', usecols=[1])
portfolio_3 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/p3-1.csv', usecols=[1])
portfolio_4 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/p4-1.csv', usecols=[1])

# %%
# Convert 'Date' column to datetime format
returns['Date'] = pd.to_datetime(returns['Date'])

# Extract year from 'Date' column
returns['Year'] = returns['Date'].dt.year

# Filter DataFrame to include only the data from 2018
returns_2019 = returns[returns['Year'] == 2019].copy()

# Drop the 'Year' column as it's no longer needed
returns_2019.drop(columns='Year', inplace=True)

# %%
returns_2019.drop(columns='Unnamed: 0', inplace=True)

# %%
returns_2019.head()
# Out:
#          Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 51 2019-01-04       0.027710       0.036884            0.024911
# 52 2019-01-11       0.024337      -0.022999            0.095139
# 53 2019-01-18       0.021668      -0.002825            0.024096
# 54 2019-01-25       0.005199      -0.025181           -0.008669
# 55 2019-02-01      -0.011799       0.002583           -0.020612
#
#     Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 51          0.048043              0.005973                    0.005894
# 52          0.031823             -0.033703                    0.032227
# 53         -0.018916             -0.065736                    0.018921
# 54          0.084035              0.031094                   -0.005571
# 55          0.013683             -0.058719                   -0.017740
#
#     Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 51                                   0.014377                     0.032675
# 52                                  -0.006590                    -0.027226
# 53                                  -0.185469                    -0.027988
# 54                                   0.011815                    -0.004669
# 55                                  -0.026975                    -0.100860
#
#     Banco Bpm 2018-2023  ...  Snam 2018-2023  Stellantis 2018-2023  \
# 51             0.048043  ...        0.056821              0.033908
# 52             0.031823  ...        0.016601              0.083891
# 53            -0.018916  ...        0.008043              0.037854
# 54             0.084035  ...       -0.011122             -0.006511
# 55             0.013683  ...       -0.002689              0.028388
#
#     Stmicroeletronics 2018-2023  Telecom 2018-2023  Tenaris 2018-2023  \
# 51                    -0.107522           0.046969           0.044492
# 52                     0.125515          -0.010672           0.045132
# 53                     0.046805          -0.024171           0.033964
# 54                     0.117807          -0.058137           0.035664
# 55                    -0.032348           0.051728          -0.007703
#
#     Terna 2018-2023  Unicredit 2018-2023  Unipol 2018-2023    BOT 3m  \
# 51         0.051484             0.031736          0.047470 -0.004981
# 52         0.017281             0.037618          0.057259 -0.004404
# 53         0.007173             0.007175          0.010010 -0.004558
# 54        -0.003373             0.031309          0.047268 -0.004615
# 55        -0.015043            -0.108162         -0.030575 -0.003423
#
#     Risk Premium
# 51      0.032691
# 52      0.028740
# 53      0.026225
# 54      0.009814
# 55     -0.008376
#
# [5 rows x 42 columns]

# %%
returns_2019.columns = returns_2019.columns.str.replace('2018-2023', '')

# %%
import numpy as np

# Copy the 2018 data to avoid modifying the original DataFrame
returns_2019_excess = returns_2019.copy()

# Calculate excess returns for each stock by subtracting the risk-free rate
risk_free_rate = returns_2019_excess['BOT 3m'].values  # Convert Series to NumPy array
returns_2019_excess.iloc[:, 2:-2] -= risk_free_rate[:, np.newaxis]

# Set 'Date' column as the index
returns_2019_excess.set_index('Date', inplace=True)

# Display the DataFrame with 'Date' as the index
returns_2019_excess.head()
# Out:
#             FTSEMIB Index      A2A   Amplifon    Azimut   BPER banca   \
# Date
# 2019-01-04       0.027710  0.041865   0.029892  0.053023     0.010954
# 2019-01-11       0.024337 -0.018595   0.099543  0.036227    -0.029299
# 2019-01-18       0.021668  0.001733   0.028654 -0.014358    -0.061178
# 2019-01-25       0.005199 -0.020566  -0.004053  0.088651     0.035710
# 2019-02-01      -0.011799  0.006006  -0.017189  0.017106    -0.055296
#
#             Banca Mediolanum   Banca Monte dei Paschi di Siena   \
# Date
# 2019-01-04           0.010875                          0.019357
# 2019-01-11           0.036630                         -0.002186
# 2019-01-18           0.023479                         -0.180912
# 2019-01-25          -0.000956                          0.016431
# 2019-02-01          -0.014317                         -0.023552
#
#             Banca pop Sondrio   Banco Bpm   Brunello cucinelli   ...  \
# Date                                                             ...
# 2019-01-04            0.037656    0.053023             0.018292  ...
# 2019-01-11           -0.022822    0.036227            -0.085908  ...
# 2019-01-18           -0.023430   -0.014358             0.055099  ...
# 2019-01-25           -0.000054    0.088651             0.054444  ...
# 2019-02-01           -0.097437    0.017106             0.042703  ...
#
#                Snam   Stellantis   Stmicroeletronics   Telecom   Tenaris   \
# Date
# 2019-01-04  0.061802     0.038889           -0.102542  0.051950  0.049472
# 2019-01-11  0.021004     0.088295            0.129919 -0.006268  0.049536
# 2019-01-18  0.012601     0.042411            0.051363 -0.019613  0.038522
# 2019-01-25 -0.006506    -0.001896            0.122423 -0.053522  0.040279
# 2019-02-01  0.000734     0.031811           -0.028925  0.055151 -0.004280
#
#               Terna   Unicredit    Unipol     BOT 3m  Risk Premium
# Date
# 2019-01-04  0.056465    0.036717  0.052451 -0.004981      0.032691
# 2019-01-11  0.021685    0.042021  0.061663 -0.004404      0.028740
# 2019-01-18  0.011730    0.011733  0.014568 -0.004558      0.026225
# 2019-01-25  0.001242    0.035924  0.051883 -0.004615      0.009814
# 2019-02-01 -0.011620   -0.104739 -0.027152 -0.003423     -0.008376
#
# [5 rows x 41 columns]

# %%
portfolio_1
# Out:
#                  Stock
# 0           Recordati
# 1  Brunello cucinelli
# 2             Campari
# 3              Saipem
# 4             Pirelli
# 5                Hera
# 6               Terna
# 7                 A2A
# 8                Snam
# 9             Italgas

# %%
portfolio_data = {}  # Dictionary to store portfolio data frames

# Iterate over each portfolio
for i in range(1, 5):
    portfolio_name = f"portfolio_{i}"  # Generate portfolio name
    portfolio_stocks = list(eval(portfolio_name)['Stock'])  # Extract stock names for current portfolio
    portfolio_data[portfolio_name] = returns_2019_excess[portfolio_stocks]  # Create data frame for current portfolio

# portfolio_data dictionary will contain data frames for each portfolio, e.g., portfolio_data['portfolio_1']

# %%
p_1 = portfolio_data['portfolio_1']
p_2 = portfolio_data['portfolio_2']
p_3 = portfolio_data['portfolio_3']
p_4 = portfolio_data['portfolio_4']

# %%
p_1.head()
# Out:
#             Recordati   Brunello cucinelli   Campari    Saipem   Pirelli   \
# Date
# 2019-01-04   -0.000632             0.018292  0.063884  0.092879  0.019598
# 2019-01-11   -0.006220            -0.085908 -0.004548  0.066616  0.069056
# 2019-01-18    0.041806             0.055099  0.034880  0.068966  0.003238
# 2019-01-25   -0.026766             0.054444 -0.019805 -0.007834  0.003294
# 2019-02-01    0.051519             0.042703  0.009200  0.036199 -0.053824
#
#                Hera     Terna       A2A      Snam   Italgas
# Date
# 2019-01-04  0.068091  0.056465  0.041865  0.061802  0.038207
# 2019-01-11  0.010764  0.021685 -0.018595  0.021004  0.020677
# 2019-01-18  0.003855  0.011730  0.001733  0.012601  0.006083
# 2019-01-25  0.007426  0.001242 -0.020566 -0.006506  0.003854
# 2019-02-01  0.041265 -0.011620  0.006006  0.000734 -0.007244

# %%
p_2.head()
# Out:
#             Amplifon   Moncler       Erg       Eni   Tenaris      Enel   \
# Date
# 2019-01-04   0.029892  0.008092  0.035284  0.048042  0.049472  0.027185
# 2019-01-11   0.099543  0.054714  0.008521 -0.007451  0.049536  0.012938
# 2019-01-18   0.028654 -0.000035  0.043222  0.035468  0.038522  0.025327
# 2019-01-25  -0.004053  0.014833 -0.021893  0.002151  0.040279 -0.017238
# 2019-02-01  -0.017189  0.098040 -0.014538  0.017148 -0.004280 -0.000814
#
#             Interpump   Diasorin   Generali Ass
# Date
# 2019-01-04    0.043442   0.062265       0.013885
# 2019-01-11    0.028848   0.006411       0.016963
# 2019-01-18    0.027696   0.077321       0.035064
# 2019-01-25    0.006029   0.005238       0.010146
# 2019-02-01   -0.009280   0.024567      -0.014371

# %%
p_3.head()
# Out:
#             Banca Mediolanum     Inwit    Azimut   Banco Bpm   Ferrari   \
# Date
# 2019-01-04           0.010875  0.050245  0.053023    0.053023  0.035172
# 2019-01-11           0.036630  0.026858  0.036227    0.036227  0.086730
# 2019-01-18           0.023479  0.019460 -0.014358   -0.014358  0.032875
# 2019-01-25          -0.000956  0.021617  0.088651    0.088651 -0.010661
# 2019-02-01          -0.014317  0.049776  0.017106    0.017106  0.132225
#
#             BPER banca   Banca pop Sondrio    Unipol   Poste Italiane
# Date
# 2019-01-04     0.010954            0.037656  0.052451         0.019299
# 2019-01-11    -0.029299           -0.022822  0.061663         0.023320
# 2019-01-18    -0.061178           -0.023430  0.014568         0.055541
# 2019-01-25     0.035710           -0.000054  0.051883         0.018588
# 2019-02-01    -0.055296           -0.097437 -0.027152        -0.041299

# %%
p_4.head()
# Out:
#             Prysmian   Mediobanca   Leonardo   Stellantis    Fineco   \
# Date
# 2019-01-04   0.019800     0.053245   0.022954     0.038889  0.024575
# 2019-01-11   0.067780     0.007249   0.021548     0.088295  0.048203
# 2019-01-18   0.027079     0.020549  -0.002486     0.042411  0.064502
# 2019-01-25   0.010793     0.017055   0.050220    -0.001896 -0.000636
# 2019-02-01   0.016237    -0.071301   0.039042     0.031811 -0.046120
#
#             Stmicroeletronics   Banca Monte dei Paschi di Siena   Unicredit   \
# Date
# 2019-01-04           -0.102542                          0.019357    0.036717
# 2019-01-11            0.129919                         -0.002186    0.042021
# 2019-01-18            0.051363                         -0.180912    0.011733
# 2019-01-25            0.122423                          0.016431    0.035924
# 2019-02-01           -0.028925                         -0.023552   -0.104739
#
#             Telecom   Intesa San Paolo
# Date
# 2019-01-04  0.051950           0.035602
# 2019-01-11 -0.006268           0.010306
# 2019-01-18 -0.019613           0.018232
# 2019-01-25 -0.053522           0.017370
# 2019-02-01  0.055151          -0.045935

# %%
p_1.to_csv('ret_p1-1.csv')
p_2.to_csv('ret_p2-1.csv')
p_3.to_csv('ret_p3-1.csv')
p_4.to_csv('ret_p4-1.csv')

# %%
p_1.head()
# Out:
#             Recordati   Brunello cucinelli   Campari    Saipem   Pirelli   \
# Date
# 2019-01-04   -0.000632             0.018292  0.063884  0.092879  0.019598
# 2019-01-11   -0.006220            -0.085908 -0.004548  0.066616  0.069056
# 2019-01-18    0.041806             0.055099  0.034880  0.068966  0.003238
# 2019-01-25   -0.026766             0.054444 -0.019805 -0.007834  0.003294
# 2019-02-01    0.051519             0.042703  0.009200  0.036199 -0.053824
#
#                Hera     Terna       A2A      Snam   Italgas
# Date
# 2019-01-04  0.068091  0.056465  0.041865  0.061802  0.038207
# 2019-01-11  0.010764  0.021685 -0.018595  0.021004  0.020677
# 2019-01-18  0.003855  0.011730  0.001733  0.012601  0.006083
# 2019-01-25  0.007426  0.001242 -0.020566 -0.006506  0.003854
# 2019-02-01  0.041265 -0.011620  0.006006  0.000734 -0.007244

# %%
p_1.mean(axis=1).head()
# Out:
# Date
# 2019-01-04    0.046045
# 2019-01-11    0.009453
# 2019-01-18    0.023999
# 2019-01-25   -0.001122
# 2019-02-01    0.011494
# dtype: float64

# %%
p_1.loc[:, 'Portfolio Excess Return'] = p_1.mean(axis=1)
# Out:
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_24286/2664584591.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_1.loc[:, 'Portfolio Excess Return'] = p_1.mean(axis=1)

# %%
p_1.head()
# Out:
#             Recordati   Brunello cucinelli   Campari    Saipem   Pirelli   \
# Date
# 2019-01-04   -0.000632             0.018292  0.063884  0.092879  0.019598
# 2019-01-11   -0.006220            -0.085908 -0.004548  0.066616  0.069056
# 2019-01-18    0.041806             0.055099  0.034880  0.068966  0.003238
# 2019-01-25   -0.026766             0.054444 -0.019805 -0.007834  0.003294
# 2019-02-01    0.051519             0.042703  0.009200  0.036199 -0.053824
#
#                Hera     Terna       A2A      Snam   Italgas   \
# Date
# 2019-01-04  0.068091  0.056465  0.041865  0.061802  0.038207
# 2019-01-11  0.010764  0.021685 -0.018595  0.021004  0.020677
# 2019-01-18  0.003855  0.011730  0.001733  0.012601  0.006083
# 2019-01-25  0.007426  0.001242 -0.020566 -0.006506  0.003854
# 2019-02-01  0.041265 -0.011620  0.006006  0.000734 -0.007244
#
#             Portfolio Excess Return
# Date
# 2019-01-04                 0.046045
# 2019-01-11                 0.009453
# 2019-01-18                 0.023999
# 2019-01-25                -0.001122
# 2019-02-01                 0.011494

# %%
p_1.shape
# Out:
# (52, 11)

# %%
p_1.loc['2019-01-04'].values
# Out:
# array([-0.00063164,  0.01829192,  0.06388395,  0.09287945,  0.01959753,
#         0.06809121,  0.05646472,  0.04186471,  0.06180193,  0.03820735,
#         0.04604511])

# %%
p_1.loc['2019-01-04'].values.mean()
# Out:
# 0.046045111858707105

# %%
p_1.index
# Out:
# DatetimeIndex(['2019-01-04', '2019-01-11', '2019-01-18', '2019-01-25',
#                '2019-02-01', '2019-02-08', '2019-02-15', '2019-02-22',
#                '2019-03-01', '2019-03-08', '2019-03-15', '2019-03-22',
#                '2019-03-29', '2019-04-05', '2019-04-12', '2019-04-19',
#                '2019-04-26', '2019-05-03', '2019-05-10', '2019-05-17',
#                '2019-05-24', '2019-05-31', '2019-06-07', '2019-06-14',
#                '2019-06-21', '2019-06-28', '2019-07-05', '2019-07-12',
#                '2019-07-19', '2019-07-26', '2019-08-02', '2019-08-09',
#                '2019-08-16', '2019-08-23', '2019-08-30', '2019-09-06',
#                '2019-09-13', '2019-09-20', '2019-09-27', '2019-10-04',
#                '2019-10-11', '2019-10-18', '2019-10-25', '2019-11-01',
#                '2019-11-08', '2019-11-15', '2019-11-22', '2019-11-29',
#                '2019-12-06', '2019-12-13', '2019-12-20', '2019-12-27'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
returns_2019.head()
# Out:
#          Date  FTSEMIB Index      A2A   Amplifon    Azimut   BPER banca   \
# 51 2019-01-04       0.027710  0.036884   0.024911  0.048043     0.005973
# 52 2019-01-11       0.024337 -0.022999   0.095139  0.031823    -0.033703
# 53 2019-01-18       0.021668 -0.002825   0.024096 -0.018916    -0.065736
# 54 2019-01-25       0.005199 -0.025181  -0.008669  0.084035     0.031094
# 55 2019-02-01      -0.011799  0.002583  -0.020612  0.013683    -0.058719
#
#     Banca Mediolanum   Banca Monte dei Paschi di Siena   Banca pop Sondrio   \
# 51           0.005894                          0.014377            0.032675
# 52           0.032227                         -0.006590           -0.027226
# 53           0.018921                         -0.185469           -0.027988
# 54          -0.005571                          0.011815           -0.004669
# 55          -0.017740                         -0.026975           -0.100860
#
#     Banco Bpm   ...     Snam   Stellantis   Stmicroeletronics   Telecom   \
# 51    0.048043  ...  0.056821     0.033908           -0.107522  0.046969
# 52    0.031823  ...  0.016601     0.083891            0.125515 -0.010672
# 53   -0.018916  ...  0.008043     0.037854            0.046805 -0.024171
# 54    0.084035  ... -0.011122    -0.006511            0.117807 -0.058137
# 55    0.013683  ... -0.002689     0.028388           -0.032348  0.051728
#
#     Tenaris     Terna   Unicredit    Unipol     BOT 3m  Risk Premium
# 51  0.044492  0.051484    0.031736  0.047470 -0.004981      0.032691
# 52  0.045132  0.017281    0.037618  0.057259 -0.004404      0.028740
# 53  0.033964  0.007173    0.007175  0.010010 -0.004558      0.026225
# 54  0.035664 -0.003373    0.031309  0.047268 -0.004615      0.009814
# 55 -0.007703 -0.015043   -0.108162 -0.030575 -0.003423     -0.008376
#
# [5 rows x 42 columns]

# %%
returns_2019 = returns_2019.set_index('Date')

# %%
returns_2019['Risk Premium'].head()
# Out:
# Date
# 2019-01-04    0.032691
# 2019-01-11    0.028740
# 2019-01-18    0.026225
# 2019-01-25    0.009814
# 2019-02-01   -0.008376
# Name: Risk Premium, dtype: float64

# %%
returns_2019.loc['2019-01-04','Risk Premium']
# Out:
# 0.0326908308274815

# %% [markdown]
# # P1 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_1.index:
    # Extract market excess return for the date
    x = returns_2019.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_1.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2019-01-04              0.032691                 0.046045
# 2019-01-11              0.028740                 0.009453
# 2019-01-18              0.026225                 0.023999
# 2019-01-25              0.009814                -0.001122
# 2019-02-01             -0.008376                 0.011494

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.019593874962643705
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.620
# Model:                                 OLS   Adj. R-squared:                  0.431
# Method:                      Least Squares   F-statistic:                     3.269
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.212
# Time:                             08:32:22   Log-Likelihood:                 12.402
# No. Observations:                        4   AIC:                            -20.80
# Df Residuals:                            2   BIC:                            -22.03
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0194      0.023     -0.846      0.486      -0.118       0.079
# Market Excess Return     1.5988      0.884      1.808      0.212      -2.206       5.403
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.659
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.334
# Skew:                          -0.529   Prob(JB):                        0.846
# Kurtosis:                       2.059   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.015667784479285952
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.886
# Model:                                 OLS   Adj. R-squared:                  0.828
# Method:                      Least Squares   F-statistic:                     15.47
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0590
# Time:                             08:32:22   Log-Likelihood:                 14.522
# No. Observations:                        4   AIC:                            -25.04
# Df Residuals:                            2   BIC:                            -26.27
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0082      0.005      1.672      0.237      -0.013       0.029
# Market Excess Return     0.7564      0.192      3.933      0.059      -0.071       1.584
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.921
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.423
# Skew:                           0.441   Prob(JB):                        0.809
# Kurtosis:                       1.674   Cond. No.                         42.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.011937180763855434
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.032
# Model:                                 OLS   Adj. R-squared:                 -0.291
# Method:                      Least Squares   F-statistic:                   0.09908
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.774
# Time:                             08:32:22   Log-Likelihood:                 21.029
# No. Observations:                        5   AIC:                            -38.06
# Df Residuals:                            3   BIC:                            -38.84
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0112      0.003      3.645      0.036       0.001       0.021
# Market Excess Return     0.0481      0.153      0.315      0.774      -0.439       0.535
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.399
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.595
# Skew:                           0.163   Prob(JB):                        0.743
# Kurtosis:                       1.341   Cond. No.                         73.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.005238160190503499
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.093
# Model:                                 OLS   Adj. R-squared:                 -0.360
# Method:                      Least Squares   F-statistic:                    0.2056
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.695
# Time:                             08:32:22   Log-Likelihood:                 11.815
# No. Observations:                        4   AIC:                            -19.63
# Df Residuals:                            2   BIC:                            -20.86
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0019      0.012      0.159      0.888      -0.048       0.052
# Market Excess Return     0.3595      0.793      0.453      0.695      -3.052       3.771
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.073
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.550
# Skew:                          -0.128   Prob(JB):                        0.760
# Kurtosis:                       1.202   Cond. No.                         88.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.004322806740053935
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.495
# Model:                                 OLS   Adj. R-squared:                  0.327
# Method:                      Least Squares   F-statistic:                     2.944
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.185
# Time:                             08:32:22   Log-Likelihood:                 14.634
# No. Observations:                        5   AIC:                            -25.27
# Df Residuals:                            3   BIC:                            -26.05
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0040      0.009      0.450      0.683      -0.024       0.032
# Market Excess Return     0.6273      0.366      1.716      0.185      -0.536       1.791
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.441
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.641
# Skew:                          -0.181   Prob(JB):                        0.726
# Kurtosis:                       1.283   Cond. No.                         48.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.013042388062724062
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.939
# Model:                                 OLS   Adj. R-squared:                  0.909
# Method:                      Least Squares   F-statistic:                     30.93
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0308
# Time:                             08:32:22   Log-Likelihood:                 13.840
# No. Observations:                        4   AIC:                            -23.68
# Df Residuals:                            2   BIC:                            -24.91
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0256      0.009     -2.915      0.100      -0.063       0.012
# Market Excess Return     1.6971      0.305      5.562      0.031       0.384       3.010
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.280
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.381
# Skew:                           0.601   Prob(JB):                        0.826
# Kurtosis:                       2.082   Cond. No.                         56.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014134452151137691
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.826
# Model:                                 OLS   Adj. R-squared:                  0.739
# Method:                      Least Squares   F-statistic:                     9.497
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0911
# Time:                             08:32:22   Log-Likelihood:                 12.949
# No. Observations:                        4   AIC:                            -21.90
# Df Residuals:                            2   BIC:                            -23.13
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0016      0.008      0.197      0.862      -0.032       0.035
# Market Excess Return     0.9732      0.316      3.082      0.091      -0.386       2.332
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.172
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.488
# Skew:                           0.236   Prob(JB):                        0.783
# Kurtosis:                       1.355   Cond. No.                         47.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0023576645591372796
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.866
# Model:                                 OLS   Adj. R-squared:                  0.822
# Method:                      Least Squares   F-statistic:                     19.47
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0216
# Time:                             08:32:22   Log-Likelihood:                 16.273
# No. Observations:                        5   AIC:                            -28.55
# Df Residuals:                            3   BIC:                            -29.33
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0012      0.005      0.220      0.840      -0.016       0.018
# Market Excess Return     0.8004      0.181      4.412      0.022       0.223       1.378
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.426
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.484
# Skew:                           0.651   Prob(JB):                        0.785
# Kurtosis:                       2.207   Cond. No.                         33.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.011084635780078652
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.351
# Model:                                 OLS   Adj. R-squared:                  0.027
# Method:                      Least Squares   F-statistic:                     1.082
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.407
# Time:                             08:32:22   Log-Likelihood:                 14.736
# No. Observations:                        4   AIC:                            -25.47
# Df Residuals:                            2   BIC:                            -26.70
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0066      0.006      1.070      0.396      -0.020       0.033
# Market Excess Return     0.3182      0.306      1.040      0.407      -0.998       1.634
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.925
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.399
# Skew:                          -0.148   Prob(JB):                        0.819
# Kurtosis:                       1.482   Cond. No.                         71.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.005274310797890031
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.798
# Model:                                 OLS   Adj. R-squared:                  0.697
# Method:                      Least Squares   F-statistic:                     7.892
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.107
# Time:                             08:32:22   Log-Likelihood:                 16.212
# No. Observations:                        4   AIC:                            -28.42
# Df Residuals:                            2   BIC:                            -29.65
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0003      0.004     -0.083      0.941      -0.016       0.015
# Market Excess Return     0.4074      0.145      2.809      0.107      -0.217       1.031
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.933
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.390
# Skew:                           0.354   Prob(JB):                        0.823
# Kurtosis:                       1.644   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010475290618766259
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.648
# Model:                                 OLS   Adj. R-squared:                  0.531
# Method:                      Least Squares   F-statistic:                     5.528
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.100
# Time:                             08:32:22   Log-Likelihood:                 17.030
# No. Observations:                        5   AIC:                            -30.06
# Df Residuals:                            3   BIC:                            -30.84
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0008      0.006      0.128      0.907      -0.019       0.021
# Market Excess Return     0.7884      0.335      2.351      0.100      -0.279       1.856
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.147
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.719
# Skew:                           0.907   Prob(JB):                        0.698
# Kurtosis:                       2.605   Cond. No.                         72.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.009440573313597371
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.648
# Model:                                 OLS   Adj. R-squared:                  0.471
# Method:                      Least Squares   F-statistic:                     3.674
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.195
# Time:                             08:32:22   Log-Likelihood:                 11.928
# No. Observations:                        4   AIC:                            -19.86
# Df Residuals:                            2   BIC:                            -21.08
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0046      0.011     -0.408      0.723      -0.054       0.044
# Market Excess Return     1.1122      0.580      1.917      0.195      -1.384       3.609
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.591
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.358
# Skew:                           0.110   Prob(JB):                        0.836
# Kurtosis:                       1.551   Cond. No.                         66.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.019594  1.598834       1.399223
# 1     02                 0.015668  0.756360       0.837573
# 2     03                 0.011937  0.048136       0.365424
# 3     04                 0.005238  0.359535       0.573023
# 4     05                -0.004323  0.627280       0.751520
# 5     06                 0.013042  1.697095       1.464730
# 6     07                 0.014134  0.973170       0.982114
# 7     08                 0.002358  0.800410       0.866940
# 8     09                 0.011085  0.318167       0.545445
# 9     10                 0.005274  0.407365       0.604910
# 10    11                 0.010475  0.788434       0.858956
# 11    12                 0.009441  1.112178       1.074785

# %%
coefficients_df.to_csv('coefficients_df_p1_1.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.009156564710768634

# %%
df['Market Excess Return'].values
# Out:
# array([ 0.03269083,  0.02874035,  0.02622529,  0.00981427, -0.00837621,
#        -0.00823657,  0.04928974,  0.00673215,  0.02485961, -0.00551976,
#         0.03357999,  0.00702698,  0.01418402,  0.02604277,  0.00879363,
#         0.00853469, -0.00570692,  0.00613506, -0.03556523,  0.01598434,
#        -0.0293222 , -0.02366643,  0.03368382,  0.01777382,  0.04307896,
#        -0.00342338,  0.04109726,  0.01482162, -0.01886073,  0.01466578,
#        -0.03131236, -0.03002665,  0.005977  ,  0.01482806,  0.04785408,
#         0.03630371,  0.01651169,  0.0032626 ,  0.00090775, -0.01791909,
#         0.03911543,  0.01388434,  0.01961726,  0.02131249,  0.03282292,
#         0.00835645, -0.0078616 ,  0.00678749,  0.00370627,  0.01374718,
#         0.03634627, -0.00319242])

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (52, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.619
# Model:                            OLS   Adj. R-squared:                  0.611
# Method:                 Least Squares   F-statistic:                     81.18
# Date:                Fri, 03 May 2024   Prob (F-statistic):           4.76e-12
# Time:                        08:32:22   Log-Likelihood:                 156.31
# No. Observations:                  52   AIC:                            -308.6
# Df Residuals:                      50   BIC:                            -304.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0013      0.002      0.709      0.482      -0.002       0.005
# x1             0.7301      0.081      9.010      0.000       0.567       0.893
# ==============================================================================
# Omnibus:                        1.051   Durbin-Watson:                   2.516
# Prob(Omnibus):                  0.591   Jarque-Bera (JB):                1.029
# Skew:                          -0.191   Prob(JB):                        0.598
# Kurtosis:                       2.426   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 0.7301374201091438
# P-value: 4.7580757773867875e-12
# Std. error: 0.08103868256203146
# Adj. R-squared: 0.6112076071186286
# F-statistic: 81.17540603620083
# T-statistic for X1: 9.009739509897098

# %% [markdown]
# # P2 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_2.index:
    # Extract market excess return for the date
    x = returns_2019.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_2.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2019-01-04              0.032691                 0.035284
# 2019-01-11              0.028740                 0.030002
# 2019-01-18              0.026225                 0.034582
# 2019-01-25              0.009814                 0.003943
# 2019-02-01             -0.008376                 0.008809

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.025953056155055314
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.927
# Model:                                 OLS   Adj. R-squared:                  0.890
# Method:                      Least Squares   F-statistic:                     25.28
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0373
# Time:                             08:32:22   Log-Likelihood:                 16.963
# No. Observations:                        4   AIC:                            -29.93
# Df Residuals:                            2   BIC:                            -31.15
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0087      0.007     -1.188      0.357      -0.040       0.023
# Market Excess Return     1.4218      0.283      5.028      0.037       0.205       2.638
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.472
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.895
# Skew:                           1.103   Prob(JB):                        0.639
# Kurtosis:                       2.291   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.013453609403402851
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.936
# Model:                                 OLS   Adj. R-squared:                  0.904
# Method:                      Least Squares   F-statistic:                     29.37
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0324
# Time:                             08:32:22   Log-Likelihood:                 17.246
# No. Observations:                        4   AIC:                            -30.49
# Df Residuals:                            2   BIC:                            -31.72
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0083      0.002      3.320      0.080      -0.002       0.019
# Market Excess Return     0.5274      0.097      5.420      0.032       0.109       0.946
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.051
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.480
# Skew:                           0.544   Prob(JB):                        0.787
# Kurtosis:                       1.697   Cond. No.                         42.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014017558657623528
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.951
# Model:                                 OLS   Adj. R-squared:                  0.935
# Method:                      Least Squares   F-statistic:                     58.24
# Date:                     Fri, 03 May 2024   Prob (F-statistic):            0.00467
# Time:                             08:32:22   Log-Likelihood:                 20.946
# No. Observations:                        5   AIC:                            -37.89
# Df Residuals:                            3   BIC:                            -38.67
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0036      0.003     -1.141      0.337      -0.014       0.006
# Market Excess Return     1.1864      0.155      7.631      0.005       0.692       1.681
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.233
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.368
# Skew:                           0.261   Prob(JB):                        0.832
# Kurtosis:                       1.778   Cond. No.                         73.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.00536380119324397
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.585
# Model:                                 OLS   Adj. R-squared:                  0.378
# Method:                      Least Squares   F-statistic:                     2.824
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.235
# Time:                             08:32:22   Log-Likelihood:                 14.512
# No. Observations:                        4   AIC:                            -25.02
# Df Residuals:                            2   BIC:                            -26.25
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0010      0.006     -0.174      0.878      -0.027       0.024
# Market Excess Return     0.6791      0.404      1.681      0.235      -1.060       2.418
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.123
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.496
# Skew:                          -0.239   Prob(JB):                        0.780
# Kurtosis:                       1.343   Cond. No.                         88.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.003678001532154528
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.674
# Model:                                 OLS   Adj. R-squared:                  0.565
# Method:                      Least Squares   F-statistic:                     6.205
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0884
# Time:                             08:32:22   Log-Likelihood:                 15.084
# No. Observations:                        5   AIC:                            -26.17
# Df Residuals:                            3   BIC:                            -26.95
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0074      0.008      0.905      0.432      -0.019       0.033
# Market Excess Return     0.8322      0.334      2.491      0.088      -0.231       1.895
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.451
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.760
# Skew:                          -0.898   Prob(JB):                        0.684
# Kurtosis:                       2.349   Cond. No.                         48.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.023672869896969196
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.915
# Model:                                 OLS   Adj. R-squared:                  0.872
# Method:                      Least Squares   F-statistic:                     21.41
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0437
# Time:                             08:32:22   Log-Likelihood:                 15.290
# No. Observations:                        4   AIC:                            -26.58
# Df Residuals:                            2   BIC:                            -27.81
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0013      0.006      0.212      0.852      -0.025       0.028
# Market Excess Return     0.9823      0.212      4.627      0.044       0.069       1.896
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.129
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.398
# Skew:                           0.002   Prob(JB):                        0.820
# Kurtosis:                       1.455   Cond. No.                         56.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.006180433112940855
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.943
# Model:                                 OLS   Adj. R-squared:                  0.915
# Method:                      Least Squares   F-statistic:                     33.31
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0287
# Time:                             08:32:22   Log-Likelihood:                 16.961
# No. Observations:                        4   AIC:                            -29.92
# Df Residuals:                            2   BIC:                            -31.15
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0025      0.003     -0.855      0.483      -0.015       0.010
# Market Excess Return     0.6685      0.116      5.771      0.029       0.170       1.167
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.183
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.480
# Skew:                           0.581   Prob(JB):                        0.787
# Kurtosis:                       1.763   Cond. No.                         47.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0032808626734268814
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.851
# Model:                                 OLS   Adj. R-squared:                  0.801
# Method:                      Least Squares   F-statistic:                     17.10
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0257
# Time:                             08:32:22   Log-Likelihood:                 17.455
# No. Observations:                        5   AIC:                            -30.91
# Df Residuals:                            3   BIC:                            -31.69
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0024      0.004      0.566      0.611      -0.011       0.016
# Market Excess Return     0.5923      0.143      4.135      0.026       0.137       1.048
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.769
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.181
# Skew:                          -0.203   Prob(JB):                        0.914
# Kurtosis:                       2.162   Cond. No.                         33.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.012037025151275199
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.683
# Model:                                 OLS   Adj. R-squared:                  0.525
# Method:                      Least Squares   F-statistic:                     4.315
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.173
# Time:                             08:32:22   Log-Likelihood:                 15.452
# No. Observations:                        4   AIC:                            -26.90
# Df Residuals:                            2   BIC:                            -28.13
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0045      0.005      0.874      0.474      -0.018       0.026
# Market Excess Return     0.5311      0.256      2.077      0.173      -0.569       1.631
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.041
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.770
# Skew:                          -0.996   Prob(JB):                        0.680
# Kurtosis:                       2.190   Cond. No.                         71.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0021755558412225
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.648
# Model:                                 OLS   Adj. R-squared:                  0.472
# Method:                      Least Squares   F-statistic:                     3.680
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.195
# Time:                             08:32:22   Log-Likelihood:                 12.776
# No. Observations:                        4   AIC:                            -21.55
# Df Residuals:                            2   BIC:                            -22.78
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0068      0.008     -0.807      0.505      -0.043       0.029
# Market Excess Return     0.6565      0.342      1.918      0.195      -0.816       2.129
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.174
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.285
# Skew:                           0.412   Prob(JB):                        0.867
# Kurtosis:                       1.984   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.023803607066645673
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.545
# Model:                                 OLS   Adj. R-squared:                  0.393
# Method:                      Least Squares   F-statistic:                     3.593
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.154
# Time:                             08:32:22   Log-Likelihood:                 16.781
# No. Observations:                        5   AIC:                            -29.56
# Df Residuals:                            3   BIC:                            -30.34
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0156      0.007      2.393      0.097      -0.005       0.036
# Market Excess Return     0.6682      0.353      1.896      0.154      -0.454       1.790
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.608
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.226
# Skew:                           1.210   Prob(JB):                        0.542
# Kurtosis:                       2.819   Cond. No.                         72.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.008500071204190626
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.694
# Model:                                 OLS   Adj. R-squared:                  0.541
# Method:                      Least Squares   F-statistic:                     4.537
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.167
# Time:                             08:32:22   Log-Likelihood:                 14.975
# No. Observations:                        4   AIC:                            -25.95
# Df Residuals:                            2   BIC:                            -27.18
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0012      0.005      0.226      0.842      -0.022       0.024
# Market Excess Return     0.5770      0.271      2.130      0.167      -0.589       1.742
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.974
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.508
# Skew:                          -0.731   Prob(JB):                        0.776
# Kurtosis:                       2.045   Cond. No.                         66.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.025953  1.421773       1.281182
# 1     02                 0.013454  0.527377       0.684918
# 2     03                 0.014018  1.186376       1.124250
# 3     04                 0.005364  0.679129       0.786086
# 4     05                -0.003678  0.832230       0.888154
# 5     06                 0.023673  0.982284       0.988189
# 6     07                 0.006180  0.668539       0.779026
# 7     08                 0.003281  0.592328       0.728219
# 8     09                 0.012037  0.531118       0.687412
# 9     10                 0.002176  0.656523       0.771015
# 10    11                 0.023804  0.668212       0.778808
# 11    12                 0.008500  0.576956       0.717971

# %%
coefficients_df.to_csv('coefficients_df_p2_1.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.011085881195402113

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (52, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.702
# Model:                            OLS   Adj. R-squared:                  0.696
# Method:                 Least Squares   F-statistic:                     117.7
# Date:                Fri, 03 May 2024   Prob (F-statistic):           9.70e-15
# Time:                        08:32:22   Log-Likelihood:                 167.51
# No. Observations:                  52   AIC:                            -331.0
# Df Residuals:                      50   BIC:                            -327.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0035      0.002      2.286      0.027       0.000       0.007
# x1             0.7088      0.065     10.847      0.000       0.578       0.840
# ==============================================================================
# Omnibus:                        0.761   Durbin-Watson:                   1.699
# Prob(Omnibus):                  0.683   Jarque-Bera (JB):                0.203
# Skew:                          -0.041   Prob(JB):                        0.903
# Kurtosis:                       3.295   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 0.7087539894114261
# P-value: 9.702158594432976e-15
# Std. error: 0.06533881984117514
# Adj. R-squared: 0.6958225971750339
# F-statistic: 117.66531480100483
# T-statistic for X1: 10.847364417267672

# %% [markdown]
# # P3 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_3.index:
    # Extract market excess return for the date
    x = returns_2019.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_3.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2019-01-04              0.032691                 0.035855
# 2019-01-11              0.028740                 0.028393
# 2019-01-18              0.026225                 0.003622
# 2019-01-25              0.009814                 0.032603
# 2019-02-01             -0.008376                -0.002143

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.02511832804815907
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.010
# Model:                                 OLS   Adj. R-squared:                 -0.484
# Method:                      Least Squares   F-statistic:                   0.02109
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.898
# Time:                             08:32:23   Log-Likelihood:                 11.813
# No. Observations:                        4   AIC:                            -19.63
# Df Residuals:                            2   BIC:                            -20.85
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0287      0.027      1.084      0.392      -0.085       0.143
# Market Excess Return    -0.1488      1.024     -0.145      0.898      -4.557       4.259
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.199
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.703
# Skew:                          -0.948   Prob(JB):                        0.704
# Kurtosis:                       2.209   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0260388653212374
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.976
# Model:                                 OLS   Adj. R-squared:                  0.964
# Method:                      Least Squares   F-statistic:                     80.59
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0122
# Time:                             08:32:23   Log-Likelihood:                 16.053
# No. Observations:                        4   AIC:                            -28.11
# Df Residuals:                            2   BIC:                            -29.33
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0144      0.003      4.309      0.050    1.98e-05       0.029
# Market Excess Return     1.1772      0.131      8.977      0.012       0.613       1.741
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.357
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.362
# Skew:                          -0.478   Prob(JB):                        0.834
# Kurtosis:                       1.878   Cond. No.                         42.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.022220506657516088
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.733
# Model:                                 OLS   Adj. R-squared:                  0.644
# Method:                      Least Squares   F-statistic:                     8.236
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0641
# Time:                             08:32:23   Log-Likelihood:                 18.875
# No. Observations:                        5   AIC:                            -33.75
# Df Residuals:                            3   BIC:                            -34.53
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0122      0.005      2.578      0.082      -0.003       0.027
# Market Excess Return     0.6751      0.235      2.870      0.064      -0.074       1.424
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.587
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.683
# Skew:                          -0.385   Prob(JB):                        0.711
# Kurtosis:                       1.362   Cond. No.                         73.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.017915576882293942
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.390
# Model:                                 OLS   Adj. R-squared:                  0.085
# Method:                      Least Squares   F-statistic:                     1.279
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.375
# Time:                             08:32:23   Log-Likelihood:                 11.607
# No. Observations:                        4   AIC:                            -19.21
# Df Residuals:                            2   BIC:                            -20.44
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0090      0.012      0.736      0.538      -0.044       0.062
# Market Excess Return     0.9447      0.835      1.131      0.375      -2.650       4.539
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.543
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.794
# Skew:                           1.019   Prob(JB):                        0.672
# Kurtosis:                       2.217   Cond. No.                         88.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.010976665795556314
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.852
# Model:                                 OLS   Adj. R-squared:                  0.803
# Method:                      Least Squares   F-statistic:                     17.28
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0253
# Time:                             08:32:23   Log-Likelihood:                 18.232
# No. Observations:                        5   AIC:                            -32.46
# Df Residuals:                            3   BIC:                            -33.24
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0011      0.004     -0.263      0.809      -0.015       0.013
# Market Excess Return     0.7400      0.178      4.157      0.025       0.173       1.307
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.746
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.622
# Skew:                          -0.483   Prob(JB):                        0.733
# Kurtosis:                       1.567   Cond. No.                         48.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.022609927206047282
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.618
# Model:                                 OLS   Adj. R-squared:                  0.427
# Method:                      Least Squares   F-statistic:                     3.237
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.214
# Time:                             08:32:23   Log-Likelihood:                 12.642
# No. Observations:                        4   AIC:                            -21.28
# Df Residuals:                            2   BIC:                            -22.51
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0057      0.012      0.484      0.676      -0.045       0.057
# Market Excess Return     0.7405      0.412      1.799      0.214      -1.030       2.512
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.795
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.502
# Skew:                          -0.618   Prob(JB):                        0.778
# Kurtosis:                       1.782   Cond. No.                         56.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.012276296179621761
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.930
# Model:                                 OLS   Adj. R-squared:                  0.895
# Method:                      Least Squares   F-statistic:                     26.58
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0356
# Time:                             08:32:23   Log-Likelihood:                 14.426
# No. Observations:                        4   AIC:                            -24.85
# Df Residuals:                            2   BIC:                            -26.08
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0023      0.005     -0.419      0.716      -0.026       0.021
# Market Excess Return     1.1255      0.218      5.155      0.036       0.186       2.065
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.186
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.475
# Skew:                          -0.565   Prob(JB):                        0.788
# Kurtosis:                       1.745   Cond. No.                         47.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0020638874328163604
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.700
# Model:                                 OLS   Adj. R-squared:                  0.601
# Method:                      Least Squares   F-statistic:                     7.015
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0771
# Time:                             08:32:23   Log-Likelihood:                 14.271
# No. Observations:                        5   AIC:                            -24.54
# Df Residuals:                            3   BIC:                            -25.32
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0031      0.008     -0.386      0.725      -0.029       0.023
# Market Excess Return     0.7171      0.271      2.649      0.077      -0.145       1.579
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.463
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.532
# Skew:                           0.084   Prob(JB):                        0.766
# Kurtosis:                       1.410   Cond. No.                         33.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.017180551092331273
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.820
# Model:                                 OLS   Adj. R-squared:                  0.730
# Method:                      Least Squares   F-statistic:                     9.127
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0943
# Time:                             08:32:23   Log-Likelihood:                 14.181
# No. Observations:                        4   AIC:                            -24.36
# Df Residuals:                            2   BIC:                            -25.59
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0021      0.007      0.293      0.797      -0.028       0.032
# Market Excess Return     1.0614      0.351      3.021      0.094      -0.450       2.573
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.013
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.405
# Skew:                           0.386   Prob(JB):                        0.817
# Kurtosis:                       1.646   Cond. No.                         71.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.021697052478402555
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.775
# Model:                                 OLS   Adj. R-squared:                  0.663
# Method:                      Least Squares   F-statistic:                     6.907
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.119
# Time:                             08:32:23   Log-Likelihood:                 12.658
# No. Observations:                        4   AIC:                            -21.32
# Df Residuals:                            2   BIC:                            -22.54
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0090      0.009      1.039      0.408      -0.028       0.046
# Market Excess Return     0.9266      0.353      2.628      0.119      -0.590       2.444
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.683
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.962
# Skew:                           1.154   Prob(JB):                        0.618
# Kurtosis:                       2.333   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.030046473327316674
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.237
# Model:                                 OLS   Adj. R-squared:                 -0.017
# Method:                      Least Squares   F-statistic:                    0.9330
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.405
# Time:                             08:32:23   Log-Likelihood:                 13.002
# No. Observations:                        5   AIC:                            -22.00
# Df Residuals:                            3   BIC:                            -22.78
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0211      0.014      1.523      0.225      -0.023       0.065
# Market Excess Return     0.7250      0.751      0.966      0.405      -1.664       3.114
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.762
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.717
# Skew:                           0.876   Prob(JB):                        0.699
# Kurtosis:                       2.393   Cond. No.                         72.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0004253284110499481
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.732
# Model:                                 OLS   Adj. R-squared:                  0.598
# Method:                      Least Squares   F-statistic:                     5.454
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.145
# Time:                             08:32:23   Log-Likelihood:                 15.356
# No. Observations:                        4   AIC:                            -26.71
# Df Residuals:                            2   BIC:                            -27.94
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0077      0.005     -1.597      0.251      -0.028       0.013
# Market Excess Return     0.5751      0.246      2.335      0.145      -0.484       1.635
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.153
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.448
# Skew:                          -0.048   Prob(JB):                        0.799
# Kurtosis:                       1.363   Cond. No.                         66.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.025118 -0.148791       0.234139
# 1     02                 0.026039  1.177221       1.118148
# 2     03                 0.022221  0.675133       0.783422
# 3     04                 0.017916  0.944681       0.963121
# 4     05                -0.010977  0.740030       0.826686
# 5     06                 0.022610  0.740521       0.827014
# 6     07                 0.012276  1.125496       1.083664
# 7     08                -0.002064  0.717120       0.811413
# 8     09                 0.017181  1.061389       1.040926
# 9     10                 0.021697  0.926598       0.951065
# 10    11                 0.030046  0.725035       0.816690
# 11    12                -0.000425  0.575077       0.716718

# %%
coefficients_df.to_csv('coefficients_df_p3_1.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.014726484787893727

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (52, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.633
# Model:                            OLS   Adj. R-squared:                  0.626
# Method:                 Least Squares   F-statistic:                     86.22
# Date:                Fri, 03 May 2024   Prob (F-statistic):           1.83e-12
# Time:                        08:32:23   Log-Likelihood:                 148.23
# No. Observations:                  52   AIC:                            -292.5
# Df Residuals:                      50   BIC:                            -288.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0053      0.002      2.396      0.020       0.001       0.010
# x1             0.8790      0.095      9.285      0.000       0.689       1.069
# ==============================================================================
# Omnibus:                        5.986   Durbin-Watson:                   1.631
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                5.114
# Skew:                           0.568   Prob(JB):                       0.0775
# Kurtosis:                       4.035   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 0.8790466590967584
# P-value: 1.8326351645112377e-12
# Std. error: 0.09466881034222183
# Adj. R-squared: 0.625606727979914
# F-statistic: 86.22039660281041
# T-statistic for X1: 9.285493880392705

# %% [markdown]
# # P4 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_4.index:
    # Extract market excess return for the date
    x = returns_2019.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_4.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2019-01-04              0.032691                 0.020055
# 2019-01-11              0.028740                 0.040687
# 2019-01-18              0.026225                 0.003286
# 2019-01-25              0.009814                 0.021416
# 2019-02-01             -0.008376                -0.017833

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.021360904697432383
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.007
# Model:                                 OLS   Adj. R-squared:                 -0.489
# Method:                      Least Squares   F-statistic:                   0.01457
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.915
# Time:                             08:32:23   Log-Likelihood:                 11.635
# No. Observations:                        4   AIC:                            -19.27
# Df Residuals:                            2   BIC:                            -20.50
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0182      0.028      0.657      0.579      -0.101       0.137
# Market Excess Return     0.1293      1.071      0.121      0.915      -4.480       4.738
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.203
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.186
# Skew:                           0.049   Prob(JB):                        0.911
# Kurtosis:                       1.948   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.009592569141833058
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.942
# Model:                                 OLS   Adj. R-squared:                  0.913
# Method:                      Least Squares   F-statistic:                     32.45
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0295
# Time:                             08:32:23   Log-Likelihood:                 13.465
# No. Observations:                        4   AIC:                            -22.93
# Df Residuals:                            2   BIC:                            -24.16
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0045      0.006     -0.697      0.558      -0.032       0.023
# Market Excess Return     1.4266      0.250      5.697      0.029       0.349       2.504
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.590
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.269
# Skew:                          -0.295   Prob(JB):                        0.874
# Kurtosis:                       1.876   Cond. No.                         42.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.013189274442345309
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.958
# Model:                                 OLS   Adj. R-squared:                  0.944
# Method:                      Least Squares   F-statistic:                     68.29
# Date:                     Fri, 03 May 2024   Prob (F-statistic):            0.00371
# Time:                             08:32:23   Log-Likelihood:                 20.428
# No. Observations:                        5   AIC:                            -36.86
# Df Residuals:                            3   BIC:                            -37.64
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0079      0.003     -2.287      0.106      -0.019       0.003
# Market Excess Return     1.4251      0.172      8.264      0.004       0.876       1.974
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.243
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.517
# Skew:                           0.770   Prob(JB):                        0.772
# Kurtosis:                       2.671   Cond. No.                         73.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.013577537905109894
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.829
# Model:                                 OLS   Adj. R-squared:                  0.743
# Method:                      Least Squares   F-statistic:                     9.684
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0896
# Time:                             08:32:23   Log-Likelihood:                 13.049
# No. Observations:                        4   AIC:                            -22.10
# Df Residuals:                            2   BIC:                            -23.32
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0035      0.009     -0.409      0.722      -0.040       0.033
# Market Excess Return     1.8128      0.583      3.112      0.090      -0.694       4.319
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.538
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.788
# Skew:                           1.013   Prob(JB):                        0.674
# Kurtosis:                       2.212   Cond. No.                         88.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.026384926559885002
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.854
# Model:                                 OLS   Adj. R-squared:                  0.806
# Method:                      Least Squares   F-statistic:                     17.58
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0248
# Time:                             08:32:23   Log-Likelihood:                 15.021
# No. Observations:                        5   AIC:                            -26.04
# Df Residuals:                            3   BIC:                            -26.82
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0075      0.008     -0.913      0.429      -0.034       0.019
# Market Excess Return     1.4185      0.338      4.192      0.025       0.342       2.495
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.586
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.701
# Skew:                           0.653   Prob(JB):                        0.704
# Kurtosis:                       1.711   Cond. No.                         48.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.027342683352851213
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.731
# Model:                                 OLS   Adj. R-squared:                  0.596
# Method:                      Least Squares   F-statistic:                     5.433
# Date:                     Fri, 03 May 2024   Prob (F-statistic):              0.145
# Time:                             08:32:23   Log-Likelihood:                 12.702
# No. Observations:                        4   AIC:                            -21.40
# Df Residuals:                            2   BIC:                            -22.63
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0058      0.012      0.497      0.668      -0.044       0.056
# Market Excess Return     0.9453      0.406      2.331      0.145      -0.800       2.690
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.297
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.595
# Skew:                           0.091   Prob(JB):                        0.743
# Kurtosis:                       1.120   Cond. No.                         56.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.026196810459176663
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.929
# Model:                                 OLS   Adj. R-squared:                  0.893
# Method:                      Least Squares   F-statistic:                     26.11
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0362
# Time:                             08:32:23   Log-Likelihood:                 12.394
# No. Observations:                        4   AIC:                            -20.79
# Df Residuals:                            2   BIC:                            -22.01
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0022      0.009      0.246      0.829      -0.037       0.041
# Market Excess Return     1.8540      0.363      5.109      0.036       0.293       3.415
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.171
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.490
# Skew:                          -0.232   Prob(JB):                        0.783
# Kurtosis:                       1.350   Cond. No.                         47.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.00027155406693718797
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.990
# Model:                                 OLS   Adj. R-squared:                  0.987
# Method:                      Least Squares   F-statistic:                     312.7
# Date:                     Fri, 03 May 2024   Prob (F-statistic):           0.000394
# Time:                             08:32:23   Log-Likelihood:                 20.099
# No. Observations:                        5   AIC:                            -36.20
# Df Residuals:                            3   BIC:                            -36.98
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0025      0.003     -0.978      0.400      -0.010       0.006
# Market Excess Return     1.4926      0.084     17.685      0.000       1.224       1.761
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.284
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.263
# Skew:                          -0.006   Prob(JB):                        0.877
# Kurtosis:                       1.876   Cond. No.                         33.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01798631558151804
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.857
# Model:                                 OLS   Adj. R-squared:                  0.785
# Method:                      Least Squares   F-statistic:                     11.95
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0745
# Time:                             08:32:23   Log-Likelihood:                 12.019
# No. Observations:                        4   AIC:                            -20.04
# Df Residuals:                            2   BIC:                            -21.26
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0117      0.012     -0.971      0.434      -0.064       0.040
# Market Excess Return     2.0854      0.603      3.457      0.074      -0.510       4.681
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.612
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.890
# Skew:                           1.100   Prob(JB):                        0.641
# Kurtosis:                       2.289   Cond. No.                         71.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01776847910056676
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.983
# Model:                                 OLS   Adj. R-squared:                  0.975
# Method:                      Least Squares   F-statistic:                     117.8
# Date:                     Fri, 03 May 2024   Prob (F-statistic):            0.00838
# Time:                             08:32:23   Log-Likelihood:                 17.272
# No. Observations:                        4   AIC:                            -30.54
# Df Residuals:                            2   BIC:                            -31.77
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0013      0.003      0.460      0.691      -0.011       0.013
# Market Excess Return     1.2073      0.111     10.855      0.008       0.729       1.686
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.294
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.208
# Skew:                          -0.207   Prob(JB):                        0.901
# Kurtosis:                       1.962   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.016008767043651694
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.954
# Model:                                 OLS   Adj. R-squared:                  0.938
# Method:                      Least Squares   F-statistic:                     61.61
# Date:                     Fri, 03 May 2024   Prob (F-statistic):            0.00431
# Time:                             08:32:23   Log-Likelihood:                 20.930
# No. Observations:                        5   AIC:                            -37.86
# Df Residuals:                            3   BIC:                            -38.64
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0012      0.003      0.418      0.704      -0.008       0.010
# Market Excess Return     1.2066      0.154      7.849      0.004       0.717       1.696
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.091
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.562
# Skew:                          -0.150   Prob(JB):                        0.755
# Kurtosis:                       1.386   Cond. No.                         72.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.009079116723162894
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.904
# Model:                                 OLS   Adj. R-squared:                  0.855
# Method:                      Least Squares   F-statistic:                     18.75
# Date:                     Fri, 03 May 2024   Prob (F-statistic):             0.0494
# Time:                             08:32:23   Log-Likelihood:                 17.067
# No. Observations:                        4   AIC:                            -30.13
# Df Residuals:                            2   BIC:                            -31.36
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0003      0.003      0.090      0.937      -0.013       0.014
# Market Excess Return     0.6952      0.161      4.330      0.049       0.004       1.386
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.591
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.359
# Skew:                          -0.112   Prob(JB):                        0.836
# Kurtosis:                       1.549   Cond. No.                         66.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.021361  0.129280       0.419520
# 1     02                 0.009593  1.426583       1.284389
# 2     03                 0.013189  1.425137       1.283425
# 3     04                 0.013578  1.812811       1.541874
# 4     05                -0.026385  1.418454       1.278970
# 5     06                 0.027343  0.945325       0.963550
# 6     07                 0.026197  1.853987       1.569325
# 7     08                -0.000272  1.492555       1.328370
# 8     09                 0.017986  2.085437       1.723625
# 9     10                 0.017768  1.207283       1.138188
# 10    11                 0.016009  1.206643       1.137762
# 11    12                 0.009079  0.695249       0.796833

# %%
coefficients_df.to_csv('coefficients_df_p4_1.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.011237028310432265

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (52, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.856
# Method:                 Least Squares   F-statistic:                     304.7
# Date:                Fri, 03 May 2024   Prob (F-statistic):           6.46e-23
# Time:                        08:32:23   Log-Likelihood:                 156.94
# No. Observations:                  52   AIC:                            -309.9
# Df Residuals:                      50   BIC:                            -306.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0037      0.002     -1.973      0.054      -0.007    6.66e-05
# x1             1.3975      0.080     17.455      0.000       1.237       1.558
# ==============================================================================
# Omnibus:                        2.930   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.231   Jarque-Bera (JB):                2.212
# Skew:                           0.187   Prob(JB):                        0.331
# Kurtosis:                       3.939   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 1.3975066175558288
# P-value: 6.456576586454685e-23
# Std. error: 0.08006193770743643
# Adj. R-squared: 0.8562117139344931
# F-statistic: 304.6881418196018
# T-statistic for X1: 17.45531843936402
