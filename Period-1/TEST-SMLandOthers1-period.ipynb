# %%
import pandas as pd

returns = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Returns_2018-2023.csv')

portfolio_1 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/p1-1.csv', usecols=[1])
portfolio_2 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/p2-1.csv', usecols=[1])
portfolio_3 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/p3-1.csv', usecols=[1])
portfolio_4 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/p4-1.csv', usecols=[1])

# %%
portfolio_1
# Out:
#                  Stock
# 0           Recordati
# 1  Brunello cucinelli
# 2             Campari
# 3              Saipem
# 4             Pirelli
# 5                Hera
# 6               Terna
# 7                 A2A
# 8                Snam
# 9             Italgas

# %%
# Convert 'Date' column to datetime format
returns['Date'] = pd.to_datetime(returns['Date'])

# Extract year from 'Date' column
returns['Year'] = returns['Date'].dt.year

# Filter DataFrame to include only the data from 2020
returns_2020 = returns[returns['Year'] == 2020].copy()

# Drop the 'Year' column as it's no longer needed
returns_2020.drop(columns='Year', inplace=True)

# %%
returns_2020.drop(columns='Unnamed: 0', inplace=True)

# %%
returns_2020.head()
# Out:
#           Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 103 2020-01-03      -0.002326      -0.020318           -0.003101
# 104 2020-01-10       0.013461       0.034866            0.021773
# 105 2020-01-17       0.004982       0.035725            0.008371
# 106 2020-01-24      -0.007122       0.011778            0.009811
# 107 2020-01-31      -0.030543      -0.000831           -0.040359
#
#      Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 103          0.000943              0.030980                   -0.017907
# 104          0.114986              0.006113                    0.025641
# 105          0.000845             -0.004765                   -0.013889
# 106         -0.003378             -0.030010                   -0.032113
# 107         -0.059746             -0.069496                   -0.051222
#
#      Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 103                                   0.004322                    -0.014138
# 104                                   0.233857                     0.011472
# 105                                  -0.007556                    -0.000945
# 106                                   0.048621                    -0.041627
# 107                                  -0.053072                    -0.040474
#
#      Banco Bpm 2018-2023  ...  Snam 2018-2023  Stellantis 2018-2023  \
# 103             0.000943  ...       -0.007660             -0.026211
# 104             0.114986  ...        0.023585             -0.018960
# 105             0.000845  ...        0.038961             -0.031027
# 106            -0.003378  ...       -0.016532             -0.023320
# 107            -0.059746  ...       -0.008405             -0.033766
#
#      Stmicroeletronics 2018-2023  Telecom 2018-2023  Tenaris 2018-2023  \
# 103                     0.010686          -0.007828           0.014371
# 104                     0.004880          -0.059172           0.014656
# 105                     0.017807          -0.023633          -0.009148
# 106                     0.103380          -0.015616          -0.005345
# 107                    -0.089009          -0.034702          -0.088617
#
#      Terna 2018-2023  Unicredit 2018-2023  Unipol 2018-2023    BOT 3m  \
# 103        -0.016661             0.016009         -0.034364 -0.007712
# 104         0.025076             0.005402          0.000000 -0.007865
# 105         0.024463            -0.018657         -0.021550 -0.007635
# 106         0.020006            -0.053688         -0.021216 -0.007115
# 107        -0.004113            -0.029090         -0.049752 -0.007192
#
#      Risk Premium
# 103      0.005386
# 104      0.021326
# 105      0.012616
# 106     -0.000007
# 107     -0.023351
#
# [5 rows x 42 columns]

# %%
risk_premium_2020 = returns_2020[['Date','Risk Premium']]

# %%
risk_premium_2020.head()
# Out:
#           Date  Risk Premium
# 103 2020-01-03      0.005386
# 104 2020-01-10      0.021326
# 105 2020-01-17      0.012616
# 106 2020-01-24     -0.000007
# 107 2020-01-31     -0.023351

# %%
risk_premium_2020['Risk Premium'].mean()
# Out:
# 0.006588179118971738

# %%
returns_2020.columns = returns_2020.columns.str.replace('2018-2023', '')

# %%
import numpy as np

# Copy the 2018 data to avoid modifying the original DataFrame
returns_2020_excess = returns_2020.copy()

# Calculate excess returns for each stock by subtracting the risk-free rate
risk_free_rate = returns_2020_excess['BOT 3m'].values  # Convert Series to NumPy array
returns_2020_excess.iloc[:, 2:-2] -= risk_free_rate[:, np.newaxis]

# Set 'Date' column as the index
returns_2020_excess.set_index('Date', inplace=True)

# Display the DataFrame with 'Date' as the index
returns_2020_excess.head()
# Out:
#             FTSEMIB Index      A2A   Amplifon    Azimut   BPER banca   \
# Date
# 2020-01-03      -0.002326 -0.012606   0.004611  0.008655     0.038692
# 2020-01-10       0.013461  0.042732   0.029638  0.122851     0.013978
# 2020-01-17       0.004982  0.043359   0.016006  0.008480     0.002870
# 2020-01-24      -0.007122  0.018893   0.016927  0.003737    -0.022895
# 2020-01-31      -0.030543  0.006361  -0.033166 -0.052553    -0.062303
#
#             Banca Mediolanum   Banca Monte dei Paschi di Siena   \
# Date
# 2020-01-03          -0.010196                          0.012034
# 2020-01-10           0.033506                          0.241722
# 2020-01-17          -0.006254                          0.000079
# 2020-01-24          -0.024997                          0.055737
# 2020-01-31          -0.044030                         -0.045880
#
#             Banca pop Sondrio   Banco Bpm   Brunello cucinelli   ...  \
# Date                                                             ...
# 2020-01-03           -0.006426    0.008655            -0.002763  ...
# 2020-01-10            0.019338    0.122851             0.100642  ...
# 2020-01-17            0.006689    0.008480             0.098233  ...
# 2020-01-24           -0.034512    0.003737            -0.045131  ...
# 2020-01-31           -0.033282   -0.052553            -0.088177  ...
#
#                Snam   Stellantis   Stmicroeletronics   Telecom   Tenaris   \
# Date
# 2020-01-03  0.000052    -0.018499            0.018398 -0.000116  0.022082
# 2020-01-10  0.031450    -0.011094            0.012745 -0.051306  0.022521
# 2020-01-17  0.046596    -0.023393            0.025441 -0.015998 -0.001513
# 2020-01-24 -0.009417    -0.016205            0.110495 -0.008500  0.001770
# 2020-01-31 -0.001213    -0.026574           -0.081817 -0.027509 -0.081425
#
#               Terna   Unicredit    Unipol     BOT 3m  Risk Premium
# Date
# 2020-01-03 -0.008950    0.023720 -0.026653 -0.007712      0.005386
# 2020-01-10  0.032942    0.013268  0.007865 -0.007865      0.021326
# 2020-01-17  0.032097   -0.011022 -0.013915 -0.007635      0.012616
# 2020-01-24  0.027122   -0.046573 -0.014101 -0.007115     -0.000007
# 2020-01-31  0.003080   -0.021898 -0.042560 -0.007192     -0.023351
#
# [5 rows x 41 columns]

# %%
portfolio_data = {}  # Dictionary to store portfolio data frames

# Iterate over each portfolio
for i in range(1, 5):
    portfolio_name = f"portfolio_{i}"  # Generate portfolio name
    portfolio_stocks = list(eval(portfolio_name)['Stock'])  # Extract stock names for current portfolio
    portfolio_data[portfolio_name] = returns_2020_excess[portfolio_stocks]  # Create data frame for current portfolio

# portfolio_data dictionary will contain data frames for each portfolio, e.g., portfolio_data['portfolio_1']

# %%
p_1 = portfolio_data['portfolio_1']
p_2 = portfolio_data['portfolio_2']
p_3 = portfolio_data['portfolio_3']
p_4 = portfolio_data['portfolio_4']

# %%
p_1.head()
# Out:
#             Recordati   Brunello cucinelli   Campari    Saipem   Pirelli   \
# Date
# 2020-01-03    0.011115            -0.002763 -0.002573  0.016387  0.009249
# 2020-01-10    0.019345             0.100642 -0.000081  0.014654  0.025140
# 2020-01-17    0.026206             0.098233  0.074178 -0.002475 -0.035762
# 2020-01-24    0.027374            -0.045131  0.014625 -0.061913 -0.048309
# 2020-01-31   -0.034009            -0.088177  0.008339 -0.078662 -0.079882
#
#                Hera     Terna       A2A      Snam   Italgas
# Date
# 2020-01-03 -0.020989 -0.008950 -0.012606  0.000052 -0.005077
# 2020-01-10  0.018233  0.032942  0.042732  0.031450  0.037013
# 2020-01-17  0.033289  0.032097  0.043359  0.046596  0.016026
# 2020-01-24  0.067145  0.027122  0.018893 -0.009417  0.013010
# 2020-01-31 -0.024898  0.003080  0.006361 -0.001213  0.040629

# %%
p_2.head()
# Out:
#             Amplifon   Moncler       Erg       Eni   Tenaris      Enel   \
# Date
# 2020-01-03   0.004611 -0.005579 -0.002534  0.015283  0.022082  0.017938
# 2020-01-10   0.029638  0.023331  0.030122  0.007440  0.022521  0.036433
# 2020-01-17   0.016006  0.056517  0.067888 -0.005415 -0.001513  0.049161
# 2020-01-24   0.016927 -0.043236  0.030993 -0.024934  0.001770  0.019284
# 2020-01-31  -0.033166 -0.031032  0.002528 -0.053090 -0.081425  0.011796
#
#             Interpump   Diasorin   Generali Ass
# Date
# 2020-01-03    0.025417   0.009436      -0.002235
# 2020-01-10   -0.002573   0.017332       0.014653
# 2020-01-17    0.023106   0.004225      -0.003153
# 2020-01-24   -0.011583  -0.008282      -0.003790
# 2020-01-31   -0.094431  -0.028429      -0.022852

# %%
p_3.head()
# Out:
#             Banca Mediolanum     Inwit    Azimut   Banco Bpm   Ferrari   \
# Date
# 2020-01-03          -0.010196  0.000901  0.008655    0.008655 -0.008736
# 2020-01-10           0.033506  0.010151  0.122851    0.122851  0.051344
# 2020-01-17          -0.006254  0.073769  0.008480    0.008480  0.014686
# 2020-01-24          -0.024997 -0.010532  0.003737    0.003737  0.006479
# 2020-01-31          -0.044030  0.027878 -0.052553   -0.052553 -0.021470
#
#             BPER banca   Banca pop Sondrio    Unipol   Poste Italiane
# Date
# 2020-01-03     0.038692           -0.006426 -0.026653        -0.009858
# 2020-01-10     0.013978            0.019338  0.007865         0.022272
# 2020-01-17     0.002870            0.006689 -0.013915         0.014980
# 2020-01-24    -0.022895           -0.034512 -0.014101         0.036284
# 2020-01-31    -0.062303           -0.033282 -0.042560        -0.015009

# %%
p_4.head()
# Out:
#             Prysmian   Mediobanca   Leonardo   Stellantis    Fineco   \
# Date
# 2020-01-03  -0.020130     0.009126   0.011983    -0.018499  0.002141
# 2020-01-10   0.014908     0.006252   0.080172    -0.011094  0.054084
# 2020-01-17   0.015094    -0.007318  -0.012639    -0.023393 -0.000844
# 2020-01-24  -0.011857    -0.012167   0.012513    -0.016205 -0.004136
# 2020-01-31  -0.045638    -0.050327   0.007640    -0.026574 -0.030131
#
#             Stmicroeletronics   Banca Monte dei Paschi di Siena   Unicredit   \
# Date
# 2020-01-03            0.018398                          0.012034    0.023720
# 2020-01-10            0.012745                          0.241722    0.013268
# 2020-01-17            0.025441                          0.000079   -0.011022
# 2020-01-24            0.110495                          0.055737   -0.046573
# 2020-01-31           -0.081817                         -0.045880   -0.021898
#
#             Telecom   Intesa San Paolo
# Date
# 2020-01-03 -0.000116           0.005376
# 2020-01-10 -0.051306           0.011058
# 2020-01-17 -0.015998          -0.001063
# 2020-01-24 -0.008500          -0.017922
# 2020-01-31 -0.027509          -0.007075

# %%
returns_2020 = returns_2020.set_index('Date')

# %% [markdown]
# # P1 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_1.index:
    # Extract market excess return for the date
    x = returns_2020.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_1.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2020-01-03              0.005386                -0.001616
# 2020-01-10              0.021326                 0.032207
# 2020-01-17              0.012616                 0.033175
# 2020-01-24             -0.000007                 0.000340
# 2020-01-31             -0.023351                -0.024843

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 1': monthly_portfolio_excess_return, 'Beta 1': x1_coefficient, 'Adjusted Beta 1': adj, "Residual Variance 1": residual_variance})

# Convert the list to a DataFrame
coefficients_df_port1 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port1
# Out:
# 0.007852567891016012
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.864
# Model:                                 OLS   Adj. R-squared:                  0.819
# Method:                      Least Squares   F-statistic:                     19.06
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0222
# Time:                             10:52:35   Log-Likelihood:                 16.947
# No. Observations:                        5   AIC:                            -29.89
# Df Residuals:                            3   BIC:                            -30.67
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0035      0.005      0.726      0.521      -0.012       0.019
# Market Excess Return     1.3642      0.312      4.366      0.022       0.370       2.359
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.799
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.138
# Skew:                           0.006   Prob(JB):                        0.933
# Kurtosis:                       2.186   Cond. No.                         66.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 6.5802822643572e-09
# -0.010017453893950848
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.962
# Model:                                 OLS   Adj. R-squared:                  0.943
# Method:                      Least Squares   F-statistic:                     51.05
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0190
# Time:                             10:52:35   Log-Likelihood:                 12.816
# No. Observations:                        4   AIC:                            -21.63
# Df Residuals:                            2   BIC:                            -22.86
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0063      0.007     -0.910      0.459      -0.036       0.024
# Market Excess Return     0.8003      0.112      7.145      0.019       0.318       1.282
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.157
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.589
# Skew:                           0.824   Prob(JB):                        0.745
# Kurtosis:                       2.095   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.3603752110314377e-08
# -0.03887898057956973
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.926
# Model:                                 OLS   Adj. R-squared:                  0.889
# Method:                      Least Squares   F-statistic:                     25.05
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0377
# Time:                             10:52:35   Log-Likelihood:                 9.2138
# No. Observations:                        4   AIC:                            -14.43
# Df Residuals:                            2   BIC:                            -15.66
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0047      0.019      0.244      0.830      -0.078       0.087
# Market Excess Return     0.7731      0.154      5.005      0.038       0.109       1.438
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.973
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.338
# Skew:                           0.267   Prob(JB):                        0.845
# Kurtosis:                       1.681   Cond. No.                         9.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.1019667967884967e-07
# 0.0062436262738995215
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.932
# Model:                                 OLS   Adj. R-squared:                  0.899
# Method:                      Least Squares   F-statistic:                     27.60
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0344
# Time:                             10:52:35   Log-Likelihood:                 18.888
# No. Observations:                        4   AIC:                            -33.78
# Df Residuals:                            2   BIC:                            -35.00
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0063      0.002      4.131      0.054      -0.000       0.013
# Market Excess Return     0.1869      0.036      5.253      0.034       0.034       0.340
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.282
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.461
# Skew:                           0.528   Prob(JB):                        0.794
# Kurtosis:                       1.716   Cond. No.                         23.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.0500049840337146e-11
# 0.016023965411656623
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.607
# Model:                                 OLS   Adj. R-squared:                  0.476
# Method:                      Least Squares   F-statistic:                     4.628
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.121
# Time:                             10:52:35   Log-Likelihood:                 13.146
# No. Observations:                        5   AIC:                            -22.29
# Df Residuals:                            3   BIC:                            -23.07
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0036      0.012      0.308      0.778      -0.033       0.041
# Market Excess Return     0.6431      0.299      2.151      0.121      -0.308       1.594
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.068
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.864
# Skew:                          -0.984   Prob(JB):                        0.649
# Kurtosis:                       2.472   Cond. No.                         29.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.7078079893487152e-07
# 0.008778692851622768
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.927
# Model:                                 OLS   Adj. R-squared:                  0.890
# Method:                      Least Squares   F-statistic:                     25.23
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0374
# Time:                             10:52:35   Log-Likelihood:                 10.945
# No. Observations:                        4   AIC:                            -17.89
# Df Residuals:                            2   BIC:                            -19.12
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0081      0.012     -0.698      0.558      -0.058       0.042
# Market Excess Return     0.8505      0.169      5.023      0.037       0.122       1.579
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.285
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.379
# Skew:                           0.348   Prob(JB):                        0.827
# Kurtosis:                       1.663   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.3428704955420375e-08
# 0.004469606992375007
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.811
# Model:                                 OLS   Adj. R-squared:                  0.748
# Method:                      Least Squares   F-statistic:                     12.88
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0370
# Time:                             10:52:35   Log-Likelihood:                 17.069
# No. Observations:                        5   AIC:                            -30.14
# Df Residuals:                            3   BIC:                            -30.92
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0006      0.005      0.129      0.906      -0.014       0.016
# Market Excess Return     0.5360      0.149      3.589      0.037       0.061       1.011
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.606
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.279
# Skew:                          -0.404   Prob(JB):                        0.870
# Kurtosis:                       2.172   Cond. No.                         32.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.8967263102974e-09
# 0.009872803901526681
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.762
# Model:                                 OLS   Adj. R-squared:                  0.643
# Method:                      Least Squares   F-statistic:                     6.414
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.127
# Time:                             10:52:36   Log-Likelihood:                 12.162
# No. Observations:                        4   AIC:                            -20.32
# Df Residuals:                            2   BIC:                            -21.55
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0126      0.012     -1.043      0.407      -0.064       0.039
# Market Excess Return     1.2512      0.494      2.533      0.127      -0.874       3.377
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.317
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.231
# Skew:                           0.062   Prob(JB):                        0.891
# Kurtosis:                       1.830   Cond. No.                         60.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.982190524373097e-08
# 0.002821746440665851
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.802
# Model:                                 OLS   Adj. R-squared:                  0.703
# Method:                      Least Squares   F-statistic:                     8.104
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.104
# Time:                             10:52:36   Log-Likelihood:                 12.886
# No. Observations:                        4   AIC:                            -21.77
# Df Residuals:                            2   BIC:                            -23.00
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0076      0.007      1.078      0.394      -0.023       0.038
# Market Excess Return     0.8451      0.297      2.847      0.104      -0.432       2.122
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.121
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.422
# Skew:                           0.358   Prob(JB):                        0.810
# Kurtosis:                       1.580   Cond. No.                         43.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 6.720833586769336e-09
# 0.0036984079283862866
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.914
# Model:                                 OLS   Adj. R-squared:                  0.885
# Method:                      Least Squares   F-statistic:                     31.88
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0110
# Time:                             10:52:36   Log-Likelihood:                 17.619
# No. Observations:                        5   AIC:                            -31.24
# Df Residuals:                            3   BIC:                            -32.02
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0023      0.004      0.562      0.613      -0.011       0.015
# Market Excess Return     0.6815      0.121      5.646      0.011       0.297       1.066
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.793
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.569
# Skew:                           0.809   Prob(JB):                        0.752
# Kurtosis:                       2.659   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.374954599957519e-09
# 0.048548285823524044
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.494
# Model:                                 OLS   Adj. R-squared:                  0.241
# Method:                      Least Squares   F-statistic:                     1.951
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.297
# Time:                             10:52:36   Log-Likelihood:                 12.708
# No. Observations:                        4   AIC:                            -21.42
# Df Residuals:                            2   BIC:                            -22.64
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0230      0.020      1.167      0.363      -0.062       0.108
# Market Excess Return     0.3837      0.275      1.397      0.297      -0.798       1.566
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.404
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.702
# Skew:                           0.926   Prob(JB):                        0.704
# Kurtosis:                       2.117   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.5454064211942266e-08
# 0.007574320491037368
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.943
# Model:                                 OLS   Adj. R-squared:                  0.914
# Method:                      Least Squares   F-statistic:                     33.05
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0289
# Time:                             10:52:36   Log-Likelihood:                 20.498
# No. Observations:                        4   AIC:                            -37.00
# Df Residuals:                            2   BIC:                            -38.22
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0039      0.001      3.230      0.084      -0.001       0.009
# Market Excess Return     0.4454      0.077      5.749      0.029       0.112       0.779
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.019
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.384
# Skew:                          -0.084   Prob(JB):                        0.825
# Kurtosis:                       1.491   Cond. No.                         76.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.8120623867088775e-12
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 1    Beta 1  Adjusted Beta 1  \
# 0     01                   0.007853  1.364170         1.242780
# 1     02                  -0.010017  0.800330         0.866887
# 2     03                  -0.038879  0.773050         0.848700
# 3     04                   0.006244  0.186866         0.457910
# 4     05                   0.016024  0.643116         0.762077
# 5     06                   0.008779  0.850517         0.900345
# 6     07                   0.004470  0.535953         0.690636
# 7     08                   0.009873  1.251173         1.167449
# 8     09                   0.002822  0.845086         0.896724
# 9     10                   0.003698  0.681464         0.787643
# 10    11                   0.048548  0.383739         0.589159
# 11    12                   0.007574  0.445367         0.630245
#
#     Residual Variance 1
# 0          6.580282e-09
# 1          1.360375e-08
# 2          3.101967e-07
# 3          2.050005e-11
# 4          1.707808e-07
# 5          5.342870e-08
# 6          5.896726e-09
# 7          1.982191e-08
# 8          6.720834e-09
# 9          5.374955e-09
# 10         1.545406e-08
# 11         2.812062e-12

# %% [markdown]
# # P2 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_2.index:
    # Extract market excess return for the date
    x = returns_2020.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_2.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2020-01-03              0.005386                 0.009380
# 2020-01-10              0.021326                 0.019877
# 2020-01-17              0.012616                 0.022980
# 2020-01-24             -0.000007                -0.002539
# 2020-01-31             -0.023351                -0.036678

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 2': monthly_portfolio_excess_return, 'Beta 2': x1_coefficient, 'Adjusted Beta 2': adj, "Residual Variance 2": residual_variance})

# Convert the list to a DataFrame
coefficients_df_port2 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port2
# Out:
# 0.0026041186375585805
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.942
# Model:                                 OLS   Adj. R-squared:                  0.922
# Method:                      Least Squares   F-statistic:                     48.40
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00609
# Time:                             10:52:36   Log-Likelihood:                 19.187
# No. Observations:                        5   AIC:                            -34.37
# Df Residuals:                            3   BIC:                            -35.16
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0018      0.003     -0.595      0.594      -0.012       0.008
# Market Excess Return     1.3887      0.200      6.957      0.006       0.753       2.024
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.187
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.268
# Skew:                          -0.097   Prob(JB):                        0.875
# Kurtosis:                       1.884   Cond. No.                         66.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.164656528294036e-10
# -0.004344631682082663
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.975
# Model:                                 OLS   Adj. R-squared:                  0.963
# Method:                      Least Squares   F-statistic:                     78.84
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0124
# Time:                             10:52:36   Log-Likelihood:                 13.125
# No. Observations:                        4   AIC:                            -22.25
# Df Residuals:                            2   BIC:                            -23.48
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0001      0.006     -0.017      0.988      -0.028       0.028
# Market Excess Return     0.9205      0.104      8.879      0.012       0.474       1.367
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.046
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.425
# Skew:                          -0.176   Prob(JB):                        0.809
# Kurtosis:                       1.443   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.03542397649038e-09
# -0.043225487135122885
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.999
# Model:                                 OLS   Adj. R-squared:                  0.999
# Method:                      Least Squares   F-statistic:                     2851.
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000351
# Time:                             10:52:36   Log-Likelihood:                 18.069
# No. Observations:                        4   AIC:                            -32.14
# Df Residuals:                            2   BIC:                            -33.37
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0076      0.002      3.603      0.069      -0.001       0.017
# Market Excess Return     0.9013      0.017     53.398      0.000       0.829       0.974
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.720
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.473
# Skew:                          -0.628   Prob(JB):                        0.789
# Kurtosis:                       1.877   Cond. No.                         9.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.6985777769241826e-11
# 0.020613732818798605
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.865
# Model:                                 OLS   Adj. R-squared:                  0.797
# Method:                      Least Squares   F-statistic:                     12.78
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0701
# Time:                             10:52:36   Log-Likelihood:                 13.116
# No. Observations:                        4   AIC:                            -22.23
# Df Residuals:                            2   BIC:                            -23.46
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0207      0.006      3.219      0.084      -0.007       0.048
# Market Excess Return     0.5383      0.151      3.575      0.070      -0.110       1.186
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.946
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.514
# Skew:                           0.715   Prob(JB):                        0.773
# Kurtosis:                       1.978   Cond. No.                         23.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.998455185747183e-09
# 0.019549846853235547
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.902
# Model:                                 OLS   Adj. R-squared:                  0.869
# Method:                      Least Squares   F-statistic:                     27.57
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0135
# Time:                             10:52:36   Log-Likelihood:                 20.434
# No. Observations:                        5   AIC:                            -36.87
# Df Residuals:                            3   BIC:                            -37.65
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0125      0.003      4.614      0.019       0.004       0.021
# Market Excess Return     0.3654      0.070      5.251      0.013       0.144       0.587
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.088
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.312
# Skew:                          -0.198   Prob(JB):                        0.855
# Kurtosis:                       1.841   Cond. No.                         29.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.8677644185535317e-10
# 0.00861322091299312
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.975
# Model:                                 OLS   Adj. R-squared:                  0.963
# Method:                      Least Squares   F-statistic:                     78.97
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0124
# Time:                             10:52:36   Log-Likelihood:                 14.343
# No. Observations:                        4   AIC:                            -24.69
# Df Residuals:                            2   BIC:                            -25.91
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0041      0.005     -0.836      0.491      -0.025       0.017
# Market Excess Return     0.6435      0.072      8.887      0.012       0.332       0.955
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.696
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.531
# Skew:                           0.688   Prob(JB):                        0.767
# Kurtosis:                       1.862   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.324372635660168e-09
# 0.0071160836167612415
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.893
# Model:                                 OLS   Adj. R-squared:                  0.858
# Method:                      Least Squares   F-statistic:                     25.08
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0153
# Time:                             10:52:36   Log-Likelihood:                 17.725
# No. Observations:                        5   AIC:                            -31.45
# Df Residuals:                            3   BIC:                            -32.23
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0024      0.004      0.577      0.604      -0.011       0.016
# Market Excess Return     0.6559      0.131      5.008      0.015       0.239       1.073
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.496
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.913
# Skew:                          -1.038   Prob(JB):                        0.633
# Kurtosis:                       2.734   Cond. No.                         32.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.160896393367734e-09
# 0.009268959817309831
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.871
# Model:                                 OLS   Adj. R-squared:                  0.806
# Method:                      Least Squares   F-statistic:                     13.48
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0668
# Time:                             10:52:36   Log-Likelihood:                 15.924
# No. Observations:                        4   AIC:                            -27.85
# Df Residuals:                            2   BIC:                            -29.07
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0034      0.005     -0.730      0.541      -0.024       0.017
# Market Excess Return     0.7082      0.193      3.671      0.067      -0.122       1.538
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.665
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.461
# Skew:                          -0.574   Prob(JB):                        0.794
# Kurtosis:                       1.796   Cond. No.                         60.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.4202337445185107e-10
# 0.00296492839460742
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.829
# Model:                                 OLS   Adj. R-squared:                  0.744
# Method:                      Least Squares   F-statistic:                     9.714
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0894
# Time:                             10:52:36   Log-Likelihood:                 12.938
# No. Observations:                        4   AIC:                            -21.88
# Df Residuals:                            2   BIC:                            -23.10
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0081      0.007      1.168      0.363      -0.022       0.038
# Market Excess Return     0.9133      0.293      3.117      0.089      -0.347       2.174
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.782
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.569
# Skew:                          -0.094   Prob(JB):                        0.753
# Kurtosis:                       1.163   Cond. No.                         43.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.7888216701159935e-09
# 0.00947163300930107
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.979
# Model:                                 OLS   Adj. R-squared:                  0.972
# Method:                      Least Squares   F-statistic:                     138.7
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00132
# Time:                             10:52:36   Log-Likelihood:                 19.506
# No. Observations:                        5   AIC:                            -35.01
# Df Residuals:                            3   BIC:                            -35.79
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0075      0.003      2.651      0.077      -0.002       0.017
# Market Excess Return     0.9747      0.083     11.778      0.001       0.711       1.238
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.170
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.894
# Skew:                          -1.030   Prob(JB):                        0.639
# Kurtosis:                       2.780   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.2742162610640072e-09
# 0.05936359729191734
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.943
# Model:                                 OLS   Adj. R-squared:                  0.914
# Method:                      Least Squares   F-statistic:                     33.07
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0289
# Time:                             10:52:36   Log-Likelihood:                 13.466
# No. Observations:                        4   AIC:                            -22.93
# Df Residuals:                            2   BIC:                            -24.16
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0278      0.016     -1.710      0.229      -0.098       0.042
# Market Excess Return     1.3071      0.227      5.751      0.029       0.329       2.285
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.721
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.895
# Skew:                          -1.104   Prob(JB):                        0.639
# Kurtosis:                       2.298   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.413745245687472e-09
# 0.016942547322466396
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.085
# Model:                                 OLS   Adj. R-squared:                 -0.372
# Method:                      Least Squares   F-statistic:                    0.1859
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.708
# Time:                             10:52:36   Log-Likelihood:                 16.064
# No. Observations:                        4   AIC:                            -28.13
# Df Residuals:                            2   BIC:                            -29.36
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0161      0.004      4.418      0.048       0.000       0.032
# Market Excess Return     0.1012      0.235      0.431      0.708      -0.909       1.111
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.138
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.438
# Skew:                           0.097   Prob(JB):                        0.803
# Kurtosis:                       1.391   Cond. No.                         76.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.8856328176856367e-10
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 2    Beta 2  Adjusted Beta 2  \
# 0     01                   0.002604  1.388659         1.259106
# 1     02                  -0.004345  0.920543         0.947029
# 2     03                  -0.043225  0.901257         0.934171
# 3     04                   0.020614  0.538285         0.692190
# 4     05                   0.019550  0.365421         0.576948
# 5     06                   0.008613  0.643525         0.762350
# 6     07                   0.007116  0.655867         0.770578
# 7     08                   0.009269  0.708245         0.805497
# 8     09                   0.002965  0.913335         0.942224
# 9     10                   0.009472  0.974687         0.983125
# 10    11                   0.059364  1.307067         1.204712
# 11    12                   0.016943  0.101181         0.400787
#
#     Residual Variance 2
# 0          8.164657e-10
# 1          4.035424e-09
# 2          5.698578e-11
# 3          8.998455e-09
# 4          2.867764e-10
# 5          2.324373e-09
# 6          5.160896e-09
# 7          4.420234e-10
# 8          1.788822e-09
# 9          1.274216e-09
# 10         8.413745e-09
# 11         1.885633e-10

# %% [markdown]
# # P3 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_3.index:
    # Extract market excess return for the date
    x = returns_2020.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_3.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2020-01-03              0.005386                -0.000552
# 2020-01-10              0.021326                 0.044906
# 2020-01-17              0.012616                 0.012198
# 2020-01-24             -0.000007                -0.006311
# 2020-01-31             -0.023351                -0.032876

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 3': monthly_portfolio_excess_return, 'Beta 3': x1_coefficient, 'Adjusted Beta 3': adj, "Residual Variance 3" : residual_variance})

# Convert the list to a DataFrame
coefficients_df_port3 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port3
# Out:
# 0.0034732113863563964
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.904
# Model:                                 OLS   Adj. R-squared:                  0.872
# Method:                      Least Squares   F-statistic:                     28.16
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0131
# Time:                             10:52:36   Log-Likelihood:                 17.121
# No. Observations:                        5   AIC:                            -30.24
# Df Residuals:                            3   BIC:                            -31.02
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0016      0.005     -0.353      0.748      -0.016       0.013
# Market Excess Return     1.6011      0.302      5.307      0.013       0.641       2.561
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.799
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.677
# Skew:                           0.553   Prob(JB):                        0.713
# Kurtosis:                       1.577   Cond. No.                         66.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.781264496533633e-09
# -0.006591067837822002
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.896
# Model:                                 OLS   Adj. R-squared:                  0.844
# Method:                      Least Squares   F-statistic:                     17.26
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0533
# Time:                             10:52:36   Log-Likelihood:                 9.3790
# No. Observations:                        4   AIC:                            -14.76
# Df Residuals:                            2   BIC:                            -15.99
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0015      0.016     -0.093      0.934      -0.072       0.069
# Market Excess Return     1.0989      0.265      4.155      0.053      -0.039       2.237
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.876
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.618
# Skew:                           0.867   Prob(JB):                        0.734
# Kurtosis:                       2.162   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.486711375347303e-07
# -0.05692193627163071
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.914
# Model:                                 OLS   Adj. R-squared:                  0.871
# Method:                      Least Squares   F-statistic:                     21.21
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0441
# Time:                             10:52:36   Log-Likelihood:                 8.1379
# No. Observations:                        4   AIC:                            -12.28
# Df Residuals:                            2   BIC:                            -13.50
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0045      0.025     -0.178      0.875      -0.112       0.104
# Market Excess Return     0.9308      0.202      4.605      0.044       0.061       1.800
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.638
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.562
# Skew:                           0.140   Prob(JB):                        0.755
# Kurtosis:                       1.184   Cond. No.                         9.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.461687482601765e-07
# 0.0001842513002097406
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.924
# Model:                                 OLS   Adj. R-squared:                  0.886
# Method:                      Least Squares   F-statistic:                     24.37
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0387
# Time:                             10:52:36   Log-Likelihood:                 11.635
# No. Observations:                        4   AIC:                            -19.27
# Df Residuals:                            2   BIC:                            -20.50
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0004      0.009      0.048      0.966      -0.040       0.041
# Market Excess Return     1.0765      0.218      4.937      0.039       0.138       2.015
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.908
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.269
# Skew:                          -0.407   Prob(JB):                        0.874
# Kurtosis:                       2.024   Cond. No.                         23.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.1431130756705794e-08
# 0.016695808537976815
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.785
# Model:                                 OLS   Adj. R-squared:                  0.713
# Method:                      Least Squares   F-statistic:                     10.96
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0454
# Time:                             10:52:36   Log-Likelihood:                 12.853
# No. Observations:                        5   AIC:                            -21.71
# Df Residuals:                            3   BIC:                            -22.49
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0036      0.012     -0.292      0.789      -0.043       0.036
# Market Excess Return     1.0492      0.317      3.310      0.045       0.040       2.058
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.903
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.952
# Skew:                          -1.036   Prob(JB):                        0.621
# Kurtosis:                       2.477   Cond. No.                         29.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.1669521773066234e-07
# 0.014187407542133964
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.989
# Model:                                 OLS   Adj. R-squared:                  0.984
# Method:                      Least Squares   F-statistic:                     187.3
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00530
# Time:                             10:52:36   Log-Likelihood:                 14.349
# No. Observations:                        4   AIC:                            -24.70
# Df Residuals:                            2   BIC:                            -25.93
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0054      0.005     -1.098      0.387      -0.027       0.016
# Market Excess Return     0.9896      0.072     13.687      0.005       0.679       1.301
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.239
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.734
# Skew:                          -0.974   Prob(JB):                        0.693
# Kurtosis:                       2.220   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.268870675292638e-09
# 0.013485348004285599
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.983
# Model:                                 OLS   Adj. R-squared:                  0.978
# Method:                      Least Squares   F-statistic:                     175.1
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000933
# Time:                             10:52:36   Log-Likelihood:                 20.588
# No. Observations:                        5   AIC:                            -37.18
# Df Residuals:                            3   BIC:                            -37.96
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0064      0.002      2.757      0.070      -0.001       0.014
# Market Excess Return     0.9775      0.074     13.232      0.001       0.742       1.213
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.289
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.932
# Skew:                           1.042   Prob(JB):                        0.627
# Kurtosis:                       2.638   Cond. No.                         32.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.936283526318913e-10
# 0.022291781176607562
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.985
# Model:                                 OLS   Adj. R-squared:                  0.978
# Method:                      Least Squares   F-statistic:                     131.8
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00750
# Time:                             10:52:36   Log-Likelihood:                 18.022
# No. Observations:                        4   AIC:                            -32.04
# Df Residuals:                            2   BIC:                            -33.27
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0012      0.003     -0.440      0.703      -0.013       0.011
# Market Excess Return     1.3107      0.114     11.480      0.008       0.819       1.802
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.312
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.301
# Skew:                           0.457   Prob(JB):                        0.860
# Kurtosis:                       2.014   Cond. No.                         60.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 6.907395597544754e-11
# -0.008182975595136572
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.879
# Model:                                 OLS   Adj. R-squared:                  0.818
# Method:                      Least Squares   F-statistic:                     14.53
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0625
# Time:                             10:52:36   Log-Likelihood:                 12.109
# No. Observations:                        4   AIC:                            -20.22
# Df Residuals:                            2   BIC:                            -21.45
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0005      0.009     -0.054      0.962      -0.037       0.036
# Market Excess Return     1.3740      0.361      3.811      0.062      -0.177       2.925
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.850
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.424
# Skew:                           0.650   Prob(JB):                        0.809
# Kurtosis:                       2.077   Cond. No.                         43.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.7135957121978235e-08
# -0.007013447757077164
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.983
# Model:                                 OLS   Adj. R-squared:                  0.977
# Method:                      Least Squares   F-statistic:                     171.3
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000963
# Time:                             10:52:36   Log-Likelihood:                 20.150
# No. Observations:                        5   AIC:                            -36.30
# Df Residuals:                            3   BIC:                            -37.08
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0089      0.002     -3.593      0.037      -0.017      -0.001
# Market Excess Return     0.9522      0.073     13.088      0.001       0.721       1.184
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.478
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.421
# Skew:                          -0.107   Prob(JB):                        0.810
# Kurtosis:                       1.594   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.541477872257793e-10
# 0.07807019800611617
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.675
# Model:                                 OLS   Adj. R-squared:                  0.513
# Method:                      Least Squares   F-statistic:                     4.157
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.178
# Time:                             10:52:36   Log-Likelihood:                 11.691
# No. Observations:                        4   AIC:                            -19.38
# Df Residuals:                            2   BIC:                            -20.61
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0299      0.025      1.179      0.360      -0.079       0.139
# Market Excess Return     0.7222      0.354      2.039      0.178      -0.802       2.246
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.906
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.519
# Skew:                          -0.117   Prob(JB):                        0.771
# Kurtosis:                       1.251   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 9.59512506714398e-09
# 0.0021191272298107747
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.837
# Model:                                 OLS   Adj. R-squared:                  0.756
# Method:                      Least Squares   F-statistic:                     10.31
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0849
# Time:                             10:52:36   Log-Likelihood:                 14.389
# No. Observations:                        4   AIC:                            -24.78
# Df Residuals:                            2   BIC:                            -26.00
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0074      0.006     -1.329      0.315      -0.031       0.016
# Market Excess Return     1.1455      0.357      3.210      0.085      -0.390       2.681
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.813
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.689
# Skew:                          -0.916   Prob(JB):                        0.709
# Kurtosis:                       2.119   Cond. No.                         76.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.883677055119007e-09
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 3    Beta 3  Adjusted Beta 3  \
# 0     01                   0.003473  1.601114         1.400743
# 1     02                  -0.006591  1.098903         1.065935
# 2     03                  -0.056922  0.930789         0.953860
# 3     04                   0.000184  1.076532         1.051021
# 4     05                   0.016696  1.049165         1.032776
# 5     06                   0.014187  0.989626         0.993084
# 6     07                   0.013485  0.977473         0.984982
# 7     08                   0.022292  1.310727         1.207151
# 8     09                  -0.008183  1.373977         1.249318
# 9     10                  -0.007013  0.952170         0.968113
# 10    11                   0.078070  0.722230         0.814820
# 11    12                   0.002119  1.145513         1.097009
#
#     Residual Variance 3
# 0          2.781264e-09
# 1          4.486711e-07
# 2          2.461687e-07
# 3          4.143113e-08
# 4          2.166952e-07
# 5          3.268871e-09
# 6          4.936284e-10
# 7          6.907396e-11
# 8          2.713596e-08
# 9          2.541478e-10
# 10         9.595125e-09
# 11         2.883677e-09

# %% [markdown]
# # P4 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_4.index:
    # Extract market excess return for the date
    x = returns_2020.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_4.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2020-01-03              0.005386                 0.004403
# 2020-01-10              0.021326                 0.037181
# 2020-01-17              0.012616                -0.003166
# 2020-01-24             -0.000007                 0.006139
# 2020-01-31             -0.023351                -0.032921

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 4': monthly_portfolio_excess_return, 'Beta 4': x1_coefficient, 'Adjusted Beta 4': adj, "Residual Variance 4" : residual_variance})

# Convert the list to a DataFrame
coefficients_df_port4 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port4
# Out:
# 0.002327066138611858
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.798
# Model:                                 OLS   Adj. R-squared:                  0.731
# Method:                      Least Squares   F-statistic:                     11.86
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0411
# Time:                             10:52:36   Log-Likelihood:                 15.901
# No. Observations:                        5   AIC:                            -27.80
# Df Residuals:                            3   BIC:                            -28.58
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0019      0.006     -0.322      0.769      -0.021       0.017
# Market Excess Return     1.3262      0.385      3.444      0.041       0.101       2.552
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.377
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.601
# Skew:                          -0.793   Prob(JB):                        0.741
# Kurtosis:                       2.394   Cond. No.                         66.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.7842480648392415e-08
# 0.000985825682893838
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.977
# Model:                                 OLS   Adj. R-squared:                  0.966
# Method:                      Least Squares   F-statistic:                     86.85
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0113
# Time:                             10:52:36   Log-Likelihood:                 12.656
# No. Observations:                        4   AIC:                            -21.31
# Df Residuals:                            2   BIC:                            -22.54
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0060      0.007      0.825      0.496      -0.025       0.037
# Market Excess Return     1.0865      0.117      9.320      0.011       0.585       1.588
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.263
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.284
# Skew:                          -0.094   Prob(JB):                        0.868
# Kurtosis:                       1.709   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.0328928941626167e-08
# -0.07683710649747315
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.859
# Model:                                 OLS   Adj. R-squared:                  0.789
# Method:                      Least Squares   F-statistic:                     12.20
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0731
# Time:                             10:52:36   Log-Likelihood:                 6.8948
# No. Observations:                        4   AIC:                            -9.790
# Df Residuals:                            2   BIC:                            -11.02
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0226      0.034     -0.659      0.578      -0.170       0.125
# Market Excess Return     0.9633      0.276      3.493      0.073      -0.223       2.150
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.795
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.510
# Skew:                           0.100   Prob(JB):                        0.775
# Kurtosis:                       1.261   Cond. No.                         9.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.2106593884642384e-06
# 0.0024844836040951663
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.971
# Model:                                 OLS   Adj. R-squared:                  0.957
# Method:                      Least Squares   F-statistic:                     67.76
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0144
# Time:                             10:52:36   Log-Likelihood:                 12.584
# No. Observations:                        4   AIC:                            -21.17
# Df Residuals:                            2   BIC:                            -22.39
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0028      0.007      0.384      0.738      -0.029       0.035
# Market Excess Return     1.4158      0.172      8.232      0.014       0.676       2.156
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.329
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.346
# Skew:                          -0.350   Prob(JB):                        0.841
# Kurtosis:                       1.741   Cond. No.                         23.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.1601635518269243e-08
# 0.02378377647785336
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.882
# Model:                                 OLS   Adj. R-squared:                  0.843
# Method:                      Least Squares   F-statistic:                     22.40
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0179
# Time:                             10:52:36   Log-Likelihood:                 13.598
# No. Observations:                        5   AIC:                            -23.20
# Df Residuals:                            3   BIC:                            -23.98
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0012      0.011     -0.115      0.916      -0.035       0.033
# Market Excess Return     1.2924      0.273      4.733      0.018       0.423       2.161
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.919
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.241
# Skew:                          -0.417   Prob(JB):                        0.887
# Kurtosis:                       2.322   Cond. No.                         29.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.0681617076838625e-07
# 0.0288744459740633
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.994
# Model:                                 OLS   Adj. R-squared:                  0.991
# Method:                      Least Squares   F-statistic:                     328.6
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00303
# Time:                             10:52:36   Log-Likelihood:                 14.617
# No. Observations:                        4   AIC:                            -25.23
# Df Residuals:                            2   BIC:                            -26.46
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0046      0.005      0.989      0.427      -0.015       0.024
# Market Excess Return     1.2258      0.068     18.126      0.003       0.935       1.517
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.168
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.634
# Skew:                           0.038   Prob(JB):                        0.728
# Kurtosis:                       1.051   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.0390780328831253e-10
# 0.009785280059074633
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.894
# Model:                                 OLS   Adj. R-squared:                  0.859
# Method:                      Least Squares   F-statistic:                     25.38
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0151
# Time:                             10:52:36   Log-Likelihood:                 14.076
# No. Observations:                        5   AIC:                            -24.15
# Df Residuals:                            3   BIC:                            -24.93
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -7.968e-05      0.009     -0.009      0.993      -0.027       0.027
# Market Excess Return     1.3689      0.272      5.038      0.015       0.504       2.234
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.160
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.591
# Skew:                           0.764   Prob(JB):                        0.744
# Kurtosis:                       2.290   Cond. No.                         32.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 7.11263499462201e-08
# 0.027434139600968285
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.723
# Model:                                 OLS   Adj. R-squared:                  0.585
# Method:                      Least Squares   F-statistic:                     5.231
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.149
# Time:                             10:52:36   Log-Likelihood:                 12.518
# No. Observations:                        4   AIC:                            -21.04
# Df Residuals:                            2   BIC:                            -22.26
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0089      0.011      0.805      0.505      -0.039       0.056
# Market Excess Return     1.0338      0.452      2.287      0.149      -0.911       2.979
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.684
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.440
# Skew:                           0.516   Prob(JB):                        0.803
# Kurtosis:                       1.746   Cond. No.                         60.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.2481069873753791e-08
# -0.012900530829519584
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.996
# Model:                                 OLS   Adj. R-squared:                  0.995
# Method:                      Least Squares   F-statistic:                     555.4
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00180
# Time:                             10:52:36   Log-Likelihood:                 21.254
# No. Observations:                        4   AIC:                            -38.51
# Df Residuals:                            2   BIC:                            -39.74
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0080      0.001     -9.275      0.011      -0.012      -0.004
# Market Excess Return     0.8636      0.037     23.568      0.002       0.706       1.021
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.498
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.385
# Skew:                          -0.543   Prob(JB):                        0.825
# Kurtosis:                       1.937   Cond. No.                         43.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.518122782242179e-12
# -0.004906037294520283
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.947
# Model:                                 OLS   Adj. R-squared:                  0.929
# Method:                      Least Squares   F-statistic:                     53.26
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00531
# Time:                             10:52:36   Log-Likelihood:                 16.400
# No. Observations:                        5   AIC:                            -28.80
# Df Residuals:                            3   BIC:                            -29.58
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0072      0.005     -1.363      0.266      -0.024       0.010
# Market Excess Return     1.1239      0.154      7.298      0.005       0.634       1.614
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.019
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.872
# Skew:                          -0.968   Prob(JB):                        0.647
# Kurtosis:                       2.339   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.1504000283421595e-08
# 0.07323438984772904
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.727
# Model:                                 OLS   Adj. R-squared:                  0.591
# Method:                      Least Squares   F-statistic:                     5.336
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.147
# Time:                             10:52:36   Log-Likelihood:                 12.931
# No. Observations:                        4   AIC:                            -21.86
# Df Residuals:                            2   BIC:                            -23.09
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0332      0.019      1.785      0.216      -0.047       0.113
# Market Excess Return     0.6002      0.260      2.310      0.147      -0.518       1.718
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.375
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.676
# Skew:                           0.897   Prob(JB):                        0.713
# Kurtosis:                       2.086   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.202316342633013e-08
# 0.004644367034020619
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.645
# Model:                                 OLS   Adj. R-squared:                  0.468
# Method:                      Least Squares   F-statistic:                     3.640
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.197
# Time:                             10:52:36   Log-Likelihood:                 11.586
# No. Observations:                        4   AIC:                            -19.17
# Df Residuals:                            2   BIC:                            -20.40
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0067      0.011     -0.601      0.609      -0.055       0.041
# Market Excess Return     1.3717      0.719      1.908      0.197      -1.722       4.465
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.774
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.615
# Skew:                           0.838   Prob(JB):                        0.735
# Kurtosis:                       2.064   Cond. No.                         76.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.51955464798592e-08
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 4    Beta 4  Adjusted Beta 4  \
# 0     01                   0.002327  1.326201         1.217468
# 1     02                   0.000986  1.086534         1.057689
# 2     03                  -0.076837  0.963331         0.975554
# 3     04                   0.002484  1.415847         1.277232
# 4     05                   0.023784  1.292435         1.194957
# 5     06                   0.028874  1.225801         1.150534
# 6     07                   0.009785  1.368859         1.245906
# 7     08                   0.027434  1.033785         1.022523
# 8     09                  -0.012901  0.863573         0.909049
# 9     10                  -0.004906  1.123933         1.082622
# 10    11                   0.073234  0.600203         0.733469
# 11    12                   0.004644  1.371697         1.247798
#
#     Residual Variance 4
# 0          1.784248e-08
# 1          1.032893e-08
# 2          1.210659e-06
# 3          1.160164e-08
# 4          1.068162e-07
# 5          1.039078e-10
# 6          7.112635e-08
# 7          1.248107e-08
# 8          2.518123e-12
# 9          1.150400e-08
# 10         1.202316e-08
# 11         4.519555e-08

# %%
merged_df = pd.merge(coefficients_df_port1, coefficients_df_port2, on="Month", how="inner")
merged_df = pd.merge(merged_df, coefficients_df_port3, on="Month", how="inner")
merged_df = pd.merge(merged_df, coefficients_df_port4, on="Month", how="inner")
merged_df
# Out:
#    Month  Portfolio Excess Return 1    Beta 1  Adjusted Beta 1  \
# 0     01                   0.007853  1.364170         1.242780
# 1     02                  -0.010017  0.800330         0.866887
# 2     03                  -0.038879  0.773050         0.848700
# 3     04                   0.006244  0.186866         0.457910
# 4     05                   0.016024  0.643116         0.762077
# 5     06                   0.008779  0.850517         0.900345
# 6     07                   0.004470  0.535953         0.690636
# 7     08                   0.009873  1.251173         1.167449
# 8     09                   0.002822  0.845086         0.896724
# 9     10                   0.003698  0.681464         0.787643
# 10    11                   0.048548  0.383739         0.589159
# 11    12                   0.007574  0.445367         0.630245
#
#     Residual Variance 1  Portfolio Excess Return 2    Beta 2  Adjusted Beta 2  \
# 0          6.580282e-09                   0.002604  1.388659         1.259106
# 1          1.360375e-08                  -0.004345  0.920543         0.947029
# 2          3.101967e-07                  -0.043225  0.901257         0.934171
# 3          2.050005e-11                   0.020614  0.538285         0.692190
# 4          1.707808e-07                   0.019550  0.365421         0.576948
# 5          5.342870e-08                   0.008613  0.643525         0.762350
# 6          5.896726e-09                   0.007116  0.655867         0.770578
# 7          1.982191e-08                   0.009269  0.708245         0.805497
# 8          6.720834e-09                   0.002965  0.913335         0.942224
# 9          5.374955e-09                   0.009472  0.974687         0.983125
# 10         1.545406e-08                   0.059364  1.307067         1.204712
# 11         2.812062e-12                   0.016943  0.101181         0.400787
#
#     Residual Variance 2  Portfolio Excess Return 3    Beta 3  Adjusted Beta 3  \
# 0          8.164657e-10                   0.003473  1.601114         1.400743
# 1          4.035424e-09                  -0.006591  1.098903         1.065935
# 2          5.698578e-11                  -0.056922  0.930789         0.953860
# 3          8.998455e-09                   0.000184  1.076532         1.051021
# 4          2.867764e-10                   0.016696  1.049165         1.032776
# 5          2.324373e-09                   0.014187  0.989626         0.993084
# 6          5.160896e-09                   0.013485  0.977473         0.984982
# 7          4.420234e-10                   0.022292  1.310727         1.207151
# 8          1.788822e-09                  -0.008183  1.373977         1.249318
# 9          1.274216e-09                  -0.007013  0.952170         0.968113
# 10         8.413745e-09                   0.078070  0.722230         0.814820
# 11         1.885633e-10                   0.002119  1.145513         1.097009
#
#     Residual Variance 3  Portfolio Excess Return 4    Beta 4  Adjusted Beta 4  \
# 0          2.781264e-09                   0.002327  1.326201         1.217468
# 1          4.486711e-07                   0.000986  1.086534         1.057689
# 2          2.461687e-07                  -0.076837  0.963331         0.975554
# 3          4.143113e-08                   0.002484  1.415847         1.277232
# 4          2.166952e-07                   0.023784  1.292435         1.194957
# 5          3.268871e-09                   0.028874  1.225801         1.150534
# 6          4.936284e-10                   0.009785  1.368859         1.245906
# 7          6.907396e-11                   0.027434  1.033785         1.022523
# 8          2.713596e-08                  -0.012901  0.863573         0.909049
# 9          2.541478e-10                  -0.004906  1.123933         1.082622
# 10         9.595125e-09                   0.073234  0.600203         0.733469
# 11         2.883677e-09                   0.004644  1.371697         1.247798
#
#     Residual Variance 4
# 0          1.784248e-08
# 1          1.032893e-08
# 2          1.210659e-06
# 3          1.160164e-08
# 4          1.068162e-07
# 5          1.039078e-10
# 6          7.112635e-08
# 7          1.248107e-08
# 8          2.518123e-12
# 9          1.150400e-08
# 10         1.202316e-08
# 11         4.519555e-08

# %%
# Assuming your DataFrame is named df
new_df = merged_df[['Portfolio Excess Return 1', 'Adjusted Beta 1','Beta 1','Residual Variance 1']].copy()  # Selecting columns for Portfolio 1
new_df.columns = ['Portfolio Excess Return', 'Adjusted Beta','Beta','Residual Variance']  # Renaming columns

# Concatenating data for other portfolios
for i in range(2, 5):
    temp_df = merged_df[['Portfolio Excess Return {}'.format(i), 'Adjusted Beta {}'.format(i), 'Beta {}'.format(i), 'Residual Variance {}'.format(i) ]].copy()
    temp_df.columns = ['Portfolio Excess Return', 'Adjusted Beta','Beta', 'Residual Variance']
    new_df = pd.concat([new_df, temp_df], ignore_index=True)

new_df
# Out:
#     Portfolio Excess Return  Adjusted Beta      Beta  Residual Variance
# 0                  0.007853       1.242780  1.364170       6.580282e-09
# 1                 -0.010017       0.866887  0.800330       1.360375e-08
# 2                 -0.038879       0.848700  0.773050       3.101967e-07
# 3                  0.006244       0.457910  0.186866       2.050005e-11
# 4                  0.016024       0.762077  0.643116       1.707808e-07
# 5                  0.008779       0.900345  0.850517       5.342870e-08
# 6                  0.004470       0.690636  0.535953       5.896726e-09
# 7                  0.009873       1.167449  1.251173       1.982191e-08
# 8                  0.002822       0.896724  0.845086       6.720834e-09
# 9                  0.003698       0.787643  0.681464       5.374955e-09
# 10                 0.048548       0.589159  0.383739       1.545406e-08
# 11                 0.007574       0.630245  0.445367       2.812062e-12
# 12                 0.002604       1.259106  1.388659       8.164657e-10
# 13                -0.004345       0.947029  0.920543       4.035424e-09
# 14                -0.043225       0.934171  0.901257       5.698578e-11
# 15                 0.020614       0.692190  0.538285       8.998455e-09
# 16                 0.019550       0.576948  0.365421       2.867764e-10
# 17                 0.008613       0.762350  0.643525       2.324373e-09
# 18                 0.007116       0.770578  0.655867       5.160896e-09
# 19                 0.009269       0.805497  0.708245       4.420234e-10
# 20                 0.002965       0.942224  0.913335       1.788822e-09
# 21                 0.009472       0.983125  0.974687       1.274216e-09
# 22                 0.059364       1.204712  1.307067       8.413745e-09
# 23                 0.016943       0.400787  0.101181       1.885633e-10
# 24                 0.003473       1.400743  1.601114       2.781264e-09
# 25                -0.006591       1.065935  1.098903       4.486711e-07
# 26                -0.056922       0.953860  0.930789       2.461687e-07
# 27                 0.000184       1.051021  1.076532       4.143113e-08
# 28                 0.016696       1.032776  1.049165       2.166952e-07
# 29                 0.014187       0.993084  0.989626       3.268871e-09
# 30                 0.013485       0.984982  0.977473       4.936284e-10
# 31                 0.022292       1.207151  1.310727       6.907396e-11
# 32                -0.008183       1.249318  1.373977       2.713596e-08
# 33                -0.007013       0.968113  0.952170       2.541478e-10
# 34                 0.078070       0.814820  0.722230       9.595125e-09
# 35                 0.002119       1.097009  1.145513       2.883677e-09
# 36                 0.002327       1.217468  1.326201       1.784248e-08
# 37                 0.000986       1.057689  1.086534       1.032893e-08
# 38                -0.076837       0.975554  0.963331       1.210659e-06
# 39                 0.002484       1.277232  1.415847       1.160164e-08
# 40                 0.023784       1.194957  1.292435       1.068162e-07
# 41                 0.028874       1.150534  1.225801       1.039078e-10
# 42                 0.009785       1.245906  1.368859       7.112635e-08
# 43                 0.027434       1.022523  1.033785       1.248107e-08
# 44                -0.012901       0.909049  0.863573       2.518123e-12
# 45                -0.004906       1.082622  1.123933       1.150400e-08
# 46                 0.073234       0.733469  0.600203       1.202316e-08
# 47                 0.004644       1.247798  1.371697       4.519555e-08

# %%
# Normalize residual variance
residual_variance_mean = new_df['Residual Variance'].mean()
residual_variance_std = new_df['Residual Variance'].std()
normalized_residual_variance = (new_df['Residual Variance'] - residual_variance_mean) / residual_variance_std

# Replace the original column with the normalized values
new_df['Normalized Residual Variance'] = normalized_residual_variance

# %%
merged_df.columns
# Out:
# Index(['Month', 'Portfolio Excess Return 1', 'Beta 1', 'Adjusted Beta 1',
#        'Residual Variance 1', 'Portfolio Excess Return 2', 'Beta 2',
#        'Adjusted Beta 2', 'Residual Variance 2', 'Portfolio Excess Return 3',
#        'Beta 3', 'Adjusted Beta 3', 'Residual Variance 3',
#        'Portfolio Excess Return 4', 'Beta 4', 'Adjusted Beta 4',
#        'Residual Variance 4'],
#       dtype='object')

# %% [markdown]
# # SML #

# %%
import statsmodels.api as sm
import pandas as pd

x = new_df['Adjusted Beta'].values # Monthly  est. Adj Beta 2020

y = new_df['Portfolio Excess Return'].values # Monthly Portfolio excess return
    
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
inter = results.params[0]
risk_premium = results.params[1]  # Coefficient
p_value_1 = results.pvalues[1]  # P-value
p_value_2 = results.pvalues[0]
std_error_1 = results.bse[1]  # Standard error
std_error_2 = results.bse[0]
t_stat_x1 = results.tvalues[1]
t_stat_const = results.tvalues[0]

# Print the retrieved values
print("Intercept:", inter)
print("Risk premium (Coefficient):", risk_premium)
print("P-value x1:", p_value_1)
print("P-value const:", p_value_2)
print("Std. error x1:", std_error_1)
print("Std. error const :", std_error_2)
print("T-statistic for X1:", t_stat_x1)
print("T-statistic for const:", t_stat_const)
# Out:
# (48, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.014
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.6462
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.426
# Time:                        10:52:36   Log-Likelihood:                 106.57
# No. Observations:                  48   AIC:                            -209.1
# Df Residuals:                      46   BIC:                            -205.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0199      0.017      1.187      0.241      -0.014       0.054
# x1            -0.0137      0.017     -0.804      0.426      -0.048       0.021
# ==============================================================================
# Omnibus:                        8.158   Durbin-Watson:                   1.900
# Prob(Omnibus):                  0.017   Jarque-Bera (JB):               14.262
# Skew:                          -0.278   Prob(JB):                     0.000800
# Kurtosis:                       5.612   Cond. No.                         8.55
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept: 0.019941117056903247
# Risk premium (Coefficient): -0.013691644189124587
# P-value x1: 0.4256135366848455
# P-value const: 0.24118049851463333
# Std. error x1: 0.017032409257534156
# Std. error const : 0.01679448148513877
# T-statistic for X1: -0.8038583374849446
# T-statistic for const: 1.1873612814154992

# %% [markdown]
# # NON-Linearity #

# %%
import statsmodels.api as sm
import pandas as pd

# Assuming new_df contains the required data

# Calculate adjusted beta squared
raw_beta_sqr = new_df['Beta'].values ** 2
adjusted_beta_sqr = 0.67 * raw_beta_sqr + 0.33 * 1.0

# Prepare the data
x = new_df['Adjusted Beta'].values
x_squared = adjusted_beta_sqr
y = new_df['Portfolio Excess Return'].values

# Prepare the independent variables matrix
X = sm.add_constant(pd.DataFrame({'Adjusted Beta': x, 'Adjusted Beta Squared': x_squared}))

# Fit the nonlinear OLS model
model = sm.OLS(y, X)
results = model.fit()

# Print the summary of results
print(results.summary())

# Retrieve specific values from the model summary
intercept = results.params[0]
gamma1 = results.params[1]  # Coefficient for adjusted beta
gamma2 = results.params[2]  # Coefficient for adjusted beta squared
p_value_int = results.pvalues[0]
p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
std_error_int = results.bse[0] 
std_error_gamma1 = results.bse[1]  # Standard error for gamma1
std_error_gamma2 = results.bse[2]  # Standard error for gamma2
t_stat_int = results.tvalues[0]
t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2

# Print the retrieved values
print("Intercept:", intercept)
print("Coefficient for adjusted beta (γ1):", gamma1)
print("Coefficient for adjusted beta squared (γ2):", gamma2)
print("Std. error for intercept:", std_error_int)
print("Std. error for γ1:", std_error_gamma1)
print("Std. error for γ2:", std_error_gamma2)
print("T-statistic for intercept:", t_stat_int)
print("T-statistic for γ1:", t_stat_gamma1)
print("T-statistic for γ2:", t_stat_gamma2)
print("P-value for intercept:", p_value_int)
print("P-value for γ1:", p_value_gamma1)
print("P-value for γ2:", p_value_gamma2)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.054
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.277
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.289
# Time:                        10:52:36   Log-Likelihood:                 107.56
# No. Observations:                  48   AIC:                            -209.1
# Df Residuals:                      45   BIC:                            -203.5
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0586      0.033      1.795      0.079      -0.007       0.124
# Adjusted Beta            -0.1122      0.074     -1.526      0.134      -0.260       0.036
# Adjusted Beta Squared     0.0559      0.041      1.377      0.175      -0.026       0.138
# ==============================================================================
# Omnibus:                        7.177   Durbin-Watson:                   1.924
# Prob(Omnibus):                  0.028   Jarque-Bera (JB):               12.782
# Skew:                          -0.018   Prob(JB):                      0.00168
# Kurtosis:                       5.528   Cond. No.                         40.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept: 0.05862982869447553
# Coefficient for adjusted beta (γ1): -0.1121929898985068
# Coefficient for adjusted beta squared (γ2): 0.055875877042021856
# Std. error for intercept: 0.03265495572288028
# Std. error for γ1: 0.07350736101417958
# Std. error for γ2: 0.040584943279354524
# T-statistic for intercept: 1.795434334439948
# T-statistic for γ1: -1.5262823797587395
# T-statistic for γ2: 1.3767637090784306
# P-value for intercept: 0.07930157038212943
# P-value for γ1: 0.1339381258650567
# P-value for γ2: 0.1753967463433405
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:26: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept = results.params[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma1 = results.params[1]  # Coefficient for adjusted beta
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma2 = results.params[2]  # Coefficient for adjusted beta squared
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_int = results.pvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_int = results.bse[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma1 = results.bse[1]  # Standard error for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma2 = results.bse[2]  # Standard error for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_int = results.tvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/2626776032.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2

# %% [markdown]
# # Non-systematic risk

# %%
import statsmodels.api as sm
import pandas as pd

# Assuming new_df contains the required data

# Calculate adjusted beta squared
raw_beta_sqr = new_df['Beta'].values ** 2
adjusted_beta_sqr = 0.67 * raw_beta_sqr + 0.33 * 1.0

# Prepare the data
x = new_df['Adjusted Beta'].values
x_squared = adjusted_beta_sqr
residual_variance = new_df['Normalized Residual Variance'].values
y = new_df['Portfolio Excess Return'].values

# Prepare the independent variables matrix
X = sm.add_constant(pd.DataFrame({'Adjusted Beta': x, 'Adjusted Beta Squared': x_squared, 'Residual Variance': residual_variance}))

# Fit the nonlinear OLS model
model = sm.OLS(y, X)
results = model.fit()

# Print the summary of results
print(results.summary())

# Retrieve specific values from the model summary
intercept = results.params[0]
gamma1 = results.params[1]  # Coefficient for adjusted beta
gamma2 = results.params[2]  # Coefficient for adjusted beta squared
gamma3 = results.params[3]  # Coefficient for residual variance
p_value_int = results.pvalues[0]
p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
p_value_gamma3 = results.pvalues[3]  # P-value for gamma3
std_error_int = results.bse[0] 
std_error_gamma1 = results.bse[1]  # Standard error for gamma1
std_error_gamma2 = results.bse[2]  # Standard error for gamma2
std_error_gamma3 = results.bse[3]  # Standard error for gamma3
t_stat_int = results.tvalues[0]
t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2
t_stat_gamma3 = results.tvalues[3]  # T-statistic for gamma3

# Function to round the values
def round_to_six_decimals(value):
    return round(value, 6)

# Print the retrieved values rounded to the sixth decimal point
print("Intercept:", round_to_six_decimals(intercept))
print("Coefficient for adjusted beta (γ1):", round_to_six_decimals(gamma1))
print("Coefficient for adjusted beta squared (γ2):", round_to_six_decimals(gamma2))
print("Coefficient for residual variance (γ3):", round_to_six_decimals(gamma3))
print("Std. error for intercept:", round_to_six_decimals(std_error_int))
print("Std. error for γ1:", round_to_six_decimals(std_error_gamma1))
print("Std. error for γ2:", round_to_six_decimals(std_error_gamma2))
print("Std. error for γ3:", round_to_six_decimals(std_error_gamma3))
print("T-statistic for intercept:", round_to_six_decimals(t_stat_int))
print("T-statistic for γ1:", round_to_six_decimals(t_stat_gamma1))
print("T-statistic for γ2:", round_to_six_decimals(t_stat_gamma2))
print("T-statistic for γ3:", round_to_six_decimals(t_stat_gamma3))
print("P-value for intercept:", round_to_six_decimals(p_value_int))
print("P-value for γ1:", round_to_six_decimals(p_value_gamma1))
print("P-value for γ2:", round_to_six_decimals(p_value_gamma2))
print("P-value for γ3:", round_to_six_decimals(p_value_gamma3))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.310
# Model:                            OLS   Adj. R-squared:                  0.263
# Method:                 Least Squares   F-statistic:                     6.582
# Date:                Sat, 04 May 2024   Prob (F-statistic):           0.000900
# Time:                        10:52:36   Log-Likelihood:                 115.13
# No. Observations:                  48   AIC:                            -222.3
# Df Residuals:                      44   BIC:                            -214.8
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0368      0.029      1.283      0.206      -0.021       0.095
# Adjusted Beta            -0.0602      0.065     -0.930      0.357      -0.191       0.070
# Adjusted Beta Squared     0.0278      0.036      0.778      0.441      -0.044       0.100
# Residual Variance        -0.0138      0.003     -4.040      0.000      -0.021      -0.007
# ==============================================================================
# Omnibus:                       11.364   Durbin-Watson:                   2.193
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               13.973
# Skew:                           0.801   Prob(JB):                     0.000924
# Kurtosis:                       5.103   Cond. No.                         41.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept = results.params[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma1 = results.params[1]  # Coefficient for adjusted beta
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma2 = results.params[2]  # Coefficient for adjusted beta squared
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma3 = results.params[3]  # Coefficient for residual variance
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_int = results.pvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma3 = results.pvalues[3]  # P-value for gamma3
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_int = results.bse[0]
# Intercept: 0.036836
# Coefficient for adjusted beta (γ1): -0.060238
# Coefficient for adjusted beta squared (γ2): 0.027792
# Coefficient for residual variance (γ3): -0.013806
# Std. error for intercept: 0.028716
# Std. error for γ1: 0.064779
# Std. error for γ2: 0.035736
# Std. error for γ3: 0.003417
# T-statistic for intercept: 1.282782
# T-statistic for γ1: -0.929904
# T-statistic for γ2: 0.77771
# T-statistic for γ3: -4.040027
# P-value for intercept: 0.206285
# P-value for γ1: 0.357495
# P-value for γ2: 0.440902
# P-value for γ3: 0.000211
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma1 = results.bse[1]  # Standard error for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma2 = results.bse[2]  # Standard error for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma3 = results.bse[3]  # Standard error for gamma3
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_int = results.tvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_30929/3466800342.py:42: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma3 = results.tvalues[3]  # T-statistic for gamma3
