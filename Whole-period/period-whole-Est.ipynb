# %%
import pandas as pd

returns_df = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Returns_2018-2023.csv')

# %%
returns_df.head()
# Out:
#    Unnamed: 0        Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 0           0  2018-01-12       0.029327      -0.044570            0.045761
# 1           1  2018-01-19       0.013632       0.040736            0.022956
# 2           2  2018-01-26       0.004538      -0.007576            0.013324
# 3           3  2018-02-02      -0.027427      -0.033079           -0.046367
# 4           4  2018-02-09      -0.044646      -0.072697           -0.066763
#
#    Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 0          0.032797              0.072444                    0.012517
# 1          0.131214             -0.021934                    0.067308
# 2         -0.006357              0.078472                    0.019305
# 3         -0.024787             -0.030991                   -0.015783
# 4         -0.023502              0.006656                   -0.042976
#
#    Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 0                                   0.032906                     0.040625
# 1                                  -0.031857                    -0.025826
# 2                                   0.011312                     0.029593
# 3                                  -0.073208                    -0.042515
# 4                                   0.036753                     0.003752
#
#    ...  Snam 2018-2023  Stellantis 2018-2023  Stmicroeletronics 2018-2023  \
# 0  ...       -0.017408              0.067525                     0.028307
# 1  ...        0.002461              0.021955                     0.023023
# 2  ...       -0.016200              0.012786                    -0.067025
# 3  ...       -0.044411             -0.050907                    -0.030414
# 4  ...       -0.069191             -0.073222                    -0.070308
#
#    Telecom 2018-2023  Tenaris 2018-2023  Terna 2018-2023  Unicredit 2018-2023  \
# 0           0.006770           0.043350        -0.023228             0.075077
# 1          -0.030262           0.002817         0.008200            -0.004007
# 2          -0.000693           0.021067        -0.002440             0.031609
# 3          -0.015406          -0.054333        -0.035671            -0.021170
# 4          -0.014942          -0.069818        -0.050518             0.010700
#
#    Unipol 2018-2023    BOT 3m  Risk Premium
# 0          0.052374 -0.008654      0.037980
# 1          0.011628 -0.008673      0.022305
# 2          0.031724 -0.009000      0.013538
# 3         -0.032308 -0.008923     -0.018504
# 4         -0.034769 -0.008865     -0.035781
#
# [5 rows x 43 columns]

# %%
returns_df.drop(columns='Unnamed: 0', inplace = True)

# %%
import numpy as np

# Copy the data to avoid modifying the original DataFrame
returns_excess = returns_df.copy()

# Calculate excess returns for each stock by subtracting the risk-free rate
risk_free_rate = returns_excess['BOT 3m'].values  # Convert Series to NumPy array
returns_excess.iloc[:, 2:-2] -= risk_free_rate[:, np.newaxis]

# Display the first few rows of the new DataFrame
returns_excess.head()
# Out:
#          Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 0  2018-01-12       0.029327      -0.035916            0.054415
# 1  2018-01-19       0.013632       0.049409            0.031629
# 2  2018-01-26       0.004538       0.001424            0.022324
# 3  2018-02-02      -0.027427      -0.024156           -0.037444
# 4  2018-02-09      -0.044646      -0.063832           -0.057898
#
#    Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 0          0.041451              0.081097                    0.021171
# 1          0.139887             -0.013260                    0.075981
# 2          0.002643              0.087472                    0.028305
# 3         -0.015864             -0.022068                   -0.006860
# 4         -0.014637              0.015522                   -0.034111
#
#    Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 0                                   0.041560                     0.049279
# 1                                  -0.023184                    -0.017153
# 2                                   0.020312                     0.038593
# 3                                  -0.064285                    -0.033592
# 4                                   0.045619                     0.012618
#
#    Banco Bpm 2018-2023  ...  Snam 2018-2023  Stellantis 2018-2023  \
# 0             0.041451  ...       -0.008754              0.076179
# 1             0.139887  ...        0.011134              0.030628
# 2             0.002643  ...       -0.007200              0.021786
# 3            -0.015864  ...       -0.035488             -0.041984
# 4            -0.014637  ...       -0.060325             -0.064356
#
#    Stmicroeletronics 2018-2023  Telecom 2018-2023  Tenaris 2018-2023  \
# 0                     0.036961           0.015424           0.052004
# 1                     0.031696          -0.021589           0.011490
# 2                    -0.058025           0.008307           0.030067
# 3                    -0.021491          -0.006483          -0.045410
# 4                    -0.061443          -0.006077          -0.060953
#
#    Terna 2018-2023  Unicredit 2018-2023  Unipol 2018-2023    BOT 3m  \
# 0        -0.014574             0.083731          0.061028 -0.008654
# 1         0.016873             0.004666          0.020301 -0.008673
# 2         0.006560             0.040609          0.040724 -0.009000
# 3        -0.026748            -0.012247         -0.023385 -0.008923
# 4        -0.041652             0.019565         -0.025903 -0.008865
#
#    Risk Premium
# 0      0.037980
# 1      0.022305
# 2      0.013538
# 3     -0.018504
# 4     -0.035781
#
# [5 rows x 42 columns]

# %%
import statsmodels.api as sm

# Create an empty DataFrame to store the beta values
beta_df = pd.DataFrame(index=returns_df.columns[1:-2], columns=['Beta'])

# Iterate over each asset
for asset in returns_excess.columns[1:-2]:
    # Extract excess returns of the asset and the market portfolio
    x = returns_df['FTSEMIB Index'] - returns_df['BOT 3m']  # Market excess return
    y = returns_df[asset] - returns_df['BOT 3m']  # Asset excess return
    
    # Add a constant to the independent variable (market excess return)
    x = sm.add_constant(x)
    
    # Fit OLS model
    model = sm.OLS(y, x)
    results = model.fit()

    print(results.summary())
    
    # Extract the beta coefficient (slope)
    beta = results.params[0]  # Index 0 corresponds to the coefficient of the independent variable
    
    # Store the beta coefficient in the DataFrame
    beta_df.loc[asset, 'Beta'] = beta

# Display the DataFrame with beta values
beta_df
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 6.273e+33
# Date:                Sat, 04 May 2024   Prob (F-statistic):               0.00
# Time:                        20:01:05   Log-Likelihood:                 11807.
# No. Observations:                 312   AIC:                        -2.361e+04
# Df Residuals:                     310   BIC:                        -2.360e+04
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -1.003e-18   5.08e-19     -1.973      0.049      -2e-18   -2.58e-21
# 0              1.0000   1.26e-17   7.92e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                       75.491   Durbin-Watson:                   1.164
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              346.401
# Skew:                           0.920   Prob(JB):                     6.02e-76
# Kurtosis:                       7.823   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.588
# Model:                            OLS   Adj. R-squared:                  0.587
# Method:                 Least Squares   F-statistic:                     442.7
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.14e-61
# Time:                        20:01:05   Log-Likelihood:                 660.44
# No. Observations:                 312   AIC:                            -1317.
# Df Residuals:                     310   BIC:                            -1309.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.002     -0.424      0.672      -0.004       0.003
# 0              0.8699      0.041     21.040      0.000       0.789       0.951
# ==============================================================================
# Omnibus:                        8.262   Durbin-Watson:                   2.160
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):               13.831
# Skew:                           0.078   Prob(JB):                     0.000992
# Kurtosis:                       4.020   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.397
# Model:                            OLS   Adj. R-squared:                  0.395
# Method:                 Least Squares   F-statistic:                     204.5
# Date:                Sat, 04 May 2024   Prob (F-statistic):           5.68e-36
# Time:                        20:01:05   Log-Likelihood:                 544.63
# No. Observations:                 312   AIC:                            -1085.
# Df Residuals:                     310   BIC:                            -1078.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0018      0.002      0.753      0.452      -0.003       0.007
# 0              0.8569      0.060     14.299      0.000       0.739       0.975
# ==============================================================================
# Omnibus:                        9.259   Durbin-Watson:                   2.060
# Prob(Omnibus):                  0.010   Jarque-Bera (JB):               11.979
# Skew:                           0.253   Prob(JB):                      0.00251
# Kurtosis:                       3.816   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.646
# Model:                            OLS   Adj. R-squared:                  0.645
# Method:                 Least Squares   F-statistic:                     565.9
# Date:                Sat, 04 May 2024   Prob (F-statistic):           6.78e-72
# Time:                        20:01:05   Log-Likelihood:                 629.49
# No. Observations:                 312   AIC:                            -1255.
# Df Residuals:                     310   BIC:                            -1247.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.002      0.844      0.400      -0.002       0.005
# 0              1.0861      0.046     23.788      0.000       0.996       1.176
# ==============================================================================
# Omnibus:                       51.493   Durbin-Watson:                   2.201
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              554.488
# Skew:                           0.077   Prob(JB):                    3.93e-121
# Kurtosis:                       9.529   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.525
# Model:                            OLS   Adj. R-squared:                  0.523
# Method:                 Least Squares   F-statistic:                     342.4
# Date:                Sat, 04 May 2024   Prob (F-statistic):           5.11e-52
# Time:                        20:01:05   Log-Likelihood:                 536.11
# No. Observations:                 312   AIC:                            -1068.
# Df Residuals:                     310   BIC:                            -1061.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.002      0.436      0.663      -0.004       0.006
# 0              1.1395      0.062     18.503      0.000       1.018       1.261
# ==============================================================================
# Omnibus:                       10.371   Durbin-Watson:                   1.852
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               16.561
# Skew:                           0.195   Prob(JB):                     0.000253
# Kurtosis:                       4.059   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.708
# Model:                            OLS   Adj. R-squared:                  0.707
# Method:                 Least Squares   F-statistic:                     753.1
# Date:                Sat, 04 May 2024   Prob (F-statistic):           5.92e-85
# Time:                        20:01:05   Log-Likelihood:                 675.48
# No. Observations:                 312   AIC:                            -1347.
# Df Residuals:                     310   BIC:                            -1339.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.002      0.302      0.763      -0.003       0.004
# 0              1.0812      0.039     27.443      0.000       1.004       1.159
# ==============================================================================
# Omnibus:                      110.797   Durbin-Watson:                   2.474
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1732.502
# Skew:                          -0.995   Prob(JB):                         0.00
# Kurtosis:                      14.371   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.267
# Model:                            OLS   Adj. R-squared:                  0.265
# Method:                 Least Squares   F-statistic:                     113.1
# Date:                Sat, 04 May 2024   Prob (F-statistic):           9.96e-23
# Time:                        20:01:05   Log-Likelihood:                 379.78
# No. Observations:                 312   AIC:                            -755.6
# Df Residuals:                     310   BIC:                            -748.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0079      0.004     -1.941      0.053      -0.016       0.000
# 0              1.0811      0.102     10.636      0.000       0.881       1.281
# ==============================================================================
# Omnibus:                      103.575   Durbin-Watson:                   1.917
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3000.702
# Skew:                          -0.671   Prob(JB):                         0.00
# Kurtosis:                      18.133   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.533
# Model:                            OLS   Adj. R-squared:                  0.531
# Method:                 Least Squares   F-statistic:                     353.3
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.89e-53
# Time:                        20:01:05   Log-Likelihood:                 554.15
# No. Observations:                 312   AIC:                            -1104.
# Df Residuals:                     310   BIC:                            -1097.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0025      0.002      1.050      0.295      -0.002       0.007
# 0              1.0925      0.058     18.796      0.000       0.978       1.207
# ==============================================================================
# Omnibus:                       22.065   Durbin-Watson:                   2.032
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               44.384
# Skew:                           0.377   Prob(JB):                     2.30e-10
# Kurtosis:                       4.687   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.646
# Model:                            OLS   Adj. R-squared:                  0.645
# Method:                 Least Squares   F-statistic:                     565.9
# Date:                Sat, 04 May 2024   Prob (F-statistic):           6.78e-72
# Time:                        20:01:05   Log-Likelihood:                 629.49
# No. Observations:                 312   AIC:                            -1255.
# Df Residuals:                     310   BIC:                            -1247.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.002      0.844      0.400      -0.002       0.005
# 0              1.0861      0.046     23.788      0.000       0.996       1.176
# ==============================================================================
# Omnibus:                       51.493   Durbin-Watson:                   2.201
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              554.488
# Skew:                           0.077   Prob(JB):                    3.93e-121
# Kurtosis:                       9.529   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.376
# Method:                 Least Squares   F-statistic:                     188.2
# Date:                Sat, 04 May 2024   Prob (F-statistic):           8.42e-34
# Time:                        20:01:05   Log-Likelihood:                 531.18
# No. Observations:                 312   AIC:                            -1058.
# Df Residuals:                     310   BIC:                            -1051.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0028      0.003      1.125      0.262      -0.002       0.008
# 0              0.8584      0.063     13.719      0.000       0.735       0.982
# ==============================================================================
# Omnibus:                       10.922   Durbin-Watson:                   1.935
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               13.388
# Skew:                           0.320   Prob(JB):                      0.00124
# Kurtosis:                       3.788   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.516
# Model:                            OLS   Adj. R-squared:                  0.514
# Method:                 Least Squares   F-statistic:                     330.1
# Date:                Sat, 04 May 2024   Prob (F-statistic):           9.68e-51
# Time:                        20:01:05   Log-Likelihood:                 638.23
# No. Observations:                 312   AIC:                            -1272.
# Df Residuals:                     310   BIC:                            -1265.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0001      0.002     -0.057      0.954      -0.004       0.003
# 0              0.8067      0.044     18.170      0.000       0.719       0.894
# ==============================================================================
# Omnibus:                        7.496   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):               11.224
# Skew:                           0.123   Prob(JB):                      0.00365
# Kurtosis:                       3.896   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.169
# Method:                 Least Squares   F-statistic:                     64.38
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.13e-14
# Time:                        20:01:05   Log-Likelihood:                 494.82
# No. Observations:                 312   AIC:                            -985.6
# Df Residuals:                     310   BIC:                            -978.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0017      0.003     -0.584      0.560      -0.007       0.004
# 0              0.5641      0.070      8.024      0.000       0.426       0.702
# ==============================================================================
# Omnibus:                       16.864   Durbin-Watson:                   1.711
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               40.366
# Skew:                           0.177   Prob(JB):                     1.72e-09
# Kurtosis:                       4.726   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.689
# Model:                            OLS   Adj. R-squared:                  0.688
# Method:                 Least Squares   F-statistic:                     686.3
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.40e-80
# Time:                        20:01:05   Log-Likelihood:                 710.75
# No. Observations:                 312   AIC:                            -1418.
# Df Residuals:                     310   BIC:                            -1410.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.001     -0.215      0.830      -0.003       0.002
# 0              0.9218      0.035     26.198      0.000       0.853       0.991
# ==============================================================================
# Omnibus:                        9.624   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):               14.143
# Skew:                           0.210   Prob(JB):                     0.000849
# Kurtosis:                       3.955   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Sat, 04 May 2024   Prob (F-statistic):           4.08e-76
# Time:                        20:01:05   Log-Likelihood:                 668.22
# No. Observations:                 312   AIC:                            -1332.
# Df Residuals:                     310   BIC:                            -1325.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0003      0.002     -0.168      0.867      -0.003       0.003
# 0              1.0061      0.040     24.949      0.000       0.927       1.085
# ==============================================================================
# Omnibus:                       55.697   Durbin-Watson:                   1.881
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              201.469
# Skew:                           0.718   Prob(JB):                     1.79e-44
# Kurtosis:                       6.665   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.428
# Model:                            OLS   Adj. R-squared:                  0.426
# Method:                 Least Squares   F-statistic:                     232.2
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.61e-39
# Time:                        20:01:05   Log-Likelihood:                 578.95
# No. Observations:                 312   AIC:                            -1154.
# Df Residuals:                     310   BIC:                            -1146.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.002      0.248      0.805      -0.004       0.005
# 0              0.8180      0.054     15.238      0.000       0.712       0.924
# ==============================================================================
# Omnibus:                       12.570   Durbin-Watson:                   2.042
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               27.424
# Skew:                           0.066   Prob(JB):                     1.11e-06
# Kurtosis:                       4.446   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.513
# Model:                            OLS   Adj. R-squared:                  0.511
# Method:                 Least Squares   F-statistic:                     326.6
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.28e-50
# Time:                        20:01:05   Log-Likelihood:                 640.26
# No. Observations:                 312   AIC:                            -1277.
# Df Residuals:                     310   BIC:                            -1269.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0022      0.002      1.215      0.225      -0.001       0.006
# 0              0.7971      0.044     18.073      0.000       0.710       0.884
# ==============================================================================
# Omnibus:                       32.691   Durbin-Watson:                   1.932
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               75.789
# Skew:                           0.517   Prob(JB):                     3.49e-17
# Kurtosis:                       5.182   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.619
# Model:                            OLS   Adj. R-squared:                  0.618
# Method:                 Least Squares   F-statistic:                     503.5
# Date:                Sat, 04 May 2024   Prob (F-statistic):           6.54e-67
# Time:                        20:01:05   Log-Likelihood:                 631.98
# No. Observations:                 312   AIC:                            -1260.
# Df Residuals:                     310   BIC:                            -1252.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.002      0.541      0.589      -0.003       0.005
# 0              1.0163      0.045     22.439      0.000       0.927       1.105
# ==============================================================================
# Omnibus:                        7.476   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                9.635
# Skew:                           0.199   Prob(JB):                      0.00809
# Kurtosis:                       3.764   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.833
# Model:                            OLS   Adj. R-squared:                  0.833
# Method:                 Least Squares   F-statistic:                     1551.
# Date:                Sat, 04 May 2024   Prob (F-statistic):          1.15e-122
# Time:                        20:01:05   Log-Likelihood:                 821.90
# No. Observations:                 312   AIC:                            -1640.
# Df Residuals:                     310   BIC:                            -1632.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0002      0.001     -0.246      0.806      -0.002       0.002
# 0              0.9703      0.025     39.377      0.000       0.922       1.019
# ==============================================================================
# Omnibus:                       39.172   Durbin-Watson:                   2.114
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              180.718
# Skew:                          -0.360   Prob(JB):                     5.72e-40
# Kurtosis:                       6.658   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     355.2
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.50e-53
# Time:                        20:01:05   Log-Likelihood:                 651.18
# No. Observations:                 312   AIC:                            -1298.
# Df Residuals:                     310   BIC:                            -1291.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0017      0.002     -0.988      0.324      -0.005       0.002
# 0              0.8027      0.043     18.846      0.000       0.719       0.886
# ==============================================================================
# Omnibus:                        8.242   Durbin-Watson:                   2.174
# Prob(Omnibus):                  0.016   Jarque-Bera (JB):               10.938
# Skew:                           0.211   Prob(JB):                      0.00421
# Kurtosis:                       3.814   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.534
# Model:                            OLS   Adj. R-squared:                  0.532
# Method:                 Least Squares   F-statistic:                     354.7
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.77e-53
# Time:                        20:01:05   Log-Likelihood:                 605.29
# No. Observations:                 312   AIC:                            -1207.
# Df Residuals:                     310   BIC:                            -1199.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.002      0.382      0.702      -0.003       0.005
# 0              0.9293      0.049     18.834      0.000       0.832       1.026
# ==============================================================================
# Omnibus:                        2.903   Durbin-Watson:                   2.133
# Prob(Omnibus):                  0.234   Jarque-Bera (JB):                3.174
# Skew:                          -0.029   Prob(JB):                        0.205
# Kurtosis:                       3.491   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.796
# Model:                            OLS   Adj. R-squared:                  0.795
# Method:                 Least Squares   F-statistic:                     1209.
# Date:                Sat, 04 May 2024   Prob (F-statistic):          5.30e-109
# Time:                        20:01:05   Log-Likelihood:                 725.75
# No. Observations:                 312   AIC:                            -1448.
# Df Residuals:                     310   BIC:                            -1440.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0002      0.001      0.148      0.882      -0.002       0.003
# 0              1.1661      0.034     34.771      0.000       1.100       1.232
# ==============================================================================
# Omnibus:                       38.517   Durbin-Watson:                   1.806
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              112.399
# Skew:                          -0.531   Prob(JB):                     3.92e-25
# Kurtosis:                       5.742   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.376
# Method:                 Least Squares   F-statistic:                     188.2
# Date:                Sat, 04 May 2024   Prob (F-statistic):           8.47e-34
# Time:                        20:01:05   Log-Likelihood:                 590.52
# No. Observations:                 312   AIC:                            -1177.
# Df Residuals:                     310   BIC:                            -1170.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const      -6.013e-06      0.002     -0.003      0.998      -0.004       0.004
# 0              0.7097      0.052     13.719      0.000       0.608       0.811
# ==============================================================================
# Omnibus:                       73.932   Durbin-Watson:                   2.235
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              318.823
# Skew:                           0.920   Prob(JB):                     5.87e-70
# Kurtosis:                       7.598   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.587
# Model:                            OLS   Adj. R-squared:                  0.586
# Method:                 Least Squares   F-statistic:                     440.6
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.75e-61
# Time:                        20:01:05   Log-Likelihood:                 694.04
# No. Observations:                 312   AIC:                            -1384.
# Df Residuals:                     310   BIC:                            -1377.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0018      0.001     -1.221      0.223      -0.005       0.001
# 0              0.7792      0.037     20.991      0.000       0.706       0.852
# ==============================================================================
# Omnibus:                        4.340   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.114   Jarque-Bera (JB):                4.929
# Skew:                           0.127   Prob(JB):                       0.0851
# Kurtosis:                       3.561   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.421
# Model:                            OLS   Adj. R-squared:                  0.419
# Method:                 Least Squares   F-statistic:                     225.4
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.14e-38
# Time:                        20:01:05   Log-Likelihood:                 508.71
# No. Observations:                 312   AIC:                            -1013.
# Df Residuals:                     310   BIC:                            -1006.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0014      0.003      0.534      0.594      -0.004       0.007
# 0              1.0095      0.067     15.013      0.000       0.877       1.142
# ==============================================================================
# Omnibus:                       64.001   Durbin-Watson:                   1.898
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              299.759
# Skew:                           0.750   Prob(JB):                     8.09e-66
# Kurtosis:                       7.562   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.729
# Method:                 Least Squares   F-statistic:                     838.6
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.60e-90
# Time:                        20:01:05   Log-Likelihood:                 671.26
# No. Observations:                 312   AIC:                            -1339.
# Df Residuals:                     310   BIC:                            -1331.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0010      0.002      0.594      0.553      -0.002       0.004
# 0              1.1565      0.040     28.959      0.000       1.078       1.235
# ==============================================================================
# Omnibus:                       43.343   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              338.586
# Skew:                          -0.105   Prob(JB):                     3.00e-74
# Kurtosis:                       8.099   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.495
# Method:                 Least Squares   F-statistic:                     306.0
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.80e-48
# Time:                        20:01:05   Log-Likelihood:                 577.19
# No. Observations:                 312   AIC:                            -1150.
# Df Residuals:                     310   BIC:                            -1143.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0019      0.002      0.854      0.394      -0.002       0.006
# 0              0.9444      0.054     17.494      0.000       0.838       1.051
# ==============================================================================
# Omnibus:                        1.948   Durbin-Watson:                   2.270
# Prob(Omnibus):                  0.377   Jarque-Bera (JB):                1.840
# Skew:                           0.030   Prob(JB):                        0.398
# Kurtosis:                       3.371   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# ...
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0014      0.001     -1.006      0.315      -0.004       0.001
# 0              0.8136      0.034     23.666      0.000       0.746       0.881
# ==============================================================================
# Omnibus:                        5.883   Durbin-Watson:                   2.005
# Prob(Omnibus):                  0.053   Jarque-Bera (JB):                7.556
# Skew:                           0.138   Prob(JB):                       0.0229
# Kurtosis:                       3.711   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.603
# Model:                            OLS   Adj. R-squared:                  0.601
# Method:                 Least Squares   F-statistic:                     470.2
# Date:                Sat, 04 May 2024   Prob (F-statistic):           4.31e-64
# Time:                        20:01:05   Log-Likelihood:                 592.32
# No. Observations:                 312   AIC:                            -1181.
# Df Residuals:                     310   BIC:                            -1173.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.002      0.576      0.565      -0.003       0.005
# 0              1.1153      0.051     21.684      0.000       1.014       1.216
# ==============================================================================
# Omnibus:                       96.449   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1116.077
# Skew:                          -0.897   Prob(JB):                    4.44e-243
# Kurtosis:                      12.090   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.549
# Model:                            OLS   Adj. R-squared:                  0.548
# Method:                 Least Squares   F-statistic:                     377.9
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.36e-55
# Time:                        20:01:05   Log-Likelihood:                 547.65
# No. Observations:                 312   AIC:                            -1091.
# Df Residuals:                     310   BIC:                            -1084.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0035      0.002      1.485      0.139      -0.001       0.008
# 0              1.1537      0.059     19.438      0.000       1.037       1.270
# ==============================================================================
# Omnibus:                       12.380   Durbin-Watson:                   2.098
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               26.429
# Skew:                          -0.080   Prob(JB):                     1.82e-06
# Kurtosis:                       4.417   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.376
# Model:                            OLS   Adj. R-squared:                  0.374
# Method:                 Least Squares   F-statistic:                     187.0
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.22e-33
# Time:                        20:01:05   Log-Likelihood:                 480.12
# No. Observations:                 312   AIC:                            -956.2
# Df Residuals:                     310   BIC:                            -948.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0024      0.003     -0.821      0.412      -0.008       0.003
# 0              1.0078      0.074     13.676      0.000       0.863       1.153
# ==============================================================================
# Omnibus:                      183.995   Durbin-Watson:                   2.173
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3877.024
# Skew:                           1.962   Prob(JB):                         0.00
# Kurtosis:                      19.818   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.524
# Model:                            OLS   Adj. R-squared:                  0.522
# Method:                 Least Squares   F-statistic:                     341.3
# Date:                Sat, 04 May 2024   Prob (F-statistic):           6.61e-52
# Time:                        20:01:05   Log-Likelihood:                 543.28
# No. Observations:                 312   AIC:                            -1083.
# Df Residuals:                     310   BIC:                            -1075.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0011      0.002      0.453      0.651      -0.004       0.006
# 0              1.1119      0.060     18.474      0.000       0.993       1.230
# ==============================================================================
# Omnibus:                       43.590   Durbin-Watson:                   1.875
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              101.848
# Skew:                           0.688   Prob(JB):                     7.66e-23
# Kurtosis:                       5.437   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.566
# Model:                            OLS   Adj. R-squared:                  0.565
# Method:                 Least Squares   F-statistic:                     404.9
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.41e-58
# Time:                        20:01:05   Log-Likelihood:                 690.11
# No. Observations:                 312   AIC:                            -1376.
# Df Residuals:                     310   BIC:                            -1369.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.002     -0.472      0.637      -0.004       0.002
# 0              0.7565      0.038     20.122      0.000       0.682       0.830
# ==============================================================================
# Omnibus:                       12.775   Durbin-Watson:                   1.873
# Prob(Omnibus):                  0.002   Jarque-Bera (JB):               19.229
# Skew:                           0.286   Prob(JB):                     6.68e-05
# Kurtosis:                       4.073   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.607
# Model:                            OLS   Adj. R-squared:                  0.606
# Method:                 Least Squares   F-statistic:                     479.8
# Date:                Sat, 04 May 2024   Prob (F-statistic):           6.48e-65
# Time:                        20:01:05   Log-Likelihood:                 567.20
# No. Observations:                 312   AIC:                            -1130.
# Df Residuals:                     310   BIC:                            -1123.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0026      0.002      1.173      0.242      -0.002       0.007
# 0              1.2210      0.056     21.904      0.000       1.111       1.331
# ==============================================================================
# Omnibus:                       10.443   Durbin-Watson:                   1.819
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               20.132
# Skew:                           0.072   Prob(JB):                     4.25e-05
# Kurtosis:                       4.236   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.745
# Model:                            OLS   Adj. R-squared:                  0.744
# Method:                 Least Squares   F-statistic:                     904.4
# Date:                Sat, 04 May 2024   Prob (F-statistic):           6.34e-94
# Time:                        20:01:05   Log-Likelihood:                 697.76
# No. Observations:                 312   AIC:                            -1392.
# Df Residuals:                     310   BIC:                            -1384.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0008      0.001      0.520      0.604      -0.002       0.004
# 0              1.1032      0.037     30.074      0.000       1.031       1.175
# ==============================================================================
# Omnibus:                       18.809   Durbin-Watson:                   2.075
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               41.606
# Skew:                           0.270   Prob(JB):                     9.23e-10
# Kurtosis:                       4.706   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                                Beta
# FTSEMIB Index                                   1.0
# A2A 2018-2023                              0.869919
# Amplifon 2018-2023                         0.856924
# Azimut 2018-2023                           1.086093
# BPER banca 2018-2023                       1.139546
# Banca Mediolanum 2018-2023                 1.081197
# Banca Monte dei Paschi di Siena 2018-2023  1.081078
# Banca pop Sondrio 2018-2023                1.092533
# Banco Bpm 2018-2023                        1.086093
# Brunello cucinelli 2018-2023               0.858398
# Campari 2018-2023                           0.80666
# Diasorin 2018-2023                         0.564082
# Enel 2018-2023                             0.921831
# Eni 2018-2023                              1.006126
# Erg 2018-2023                              0.818049
# Ferrari 2018-2023                          0.797131
# Fineco 2018-2023                           1.016338
# Generali Ass 2018-2023                     0.970315
# Hera 2018-2023                             0.802654
# Interpump 2018-2023                        0.929261
# Intesa San Paolo 2018-2023                 1.166066
# Inwit 2018-2023                            0.709682
# Italgas 2018-2023                           0.77924
# Leonardo 2018-2023                         1.009513
# Mediobanca 2018-2023                        1.15652
# Moncler 2018-2023                          0.944442
# Pirelli 2018-2023                          0.966646
# Poste Italiane 2018-2023                   1.065785
# Prysmian 2018-2023                         0.954006
# Recordati 2018-2023                         0.68263
# Saipem 2018-2023                           1.025014
# Snam 2018-2023                             0.813643
# Stellantis 2018-2023                       1.115258
# Stmicroeletronics 2018-2023                1.153672
# Telecom 2018-2023                          1.007792
# Tenaris 2018-2023                          1.111927
# Terna 2018-2023                            0.756466
# Unicredit 2018-2023                        1.221009
# Unipol 2018-2023                           1.103208

# %%
beta_df.drop(index='FTSEMIB Index', inplace=True)

# %%
beta_df.sort_values(by="Beta")
# Out:
#                                                Beta
# Diasorin 2018-2023                         0.564082
# Recordati 2018-2023                         0.68263
# Inwit 2018-2023                            0.709682
# Terna 2018-2023                            0.756466
# Italgas 2018-2023                           0.77924
# Ferrari 2018-2023                          0.797131
# Hera 2018-2023                             0.802654
# Campari 2018-2023                           0.80666
# Snam 2018-2023                             0.813643
# Erg 2018-2023                              0.818049
# Amplifon 2018-2023                         0.856924
# Brunello cucinelli 2018-2023               0.858398
# A2A 2018-2023                              0.869919
# Enel 2018-2023                             0.921831
# Interpump 2018-2023                        0.929261
# Moncler 2018-2023                          0.944442
# Prysmian 2018-2023                         0.954006
# Pirelli 2018-2023                          0.966646
# Generali Ass 2018-2023                     0.970315
# Eni 2018-2023                              1.006126
# Telecom 2018-2023                          1.007792
# Leonardo 2018-2023                         1.009513
# Fineco 2018-2023                           1.016338
# Saipem 2018-2023                           1.025014
# Poste Italiane 2018-2023                   1.065785
# Banca Monte dei Paschi di Siena 2018-2023  1.081078
# Banca Mediolanum 2018-2023                 1.081197
# Banco Bpm 2018-2023                        1.086093
# Azimut 2018-2023                           1.086093
# Banca pop Sondrio 2018-2023                1.092533
# Unipol 2018-2023                           1.103208
# Tenaris 2018-2023                          1.111927
# Stellantis 2018-2023                       1.115258
# BPER banca 2018-2023                       1.139546
# Stmicroeletronics 2018-2023                1.153672
# Mediobanca 2018-2023                        1.15652
# Intesa San Paolo 2018-2023                 1.166066
# Unicredit 2018-2023                        1.221009

# %%
# Sort stocks based on beta values
sorted_df = beta_df.sort_values(by='Beta')

# Divide stocks into four portfolios
portfolio_1 = sorted_df.head(10)
portfolio_2 = sorted_df.iloc[10:19]
portfolio_3 = sorted_df.iloc[19:28]
portfolio_4 = sorted_df.tail(10)

# %%
print("Portfolio 1 (Lowest Beta):")
portfolio_1.to_csv("p1-tot.csv")
portfolio_1
# Out:
# Portfolio 1 (Lowest Beta):
#                          Beta
# Diasorin 2018-2023   0.564082
# Recordati 2018-2023   0.68263
# Inwit 2018-2023      0.709682
# Terna 2018-2023      0.756466
# Italgas 2018-2023     0.77924
# Ferrari 2018-2023    0.797131
# Hera 2018-2023       0.802654
# Campari 2018-2023     0.80666
# Snam 2018-2023       0.813643
# Erg 2018-2023        0.818049

# %%
print("Portfolio 2:")
portfolio_2.to_csv("p2-tot.csv")
portfolio_2
# Out:
# Portfolio 2:
#                                   Beta
# Amplifon 2018-2023            0.856924
# Brunello cucinelli 2018-2023  0.858398
# A2A 2018-2023                 0.869919
# Enel 2018-2023                0.921831
# Interpump 2018-2023           0.929261
# Moncler 2018-2023             0.944442
# Prysmian 2018-2023            0.954006
# Pirelli 2018-2023             0.966646
# Generali Ass 2018-2023        0.970315

# %%
print("Portfolio 3:")
portfolio_3.to_csv("p3-tot.csv")
portfolio_3
# Out:
# Portfolio 3:
#                                                Beta
# Eni 2018-2023                              1.006126
# Telecom 2018-2023                          1.007792
# Leonardo 2018-2023                         1.009513
# Fineco 2018-2023                           1.016338
# Saipem 2018-2023                           1.025014
# Poste Italiane 2018-2023                   1.065785
# Banca Monte dei Paschi di Siena 2018-2023  1.081078
# Banca Mediolanum 2018-2023                 1.081197
# Banco Bpm 2018-2023                        1.086093

# %%
print("Portfolio 4 (Highest Beta):")
portfolio_4.to_csv("p4-tot.csv")
portfolio_4
# Out:
# Portfolio 4 (Highest Beta):
#                                  Beta
# Azimut 2018-2023             1.086093
# Banca pop Sondrio 2018-2023  1.092533
# Unipol 2018-2023             1.103208
# Tenaris 2018-2023            1.111927
# Stellantis 2018-2023         1.115258
# BPER banca 2018-2023         1.139546
# Stmicroeletronics 2018-2023  1.153672
# Mediobanca 2018-2023          1.15652
# Intesa San Paolo 2018-2023   1.166066
# Unicredit 2018-2023          1.221009

# %%
# Remove '2021' from the stock names
portfolio_1.index = portfolio_1.index.str.replace(' 2018-2023', '')

# Rename the index to 'Stock'
portfolio_1.index.name = 'Stock'

# Print the modified DataFrame
portfolio_1
# Out:
#                Beta
# Stock
# Diasorin   0.564082
# Recordati   0.68263
# Inwit      0.709682
# Terna      0.756466
# Italgas     0.77924
# Ferrari    0.797131
# Hera       0.802654
# Campari     0.80666
# Snam       0.813643
# Erg        0.818049

# %%
# Remove '2021' from the stock names
portfolio_2.index = portfolio_2.index.str.replace(' 2018-2023', '')

# Rename the index to 'Stock'
portfolio_2.index.name = 'Stock'

# %%
# Remove '2021' from the stock names
portfolio_3.index = portfolio_3.index.str.replace(' 2018-2023', '')

# Rename the index to 'Stock'
portfolio_3.index.name = 'Stock'

# %%
# Remove '2021' from the stock names
portfolio_4.index = portfolio_4.index.str.replace(' 2018-2023', '')

# Rename the index to 'Stock'
portfolio_4.index.name = 'Stock'

# %%
portfolio_1.index
# Out:
# Index(['Diasorin', 'Recordati', 'Inwit', 'Terna', 'Italgas', 'Ferrari', 'Hera',
#        'Campari', 'Snam', 'Erg'],
#       dtype='object', name='Stock')

# %%
returns_excess.columns = returns_excess.columns.str.strip()

# %%
returns_excess.columns = returns_excess.columns.str.replace(' 2018-2023', '')

# %%
returns_excess.set_index('Date', inplace=True)

# %%
returns_excess.columns
# Out:
# Index(['FTSEMIB Index', 'A2A', 'Amplifon', 'Azimut', 'BPER banca',
#        'Banca Mediolanum', 'Banca Monte dei Paschi di Siena',
#        'Banca pop Sondrio', 'Banco Bpm', 'Brunello cucinelli', 'Campari',
#        'Diasorin', 'Enel', 'Eni', 'Erg', 'Ferrari', 'Fineco', 'Generali Ass',
#        'Hera', 'Interpump', 'Intesa San Paolo', 'Inwit', 'Italgas', 'Leonardo',
#        'Mediobanca', 'Moncler', 'Pirelli', 'Poste Italiane', 'Prysmian',
#        'Recordati', 'Saipem', 'Snam', 'Stellantis', 'Stmicroeletronics',
#        'Telecom', 'Tenaris', 'Terna', 'Unicredit', 'Unipol', 'BOT 3m',
#        'Risk Premium'],
#       dtype='object')

# %%
p_1 = returns_excess[portfolio_1.index]
p_1.head()
# Out:
#             Diasorin  Recordati     Inwit     Terna   Italgas   Ferrari  \
# Date
# 2018-01-12  0.046414   0.014910 -0.017236 -0.014574 -0.022360  0.048825
# 2018-01-19  0.001772   0.007637  0.016979  0.016873  0.027549  0.024636
# 2018-01-26  0.010895   0.004851 -0.019830  0.006560  0.006986 -0.013808
# 2018-02-02 -0.025755  -0.072327 -0.023308 -0.026748 -0.014483  0.085687
# 2018-02-09 -0.082578  -0.116135 -0.040214 -0.041652 -0.064688 -0.048938
#
#                 Hera   Campari      Snam       Erg
# Date
# 2018-01-12  0.000062  0.005509 -0.008754  0.007403
# 2018-01-19  0.028673  0.002364  0.011134  0.056888
# 2018-01-26  0.006386  0.028841 -0.007200  0.016766
# 2018-02-02 -0.033017  0.015927 -0.035488 -0.019530
# 2018-02-09 -0.041750 -0.056822 -0.060325 -0.033844

# %%
p_2 = returns_excess[portfolio_2.index]
p_2.head()
# Out:
#             Amplifon  Brunello cucinelli       A2A      Enel  Interpump  \
# Date
# 2018-01-12  0.054415           -0.026682 -0.035916 -0.009136   0.039104
# 2018-01-19  0.031629            0.012336  0.049409  0.036318   0.039566
# 2018-01-26  0.022324            0.009000  0.001424 -0.029961  -0.004681
# 2018-02-02 -0.037444           -0.038522 -0.024156 -0.031617  -0.053164
# 2018-02-09 -0.057898           -0.014123 -0.063832 -0.058740  -0.028459
#
#              Moncler  Prysmian   Pirelli  Generali Ass
# Date
# 2018-01-12 -0.021416  0.019201  0.024804      0.039575
# 2018-01-19  0.083395  0.021896  0.009309      0.040581
# 2018-01-26  0.010479  0.002820  0.002647      0.012092
# 2018-02-02 -0.030220 -0.034270 -0.019210     -0.008031
# 2018-02-09 -0.002664 -0.038444 -0.038766     -0.028450

# %%
p_3 = returns_excess[portfolio_3.index]
p_3.head()
# Out:
#                  Eni   Telecom  Leonardo    Fineco    Saipem  Poste Italiane  \
# Date
# 2018-01-12  0.028751  0.015424  0.051923  0.086095  0.045486        0.021925
# 2018-01-19  0.016146 -0.021589  0.045539  0.019611 -0.000702        0.044883
# 2018-01-26  0.017092  0.008307 -0.004333  0.049701  0.020457        0.003796
# 2018-02-02 -0.031344 -0.006483 -0.126212 -0.015433 -0.078716       -0.006921
# 2018-02-09 -0.057346 -0.006077 -0.085926 -0.056083 -0.068305       -0.013613
#
#             Banca Monte dei Paschi di Siena  Banca Mediolanum  Banco Bpm
# Date
# 2018-01-12                         0.041560          0.021171   0.041451
# 2018-01-19                        -0.023184          0.075981   0.139887
# 2018-01-26                         0.020312          0.028305   0.002643
# 2018-02-02                        -0.064285         -0.006860  -0.015864
# 2018-02-09                         0.045619         -0.034111  -0.014637

# %%
p_4 = returns_excess[portfolio_4.index]
p_4.head()
# Out:
#               Azimut  Banca pop Sondrio    Unipol   Tenaris  Stellantis  \
# Date
# 2018-01-12  0.041451           0.049279  0.061028  0.052004    0.076179
# 2018-01-19  0.139887          -0.017153  0.020301  0.011490    0.030628
# 2018-01-26  0.002643           0.038593  0.040724  0.030067    0.021786
# 2018-02-02 -0.015864          -0.033592 -0.023385 -0.045410   -0.041984
# 2018-02-09 -0.014637           0.012618 -0.025903 -0.060953   -0.064356
#
#             BPER banca  Stmicroeletronics  Mediobanca  Intesa San Paolo  \
# Date
# 2018-01-12    0.081097           0.036961    0.035454          0.083228
# 2018-01-19   -0.013260           0.031696    0.027609          0.029162
# 2018-01-26    0.087472          -0.058025   -0.003557          0.032316
# 2018-02-02   -0.022068          -0.021491    0.020724         -0.005159
# 2018-02-09    0.015522          -0.061443   -0.014058         -0.001406
#
#             Unicredit
# Date
# 2018-01-12   0.083731
# 2018-01-19   0.004666
# 2018-01-26   0.040609
# 2018-02-02  -0.012247
# 2018-02-09   0.019565

# %%
returns_df.head()
# Out:
#          Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 0  2018-01-12       0.029327      -0.044570            0.045761
# 1  2018-01-19       0.013632       0.040736            0.022956
# 2  2018-01-26       0.004538      -0.007576            0.013324
# 3  2018-02-02      -0.027427      -0.033079           -0.046367
# 4  2018-02-09      -0.044646      -0.072697           -0.066763
#
#    Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 0          0.032797              0.072444                    0.012517
# 1          0.131214             -0.021934                    0.067308
# 2         -0.006357              0.078472                    0.019305
# 3         -0.024787             -0.030991                   -0.015783
# 4         -0.023502              0.006656                   -0.042976
#
#    Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 0                                   0.032906                     0.040625
# 1                                  -0.031857                    -0.025826
# 2                                   0.011312                     0.029593
# 3                                  -0.073208                    -0.042515
# 4                                   0.036753                     0.003752
#
#    Banco Bpm 2018-2023  ...  Snam 2018-2023  Stellantis 2018-2023  \
# 0             0.032797  ...       -0.017408              0.067525
# 1             0.131214  ...        0.002461              0.021955
# 2            -0.006357  ...       -0.016200              0.012786
# 3            -0.024787  ...       -0.044411             -0.050907
# 4            -0.023502  ...       -0.069191             -0.073222
#
#    Stmicroeletronics 2018-2023  Telecom 2018-2023  Tenaris 2018-2023  \
# 0                     0.028307           0.006770           0.043350
# 1                     0.023023          -0.030262           0.002817
# 2                    -0.067025          -0.000693           0.021067
# 3                    -0.030414          -0.015406          -0.054333
# 4                    -0.070308          -0.014942          -0.069818
#
#    Terna 2018-2023  Unicredit 2018-2023  Unipol 2018-2023    BOT 3m  \
# 0        -0.023228             0.075077          0.052374 -0.008654
# 1         0.008200            -0.004007          0.011628 -0.008673
# 2        -0.002440             0.031609          0.031724 -0.009000
# 3        -0.035671            -0.021170         -0.032308 -0.008923
# 4        -0.050518             0.010700         -0.034769 -0.008865
#
#    Risk Premium
# 0      0.037980
# 1      0.022305
# 2      0.013538
# 3     -0.018504
# 4     -0.035781
#
# [5 rows x 42 columns]

# %%
returns_df = returns_df.set_index('Date')

# %% [markdown]
# # P1 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_1.index:
    # Extract market excess return for the date
    x = returns_df.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_1.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

df['Date'] = pd.to_datetime(df['Date'])

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2018-01-12              0.037980                 0.006020
# 2018-01-19              0.022305                 0.019450
# 2018-01-26              0.013538                 0.004045
# 2018-02-02             -0.018504                -0.014904
# 2018-02-09             -0.035781                -0.058695

# %%
df.tail()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2023-12-01             -0.053797                -0.063997
# 2023-12-08             -0.056498                -0.046504
# 2023-12-15             -0.069756                -0.067063
# 2023-12-22             -0.072332                -0.070881
# 2023-12-29             -0.070055                -0.071128

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.009838345313220502
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.002
# Model:                                 OLS   Adj. R-squared:                 -0.996
# Method:                      Least Squares   F-statistic:                  0.001909
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.972
# Time:                             20:01:05   Log-Likelihood:                 10.699
# No. Observations:                        3   AIC:                            -17.40
# Df Residuals:                            1   BIC:                            -19.20
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0106      0.018      0.587      0.662      -0.218       0.239
# Market Excess Return    -0.0296      0.676     -0.044      0.972      -8.623       8.564
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.948
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.477
# Skew:                           0.625   Prob(JB):                        0.788
# Kurtosis:                       1.500   Cond. No.                         99.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.00684267190532052
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.906
# Model:                                 OLS   Adj. R-squared:                  0.859
# Method:                      Least Squares   F-statistic:                     19.30
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0481
# Time:                             20:01:05   Log-Likelihood:                 12.504
# No. Observations:                        4   AIC:                            -21.01
# Df Residuals:                            2   BIC:                            -22.24
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0030      0.008     -0.398      0.729      -0.036       0.030
# Market Excess Return     1.1965      0.272      4.393      0.048       0.025       2.368
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.020
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.605
# Skew:                          -0.074   Prob(JB):                        0.739
# Kurtosis:                       1.101   Cond. No.                         36.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0178847378906566
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.903
# Model:                                 OLS   Adj. R-squared:                  0.871
# Method:                      Least Squares   F-statistic:                     27.92
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0132
# Time:                             20:01:05   Log-Likelihood:                 15.380
# No. Observations:                        5   AIC:                            -26.76
# Df Residuals:                            3   BIC:                            -27.54
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0086      0.007      1.290      0.288      -0.013       0.030
# Market Excess Return     1.3440      0.254      5.284      0.013       0.535       2.154
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.016
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.285
# Skew:                          -0.019   Prob(JB):                        0.867
# Kurtosis:                       1.831   Cond. No.                         39.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.020552797118095087
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.154
# Model:                                 OLS   Adj. R-squared:                 -0.269
# Method:                      Least Squares   F-statistic:                    0.3650
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.607
# Time:                             20:01:05   Log-Likelihood:                 13.347
# No. Observations:                        4   AIC:                            -22.69
# Df Residuals:                            2   BIC:                            -23.92
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0331      0.022      1.532      0.265      -0.060       0.126
# Market Excess Return    -0.4683      0.775     -0.604      0.607      -3.804       2.867
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.783
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.589
# Skew:                          -0.842   Prob(JB):                        0.745
# Kurtosis:                       2.165   Cond. No.                         128.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0019509794255893349
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.844
# Model:                                 OLS   Adj. R-squared:                  0.766
# Method:                      Least Squares   F-statistic:                     10.85
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0811
# Time:                             20:01:05   Log-Likelihood:                 14.652
# No. Observations:                        4   AIC:                            -25.30
# Df Residuals:                            2   BIC:                            -26.53
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0069      0.005      1.496      0.273      -0.013       0.027
# Market Excess Return     0.5964      0.181      3.293      0.081      -0.183       1.376
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.436
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.512
# Skew:                          -0.704   Prob(JB):                        0.774
# Kurtosis:                       1.955   Cond. No.                         41.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.013863963775313515
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.808
# Model:                                 OLS   Adj. R-squared:                  0.744
# Method:                      Least Squares   F-statistic:                     12.64
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0379
# Time:                             20:01:05   Log-Likelihood:                 15.287
# No. Observations:                        5   AIC:                            -26.57
# Df Residuals:                            3   BIC:                            -27.36
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0147      0.007      2.231      0.112      -0.006       0.036
# Market Excess Return     0.9229      0.260      3.555      0.038       0.097       1.749
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.296
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.283
# Skew:                          -0.029   Prob(JB):                        0.868
# Kurtosis:                       1.835   Cond. No.                         39.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.008183498840145333
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.212
# Model:                                 OLS   Adj. R-squared:                 -0.182
# Method:                      Least Squares   F-statistic:                    0.5378
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.540
# Time:                             20:01:05   Log-Likelihood:                 12.240
# No. Observations:                        4   AIC:                            -20.48
# Df Residuals:                            2   BIC:                            -21.71
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0152      0.012      1.218      0.347      -0.038       0.069
# Market Excess Return    -0.8277      1.129     -0.733      0.540      -5.684       4.029
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.553
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.524
# Skew:                          -0.210   Prob(JB):                        0.769
# Kurtosis:                       1.277   Cond. No.                         141.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.003017926229628476
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.520
# Model:                                 OLS   Adj. R-squared:                  0.360
# Method:                      Least Squares   F-statistic:                     3.252
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.169
# Time:                             20:01:05   Log-Likelihood:                 18.386
# No. Observations:                        5   AIC:                            -32.77
# Df Residuals:                            3   BIC:                            -33.55
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0018      0.004      0.402      0.715      -0.012       0.016
# Market Excess Return     0.3826      0.212      1.803      0.169      -0.293       1.058
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.907
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.832
# Skew:                          -0.989   Prob(JB):                        0.660
# Kurtosis:                       2.719   Cond. No.                         60.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0020126120465734938
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.793
# Model:                                 OLS   Adj. R-squared:                  0.689
# Method:                      Least Squares   F-statistic:                     7.660
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.110
# Time:                             20:01:05   Log-Likelihood:                 14.427
# No. Observations:                        4   AIC:                            -24.85
# Df Residuals:                            2   BIC:                            -26.08
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0022      0.005     -0.452      0.696      -0.023       0.019
# Market Excess Return     0.4600      0.166      2.768      0.110      -0.255       1.175
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.757
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.471
# Skew:                          -0.338   Prob(JB):                        0.790
# Kurtosis:                       1.460   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.011854372492229181
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.842
# Model:                                 OLS   Adj. R-squared:                  0.764
# Method:                      Least Squares   F-statistic:                     10.69
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0822
# Time:                             20:01:05   Log-Likelihood:                 12.712
# No. Observations:                        4   AIC:                            -21.42
# Df Residuals:                            2   BIC:                            -22.65
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0182      0.012      1.565      0.258      -0.032       0.068
# Market Excess Return     1.3968      0.427      3.269      0.082      -0.441       3.235
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.133
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.477
# Skew:                           0.375   Prob(JB):                        0.788
# Kurtosis:                       1.483   Cond. No.                         60.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010316665346344067
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.194
# Model:                                 OLS   Adj. R-squared:                 -0.075
# Method:                      Least Squares   F-statistic:                    0.7212
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.458
# Time:                             20:01:05   Log-Likelihood:                 13.082
# No. Observations:                        5   AIC:                            -22.16
# Df Residuals:                            3   BIC:                            -22.94
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0056      0.012      0.485      0.661      -0.031       0.043
# Market Excess Return     0.4213      0.496      0.849      0.458      -1.157       2.000
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.016
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.353
# Skew:                           0.083   Prob(JB):                        0.838
# Kurtosis:                       1.710   Cond. No.                         48.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.004071748480723899
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.093
# Model:                                 OLS   Adj. R-squared:                 -0.361
# Method:                      Least Squares   F-statistic:                    0.2051
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.695
# Time:                             20:01:06   Log-Likelihood:                 11.288
# No. Observations:                        4   AIC:                            -18.58
# Df Residuals:                            2   BIC:                            -19.80
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0065      0.011      0.564      0.630      -0.043       0.056
# Market Excess Return     0.3091      0.683      0.453      0.695      -2.628       3.247
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.184
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.702
# Skew:                          -0.948   Prob(JB):                        0.704
# Kurtosis:                       2.211   Cond. No.                         67.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.022506102082863872
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.844
# Model:                                 OLS   Adj. R-squared:                  0.766
# Method:                      Least Squares   F-statistic:                     10.80
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0814
# Time:                             20:01:06   Log-Likelihood:                 13.973
# No. Observations:                        4   AIC:                            -23.95
# Df Residuals:                            2   BIC:                            -25.17
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0253      0.015     -1.638      0.243      -0.092       0.041
# Market Excess Return     1.9621      0.597      3.286      0.081      -0.607       4.531
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.799
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.457
# Skew:                          -0.697   Prob(JB):                        0.796
# Kurtosis:                       2.106   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.02119342833877845
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.358
# Model:                                 OLS   Adj. R-squared:                  0.037
# Method:                      Least Squares   F-statistic:                     1.116
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.402
# Time:                             20:01:06   Log-Likelihood:                 13.403
# No. Observations:                        4   AIC:                            -22.81
# Df Residuals:                            2   BIC:                            -24.03
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0185      0.007      2.853      0.104      -0.009       0.047
# Market Excess Return     0.2687      0.254      1.056      0.402      -0.826       1.363
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.501
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.204
# Skew:                          -0.217   Prob(JB):                        0.903
# Kurtosis:                       1.982   Cond. No.                         42.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.013655863847854794
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.259
# Model:                                 OLS   Adj. R-squared:                  0.012
# Method:                      Least Squares   F-statistic:                     1.048
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.381
# Time:                             20:01:06   Log-Likelihood:                 19.352
# No. Observations:                        5   AIC:                            -34.70
# Df Residuals:                            3   BIC:                            -35.48
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0104      0.004      2.417      0.094      -0.003       0.024
# Market Excess Return     0.2190      0.214      1.024      0.381      -0.462       0.900
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.436
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.542
# Skew:                           0.325   Prob(JB):                        0.763
# Kurtosis:                       1.524   Cond. No.                         73.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.00037588381915687995
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.022
# Model:                                 OLS   Adj. R-squared:                 -0.467
# Method:                      Least Squares   F-statistic:                   0.04452
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.852
# Time:                             20:01:06   Log-Likelihood:                 12.602
# No. Observations:                        4   AIC:                            -21.20
# Df Residuals:                            2   BIC:                            -22.43
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0009      0.010     -0.096      0.932      -0.042       0.040
# Market Excess Return     0.1374      0.651      0.211      0.852      -2.665       2.940
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.517
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.759
# Skew:                          -0.986   Prob(JB):                        0.684
# Kurtosis:                       2.186   Cond. No.                         88.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01210332295735278
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.151
# Model:                                 OLS   Adj. R-squared:                 -0.131
# Method:                      Least Squares   F-statistic:                    0.5355
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.517
# Time:                             20:01:06   Log-Likelihood:                 13.523
# No. Observations:                        5   AIC:                            -23.05
# Df Residuals:                            3   BIC:                            -23.83
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0165      0.011      1.485      0.234      -0.019       0.052
# Market Excess Return     0.3341      0.457      0.732      0.517      -1.119       1.787
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.541
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.705
# Skew:                          -0.637   Prob(JB):                        0.703
# Kurtosis:                       1.674   Cond. No.                         48.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014915744416201315
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.889
# Model:                                 OLS   Adj. R-squared:                  0.834
# Method:                      Least Squares   F-statistic:                     16.08
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0569
# Time:                             20:01:06   Log-Likelihood:                 13.280
# No. Observations:                        4   AIC:                            -22.56
# Df Residuals:                            2   BIC:                            -23.79
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0171      0.010     -1.696      0.232      -0.061       0.026
# Market Excess Return     1.4074      0.351      4.010      0.057      -0.103       2.917
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.149
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.453
# Skew:                          -0.047   Prob(JB):                        0.797
# Kurtosis:                       1.355   Cond. No.                         56.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01042200783715237
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.934
# Model:                                 OLS   Adj. R-squared:                  0.901
# Method:                      Least Squares   F-statistic:                     28.42
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0334
# Time:                             20:01:06   Log-Likelihood:                 16.308
# No. Observations:                        4   AIC:                            -28.62
# Df Residuals:                            2   BIC:                            -29.84
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0010      0.003      0.301      0.792      -0.014       0.016
# Market Excess Return     0.7271      0.136      5.331      0.033       0.140       1.314
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.927
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.437
# Skew:                           0.673   Prob(JB):                        0.804
# Kurtosis:                       2.102   Cond. No.                         47.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.008616532280837202
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.838
# Model:                                 OLS   Adj. R-squared:                  0.784
# Method:                      Least Squares   F-statistic:                     15.54
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0291
# Time:                             20:01:06   Log-Likelihood:                 17.905
# No. Observations:                        5   AIC:                            -31.81
# Df Residuals:                            3   BIC:                            -32.59
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0079      0.004      2.018      0.137      -0.005       0.020
# Market Excess Return     0.5160      0.131      3.942      0.029       0.099       0.933
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.487
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.084
# Skew:                          -0.138   Prob(JB):                        0.959
# Kurtosis:                       2.427   Cond. No.                         33.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.007271979834900297
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.030
# Model:                                 OLS   Adj. R-squared:                 -0.455
# Method:                      Least Squares   F-statistic:                   0.06214
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.826
# Time:                             20:01:06   Log-Likelihood:                 10.354
# No. Observations:                        4   AIC:                            -16.71
# Df Residuals:                            2   BIC:                            -17.93
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0105      0.018      0.575      0.624      -0.068       0.089
# Market Excess Return    -0.2280      0.915     -0.249      0.826      -4.164       3.708
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.690
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.916
# Skew:                          -1.120   Prob(JB):                        0.633
# Kurtosis:                       2.308   Cond. No.                         71.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0024891998955438002
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.082
# Model:                                 OLS   Adj. R-squared:                 -0.377
# Method:                      Least Squares   F-statistic:                    0.1785
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.714
# Time:                             20:01:06   Log-Likelihood:                 18.889
# No. Observations:                        4   AIC:                            -33.78
# Df Residuals:                            2   BIC:                            -35.00
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0021      0.002      1.126      0.377      -0.006       0.010
# Market Excess Return     0.0314      0.074      0.423      0.714      -0.288       0.351
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.015
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.500
# Skew:                           0.047   Prob(JB):                        0.779
# Kurtosis:                       1.270   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.016078341974554832
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.054
# Model:                                 OLS   Adj. R-squared:                 -0.262
# Method:                      Least Squares   F-statistic:                    0.1696
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.708
# Time:                             20:01:06   Log-Likelihood:                 15.260
# No. Observations:                        5   AIC:                            -26.52
# Df Residuals:                            3   BIC:                            -27.30
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0137      0.009      1.546      0.220      -0.014       0.042
# Market Excess Return     0.1968      0.478      0.412      0.708      -1.324       1.717
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.230
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.656
# Skew:                          -0.273   Prob(JB):                        0.720
# Kurtosis:                       1.312   Cond. No.                         72.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0060544640391898595
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.769
# Model:                                 OLS   Adj. R-squared:                  0.653
# Method:                      Least Squares   F-statistic:                     6.643
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.123
# Time:                             20:01:06   Log-Likelihood:                 12.205
# No. Observations:                        4   AIC:                            -20.41
# Df Residuals:                            2   BIC:                            -21.64
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0116      0.011     -1.094      0.388      -0.057       0.034
# Market Excess Return     1.3956      0.541      2.577      0.123      -0.934       3.725
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.644
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.483
# Skew:                           0.215   Prob(JB):                        0.785
# Kurtosis:                       1.353   Cond. No.                         66.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014808131651891935
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.470
# Model:                                 OLS   Adj. R-squared:                  0.293
# Method:                      Least Squares   F-statistic:                     2.656
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.202
# Time:                             20:01:06   Log-Likelihood:                 15.133
# No. Observations:                        5   AIC:                            -26.27
# Df Residuals:                            3   BIC:                            -27.05
# Df Model:                                1
# ...
# Market Excess Return     1.0728      0.205      5.224      0.014       0.419       1.726
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.588
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.768
# Skew:                           0.347   Prob(JB):                        0.681
# Kurtosis:                       1.210   Cond. No.                         50.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.06844785155103092
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.906
# Model:                                 OLS   Adj. R-squared:                  0.859
# Method:                      Least Squares   F-statistic:                     19.31
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0481
# Time:                             20:01:06   Log-Likelihood:                 14.327
# No. Observations:                        4   AIC:                            -24.65
# Df Residuals:                            2   BIC:                            -25.88
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0034      0.016     -0.220      0.846      -0.070       0.063
# Market Excess Return     1.1202      0.255      4.394      0.048       0.023       2.217
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.463
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.617
# Skew:                           0.838   Prob(JB):                        0.735
# Kurtosis:                       2.055   Cond. No.                         53.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.07433876052225545
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.956
# Model:                                 OLS   Adj. R-squared:                  0.935
# Method:                      Least Squares   F-statistic:                     43.87
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0220
# Time:                             20:01:06   Log-Likelihood:                 14.680
# No. Observations:                        4   AIC:                            -25.36
# Df Residuals:                            2   BIC:                            -26.59
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0482      0.019      2.537      0.127      -0.034       0.130
# Market Excess Return     1.5905      0.240      6.623      0.022       0.557       2.624
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.579
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.880
# Skew:                           1.091   Prob(JB):                        0.644
# Kurtosis:                       2.280   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.08263934926393182
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.556
# Model:                                 OLS   Adj. R-squared:                  0.407
# Method:                      Least Squares   F-statistic:                     3.750
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.148
# Time:                             20:01:06   Log-Likelihood:                 14.112
# No. Observations:                        5   AIC:                            -24.22
# Df Residuals:                            3   BIC:                            -25.00
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0107      0.038     -0.280      0.798      -0.132       0.111
# Market Excess Return     0.9882      0.510      1.937      0.148      -0.636       2.612
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.505
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.191
# Skew:                           0.184   Prob(JB):                        0.909
# Kurtosis:                       2.115   Cond. No.                         61.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.08171318672842118
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.597
# Model:                                 OLS   Adj. R-squared:                  0.395
# Method:                      Least Squares   F-statistic:                     2.963
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.227
# Time:                             20:01:06   Log-Likelihood:                 15.110
# No. Observations:                        4   AIC:                            -26.22
# Df Residuals:                            2   BIC:                            -27.45
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0481      0.020     -2.421      0.137      -0.134       0.037
# Market Excess Return     0.4073      0.237      1.721      0.227      -0.611       1.425
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.233
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.704
# Skew:                          -0.950   Prob(JB):                        0.703
# Kurtosis:                       2.213   Cond. No.                         60.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.055580256866486204
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.959
# Model:                                 OLS   Adj. R-squared:                  0.939
# Method:                      Least Squares   F-statistic:                     47.12
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0206
# Time:                             20:01:06   Log-Likelihood:                 15.000
# No. Observations:                        4   AIC:                            -26.00
# Df Residuals:                            2   BIC:                            -27.23
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0063      0.010      0.635      0.590      -0.036       0.049
# Market Excess Return     1.1245      0.164      6.864      0.021       0.420       1.829
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.369
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.184
# Skew:                           0.145   Prob(JB):                        0.912
# Kurtosis:                       1.990   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.06391448504791356
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.505
# Model:                                 OLS   Adj. R-squared:                  0.340
# Method:                      Least Squares   F-statistic:                     3.058
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.179
# Time:                             20:01:06   Log-Likelihood:                 18.162
# No. Observations:                        5   AIC:                            -32.32
# Df Residuals:                            3   BIC:                            -33.11
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0100      0.031     -0.321      0.769      -0.109       0.089
# Market Excess Return     0.8364      0.478      1.749      0.179      -0.686       2.359
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.379
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.195
# Skew:                           0.370   Prob(JB):                        0.907
# Kurtosis:                       2.375   Cond. No.                         130.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.009838 -0.029550       0.313633
# 1     02                -0.006843  1.196517       1.131011
# 2     03                 0.017885  1.344046       1.229364
# 3     04                 0.020553 -0.468298       0.021135
# 4     05                 0.001951  0.596374       0.730916
# ..   ...                      ...       ...            ...
# 67    08                -0.074339  1.590534       1.393689
# 68    09                -0.082639  0.988216       0.992144
# 69    10                -0.081713  0.407265       0.604843
# 70    11                -0.055580  1.124455       1.082970
# 71    12                -0.063914  0.836428       0.890952
#
# [72 rows x 4 columns]

# %%
coefficients_df.to_csv('coefficients_df_p1_tot.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# -0.003918568332029561

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (312, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.703
# Model:                            OLS   Adj. R-squared:                  0.702
# Method:                 Least Squares   F-statistic:                     735.2
# Date:                Sat, 04 May 2024   Prob (F-statistic):           8.25e-84
# Time:                        20:01:06   Log-Likelihood:                 784.59
# No. Observations:                 312   AIC:                            -1565.
# Df Residuals:                     310   BIC:                            -1558.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.001     -0.552      0.582      -0.003       0.002
# x1             0.7530      0.028     27.115      0.000       0.698       0.808
# ==============================================================================
# Omnibus:                        3.526   Durbin-Watson:                   1.623
# Prob(Omnibus):                  0.172   Jarque-Bera (JB):                3.602
# Skew:                           0.137   Prob(JB):                        0.165
# Kurtosis:                       3.449   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 0.7530237253818454
# P-value: 8.247999250436428e-84
# Std. error: 0.027771765762733398
# Adj. R-squared: 0.7024516215081966
# F-statistic: 735.2081828722418
# T-statistic for X1: 27.114722622078247

# %% [markdown]
# # P2 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_2.index:
    # Extract market excess return for the date
    x = returns_df.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_2.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

df['Date'] = pd.to_datetime(df['Date'])


# Set Date column as index
df.set_index('Date', inplace=True)



# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2018-01-12              0.037980                 0.009328
# 2018-01-19              0.022305                 0.036049
# 2018-01-26              0.013538                 0.002905
# 2018-02-02             -0.018504                -0.030737
# 2018-02-09             -0.035781                -0.036820

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.01609376340889836
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.000
# Model:                                 OLS   Adj. R-squared:                 -0.999
# Method:                      Least Squares   F-statistic:                 0.0004829
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.986
# Time:                             20:01:29   Log-Likelihood:                 8.4755
# No. Observations:                        3   AIC:                            -12.95
# Df Residuals:                            1   BIC:                            -14.75
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0153      0.038      0.406      0.755      -0.464       0.495
# Market Excess Return     0.0312      1.419      0.022      0.986     -18.001      18.063
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.948
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.477
# Skew:                           0.625   Prob(JB):                        0.788
# Kurtosis:                       1.500   Cond. No.                         99.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.005115372932773606
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.931
# Model:                                 OLS   Adj. R-squared:                  0.896
# Method:                      Least Squares   F-statistic:                     26.92
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0352
# Time:                             20:01:29   Log-Likelihood:                 12.850
# No. Observations:                        4   AIC:                            -21.70
# Df Residuals:                            2   BIC:                            -22.93
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0010      0.007     -0.138      0.903      -0.031       0.029
# Market Excess Return     1.2961      0.250      5.189      0.035       0.221       2.371
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.896
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.514
# Skew:                          -0.175   Prob(JB):                        0.773
# Kurtosis:                       1.279   Cond. No.                         36.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014122999657085373
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.959
# Model:                                 OLS   Adj. R-squared:                  0.945
# Method:                      Least Squares   F-statistic:                     69.41
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00362
# Time:                             20:01:29   Log-Likelihood:                 19.206
# No. Observations:                        5   AIC:                            -34.41
# Df Residuals:                            3   BIC:                            -35.19
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0073      0.003      2.356      0.100      -0.003       0.017
# Market Excess Return     0.9860      0.118      8.332      0.004       0.609       1.363
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.346
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.789
# Skew:                          -0.931   Prob(JB):                        0.674
# Kurtosis:                       2.431   Cond. No.                         39.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.022249967957019858
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.139
# Model:                                 OLS   Adj. R-squared:                 -0.292
# Method:                      Least Squares   F-statistic:                    0.3218
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.628
# Time:                             20:01:29   Log-Likelihood:                 15.542
# No. Observations:                        4   AIC:                            -27.08
# Df Residuals:                            2   BIC:                            -28.31
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0155      0.012      1.240      0.341      -0.038       0.069
# Market Excess Return     0.2540      0.448      0.567      0.628      -1.673       2.181
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.819
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.302
# Skew:                           0.466   Prob(JB):                        0.860
# Kurtosis:                       2.029   Cond. No.                         128.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.008763997848224755
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.921
# Model:                                 OLS   Adj. R-squared:                  0.882
# Method:                      Least Squares   F-statistic:                     23.40
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0402
# Time:                             20:01:29   Log-Likelihood:                 15.896
# No. Observations:                        4   AIC:                            -27.79
# Df Residuals:                            2   BIC:                            -29.02
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0141      0.003      4.155      0.053      -0.001       0.029
# Market Excess Return     0.6419      0.133      4.838      0.040       0.071       1.213
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.448
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.518
# Skew:                           0.716   Prob(JB):                        0.772
# Kurtosis:                       1.971   Cond. No.                         41.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.007286602928676496
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.677
# Model:                                 OLS   Adj. R-squared:                  0.569
# Method:                      Least Squares   F-statistic:                     6.290
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0871
# Time:                             20:01:29   Log-Likelihood:                 14.862
# No. Observations:                        5   AIC:                            -25.72
# Df Residuals:                            3   BIC:                            -26.50
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0079      0.007      1.104      0.350      -0.015       0.031
# Market Excess Return     0.7088      0.283      2.508      0.087      -0.191       1.608
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.980
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.487
# Skew:                          -0.031   Prob(JB):                        0.784
# Kurtosis:                       1.473   Cond. No.                         39.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.009547693491077442
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.719
# Model:                                 OLS   Adj. R-squared:                  0.578
# Method:                      Least Squares   F-statistic:                     5.111
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.152
# Time:                             20:01:29   Log-Likelihood:                 14.262
# No. Observations:                        4   AIC:                            -24.52
# Df Residuals:                            2   BIC:                            -25.75
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0225      0.008      3.000      0.095      -0.010       0.055
# Market Excess Return    -1.5393      0.681     -2.261      0.152      -4.469       1.390
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.888
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.463
# Skew:                           0.558   Prob(JB):                        0.793
# Kurtosis:                       1.762   Cond. No.                         141.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.00019454276067724444
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.038
# Model:                                 OLS   Adj. R-squared:                 -0.282
# Method:                      Least Squares   F-statistic:                    0.1190
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.753
# Time:                             20:01:29   Log-Likelihood:                 17.411
# No. Observations:                        5   AIC:                            -30.82
# Df Residuals:                            3   BIC:                            -31.60
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0009      0.005      0.171      0.875      -0.016       0.018
# Market Excess Return     0.0889      0.258      0.345      0.753      -0.732       0.909
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.175
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.435
# Skew:                           0.556   Prob(JB):                        0.804
# Kurtosis:                       2.078   Cond. No.                         60.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0017182172157465979
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.756
# Model:                                 OLS   Adj. R-squared:                  0.635
# Method:                      Least Squares   F-statistic:                     6.212
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.130
# Time:                             20:01:29   Log-Likelihood:                 13.075
# No. Observations:                        4   AIC:                            -22.15
# Df Residuals:                            2   BIC:                            -23.38
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0036      0.007     -0.527      0.651      -0.033       0.026
# Market Excess Return     0.5808      0.233      2.492      0.130      -0.422       1.584
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.190
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.598
# Skew:                           0.811   Prob(JB):                        0.742
# Kurtosis:                       2.021   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.026930948965625836
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.970
# Model:                                 OLS   Adj. R-squared:                  0.954
# Method:                      Least Squares   F-statistic:                     63.86
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0153
# Time:                             20:01:29   Log-Likelihood:                 15.534
# No. Observations:                        4   AIC:                            -27.07
# Df Residuals:                            2   BIC:                            -28.30
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0094      0.006      1.629      0.245      -0.015       0.034
# Market Excess Return     1.6858      0.211      7.991      0.015       0.778       2.594
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.422
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.718
# Skew:                           0.953   Prob(JB):                        0.698
# Kurtosis:                       2.179   Cond. No.                         60.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010131276934545932
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.848
# Model:                                 OLS   Adj. R-squared:                  0.797
# Method:                      Least Squares   F-statistic:                     16.70
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0265
# Time:                             20:01:29   Log-Likelihood:                 17.227
# No. Observations:                        5   AIC:                            -30.45
# Df Residuals:                            3   BIC:                            -31.24
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0003      0.005      0.055      0.959      -0.016       0.016
# Market Excess Return     0.8848      0.217      4.087      0.026       0.196       1.574
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.579
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.492
# Skew:                          -0.666   Prob(JB):                        0.782
# Kurtosis:                       2.231   Cond. No.                         48.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.00411168125101655
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.346
# Model:                                 OLS   Adj. R-squared:                  0.019
# Method:                      Least Squares   F-statistic:                     1.058
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.412
# Time:                             20:01:29   Log-Likelihood:                 13.155
# No. Observations:                        4   AIC:                            -22.31
# Df Residuals:                            2   BIC:                            -23.54
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0075      0.007      1.046      0.405      -0.023       0.038
# Market Excess Return     0.4404      0.428      1.029      0.412      -1.401       2.282
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.938
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.637
# Skew:                           0.862   Prob(JB):                        0.727
# Kurtosis:                       2.078   Cond. No.                         67.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.020247854001288486
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.925
# Model:                                 OLS   Adj. R-squared:                  0.888
# Method:                      Least Squares   F-statistic:                     24.67
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0382
# Time:                             20:01:29   Log-Likelihood:                 18.741
# No. Observations:                        4   AIC:                            -33.48
# Df Residuals:                            2   BIC:                            -34.71
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0017      0.005     -0.360      0.753      -0.022       0.018
# Market Excess Return     0.9002      0.181      4.967      0.038       0.120       1.680
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.276
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.242
# Skew:                           0.004   Prob(JB):                        0.886
# Kurtosis:                       1.796   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.009571742889175837
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.784
# Model:                                 OLS   Adj. R-squared:                  0.676
# Method:                      Least Squares   F-statistic:                     7.248
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.115
# Time:                             20:01:29   Log-Likelihood:                 13.447
# No. Observations:                        4   AIC:                            -22.89
# Df Residuals:                            2   BIC:                            -24.12
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0029      0.006      0.451      0.696      -0.025       0.031
# Market Excess Return     0.6773      0.252      2.692      0.115      -0.405       1.760
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.428
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.307
# Skew:                          -0.414   Prob(JB):                        0.858
# Kurtosis:                       1.926   Cond. No.                         42.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.008424777034017398
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.769
# Model:                                 OLS   Adj. R-squared:                  0.693
# Method:                      Least Squares   F-statistic:                     10.01
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0507
# Time:                             20:01:29   Log-Likelihood:                 17.869
# No. Observations:                        5   AIC:                            -31.74
# Df Residuals:                            3   BIC:                            -32.52
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0051      0.006     -0.876      0.446      -0.024       0.013
# Market Excess Return     0.9103      0.288      3.164      0.051      -0.005       1.826
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.019
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.497
# Skew:                           0.439   Prob(JB):                        0.780
# Kurtosis:                       1.729   Cond. No.                         73.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010391984353978033
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.175
# Model:                                 OLS   Adj. R-squared:                 -0.237
# Method:                      Least Squares   F-statistic:                    0.4243
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.582
# Time:                             20:01:29   Log-Likelihood:                 12.371
# No. Observations:                        4   AIC:                            -20.74
# Df Residuals:                            2   BIC:                            -21.97
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0062      0.010      0.608      0.605      -0.037       0.050
# Market Excess Return     0.4495      0.690      0.651      0.582      -2.520       3.419
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.006
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.578
# Skew:                          -0.087   Prob(JB):                        0.749
# Kurtosis:                       1.147   Cond. No.                         88.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.011071790421999397
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.818
# Model:                                 OLS   Adj. R-squared:                  0.757
# Method:                      Least Squares   F-statistic:                     13.49
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0349
# Time:                             20:01:29   Log-Likelihood:                 17.233
# No. Observations:                        5   AIC:                            -30.47
# Df Residuals:                            3   BIC:                            -31.25
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0005      0.005     -0.087      0.936      -0.017       0.016
# Market Excess Return     0.7984      0.217      3.673      0.035       0.107       1.490
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.100
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.133
# Skew:                          -0.208   Prob(JB):                        0.936
# Kurtosis:                       2.320   Cond. No.                         48.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.023965204798375512
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.945
# Model:                                 OLS   Adj. R-squared:                  0.917
# Method:                      Least Squares   F-statistic:                     34.31
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0279
# Time:                             20:01:29   Log-Likelihood:                 15.423
# No. Observations:                        4   AIC:                            -26.85
# Df Residuals:                            2   BIC:                            -28.07
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0034      0.006     -0.581      0.620      -0.029       0.022
# Market Excess Return     1.2030      0.205      5.857      0.028       0.319       2.087
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.124
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.280
# Skew:                           0.224   Prob(JB):                        0.869
# Kurtosis:                       1.785   Cond. No.                         56.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01338317689569281
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.955
# Model:                                 OLS   Adj. R-squared:                  0.933
# Method:                      Least Squares   F-statistic:                     42.55
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0227
# Time:                             20:01:29   Log-Likelihood:                 17.020
# No. Observations:                        4   AIC:                            -30.04
# Df Residuals:                            2   BIC:                            -31.27
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0038      0.003      1.322      0.317      -0.008       0.016
# Market Excess Return     0.7445      0.114      6.523      0.023       0.253       1.236
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.431
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.524
# Skew:                           0.156   Prob(JB):                        0.769
# Kurtosis:                       1.254   Cond. No.                         47.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0018398095893401452
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.760
# Model:                                 OLS   Adj. R-squared:                  0.680
# Method:                      Least Squares   F-statistic:                     9.487
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0541
# Time:                             20:01:29   Log-Likelihood:                 15.164
# No. Observations:                        5   AIC:                            -26.33
# Df Residuals:                            3   BIC:                            -27.11
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0008      0.007      0.121      0.911      -0.021       0.022
# Market Excess Return     0.6976      0.226      3.080      0.054      -0.023       1.418
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.040
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.248
# Skew:                           1.222   Prob(JB):                        0.536
# Kurtosis:                       2.866   Cond. No.                         33.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01659835881830246
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.747
# Model:                                 OLS   Adj. R-squared:                  0.620
# Method:                      Least Squares   F-statistic:                     5.903
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.136
# Time:                             20:01:29   Log-Likelihood:                 13.491
# No. Observations:                        4   AIC:                            -22.98
# Df Residuals:                            2   BIC:                            -24.21
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0021      0.008      0.257      0.821      -0.034       0.038
# Market Excess Return     1.0144      0.418      2.430      0.136      -0.782       2.811
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.835
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.292
# Skew:                          -0.414   Prob(JB):                        0.864
# Kurtosis:                       1.968   Cond. No.                         71.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.00665147678614154
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.878
# Model:                                 OLS   Adj. R-squared:                  0.818
# Method:                      Least Squares   F-statistic:                     14.45
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0628
# Time:                             20:01:29   Log-Likelihood:                 14.208
# No. Observations:                        4   AIC:                            -24.42
# Df Residuals:                            2   BIC:                            -25.64
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0058      0.006     -0.981      0.430      -0.031       0.020
# Market Excess Return     0.9096      0.239      3.801      0.063      -0.120       1.939
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.053
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.391
# Skew:                           0.589   Prob(JB):                        0.822
# Kurtosis:                       2.022   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 3 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# ...
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0125
# Time:                             20:01:30   Log-Likelihood:                 17.350
# No. Observations:                        5   AIC:                            -30.70
# Df Residuals:                            3   BIC:                            -31.48
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0032      0.012      0.259      0.812      -0.036       0.042
# Market Excess Return     1.1760      0.218      5.398      0.012       0.483       1.869
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.390
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.522
# Skew:                          -0.142   Prob(JB):                        0.770
# Kurtosis:                       1.443   Cond. No.                         50.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.06928794327449922
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.949
# Model:                                 OLS   Adj. R-squared:                  0.923
# Method:                      Least Squares   F-statistic:                     37.04
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0259
# Time:                             20:01:30   Log-Likelihood:                 15.349
# No. Observations:                        4   AIC:                            -26.70
# Df Residuals:                            2   BIC:                            -27.93
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0005      0.012      0.039      0.973      -0.051       0.052
# Market Excess Return     1.2015      0.197      6.086      0.026       0.352       2.051
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.124
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.368
# Skew:                          -0.033   Prob(JB):                        0.832
# Kurtosis:                       1.516   Cond. No.                         53.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0770793025795334
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.985
# Model:                                 OLS   Adj. R-squared:                  0.978
# Method:                      Least Squares   F-statistic:                     135.3
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00731
# Time:                             20:01:30   Log-Likelihood:                 18.924
# No. Observations:                        4   AIC:                            -33.85
# Df Residuals:                            2   BIC:                            -35.08
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0026      0.007     -0.395      0.731      -0.031       0.026
# Market Excess Return     0.9666      0.083     11.630      0.007       0.609       1.324
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.951
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.425
# Skew:                           0.167   Prob(JB):                        0.809
# Kurtosis:                       1.439   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0762244567469052
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.858
# Model:                                 OLS   Adj. R-squared:                  0.810
# Method:                      Least Squares   F-statistic:                     18.11
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0238
# Time:                             20:01:30   Log-Likelihood:                 16.593
# No. Observations:                        5   AIC:                            -29.19
# Df Residuals:                            3   BIC:                            -29.97
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0200      0.023      0.865      0.451      -0.054       0.094
# Market Excess Return     1.3219      0.311      4.255      0.024       0.333       2.310
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.526
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.286
# Skew:                          -0.235   Prob(JB):                        0.867
# Kurtosis:                       1.927   Cond. No.                         61.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.08856686223074085
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.554
# Model:                                 OLS   Adj. R-squared:                  0.331
# Method:                      Least Squares   F-statistic:                     2.486
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.256
# Time:                             20:01:30   Log-Likelihood:                 16.272
# No. Observations:                        4   AIC:                            -28.54
# Df Residuals:                            2   BIC:                            -29.77
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0656      0.015     -4.407      0.048      -0.130      -0.002
# Market Excess Return     0.2791      0.177      1.577      0.256      -0.482       1.041
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.960
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.590
# Skew:                          -0.034   Prob(JB):                        0.745
# Kurtosis:                       1.120   Cond. No.                         60.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.054374851261500365
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.925
# Model:                                 OLS   Adj. R-squared:                  0.888
# Method:                      Least Squares   F-statistic:                     24.83
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0380
# Time:                             20:01:30   Log-Likelihood:                 14.050
# No. Observations:                        4   AIC:                            -24.10
# Df Residuals:                            2   BIC:                            -25.33
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0026      0.013      0.205      0.857      -0.051       0.056
# Market Excess Return     1.0352      0.208      4.983      0.038       0.141       1.929
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.065
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.561
# Skew:                          -0.105   Prob(JB):                        0.756
# Kurtosis:                       1.178   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.05605089987094204
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.000
# Model:                                 OLS   Adj. R-squared:                 -0.333
# Method:                      Least Squares   F-statistic:                 0.0008074
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.979
# Time:                             20:01:30   Log-Likelihood:                 13.681
# No. Observations:                        5   AIC:                            -23.36
# Df Residuals:                            3   BIC:                            -24.14
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0582      0.076     -0.764      0.500      -0.300       0.184
# Market Excess Return    -0.0333      1.172     -0.028      0.979      -3.764       3.697
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.717
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.748
# Skew:                           0.510   Prob(JB):                        0.688
# Kurtosis:                       1.404   Cond. No.                         130.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.016094  0.031185       0.354123
# 1     02                -0.005115  1.296077       1.197385
# 2     03                 0.014123  0.986023       0.990682
# 3     04                 0.022250  0.254032       0.502688
# 4     05                 0.008764  0.641945       0.761297
# ..   ...                      ...       ...            ...
# 67    08                -0.077079  0.966564       0.977709
# 68    09                -0.076224  1.321857       1.214571
# 69    10                -0.088567  0.279072       0.519382
# 70    11                -0.054375  1.035174       1.023449
# 71    12                -0.056051 -0.033309       0.311128
#
# [72 rows x 4 columns]

# %%
coefficients_df.to_csv('coefficients_df_p2_tot.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# -0.0035124914673848864

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (312, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.877
# Model:                            OLS   Adj. R-squared:                  0.876
# Method:                 Least Squares   F-statistic:                     2203.
# Date:                Sat, 04 May 2024   Prob (F-statistic):          6.70e-143
# Time:                        20:02:45   Log-Likelihood:                 893.59
# No. Observations:                 312   AIC:                            -1783.
# Df Residuals:                     310   BIC:                            -1776.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0005      0.001      0.656      0.512      -0.001       0.002
# x1             0.9191      0.020     46.932      0.000       0.881       0.958
# ==============================================================================
# Omnibus:                        1.413   Durbin-Watson:                   1.862
# Prob(Omnibus):                  0.493   Jarque-Bera (JB):                1.137
# Skew:                           0.106   Prob(JB):                        0.566
# Kurtosis:                       3.205   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 0.9190823437408477
# P-value: 6.697113415437841e-143
# Std. error: 0.019583272824272642
# Adj. R-squared: 0.8762244971093389
# F-statistic: 2202.6135037780978
# T-statistic for X1: 46.93200937290134

# %% [markdown]
# # P3 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_3.index:
    # Extract market excess return for the date
    x = returns_df.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_3.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

df['Date'] = pd.to_datetime(df['Date'])
# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2018-01-12              0.037980                 0.039310
# 2018-01-19              0.022305                 0.032952
# 2018-01-26              0.013538                 0.016253
# 2018-02-02             -0.018504                -0.039124
# 2018-02-09             -0.035781                -0.032276

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.02950502003478661
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.837
# Model:                                 OLS   Adj. R-squared:                  0.675
# Method:                      Least Squares   F-statistic:                     5.147
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.264
# Time:                             20:03:02   Log-Likelihood:                 12.367
# No. Observations:                        3   AIC:                            -20.73
# Df Residuals:                            1   BIC:                            -22.54
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0079      0.010      0.761      0.586      -0.123       0.139
# Market Excess Return     0.8800      0.388      2.269      0.264      -4.049       5.809
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.948
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.477
# Skew:                           0.625   Prob(JB):                        0.788
# Kurtosis:                       1.500   Cond. No.                         99.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.011881545415398275
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.757
# Model:                                 OLS   Adj. R-squared:                  0.636
# Method:                      Least Squares   F-statistic:                     6.239
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.130
# Time:                             20:03:02   Log-Likelihood:                 12.075
# No. Observations:                        4   AIC:                            -20.15
# Df Residuals:                            2   BIC:                            -21.38
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0095      0.008     -1.123      0.378      -0.046       0.027
# Market Excess Return     0.7575      0.303      2.498      0.130      -0.547       2.062
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.693
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.280
# Skew:                           0.084   Prob(JB):                        0.869
# Kurtosis:                       1.715   Cond. No.                         36.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0068725708833939445
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.854
# Model:                                 OLS   Adj. R-squared:                  0.806
# Method:                      Least Squares   F-statistic:                     17.61
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0247
# Time:                             20:03:02   Log-Likelihood:                 15.457
# No. Observations:                        5   AIC:                            -26.91
# Df Residuals:                            3   BIC:                            -27.69
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0004      0.007     -0.058      0.958      -0.021       0.021
# Market Excess Return     1.0513      0.250      4.197      0.025       0.254       1.848
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.659
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.613
# Skew:                           0.233   Prob(JB):                        0.736
# Kurtosis:                       1.349   Cond. No.                         39.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01751604382676687
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.824
# Model:                                 OLS   Adj. R-squared:                  0.737
# Method:                      Least Squares   F-statistic:                     9.395
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0920
# Time:                             20:03:02   Log-Likelihood:                 12.864
# No. Observations:                        4   AIC:                            -21.73
# Df Residuals:                            2   BIC:                            -22.96
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0541      0.024     -2.222      0.156      -0.159       0.051
# Market Excess Return     2.6812      0.875      3.065      0.092      -1.083       6.445
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.908
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.814
# Skew:                          -1.039   Prob(JB):                        0.666
# Kurtosis:                       2.245   Cond. No.                         128.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0026872637407674323
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.791
# Model:                                 OLS   Adj. R-squared:                  0.687
# Method:                      Least Squares   F-statistic:                     7.587
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.110
# Time:                             20:03:02   Log-Likelihood:                 11.954
# No. Observations:                        4   AIC:                            -19.91
# Df Residuals:                            2   BIC:                            -21.14
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0055      0.009      0.605      0.607      -0.034       0.045
# Market Excess Return     0.9790      0.355      2.755      0.110      -0.550       2.508
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.387
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.387
# Skew:                          -0.295   Prob(JB):                        0.824
# Kurtosis:                       1.596   Cond. No.                         41.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0006240637188048966
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.868
# Model:                                 OLS   Adj. R-squared:                  0.824
# Method:                      Least Squares   F-statistic:                     19.79
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0211
# Time:                             20:03:02   Log-Likelihood:                 17.221
# No. Observations:                        5   AIC:                            -30.44
# Df Residuals:                            3   BIC:                            -31.22
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0013      0.004      0.292      0.789      -0.013       0.016
# Market Excess Return     0.7843      0.176      4.448      0.021       0.223       1.345
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.524
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.240
# Skew:                           0.398   Prob(JB):                        0.887
# Kurtosis:                       2.281   Cond. No.                         39.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.019296402033257547
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.349
# Model:                                 OLS   Adj. R-squared:                  0.024
# Method:                      Least Squares   F-statistic:                     1.072
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.409
# Time:                             20:03:02   Log-Likelihood:                 11.686
# No. Observations:                        4   AIC:                            -19.37
# Df Residuals:                            2   BIC:                            -20.60
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0080      0.014      0.560      0.632      -0.053       0.069
# Market Excess Return     1.3426      1.296      1.036      0.409      -4.235       6.921
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.253
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.564
# Skew:                           0.812   Prob(JB):                        0.754
# Kurtosis:                       2.135   Cond. No.                         141.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.007708378278739403
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.668
# Model:                                 OLS   Adj. R-squared:                  0.558
# Method:                      Least Squares   F-statistic:                     6.040
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0911
# Time:                             20:03:02   Log-Likelihood:                 16.048
# No. Observations:                        5   AIC:                            -28.10
# Df Residuals:                            3   BIC:                            -28.88
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0027      0.007      0.385      0.726      -0.020       0.025
# Market Excess Return     0.8323      0.339      2.458      0.091      -0.245       1.910
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.040
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.727
# Skew:                          -0.900   Prob(JB):                        0.695
# Kurtosis:                       2.503   Cond. No.                         60.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014801506149777825
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.977
# Model:                                 OLS   Adj. R-squared:                  0.966
# Method:                      Least Squares   F-statistic:                     85.86
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0114
# Time:                             20:03:02   Log-Likelihood:                 16.505
# No. Observations:                        4   AIC:                            -29.01
# Df Residuals:                            2   BIC:                            -30.24
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0064      0.003      2.199      0.159      -0.006       0.019
# Market Excess Return     0.9160      0.099      9.266      0.011       0.491       1.341
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.586
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.216
# Skew:                          -0.102   Prob(JB):                        0.898
# Kurtosis:                       1.880   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.037282947629570656
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.903
# Model:                                 OLS   Adj. R-squared:                  0.855
# Method:                      Least Squares   F-statistic:                     18.69
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0496
# Time:                             20:03:02   Log-Likelihood:                 16.463
# No. Observations:                        4   AIC:                            -28.93
# Df Residuals:                            2   BIC:                            -30.15
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0217      0.005     -4.766      0.041      -0.041      -0.002
# Market Excess Return     0.7231      0.167      4.323      0.050       0.003       1.443
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.010
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.745
# Skew:                           0.975   Prob(JB):                        0.689
# Kurtosis:                       2.184   Cond. No.                         60.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010760510853203845
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.983
# Model:                                 OLS   Adj. R-squared:                  0.978
# Method:                      Least Squares   F-statistic:                     176.2
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000924
# Time:                             20:03:02   Log-Likelihood:                 20.095
# No. Observations:                        5   AIC:                            -36.19
# Df Residuals:                            3   BIC:                            -36.97
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0073      0.003     -2.547      0.084      -0.016       0.002
# Market Excess Return     1.6194      0.122     13.272      0.001       1.231       2.008
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.636
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.539
# Skew:                           0.445   Prob(JB):                        0.764
# Kurtosis:                       1.661   Cond. No.                         48.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.01699383581288906
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.616
# Model:                                 OLS   Adj. R-squared:                  0.425
# Method:                      Least Squares   F-statistic:                     3.214
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.215
# Time:                             20:03:02   Log-Likelihood:                 12.548
# No. Observations:                        4   AIC:                            -21.10
# Df Residuals:                            2   BIC:                            -22.32
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0101      0.008     -1.204      0.352      -0.046       0.026
# Market Excess Return     0.8933      0.498      1.793      0.215      -1.251       3.037
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.975
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.445
# Skew:                          -0.192   Prob(JB):                        0.801
# Kurtosis:                       1.413   Cond. No.                         67.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.019535376100704098
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.295
# Model:                                 OLS   Adj. R-squared:                 -0.057
# Method:                      Least Squares   F-statistic:                    0.8375
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.457
# Time:                             20:03:02   Log-Likelihood:                 12.400
# No. Observations:                        4   AIC:                            -20.80
# Df Residuals:                            2   BIC:                            -22.03
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0002      0.023     -0.008      0.994      -0.099       0.098
# Market Excess Return     0.8097      0.885      0.915      0.457      -2.997       4.616
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.038
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.488
# Skew:                          -0.718   Prob(JB):                        0.784
# Kurtosis:                       2.071   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.022399263103652593
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.955
# Model:                                 OLS   Adj. R-squared:                  0.933
# Method:                      Least Squares   F-statistic:                     42.58
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0227
# Time:                             20:03:02   Log-Likelihood:                 14.193
# No. Observations:                        4   AIC:                            -24.39
# Df Residuals:                            2   BIC:                            -25.61
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0090      0.005      1.683      0.234      -0.014       0.032
# Market Excess Return     1.3622      0.209      6.525      0.023       0.464       2.260
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.248
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.658
# Skew:                          -0.906   Prob(JB):                        0.720
# Kurtosis:                       2.182   Cond. No.                         42.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.023989099502444523
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.706
# Model:                                 OLS   Adj. R-squared:                  0.608
# Method:                      Least Squares   F-statistic:                     7.193
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0749
# Time:                             20:03:02   Log-Likelihood:                 18.073
# No. Observations:                        5   AIC:                            -32.15
# Df Residuals:                            3   BIC:                            -32.93
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0130      0.006      2.339      0.101      -0.005       0.031
# Market Excess Return     0.7407      0.276      2.682      0.075      -0.138       1.620
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.975
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.309
# Skew:                          -0.278   Prob(JB):                        0.857
# Kurtosis:                       1.917   Cond. No.                         73.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.009051485887417308
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.744
# Model:                                 OLS   Adj. R-squared:                  0.616
# Method:                      Least Squares   F-statistic:                     5.818
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.137
# Time:                             20:03:02   Log-Likelihood:                 13.754
# No. Observations:                        4   AIC:                            -23.51
# Df Residuals:                            2   BIC:                            -24.74
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0020      0.007     -0.285      0.803      -0.033       0.029
# Market Excess Return     1.1780      0.488      2.412      0.137      -0.923       3.279
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.568
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.827
# Skew:                           1.048   Prob(JB):                        0.661
# Kurtosis:                       2.244   Cond. No.                         88.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.02175516729572507
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.884
# Model:                                 OLS   Adj. R-squared:                  0.846
# Method:                      Least Squares   F-statistic:                     22.97
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0173
# Time:                             20:03:02   Log-Likelihood:                 16.980
# No. Observations:                        5   AIC:                            -29.96
# Df Residuals:                            3   BIC:                            -30.74
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0072      0.006     -1.289      0.288      -0.025       0.011
# Market Excess Return     1.0960      0.229      4.793      0.017       0.368       1.824
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.959
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.217
# Skew:                          -0.185   Prob(JB):                        0.897
# Kurtosis:                       2.050   Cond. No.                         48.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.027153101356782405
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.904
# Model:                                 OLS   Adj. R-squared:                  0.856
# Method:                      Least Squares   F-statistic:                     18.84
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0492
# Time:                             20:03:02   Log-Likelihood:                 14.294
# No. Observations:                        4   AIC:                            -24.59
# Df Residuals:                            2   BIC:                            -25.82
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0002      0.008      0.029      0.980      -0.034       0.034
# Market Excess Return     1.1821      0.272      4.340      0.049       0.010       2.354
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.654
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.494
# Skew:                          -0.239   Prob(JB):                        0.781
# Kurtosis:                       1.346   Cond. No.                         56.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.021660114691993075
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.983
# Model:                                 OLS   Adj. R-squared:                  0.974
# Method:                      Least Squares   F-statistic:                     115.5
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00855
# Time:                             20:03:02   Log-Likelihood:                 15.057
# No. Observations:                        4   AIC:                            -26.11
# Df Residuals:                            2   BIC:                            -27.34
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0042      0.005     -0.916      0.457      -0.024       0.016
# Market Excess Return     2.0037      0.186     10.748      0.009       1.202       2.806
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.861
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.648
# Skew:                           0.022   Prob(JB):                        0.723
# Kurtosis:                       1.029   Cond. No.                         47.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0012776727192759893
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.985
# Model:                                 OLS   Adj. R-squared:                  0.981
# Method:                      Least Squares   F-statistic:                     203.5
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000747
# Time:                             20:03:02   Log-Likelihood:                 19.556
# No. Observations:                        5   AIC:                            -35.11
# Df Residuals:                            3   BIC:                            -35.89
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0007      0.003     -0.245      0.822      -0.010       0.008
# Market Excess Return     1.3421      0.094     14.265      0.001       1.043       1.642
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.149
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.372
# Skew:                          -0.247   Prob(JB):                        0.830
# Kurtosis:                       1.759   Cond. No.                         33.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.013993005254702305
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.778
# Model:                                 OLS   Adj. R-squared:                  0.667
# Method:                      Least Squares   F-statistic:                     7.008
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.118
# Time:                             20:03:02   Log-Likelihood:                 12.028
# No. Observations:                        4   AIC:                            -20.06
# Df Residuals:                            2   BIC:                            -21.28
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0087      0.012     -0.723      0.545      -0.061       0.043
# Market Excess Return     1.5932      0.602      2.647      0.118      -0.996       4.183
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.953
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.394
# Skew:                           0.235   Prob(JB):                        0.821
# Kurtosis:                       1.537   Cond. No.                         71.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.015451304673519782
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.977
# Model:                                 OLS   Adj. R-squared:                  0.966
# Method:                      Least Squares   F-statistic:                     84.99
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0116
# Time:                             20:03:02   Log-Likelihood:                 17.458
# No. Observations:                        4   AIC:                            -30.92
# Df Residuals:                            2   BIC:                            -32.14
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0021      0.003      0.789      0.513      -0.009       0.013
# Market Excess Return     0.9789      0.106      9.219      0.012       0.522       1.436
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.563
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.534
# Skew:                           0.070   Prob(JB):                        0.766
# Kurtosis:                       1.215   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01819301319515696
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.343
# Model:                                 OLS   Adj. R-squared:                  0.124
# Method:                      Least Squares   F-statistic:                     1.567
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.299
# Time:                             20:03:02   Log-Likelihood:                 12.765
# No. Observations:                        5   AIC:                            -21.53
# Df Residuals:                            3   BIC:                            -22.31
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0061      0.015      0.419      0.704      -0.040       0.052
# Market Excess Return     0.9853      0.787      1.252      0.299      -1.519       3.490
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.596
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.778
# Skew:                          -0.352   Prob(JB):                        0.678
# Kurtosis:                       1.200   Cond. No.                         72.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.002146003949987859
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.577
# Model:                                 OLS   Adj. R-squared:                  0.365
# Method:                      Least Squares   F-statistic:                     2.727
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.240
# Time:                             20:03:02   Log-Likelihood:                 14.824
# No. Observations:                        4   AIC:                            -25.65
# Df Residuals:                            2   BIC:                            -26.87
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0037      0.006     -0.677      0.568      -0.027       0.020
# Market Excess Return     0.4646      0.281      1.651      0.240      -0.746       1.675
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.692
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.439
# Skew:                          -0.513   Prob(JB):                        0.803
# Kurtosis:                       1.742   Cond. No.                         66.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.004359702031455438
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.779
# Model:                                 OLS   Adj. R-squared:                  0.705
# Method:                      Least Squares   F-statistic:                     10.56
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0475
# Time:                             20:03:02   Log-Likelihood:                 14.065
# No. Observations:                        5   AIC:                            -24.13
# Df Residuals:                            3   BIC:                            -24.91
# ...
# Market Excess Return     0.6203      0.518      1.198      0.354      -1.608       2.848
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.759
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.849
# Skew:                           1.069   Prob(JB):                        0.654
# Kurtosis:                       2.277   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.07198840081103154
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.863
# Model:                                 OLS   Adj. R-squared:                  0.817
# Method:                      Least Squares   F-statistic:                     18.84
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0226
# Time:                             20:03:03   Log-Likelihood:                 17.183
# No. Observations:                        5   AIC:                            -30.37
# Df Residuals:                            3   BIC:                            -31.15
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0153      0.021      0.742      0.512      -0.050       0.081
# Market Excess Return     1.1984      0.276      4.341      0.023       0.320       2.077
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.735
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.460
# Skew:                          -0.582   Prob(JB):                        0.794
# Kurtosis:                       2.076   Cond. No.                         61.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.08593636804155373
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.929
# Model:                                 OLS   Adj. R-squared:                  0.894
# Method:                      Least Squares   F-statistic:                     26.23
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0361
# Time:                             20:03:03   Log-Likelihood:                 15.233
# No. Observations:                        4   AIC:                            -26.47
# Df Residuals:                            2   BIC:                            -27.69
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0109      0.019      0.567      0.628      -0.072       0.094
# Market Excess Return     1.1753      0.229      5.121      0.036       0.188       2.163
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.003
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.660
# Skew:                           0.006   Prob(JB):                        0.719
# Kurtosis:                       1.009   Cond. No.                         60.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.05342508539226634
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.968
# Model:                                 OLS   Adj. R-squared:                  0.952
# Method:                      Least Squares   F-statistic:                     59.98
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0163
# Time:                             20:03:03   Log-Likelihood:                 15.580
# No. Observations:                        4   AIC:                            -27.16
# Df Residuals:                            2   BIC:                            -28.39
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0069      0.009      0.812      0.502      -0.030       0.044
# Market Excess Return     1.0974      0.142      7.745      0.016       0.488       1.707
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.535
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.227
# Skew:                          -0.253   Prob(JB):                        0.893
# Kurtosis:                       1.948   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.05977030929220635
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.082
# Model:                                 OLS   Adj. R-squared:                 -0.224
# Method:                      Least Squares   F-statistic:                    0.2668
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.641
# Time:                             20:03:03   Log-Likelihood:                 16.815
# No. Observations:                        5   AIC:                            -29.63
# Df Residuals:                            3   BIC:                            -30.41
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0806      0.041     -1.982      0.142      -0.210       0.049
# Market Excess Return    -0.3235      0.626     -0.517      0.641      -2.316       1.669
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.582
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.682
# Skew:                          -0.263   Prob(JB):                        0.711
# Kurtosis:                       1.269   Cond. No.                         130.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.029505  0.879988       0.919992
# 1     02                -0.011882  0.757452       0.838302
# 2     03                 0.006873  1.051312       1.034208
# 3     04                 0.017516  2.681215       2.120810
# 4     05                -0.002687  0.979019       0.986012
# ..   ...                      ...       ...            ...
# 67    08                -0.069264  0.620262       0.746841
# 68    09                -0.071988  1.198373       1.132249
# 69    10                -0.085936  1.175292       1.116861
# 70    11                -0.053425  1.097357       1.064904
# 71    12                -0.059770 -0.323479       0.117681
#
# [72 rows x 4 columns]

# %%
coefficients_df.to_csv('coefficients_df_p3_tot.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# -0.005217063861049363

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (312, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.813
# Model:                            OLS   Adj. R-squared:                  0.812
# Method:                 Least Squares   F-statistic:                     1346.
# Date:                Sat, 04 May 2024   Prob (F-statistic):          8.42e-115
# Time:                        20:03:34   Log-Likelihood:                 777.51
# No. Observations:                 312   AIC:                            -1551.
# Df Residuals:                     310   BIC:                            -1544.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0006      0.001     -0.566      0.571      -0.003       0.002
# x1             1.0421      0.028     36.682      0.000       0.986       1.098
# ==============================================================================
# Omnibus:                       61.279   Durbin-Watson:                   1.999
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              965.811
# Skew:                          -0.008   Prob(JB):                    1.89e-210
# Kurtosis:                      11.619   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 1.0421040706751872
# P-value: 8.416043977681431e-115
# Std. error: 0.028409210040325247
# Adj. R-squared: 0.8121484369332048
# F-statistic: 1345.5624820082894
# T-statistic for X1: 36.68190946513402

# %% [markdown]
# # P4 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_4.index:
    # Extract market excess return for the date
    x = returns_df.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_4.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

df['Date'] = pd.to_datetime(df['Date'])
# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2018-01-12              0.037980                 0.060041
# 2018-01-19              0.022305                 0.026503
# 2018-01-26              0.013538                 0.023263
# 2018-02-02             -0.018504                -0.020048
# 2018-02-09             -0.035781                -0.019505

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.03660222290300373
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.922
# Model:                                 OLS   Adj. R-squared:                  0.845
# Method:                      Least Squares   F-statistic:                     11.89
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.180
# Time:                             20:08:59   Log-Likelihood:                 11.869
# No. Observations:                        3   AIC:                            -19.74
# Df Residuals:                            1   BIC:                            -21.54
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0023      0.012     -0.186      0.883      -0.157       0.153
# Market Excess Return     1.5794      0.458      3.449      0.180      -4.239       7.398
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.948
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.477
# Skew:                          -0.625   Prob(JB):                        0.788
# Kurtosis:                       1.500   Cond. No.                         99.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0009028407869726418
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.922
# Model:                                 OLS   Adj. R-squared:                  0.883
# Method:                      Least Squares   F-statistic:                     23.72
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0397
# Time:                             20:08:59   Log-Likelihood:                 14.750
# No. Observations:                        4   AIC:                            -25.50
# Df Residuals:                            2   BIC:                            -26.73
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0033      0.004      0.772      0.521      -0.015       0.022
# Market Excess Return     0.7565      0.155      4.870      0.040       0.088       1.425
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.836
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.457
# Skew:                          -0.565   Prob(JB):                        0.796
# Kurtosis:                       1.788   Cond. No.                         36.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.002015784497623027
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.982
# Model:                                 OLS   Adj. R-squared:                  0.977
# Method:                      Least Squares   F-statistic:                     167.5
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000996
# Time:                             20:08:59   Log-Likelihood:                 21.991
# No. Observations:                        5   AIC:                            -39.98
# Df Residuals:                            3   BIC:                            -40.76
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0040      0.002     -2.267      0.108      -0.010       0.002
# Market Excess Return     0.8777      0.068     12.943      0.001       0.662       1.093
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.580
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.563
# Skew:                          -0.722   Prob(JB):                        0.754
# Kurtosis:                       2.213   Cond. No.                         39.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.02972128262892529
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.827
# Model:                                 OLS   Adj. R-squared:                  0.740
# Method:                      Least Squares   F-statistic:                     9.551
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0907
# Time:                             20:08:59   Log-Likelihood:                 15.582
# No. Observations:                        4   AIC:                            -27.16
# Df Residuals:                            2   BIC:                            -28.39
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0069      0.012     -0.558      0.633      -0.060       0.046
# Market Excess Return     1.3703      0.443      3.090      0.091      -0.537       3.278
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.511
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.202
# Skew:                          -0.202   Prob(JB):                        0.904
# Kurtosis:                       1.976   Cond. No.                         128.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.009091808545471003
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.949
# Model:                                 OLS   Adj. R-squared:                  0.924
# Method:                      Least Squares   F-statistic:                     37.41
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0257
# Time:                             20:08:59   Log-Likelihood:                 14.746
# No. Observations:                        4   AIC:                            -25.49
# Df Residuals:                            2   BIC:                            -26.72
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -2.951e-05      0.005     -0.007      0.995      -0.020       0.019
# Market Excess Return     1.0819      0.177      6.117      0.026       0.321       1.843
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.391
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.380
# Skew:                          -0.269   Prob(JB):                        0.827
# Kurtosis:                       1.589   Cond. No.                         41.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0068634919664482905
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.763
# Model:                                 OLS   Adj. R-squared:                  0.684
# Method:                      Least Squares   F-statistic:                     9.640
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0531
# Time:                             20:08:59   Log-Likelihood:                 14.629
# No. Observations:                        5   AIC:                            -25.26
# Df Residuals:                            3   BIC:                            -26.04
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0061      0.007     -0.810      0.477      -0.030       0.018
# Market Excess Return     0.9192      0.296      3.105      0.053      -0.023       1.861
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.676
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.135
# Skew:                           1.163   Prob(JB):                        0.567
# Kurtosis:                       2.812   Cond. No.                         39.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010931212375864443
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.838
# Model:                                 OLS   Adj. R-squared:                  0.757
# Method:                      Least Squares   F-statistic:                     10.34
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0846
# Time:                             20:08:59   Log-Likelihood:                 14.505
# No. Observations:                        4   AIC:                            -25.01
# Df Residuals:                            2   BIC:                            -26.24
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0064      0.007     -0.908      0.460      -0.037       0.024
# Market Excess Return     2.0603      0.641      3.215      0.085      -0.697       4.817
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.029
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.435
# Skew:                          -0.444   Prob(JB):                        0.805
# Kurtosis:                       1.650   Cond. No.                         141.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.014659837593885148
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.896
# Model:                                 OLS   Adj. R-squared:                  0.861
# Method:                      Least Squares   F-statistic:                     25.81
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0147
# Time:                             20:08:59   Log-Likelihood:                 18.640
# No. Observations:                        5   AIC:                            -33.28
# Df Residuals:                            3   BIC:                            -34.06
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0018      0.004     -0.434      0.694      -0.015       0.012
# Market Excess Return     1.0244      0.202      5.080      0.015       0.383       1.666
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.995
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.267
# Skew:                           0.358   Prob(JB):                        0.875
# Kurtosis:                       2.122   Cond. No.                         60.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.007493729852917283
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.918
# Model:                                 OLS   Adj. R-squared:                  0.878
# Method:                      Least Squares   F-statistic:                     22.52
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0417
# Time:                             20:08:59   Log-Likelihood:                 13.013
# No. Observations:                        4   AIC:                            -22.03
# Df Residuals:                            2   BIC:                            -23.25
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0028      0.007     -0.404      0.725      -0.033       0.027
# Market Excess Return     1.1232      0.237      4.745      0.042       0.105       2.142
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.029
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.332
# Skew:                           0.331   Prob(JB):                        0.847
# Kurtosis:                       1.753   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.033552863250899186
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.654
# Model:                                 OLS   Adj. R-squared:                  0.482
# Method:                      Least Squares   F-statistic:                     3.788
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.191
# Time:                             20:08:59   Log-Likelihood:                 13.276
# No. Observations:                        4   AIC:                            -22.55
# Df Residuals:                            2   BIC:                            -23.78
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0180      0.010     -1.781      0.217      -0.061       0.025
# Market Excess Return     0.7222      0.371      1.946      0.191      -0.874       2.319
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.604
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.812
# Skew:                          -1.033   Prob(JB):                        0.666
# Kurtosis:                       2.225   Cond. No.                         60.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010564694896947906
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.981
# Model:                                 OLS   Adj. R-squared:                  0.975
# Method:                      Least Squares   F-statistic:                     158.2
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00108
# Time:                             20:08:59   Log-Likelihood:                 20.314
# No. Observations:                        5   AIC:                            -36.63
# Df Residuals:                            3   BIC:                            -37.41
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0058      0.003     -2.118      0.124      -0.014       0.003
# Market Excess Return     1.4686      0.117     12.577      0.001       1.097       1.840
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.562
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.813
# Skew:                          -0.401   Prob(JB):                        0.666
# Kurtosis:                       1.194   Cond. No.                         48.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.016706103909188176
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.673
# Model:                                 OLS   Adj. R-squared:                  0.509
# Method:                      Least Squares   F-statistic:                     4.112
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.180
# Time:                             20:08:59   Log-Likelihood:                 11.175
# No. Observations:                        4   AIC:                            -18.35
# Df Residuals:                            2   BIC:                            -19.58
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0057      0.012     -0.481      0.678      -0.056       0.045
# Market Excess Return     1.4240      0.702      2.028      0.180      -1.598       4.446
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.879
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.472
# Skew:                           0.397   Prob(JB):                        0.790
# Kurtosis:                       1.516   Cond. No.                         67.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.028608016268311838
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.206
# Model:                                 OLS   Adj. R-squared:                 -0.191
# Method:                      Least Squares   F-statistic:                    0.5196
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.546
# Time:                             20:08:59   Log-Likelihood:                 12.466
# No. Observations:                        4   AIC:                            -20.93
# Df Residuals:                            2   BIC:                            -22.16
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0439      0.023      1.949      0.191      -0.053       0.141
# Market Excess Return    -0.6272      0.870     -0.721      0.546      -4.371       3.116
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.907
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.539
# Skew:                          -0.790   Prob(JB):                        0.764
# Kurtosis:                       2.144   Cond. No.                         115.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010836247140971197
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.878
# Model:                                 OLS   Adj. R-squared:                  0.818
# Method:                      Least Squares   F-statistic:                     14.44
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0628
# Time:                             20:08:59   Log-Likelihood:                 11.355
# No. Observations:                        4   AIC:                            -18.71
# Df Residuals:                            2   BIC:                            -19.94
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0051      0.011     -0.466      0.687      -0.052       0.042
# Market Excess Return     1.6128      0.424      3.800      0.063      -0.213       3.439
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.503
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.167
# Skew:                          -0.007   Prob(JB):                        0.920
# Kurtosis:                       2.000   Cond. No.                         42.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014912361259155873
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.970
# Model:                                 OLS   Adj. R-squared:                  0.960
# Method:                      Least Squares   F-statistic:                     96.33
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00225
# Time:                             20:08:59   Log-Likelihood:                 21.223
# No. Observations:                        5   AIC:                            -38.45
# Df Residuals:                            3   BIC:                            -39.23
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0065      0.003     -2.192      0.116      -0.016       0.003
# Market Excess Return     1.4437      0.147      9.815      0.002       0.976       1.912
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.403
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.959
# Skew:                          -1.049   Prob(JB):                        0.619
# Kurtosis:                       2.551   Cond. No.                         73.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.021892131327184823
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.717
# Model:                                 OLS   Adj. R-squared:                  0.575
# Method:                      Least Squares   F-statistic:                     5.056
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.154
# Time:                             20:08:59   Log-Likelihood:                 11.293
# No. Observations:                        4   AIC:                            -18.59
# Df Residuals:                            2   BIC:                            -19.81
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0028      0.013      0.208      0.854      -0.054       0.060
# Market Excess Return     2.0316      0.904      2.249      0.154      -1.856       5.919
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.579
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.840
# Skew:                           1.059   Prob(JB):                        0.657
# Kurtosis:                       2.254   Cond. No.                         88.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.02645599490627946
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.800
# Model:                                 OLS   Adj. R-squared:                  0.733
# Method:                      Least Squares   F-statistic:                     11.99
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0406
# Time:                             20:08:59   Log-Likelihood:                 14.053
# No. Observations:                        5   AIC:                            -24.11
# Df Residuals:                            3   BIC:                            -24.89
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0076      0.010     -0.755      0.505      -0.039       0.024
# Market Excess Return     1.4217      0.411      3.463      0.041       0.115       2.728
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.074
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.384
# Skew:                          -0.432   Prob(JB):                        0.825
# Kurtosis:                       1.952   Cond. No.                         48.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.021117368852446673
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.430
# Model:                                 OLS   Adj. R-squared:                  0.144
# Method:                      Least Squares   F-statistic:                     1.507
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.345
# Time:                             20:08:59   Log-Likelihood:                 11.703
# No. Observations:                        4   AIC:                            -19.41
# Df Residuals:                            2   BIC:                            -20.63
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0066      0.015      0.438      0.704      -0.058       0.071
# Market Excess Return     0.6389      0.521      1.227      0.345      -1.601       2.879
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.214
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.321
# Skew:                          -0.500   Prob(JB):                        0.852
# Kurtosis:                       2.037   Cond. No.                         56.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014981348707551034
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.956
# Model:                                 OLS   Adj. R-squared:                  0.935
# Method:                      Least Squares   F-statistic:                     43.82
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0221
# Time:                             20:08:59   Log-Likelihood:                 15.034
# No. Observations:                        4   AIC:                            -26.07
# Df Residuals:                            2   BIC:                            -27.30
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0011      0.005     -0.229      0.840      -0.021       0.019
# Market Excess Return     1.2414      0.188      6.620      0.022       0.435       2.048
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.462
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.900
# Skew:                          -1.108   Prob(JB):                        0.638
# Kurtosis:                       2.299   Cond. No.                         47.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.008240878149842165
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.935
# Model:                                 OLS   Adj. R-squared:                  0.914
# Method:                      Least Squares   F-statistic:                     43.47
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00710
# Time:                             20:08:59   Log-Likelihood:                 16.603
# No. Observations:                        5   AIC:                            -29.21
# Df Residuals:                            3   BIC:                            -29.99
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0099      0.005     -1.955      0.146      -0.026       0.006
# Market Excess Return     1.1198      0.170      6.593      0.007       0.579       1.660
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.050
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.764
# Skew:                           0.939   Prob(JB):                        0.683
# Kurtosis:                       2.623   Cond. No.                         33.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.02056256248023793
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.688
# Model:                                 OLS   Adj. R-squared:                  0.532
# Method:                      Least Squares   F-statistic:                     4.414
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.170
# Time:                             20:08:59   Log-Likelihood:                 10.802
# No. Observations:                        4   AIC:                            -17.60
# Df Residuals:                            2   BIC:                            -18.83
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0039      0.016     -0.239      0.833      -0.074       0.066
# Market Excess Return     1.7181      0.818      2.101      0.170      -1.800       5.236
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.434
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.771
# Skew:                           0.996   Prob(JB):                        0.680
# Kurtosis:                       2.188   Cond. No.                         71.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.022146434176880354
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.929
# Model:                                 OLS   Adj. R-squared:                  0.894
# Method:                      Least Squares   F-statistic:                     26.32
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0360
# Time:                             20:08:59   Log-Likelihood:                 13.953
# No. Observations:                        4   AIC:                            -23.91
# Df Residuals:                            2   BIC:                            -25.13
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0043      0.006      0.677      0.568      -0.023       0.031
# Market Excess Return     1.3085      0.255      5.131      0.036       0.211       2.406
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.704
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.952
# Skew:                           1.146   Prob(JB):                        0.621
# Kurtosis:                       2.327   Cond. No.                         48.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.024217205969151473
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.830
# Model:                                 OLS   Adj. R-squared:                  0.773
# Method:                      Least Squares   F-statistic:                     14.63
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0315
# Time:                             20:08:59   Log-Likelihood:                 16.832
# No. Observations:                        5   AIC:                            -29.66
# Df Residuals:                            3   BIC:                            -30.45
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0078      0.006      1.214      0.312      -0.013       0.028
# Market Excess Return     1.3342      0.349      3.824      0.031       0.224       2.445
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.945
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.880
# Skew:                           1.024   Prob(JB):                        0.644
# Kurtosis:                       2.812   Cond. No.                         72.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.009562325116897682
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.673
# Model:                                 OLS   Adj. R-squared:                  0.510
# Method:                      Least Squares   F-statistic:                     4.125
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.179
# Time:                             20:08:59   Log-Likelihood:                 15.002
# No. Observations:                        4   AIC:                            -26.00
# Df Residuals:                            2   BIC:                            -27.23
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0026      0.005      0.503      0.665      -0.020       0.025
# Market Excess Return     0.5465      0.269      2.031      0.179      -0.611       1.704
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.997
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.489
# Skew:                          -0.070   Prob(JB):                        0.783
# Kurtosis:                       1.292   Cond. No.                         66.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.004593524373142646
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.915
# Model:                                 OLS   Adj. R-squared:                  0.887
# Method:                      Least Squares   F-statistic:                     32.46
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0107
# Time:                             20:08:59   Log-Likelihood:                 18.014
# No. Observations:                        5   AIC:                            -32.03
# Df Residuals:                            3   BIC:                            -32.81
# ...
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.0652303915137505
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.652
# Model:                                 OLS   Adj. R-squared:                  0.536
# Method:                      Least Squares   F-statistic:                     5.616
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0985
# Time:                             20:08:59   Log-Likelihood:                 15.771
# No. Observations:                        5   AIC:                            -27.54
# Df Residuals:                            3   BIC:                            -28.32
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0020      0.027     -0.075      0.945      -0.089       0.085
# Market Excess Return     0.8677      0.366      2.370      0.099      -0.298       2.033
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.072
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.587
# Skew:                           0.796   Prob(JB):                        0.746
# Kurtosis:                       2.468   Cond. No.                         61.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.08290128272661182
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.849
# Model:                                 OLS   Adj. R-squared:                  0.773
# Method:                      Least Squares   F-statistic:                     11.21
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0788
# Time:                             20:08:59   Log-Likelihood:                 13.822
# No. Observations:                        4   AIC:                            -23.64
# Df Residuals:                            2   BIC:                            -24.87
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0072      0.027      0.263      0.817      -0.111       0.125
# Market Excess Return     1.0934      0.327      3.349      0.079      -0.312       2.498
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.266
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.555
# Skew:                           0.807   Prob(JB):                        0.758
# Kurtosis:                       2.149   Cond. No.                         60.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.04982685016161611
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.869
# Model:                                 OLS   Adj. R-squared:                  0.804
# Method:                      Least Squares   F-statistic:                     13.30
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0676
# Time:                             20:08:59   Log-Likelihood:                 12.777
# No. Observations:                        4   AIC:                            -21.55
# Df Residuals:                            2   BIC:                            -22.78
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0075      0.017      0.434      0.707      -0.067       0.081
# Market Excess Return     1.0416      0.286      3.647      0.068      -0.187       2.270
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.291
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.209
# Skew:                          -0.073   Prob(JB):                        0.901
# Kurtosis:                       1.889   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.06730862342957916
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.409
# Model:                                 OLS   Adj. R-squared:                  0.211
# Method:                      Least Squares   F-statistic:                     2.073
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.246
# Time:                             20:08:59   Log-Likelihood:                 17.925
# No. Observations:                        5   AIC:                            -31.85
# Df Residuals:                            3   BIC:                            -32.63
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0207      0.033     -0.637      0.570      -0.124       0.083
# Market Excess Return     0.7222      0.502      1.440      0.246      -0.874       2.319
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.964
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.698
# Skew:                          -0.250   Prob(JB):                        0.705
# Kurtosis:                       1.239   Cond. No.                         130.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.036602  1.579406       1.386271
# 1     02                 0.000903  0.756465       0.837643
# 2     03                 0.002016  0.877690       0.918460
# 3     04                 0.029721  1.370266       1.246844
# 4     05                -0.009092  1.081912       1.054608
# ..   ...                      ...       ...            ...
# 67    08                -0.080091  0.837540       0.891693
# 68    09                -0.065230  0.867705       0.911803
# 69    10                -0.082901  1.093390       1.062260
# 70    11                -0.049827  1.041590       1.027727
# 71    12                -0.067309  0.722177       0.814784
#
# [72 rows x 4 columns]

# %%
coefficients_df.to_csv('coefficients_df_p4_tot.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# -0.0034262957917914425

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (312, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                     2893.
# Date:                Sat, 04 May 2024   Prob (F-statistic):          2.99e-159
# Time:                        20:09:19   Log-Likelihood:                 870.41
# No. Observations:                 312   AIC:                            -1737.
# Df Residuals:                     310   BIC:                            -1729.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0015      0.001      1.823      0.069      -0.000       0.003
# x1             1.1346      0.021     53.788      0.000       1.093       1.176
# ==============================================================================
# Omnibus:                       10.114   Durbin-Watson:                   1.897
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               14.355
# Skew:                          -0.239   Prob(JB):                     0.000764
# Kurtosis:                       3.935   Cond. No.                         25.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 1.1345833110932078
# P-value: 2.988345875668752e-159
# Std. error: 0.021093780646553945
# Adj. R-squared: 0.9029066574007075
# F-statistic: 2893.103237299258
# T-statistic for X1: 53.78757512008937

# %%
returns_df['Risk Premium'].mean()
# Out:
# -0.004384438915284626
