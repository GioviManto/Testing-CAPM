# %%
import pandas as pd

returns = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Returns_2018-2023.csv')

portfolio_1 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-2/p1-2.csv', usecols=[0])
portfolio_2 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-2/p2-2.csv', usecols=[0])
portfolio_3 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-2/p3-2.csv', usecols=[0])
portfolio_4 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-2/p4-2.csv', usecols=[0])

# %%
# Rename the column
portfolio_1 = portfolio_1.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2019' from the values in the 'Stock' column
portfolio_1['Stock'] = portfolio_1['Stock'].str.replace(' 2019', '')

# %%
portfolio_1
# Out:
#                 Stock
# 0               Inwit
# 1            Diasorin
# 2            Amplifon
# 3  Brunello cucinelli
# 4                Hera
# 5                 Erg
# 6           Recordati
# 7             Italgas
# 8                Enel
# 9                Snam

# %%
# Rename the column
portfolio_2 = portfolio_2.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2019' from the values in the 'Stock' column
portfolio_2['Stock'] = portfolio_2['Stock'].str.replace(' 2019', '')

# %%
portfolio_2
# Out:
#                Stock
# 0              Terna
# 1                A2A
# 2            Ferrari
# 3            Campari
# 4       Generali Ass
# 5   Banca Mediolanum
# 6  Banca pop Sondrio
# 7            Moncler
# 8     Poste Italiane

# %%
# Rename the column
portfolio_3 = portfolio_3.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2019' from the values in the 'Stock' column
portfolio_3['Stock'] = portfolio_3['Stock'].str.replace(' 2019', '')

# %%
portfolio_3
# Out:
#         Stock
# 0         Eni
# 1   Interpump
# 2  Mediobanca
# 3      Unipol
# 4      Azimut
# 5   Banco Bpm
# 6     Telecom
# 7    Leonardo
# 8  BPER banca

# %%
# Rename the column
portfolio_4 = portfolio_4.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2019' from the values in the 'Stock' column
portfolio_4['Stock'] = portfolio_4['Stock'].str.replace(' 2019', '')

# %%
portfolio_4
# Out:
#                              Stock
# 0                         Prysmian
# 1                 Intesa San Paolo
# 2                           Fineco
# 3                Stmicroeletronics
# 4                          Tenaris
# 5                       Stellantis
# 6                           Saipem
# 7                          Pirelli
# 8                        Unicredit
# 9  Banca Monte dei Paschi di Siena

# %%
# Convert 'Date' column to datetime format
returns['Date'] = pd.to_datetime(returns['Date'])

# Extract year from 'Date' column
returns['Year'] = returns['Date'].dt.year

# Filter DataFrame to include only the data from 2020
returns_2021 = returns[returns['Year'] == 2021].copy()

# Drop the 'Year' column as it's no longer needed
returns_2021.drop(columns='Year', inplace=True)

# %%
returns_2021.drop(columns='Unnamed: 0', inplace=True)

# %%
returns_2021.head()
# Out:
#           Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 155 2021-01-01       0.004642       0.029597            0.024067
# 156 2021-01-08       0.025235       0.025297           -0.005875
# 157 2021-01-15      -0.018101      -0.018318            0.004728
# 158 2021-01-22      -0.013091       0.025514           -0.012353
# 159 2021-01-29      -0.023353      -0.004827           -0.025313
#
#      Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 155         -0.006430              0.003378                    0.006378
# 156          0.003658              0.097643                   -0.004930
# 157          0.032240             -0.012883                    0.041047
# 158         -0.028246             -0.020820                   -0.039429
# 159         -0.029625             -0.035544                   -0.073602
#
#      Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# ...

# %%
risk_premium_2021 = returns_2021[['Date','Risk Premium']]

# %%
risk_premium_2021.head()
# Out:
#           Date  Risk Premium
# 155 2021-01-01      0.017161
# 156 2021-01-08      0.036139
# 157 2021-01-15     -0.008024
# 158 2021-01-22     -0.003783
# 159 2021-01-29     -0.014488

# %%
risk_premium_2021['Risk Premium'].mean()
# Out:
# 0.015213248876278293

# %%
returns_2021.columns = returns_2021.columns.str.replace('2018-2023', '')

# %%
import numpy as np

# Copy the 2021 data to avoid modifying the original DataFrame
returns_2021_excess = returns_2021.copy()

# Calculate excess returns for each stock by subtracting the risk-free rate
risk_free_rate = returns_2021_excess['BOT 3m'].values  # Convert Series to NumPy array
returns_2021_excess.iloc[:, 2:-2] -= risk_free_rate[:, np.newaxis]

# Set 'Date' column as the index
returns_2021_excess.set_index('Date', inplace=True)

# Display the DataFrame with 'Date' as the index
returns_2021_excess.head()
# Out:
#             FTSEMIB Index      A2A   Amplifon    Azimut   BPER banca   \
# Date
# 2021-01-01       0.004642  0.042117   0.036587  0.006089     0.015898
# 2021-01-08       0.025235  0.036201   0.005028  0.014562     0.108547
# 2021-01-15      -0.018101 -0.008241   0.014805  0.042317    -0.002807
# 2021-01-22      -0.013091  0.034822  -0.003045 -0.018938    -0.011513
# 2021-01-29      -0.023353  0.004038  -0.016447 -0.020760    -0.026679
#
#             Banca Mediolanum   Banca Monte dei Paschi di Siena   \
# Date
# 2021-01-01           0.018898                          0.005851
# 2021-01-08           0.005974                          0.103905
# 2021-01-15           0.051124                         -0.046940
# 2021-01-22          -0.030121                          0.011165
# 2021-01-29          -0.064737                         -0.032915
#
#             Banca pop Sondrio   Banco Bpm   Brunello cucinelli   ...  \
# Date                                                             ...
# ...

# %%
portfolio_1['Stock']
# Out:
# 0                 Inwit
# 1              Diasorin
# 2              Amplifon
# 3    Brunello cucinelli
# 4                  Hera
# 5                   Erg
# 6             Recordati
# 7               Italgas
# 8                  Enel
# 9                  Snam
# Name: Stock, dtype: object

# %%
returns_2021_excess.columns = returns_2021_excess.columns.str.strip()

# %%
p_1 = returns_2021_excess[portfolio_1['Stock'].values]
p_1.head()
# Out:
#                Inwit  Diasorin  Amplifon  Brunello cucinelli      Hera  \
# Date
# 2021-01-01  0.011011  0.028648  0.036587           -0.004010  0.026815
# 2021-01-08 -0.032903 -0.037891  0.005028           -0.029993  0.027011
# 2021-01-15 -0.014146  0.015021  0.014805            0.008325  0.020645
# 2021-01-22  0.017403  0.085568 -0.003045            0.015159 -0.060627
# 2021-01-29 -0.041991  0.040865 -0.016447           -0.030111  0.022217
#
#                  Erg  Recordati   Italgas      Enel      Snam
# Date
# 2021-01-01  0.064678   0.036001  0.028144  0.013124  0.012302
# 2021-01-08  0.080989  -0.045130  0.001288  0.090894  0.021554
# 2021-01-15  0.021259   0.030642 -0.003515  0.001238 -0.008633
# 2021-01-22  0.068549  -0.007638 -0.019826 -0.048712 -0.036496
# 2021-01-29 -0.052283   0.003974  0.012921 -0.009589  0.002894

# %%
p_2 = returns_2021_excess[portfolio_2['Stock'].values]
p_2.head()
# Out:
#                Terna       A2A   Ferrari   Campari  Generali Ass  \
# Date
# 2021-01-01  0.026471  0.042117  0.023234  0.028178      0.011119
# 2021-01-08  0.004184  0.036201 -0.033623 -0.040916      0.027734
# 2021-01-15 -0.008609 -0.008241 -0.013224 -0.004828      0.000767
# 2021-01-22 -0.008420  0.034822  0.002491  0.019624      0.019402
# 2021-01-29  0.010537  0.004038 -0.006005  0.015900     -0.020080
#
#             Banca Mediolanum  Banca pop Sondrio   Moncler  Poste Italiane
# Date
# 2021-01-01          0.018898           0.024479  0.052552        0.006783
# 2021-01-08          0.005974           0.068177 -0.030580        0.043837
# 2021-01-15          0.051124          -0.049252 -0.004696       -0.018082
# 2021-01-22         -0.030121          -0.015372  0.037185       -0.000750
# 2021-01-29         -0.064737          -0.041744 -0.033460       -0.014357

# %%
p_3 = returns_2021_excess[portfolio_3['Stock'].values]
p_3.head()
# Out:
#                  Eni  Interpump  Mediobanca    Unipol    Azimut  Banco Bpm  \
# Date
# 2021-01-01  0.008325   0.033785    0.013581  0.020771  0.006089   0.006089
# 2021-01-08  0.067291   0.004954    0.011965  0.040060  0.014562   0.014562
# 2021-01-15 -0.011961   0.015064   -0.000257 -0.019247  0.042317   0.042317
# 2021-01-22 -0.023418  -0.001114    0.001543 -0.025511 -0.018938  -0.018938
# 2021-01-29 -0.013378  -0.062348    0.002389 -0.029861 -0.020760  -0.020760
#
#              Telecom  Leonardo  BPER banca
# Date
# 2021-01-01  0.000995  0.017621    0.015898
# 2021-01-08  0.056214  0.011919    0.108547
# 2021-01-15 -0.044422  0.000611   -0.002807
# 2021-01-22 -0.031711 -0.026528   -0.011513
# 2021-01-29 -0.003156  0.024087   -0.026679

# %%
p_4 = returns_2021_excess[portfolio_4['Stock'].values]
p_4.head()
# Out:
#             Prysmian  Intesa San Paolo    Fineco  Stmicroeletronics   Tenaris  \
# Date
# 2021-01-01  0.043725          0.012310  0.024986           0.019773 -0.000886
# 2021-01-08  0.054920          0.033073  0.026202           0.091100  0.080046
# 2021-01-15 -0.074245         -0.017033  0.015957           0.007047 -0.027201
# 2021-01-22  0.016502         -0.000051 -0.018460           0.000189 -0.068134
# 2021-01-29 -0.039706         -0.033062 -0.023453           0.029418  0.031123
#
#             Stellantis    Saipem   Pirelli  Unicredit  \
# Date
# 2021-01-01    0.010338  0.031462  0.019333   0.006799
# 2021-01-08    0.000944  0.114300  0.013836   0.080203
# 2021-01-15   -0.123864 -0.033494 -0.014215  -0.048250
# 2021-01-22    0.062615 -0.078363 -0.001527   0.015541
# 2021-01-29   -0.044762  0.030070  0.013293  -0.015912
#
#             Banca Monte dei Paschi di Siena
# Date
# 2021-01-01                         0.005851
# 2021-01-08                         0.103905
# ...

# %%
returns_2021 = returns_2021.set_index('Date')

# %% [markdown]
# # P1 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_1.index:
    # Extract market excess return for the date
    x = returns_2021.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_1.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2021-01-01              0.017161                 0.025330
# 2021-01-08              0.036139                 0.008085
# 2021-01-15             -0.008024                 0.008564
# 2021-01-22             -0.003783                 0.001034
# 2021-01-29             -0.014488                -0.006755

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 1': monthly_portfolio_excess_return, 'Beta 1': x1_coefficient, 'Adjusted Beta 1': adj, "Residual Variance 1": residual_variance})

# Convert the list to a DataFrame
coefficients_df_port1 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port1
# Out:
# 0.007251505730459386
#                                OLS Regression Results
# ...
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.315
# Model:                                 OLS   Adj. R-squared:                  0.086
# Method:                      Least Squares   F-statistic:                     1.378
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.325
# Time:                             10:53:42   Log-Likelihood:                 16.574
# No. Observations:                        5   AIC:                            -29.15
# Df Residuals:                            3   BIC:                            -29.93
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # P2 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_2.index:
    # Extract market excess return for the date
    x = returns_2021.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_2.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2021-01-01              0.017161                 0.025981
# 2021-01-08              0.036139                 0.008999
# 2021-01-15             -0.008024                -0.006116
# 2021-01-22             -0.003783                 0.006540
# 2021-01-29             -0.014488                -0.016656

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 2': monthly_portfolio_excess_return, 'Beta 2': x1_coefficient, 'Adjusted Beta 2': adj, "Residual Variance 2": residual_variance})

# Convert the list to a DataFrame
coefficients_df_port2 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port2
# Out:
# 0.003749518570260006
#                                OLS Regression Results
# ...
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.481
# Model:                                 OLS   Adj. R-squared:                  0.308
# Method:                      Least Squares   F-statistic:                     2.782
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.194
# Time:                             10:53:43   Log-Likelihood:                 15.733
# No. Observations:                        5   AIC:                            -27.47
# Df Residuals:                            3   BIC:                            -28.25
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # P3 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_3.index:
    # Extract market excess return for the date
    x = returns_2021.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_3.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2021-01-01              0.017161                 0.013684
# 2021-01-08              0.036139                 0.036675
# 2021-01-15             -0.008024                 0.002402
# 2021-01-22             -0.003783                -0.017347
# 2021-01-29             -0.014488                -0.016718

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 3': monthly_portfolio_excess_return, 'Beta 3': x1_coefficient, 'Adjusted Beta 3': adj, "Residual Variance 3" : residual_variance})

# Convert the list to a DataFrame
coefficients_df_port3 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port3
# Out:
# 0.0037389064613730497
#                                OLS Regression Results
# ...
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.855
# Model:                                 OLS   Adj. R-squared:                  0.807
# Method:                      Least Squares   F-statistic:                     17.75
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0244
# Time:                             10:53:43   Log-Likelihood:                 17.240
# No. Observations:                        5   AIC:                            -30.48
# Df Residuals:                            3   BIC:                            -31.26
# Df Model:                                1
# Covariance Type:                 nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %% [markdown]
# # P4 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_4.index:
    # Extract market excess return for the date
    x = returns_2021.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_4.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2021-01-01              0.017161                 0.017369
# 2021-01-08              0.036139                 0.059853
# 2021-01-15             -0.008024                -0.036224
# 2021-01-22             -0.003783                -0.006052
# 2021-01-29             -0.014488                -0.008591

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 4': monthly_portfolio_excess_return, 'Beta 4': x1_coefficient, 'Adjusted Beta 4': adj, "Residual Variance 4" : residual_variance})

# Convert the list to a DataFrame
coefficients_df_port4 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port4
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# 0.005271100860719901
#                                OLS Regression Results
# ...

# %%
merged_df = pd.merge(coefficients_df_port1, coefficients_df_port2, on="Month", how="inner")
merged_df = pd.merge(merged_df, coefficients_df_port3, on="Month", how="inner")
merged_df = pd.merge(merged_df, coefficients_df_port4, on="Month", how="inner")
merged_df
# Out:
#    Month  Portfolio Excess Return 1    Beta 1  Adjusted Beta 1  \
# 0     01                   0.007252  0.319105         0.546070
# 1     02                   0.004835  0.921365         0.947577
# 2     03                   0.024368  1.151962         1.101308
# 3     04                   0.015193  0.587757         0.725171
# 4     05                   0.017519  0.525333         0.683555
# 5     06                   0.018365 -0.464920         0.023387
# 6     07                   0.017486  0.438400         0.625600
# 7     08                   0.014811  0.186629         0.457753
# 8     09                   0.007005  0.980589         0.987059
# 9     10                   0.016483  1.387098         1.258065
# 10    11                   0.012088  0.650705         0.767137
# 11    12                   0.023452  0.596754         0.731169
#
#     Residual Variance 1  Portfolio Excess Return 2    Beta 2  Adjusted Beta 2  \
# ...

# %%
# Assuming your DataFrame is named df
new_df = merged_df[['Portfolio Excess Return 1', 'Adjusted Beta 1','Beta 1','Residual Variance 1']].copy()  # Selecting columns for Portfolio 1
new_df.columns = ['Portfolio Excess Return', 'Adjusted Beta','Beta','Residual Variance']  # Renaming columns

# Concatenating data for other portfolios
for i in range(2, 5):
    temp_df = merged_df[['Portfolio Excess Return {}'.format(i), 'Adjusted Beta {}'.format(i), 'Beta {}'.format(i), 'Residual Variance {}'.format(i) ]].copy()
    temp_df.columns = ['Portfolio Excess Return', 'Adjusted Beta','Beta', 'Residual Variance']
    new_df = pd.concat([new_df, temp_df], ignore_index=True)

new_df
# Out:
#     Portfolio Excess Return  Adjusted Beta      Beta  Residual Variance
# 0                  0.007252       0.546070  0.319105       5.814567e-09
# 1                  0.004835       0.947577  0.921365       3.373165e-08
# 2                  0.024368       1.101308  1.151962       3.345839e-08
# 3                  0.015193       0.725171  0.587757       4.007671e-08
# 4                  0.017519       0.683555  0.525333       1.896232e-07
# 5                  0.018365       0.023387 -0.464920       7.889879e-09
# 6                  0.017486       0.625600  0.438400       1.280131e-09
# 7                  0.014811       0.457753  0.186629       6.870896e-08
# 8                  0.007005       0.987059  0.980589       1.637440e-09
# 9                  0.016483       1.258065  1.387098       2.396230e-07
# 10                 0.012088       0.767137  0.650705       1.223715e-09
# 11                 0.023452       0.731169  0.596754       1.442562e-08
# ...

# %%
# Normalize residual variance
residual_variance_mean = new_df['Residual Variance'].mean()
residual_variance_std = new_df['Residual Variance'].std()
normalized_residual_variance = (new_df['Residual Variance'] - residual_variance_mean) / residual_variance_std

# Replace the original column with the normalized values
new_df['Normalized Residual Variance'] = normalized_residual_variance

# %%
merged_df.columns
# Out:
# Index(['Month', 'Portfolio Excess Return 1', 'Beta 1', 'Adjusted Beta 1',
#        'Residual Variance 1', 'Portfolio Excess Return 2', 'Beta 2',
#        'Adjusted Beta 2', 'Residual Variance 2', 'Portfolio Excess Return 3',
#        'Beta 3', 'Adjusted Beta 3', 'Residual Variance 3',
#        'Portfolio Excess Return 4', 'Beta 4', 'Adjusted Beta 4',
#        'Residual Variance 4'],
#       dtype='object')

# %% [markdown]
# # SML #

# %%
import statsmodels.api as sm
import pandas as pd

x = new_df['Adjusted Beta'].values # Monthly  est. Adj Beta 2021

y = new_df['Portfolio Excess Return'].values # Monthly Portfolio excess return
    
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
inter = results.params[0]
risk_premium = results.params[1]  # Coefficient
p_value_1 = results.pvalues[1]  # P-value
p_value_2 = results.pvalues[0]
std_error_1 = results.bse[1]  # Standard error
std_error_2 = results.bse[0]
t_stat_x1 = results.tvalues[1]
t_stat_const = results.tvalues[0]

# Print the retrieved values
print("Intercept:", inter)
print("Risk premium (Coefficient):", risk_premium)
print("P-value x1:", p_value_1)
print("P-value const:", p_value_2)
print("Std. error x1:", std_error_1)
print("Std. error const :", std_error_2)
print("T-statistic for X1:", t_stat_x1)
print("T-statistic for const:", t_stat_const)
# Out:
# (48, 2)
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.000
# Model:                            OLS   Adj. R-squared:                 -0.022
# Method:                 Least Squares   F-statistic:                  0.002586
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.960
# Time:                        10:53:43   Log-Likelihood:                 158.08
# No. Observations:                  48   AIC:                            -312.2
# Df Residuals:                      46   BIC:                            -308.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0161      0.004      4.204      0.000       0.008       0.024
# ...

# %% [markdown]
# # NON-Linearity #

# %%
import statsmodels.api as sm
import pandas as pd

# Assuming new_df contains the required data

# Calculate adjusted beta squared
raw_beta_sqr = new_df['Beta'].values ** 2
adjusted_beta_sqr = 0.67 * raw_beta_sqr + 0.33 * 1.0

# Prepare the data
x = new_df['Adjusted Beta'].values
x_squared = adjusted_beta_sqr
y = new_df['Portfolio Excess Return'].values

# Prepare the independent variables matrix
X = sm.add_constant(pd.DataFrame({'Adjusted Beta': x, 'Adjusted Beta Squared': x_squared}))

# Fit the nonlinear OLS model
model = sm.OLS(y, X)
results = model.fit()

# Print the summary of results
print(results.summary())

# Retrieve specific values from the model summary
intercept = results.params[0]
gamma1 = results.params[1]  # Coefficient for adjusted beta
gamma2 = results.params[2]  # Coefficient for adjusted beta squared
p_value_int = results.pvalues[0]
p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
std_error_int = results.bse[0] 
std_error_gamma1 = results.bse[1]  # Standard error for gamma1
std_error_gamma2 = results.bse[2]  # Standard error for gamma2
t_stat_int = results.tvalues[0]
t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2

# Print the retrieved values
print("Intercept:", intercept)
print("Coefficient for adjusted beta (γ1):", gamma1)
print("Coefficient for adjusted beta squared (γ2):", gamma2)
print("Std. error for intercept:", std_error_int)
print("Std. error for γ1:", std_error_gamma1)
print("Std. error for γ2:", std_error_gamma2)
print("T-statistic for intercept:", t_stat_int)
print("T-statistic for γ1:", t_stat_gamma1)
print("T-statistic for γ2:", t_stat_gamma2)
print("P-value for intercept:", p_value_int)
print("P-value for γ1:", p_value_gamma1)
print("P-value for γ2:", p_value_gamma2)
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.043
# Method:                 Least Squares   F-statistic:                   0.03750
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.963
# Time:                        10:53:43   Log-Likelihood:                 158.12
# No. Observations:                  48   AIC:                            -310.2
# Df Residuals:                      45   BIC:                            -304.6
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0155      0.005      3.444      0.001       0.006       0.025
# ...

# %% [markdown]
# # Non-systematic risk

# %%
import statsmodels.api as sm
import pandas as pd

# Assuming new_df contains the required data

# Calculate adjusted beta squared
raw_beta_sqr = new_df['Beta'].values ** 2
adjusted_beta_sqr = 0.67 * raw_beta_sqr + 0.33 * 1.0

# Prepare the data
x = new_df['Adjusted Beta'].values
x_squared = adjusted_beta_sqr
residual_variance = new_df['Normalized Residual Variance'].values
y = new_df['Portfolio Excess Return'].values

# Prepare the independent variables matrix
X = sm.add_constant(pd.DataFrame({'Adjusted Beta': x, 'Adjusted Beta Squared': x_squared, 'Residual Variance': residual_variance}))

# Fit the nonlinear OLS model
model = sm.OLS(y, X)
results = model.fit()

# Print the summary of results
print(results.summary())

# Retrieve specific values from the model summary
intercept = results.params[0]
gamma1 = results.params[1]  # Coefficient for adjusted beta
gamma2 = results.params[2]  # Coefficient for adjusted beta squared
gamma3 = results.params[3]  # Coefficient for residual variance
p_value_int = results.pvalues[0]
p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
p_value_gamma3 = results.pvalues[3]  # P-value for gamma3
std_error_int = results.bse[0] 
std_error_gamma1 = results.bse[1]  # Standard error for gamma1
std_error_gamma2 = results.bse[2]  # Standard error for gamma2
std_error_gamma3 = results.bse[3]  # Standard error for gamma3
t_stat_int = results.tvalues[0]
t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2
t_stat_gamma3 = results.tvalues[3]  # T-statistic for gamma3

# Function to round the values
def round_to_six_decimals(value):
    return round(value, 6)

# Print the retrieved values rounded to the sixth decimal point
print("Intercept:", round_to_six_decimals(intercept))
print("Coefficient for adjusted beta (γ1):", round_to_six_decimals(gamma1))
print("Coefficient for adjusted beta squared (γ2):", round_to_six_decimals(gamma2))
print("Coefficient for residual variance (γ3):", round_to_six_decimals(gamma3))
print("Std. error for intercept:", round_to_six_decimals(std_error_int))
print("Std. error for γ1:", round_to_six_decimals(std_error_gamma1))
print("Std. error for γ2:", round_to_six_decimals(std_error_gamma2))
print("Std. error for γ3:", round_to_six_decimals(std_error_gamma3))
print("T-statistic for intercept:", round_to_six_decimals(t_stat_int))
print("T-statistic for γ1:", round_to_six_decimals(t_stat_gamma1))
print("T-statistic for γ2:", round_to_six_decimals(t_stat_gamma2))
print("T-statistic for γ3:", round_to_six_decimals(t_stat_gamma3))
print("P-value for intercept:", round_to_six_decimals(p_value_int))
print("P-value for γ1:", round_to_six_decimals(p_value_gamma1))
print("P-value for γ2:", round_to_six_decimals(p_value_gamma2))
print("P-value for γ3:", round_to_six_decimals(p_value_gamma3))
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.065
# Method:                 Least Squares   F-statistic:                   0.03835
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.990
# Time:                        10:53:43   Log-Likelihood:                 158.14
# No. Observations:                  48   AIC:                            -308.3
# Df Residuals:                      44   BIC:                            -300.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                     0.0155      0.005      3.409      0.001       0.006       0.025
# ...
