# %%
import pandas as pd

returns_df = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Returns_2018-2023.csv')

# %%
returns_df.head()
# Out:
#    Unnamed: 0        Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 0           0  2018-01-12       0.029327      -0.044570            0.045761
# 1           1  2018-01-19       0.013632       0.040736            0.022956
# 2           2  2018-01-26       0.004538      -0.007576            0.013324
# 3           3  2018-02-02      -0.027427      -0.033079           -0.046367
# 4           4  2018-02-09      -0.044646      -0.072697           -0.066763
#
#    Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 0          0.032797              0.072444                    0.012517
# 1          0.131214             -0.021934                    0.067308
# 2         -0.006357              0.078472                    0.019305
# 3         -0.024787             -0.030991                   -0.015783
# 4         -0.023502              0.006656                   -0.042976
#
#    Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 0                                   0.032906                     0.040625
# 1                                  -0.031857                    -0.025826
# 2                                   0.011312                     0.029593
# 3                                  -0.073208                    -0.042515
# 4                                   0.036753                     0.003752
#
#    ...  Snam 2018-2023  Stellantis 2018-2023  Stmicroeletronics 2018-2023  \
# 0  ...       -0.017408              0.067525                     0.028307
# 1  ...        0.002461              0.021955                     0.023023
# 2  ...       -0.016200              0.012786                    -0.067025
# 3  ...       -0.044411             -0.050907                    -0.030414
# 4  ...       -0.069191             -0.073222                    -0.070308
#
#    Telecom 2018-2023  Tenaris 2018-2023  Terna 2018-2023  Unicredit 2018-2023  \
# 0           0.006770           0.043350        -0.023228             0.075077
# 1          -0.030262           0.002817         0.008200            -0.004007
# 2          -0.000693           0.021067        -0.002440             0.031609
# 3          -0.015406          -0.054333        -0.035671            -0.021170
# 4          -0.014942          -0.069818        -0.050518             0.010700
#
#    Unipol 2018-2023    BOT 3m  Risk Premium
# 0          0.052374 -0.008654      0.037980
# 1          0.011628 -0.008673      0.022305
# 2          0.031724 -0.009000      0.013538
# 3         -0.032308 -0.008923     -0.018504
# 4         -0.034769 -0.008865     -0.035781
#
# [5 rows x 43 columns]

# %%
returns_df.drop(columns='Unnamed: 0', inplace = True)

# %%
# Convert 'Date' column to datetime format
returns_df['Date'] = pd.to_datetime(returns_df['Date'])

# Extract year from 'Date' column
returns_df['Year'] = returns_df['Date'].dt.year

# Filter DataFrame to include only the data from 2018
returns_2019 = returns_df[returns_df['Year'] == 2019].copy()

# Drop the 'Year' column as it's no longer needed
returns_2019.drop(columns='Year', inplace=True)

# %%
returns_2019.columns = returns_2019.columns.str.replace('2018-2023', '2019')

# %%
import numpy as np

# Copy the 2019 data to avoid modifying the original DataFrame
returns_2019_excess = returns_2019.copy()

# Calculate excess returns for each stock by subtracting the risk-free rate
risk_free_rate = returns_2019_excess['BOT 3m'].values  # Convert Series to NumPy array
returns_2019_excess.iloc[:, 2:-2] -= risk_free_rate[:, np.newaxis]

# Display the first few rows of the new DataFrame
returns_2019_excess.head()
# Out:
#          Date  FTSEMIB Index  A2A 2019  Amplifon 2019  Azimut 2019  \
# 51 2019-01-04       0.027710  0.041865       0.029892     0.053023
# 52 2019-01-11       0.024337 -0.018595       0.099543     0.036227
# 53 2019-01-18       0.021668  0.001733       0.028654    -0.014358
# 54 2019-01-25       0.005199 -0.020566      -0.004053     0.088651
# 55 2019-02-01      -0.011799  0.006006      -0.017189     0.017106
#
#     BPER banca 2019  Banca Mediolanum 2019  \
# 51         0.010954               0.010875
# 52        -0.029299               0.036630
# 53        -0.061178               0.023479
# 54         0.035710              -0.000956
# 55        -0.055296              -0.014317
#
#     Banca Monte dei Paschi di Siena 2019  Banca pop Sondrio 2019  \
# 51                              0.019357                0.037656
# 52                             -0.002186               -0.022822
# 53                             -0.180912               -0.023430
# 54                              0.016431               -0.000054
# 55                             -0.023552               -0.097437
#
#     Banco Bpm 2019  ...  Snam 2019  Stellantis 2019  Stmicroeletronics 2019  \
# 51        0.053023  ...   0.061802         0.038889               -0.102542
# 52        0.036227  ...   0.021004         0.088295                0.129919
# 53       -0.014358  ...   0.012601         0.042411                0.051363
# 54        0.088651  ...  -0.006506        -0.001896                0.122423
# 55        0.017106  ...   0.000734         0.031811               -0.028925
#
#     Telecom 2019  Tenaris 2019  Terna 2019  Unicredit 2019  Unipol 2019  \
# 51      0.051950      0.049472    0.056465        0.036717     0.052451
# 52     -0.006268      0.049536    0.021685        0.042021     0.061663
# 53     -0.019613      0.038522    0.011730        0.011733     0.014568
# 54     -0.053522      0.040279    0.001242        0.035924     0.051883
# 55      0.055151     -0.004280   -0.011620       -0.104739    -0.027152
#
#       BOT 3m  Risk Premium
# 51 -0.004981      0.032691
# 52 -0.004404      0.028740
# 53 -0.004558      0.026225
# 54 -0.004615      0.009814
# 55 -0.003423     -0.008376
#
# [5 rows x 42 columns]

# %%
import statsmodels.api as sm

# Create an empty DataFrame to store the beta values
beta_df = pd.DataFrame(index=returns_2019.columns[1:-2], columns=['Beta'])

# Iterate over each asset
for asset in returns_2019_excess.columns[1:-2]:
    # Extract excess returns of the asset and the market portfolio
    x = returns_2019['FTSEMIB Index'] - returns_2019['BOT 3m']  # Market excess return
    y = returns_2019[asset] - returns_2019['BOT 3m']  # Asset excess return
    
    # Add a constant to the independent variable (market excess return)
    x = sm.add_constant(x)
    
    # Fit OLS model
    model = sm.OLS(y, x)
    results = model.fit()

    print(results.summary())
    
    # Extract the beta coefficient (slope)
    beta = results.params[0]  # Index 0 corresponds to the coefficient of the independent variable
    
    # Store the beta coefficient in the DataFrame
    beta_df.loc[asset, 'Beta'] = beta

# Display the DataFrame with beta values
beta_df
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       1.000
# Model:                            OLS   Adj. R-squared:                  1.000
# Method:                 Least Squares   F-statistic:                 2.010e+32
# Date:                Sat, 04 May 2024   Prob (F-statistic):               0.00
# Time:                        10:47:18   Log-Likelihood:                 1959.5
# No. Observations:                  52   AIC:                            -3915.
# Df Residuals:                      50   BIC:                            -3911.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       6.505e-19   1.66e-18      0.393      0.696   -2.68e-18    3.98e-18
# 0              1.0000   7.05e-17   1.42e+16      0.000       1.000       1.000
# ==============================================================================
# Omnibus:                        0.854   Durbin-Watson:                   1.379
# Prob(Omnibus):                  0.652   Jarque-Bera (JB):                0.879
# Skew:                           0.283   Prob(JB):                        0.645
# Kurtosis:                       2.710   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.205
# Model:                            OLS   Adj. R-squared:                  0.189
# Method:                 Least Squares   F-statistic:                     12.87
# Date:                Sat, 04 May 2024   Prob (F-statistic):           0.000759
# Time:                        10:47:18   Log-Likelihood:                 121.06
# No. Observations:                  52   AIC:                            -238.1
# Df Residuals:                      50   BIC:                            -234.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0012      0.004      0.311      0.757      -0.006       0.009
# 0              0.5726      0.160      3.587      0.001       0.252       0.893
# ==============================================================================
# Omnibus:                        3.401   Durbin-Watson:                   2.071
# Prob(Omnibus):                  0.183   Jarque-Bera (JB):                2.578
# Skew:                           0.295   Prob(JB):                        0.276
# Kurtosis:                       3.917   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.3697
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.546
# Time:                        10:47:18   Log-Likelihood:                 100.97
# No. Observations:                  52   AIC:                            -197.9
# Df Residuals:                      50   BIC:                            -194.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0163      0.006      2.955      0.005       0.005       0.027
# 0              0.1428      0.235      0.608      0.546      -0.329       0.615
# ==============================================================================
# Omnibus:                        0.748   Durbin-Watson:                   2.199
# Prob(Omnibus):                  0.688   Jarque-Bera (JB):                0.583
# Skew:                           0.255   Prob(JB):                        0.747
# Kurtosis:                       2.908   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.323
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     23.81
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.12e-05
# Time:                        10:47:18   Log-Likelihood:                 101.75
# No. Observations:                  52   AIC:                            -199.5
# Df Residuals:                      50   BIC:                            -195.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0101      0.005      1.857      0.069      -0.001       0.021
# 0              1.1292      0.231      4.880      0.000       0.664       1.594
# ==============================================================================
# Omnibus:                        5.714   Durbin-Watson:                   1.651
# Prob(Omnibus):                  0.057   Jarque-Bera (JB):                4.713
# Skew:                           0.575   Prob(JB):                       0.0948
# Kurtosis:                       3.923   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.322
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     23.74
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.15e-05
# Time:                        10:47:18   Log-Likelihood:                 96.473
# No. Observations:                  52   AIC:                            -188.9
# Df Residuals:                      50   BIC:                            -185.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0014      0.006     -0.235      0.815      -0.013       0.011
# 0              1.2478      0.256      4.872      0.000       0.733       1.762
# ==============================================================================
# Omnibus:                        4.953   Durbin-Watson:                   1.879
# Prob(Omnibus):                  0.084   Jarque-Bera (JB):                4.307
# Skew:                           0.422   Prob(JB):                        0.116
# Kurtosis:                       4.130   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.369
# Model:                            OLS   Adj. R-squared:                  0.357
# Method:                 Least Squares   F-statistic:                     29.30
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.76e-06
# Time:                        10:47:18   Log-Likelihood:                 123.53
# No. Observations:                  52   AIC:                            -243.1
# Df Residuals:                      50   BIC:                            -239.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0079      0.004      2.220      0.031       0.001       0.015
# 0              0.8240      0.152      5.413      0.000       0.518       1.130
# ==============================================================================
# Omnibus:                        5.693   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.058   Jarque-Bera (JB):                4.600
# Skew:                           0.613   Prob(JB):                        0.100
# Kurtosis:                       3.786   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.221
# Model:                            OLS   Adj. R-squared:                  0.206
# Method:                 Least Squares   F-statistic:                     14.23
# Date:                Sat, 04 May 2024   Prob (F-statistic):           0.000430
# Time:                        10:47:18   Log-Likelihood:                 60.674
# No. Observations:                  52   AIC:                            -117.3
# Df Residuals:                      50   BIC:                            -113.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0133      0.012     -1.110      0.272      -0.037       0.011
# 0              1.9230      0.510      3.772      0.000       0.899       2.947
# ==============================================================================
# Omnibus:                       50.555   Durbin-Watson:                   1.757
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              381.942
# Skew:                           2.282   Prob(JB):                     1.15e-83
# Kurtosis:                      15.468   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.151
# Model:                            OLS   Adj. R-squared:                  0.134
# Method:                 Least Squares   F-statistic:                     8.909
# Date:                Sat, 04 May 2024   Prob (F-statistic):            0.00438
# Time:                        10:47:18   Log-Likelihood:                 90.577
# No. Observations:                  52   AIC:                            -177.2
# Df Residuals:                      50   BIC:                            -173.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0068      0.007     -1.006      0.319      -0.020       0.007
# 0              0.8563      0.287      2.985      0.004       0.280       1.432
# ==============================================================================
# Omnibus:                        6.351   Durbin-Watson:                   2.382
# Prob(Omnibus):                  0.042   Jarque-Bera (JB):                5.314
# Skew:                           0.651   Prob(JB):                       0.0702
# Kurtosis:                       3.872   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.323
# Model:                            OLS   Adj. R-squared:                  0.309
# Method:                 Least Squares   F-statistic:                     23.81
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.12e-05
# Time:                        10:47:18   Log-Likelihood:                 101.75
# No. Observations:                  52   AIC:                            -199.5
# Df Residuals:                      50   BIC:                            -195.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0101      0.005      1.857      0.069      -0.001       0.021
# 0              1.1292      0.231      4.880      0.000       0.664       1.594
# ==============================================================================
# Omnibus:                        5.714   Durbin-Watson:                   1.651
# Prob(Omnibus):                  0.057   Jarque-Bera (JB):                4.713
# Skew:                           0.575   Prob(JB):                       0.0948
# Kurtosis:                       3.923   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.032
# Model:                            OLS   Adj. R-squared:                  0.012
# Method:                 Least Squares   F-statistic:                     1.641
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.206
# Time:                        10:47:18   Log-Likelihood:                 94.892
# No. Observations:                  52   AIC:                            -185.8
# Df Residuals:                      50   BIC:                            -181.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.006      0.665      0.509      -0.008       0.017
# 0              0.3383      0.264      1.281      0.206      -0.192       0.869
# ==============================================================================
# Omnibus:                        6.376   Durbin-Watson:                   2.223
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                7.817
# Skew:                           0.345   Prob(JB):                       0.0201
# Kurtosis:                       4.770   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.237
# Model:                            OLS   Adj. R-squared:                  0.221
# Method:                 Least Squares   F-statistic:                     15.51
# Date:                Sat, 04 May 2024   Prob (F-statistic):           0.000255
# Time:                        10:47:18   Log-Likelihood:                 123.48
# No. Observations:                  52   AIC:                            -243.0
# Df Residuals:                      50   BIC:                            -239.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.004      0.434      0.666      -0.006       0.009
# 0              0.6001      0.152      3.938      0.000       0.294       0.906
# ==============================================================================
# Omnibus:                        1.583   Durbin-Watson:                   2.265
# Prob(Omnibus):                  0.453   Jarque-Bera (JB):                0.813
# Skew:                           0.218   Prob(JB):                        0.666
# Kurtosis:                       3.431   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.2114
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.648
# Time:                        10:47:18   Log-Likelihood:                 102.79
# No. Observations:                  52   AIC:                            -201.6
# Df Residuals:                      50   BIC:                            -197.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0145      0.005      2.721      0.009       0.004       0.025
# 0              0.1043      0.227      0.460      0.648      -0.351       0.560
# ==============================================================================
# Omnibus:                        1.658   Durbin-Watson:                   1.918
# Prob(Omnibus):                  0.437   Jarque-Bera (JB):                0.860
# Skew:                           0.187   Prob(JB):                        0.651
# Kurtosis:                       3.506   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.262
# Model:                            OLS   Adj. R-squared:                  0.247
# Method:                 Least Squares   F-statistic:                     17.72
# Date:                Sat, 04 May 2024   Prob (F-statistic):           0.000107
# Time:                        10:47:18   Log-Likelihood:                 133.83
# No. Observations:                  52   AIC:                            -263.7
# Df Residuals:                      50   BIC:                            -259.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0068      0.003      2.311      0.025       0.001       0.013
# 0              0.5256      0.125      4.209      0.000       0.275       0.776
# ==============================================================================
# Omnibus:                        3.751   Durbin-Watson:                   2.519
# Prob(Omnibus):                  0.153   Jarque-Bera (JB):                3.578
# Skew:                           0.593   Prob(JB):                        0.167
# Kurtosis:                       2.505   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.604
# Model:                            OLS   Adj. R-squared:                  0.596
# Method:                 Least Squares   F-statistic:                     76.27
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.25e-11
# Time:                        10:47:18   Log-Likelihood:                 139.33
# No. Observations:                  52   AIC:                            -274.7
# Df Residuals:                      50   BIC:                            -270.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0043      0.003     -1.640      0.107      -0.010       0.001
# 0              0.9811      0.112      8.733      0.000       0.755       1.207
# ==============================================================================
# Omnibus:                        0.282   Durbin-Watson:                   2.717
# Prob(Omnibus):                  0.868   Jarque-Bera (JB):                0.020
# Skew:                          -0.037   Prob(JB):                        0.990
# Kurtosis:                       3.062   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.097
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     5.388
# Date:                Sat, 04 May 2024   Prob (F-statistic):             0.0244
# Time:                        10:47:18   Log-Likelihood:                 114.03
# No. Observations:                  52   AIC:                            -224.1
# Df Residuals:                      50   BIC:                            -220.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0046      0.004      1.066      0.292      -0.004       0.013
# 0              0.4241      0.183      2.321      0.024       0.057       0.791
# ==============================================================================
# Omnibus:                        3.969   Durbin-Watson:                   2.570
# Prob(Omnibus):                  0.137   Jarque-Bera (JB):                3.254
# Skew:                           0.608   Prob(JB):                        0.197
# Kurtosis:                       3.150   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.161
# Model:                            OLS   Adj. R-squared:                  0.144
# Method:                 Least Squares   F-statistic:                     9.565
# Date:                Sat, 04 May 2024   Prob (F-statistic):            0.00324
# Time:                        10:47:18   Log-Likelihood:                 112.82
# No. Observations:                  52   AIC:                            -221.6
# Df Residuals:                      50   BIC:                            -217.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0106      0.004      2.408      0.020       0.002       0.019
# 0              0.5784      0.187      3.093      0.003       0.203       0.954
# ==============================================================================
# Omnibus:                       35.721   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              151.187
# Skew:                           1.652   Prob(JB):                     1.48e-33
# Kurtosis:                      10.672   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.467
# Model:                            OLS   Adj. R-squared:                  0.456
# Method:                 Least Squares   F-statistic:                     43.81
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.37e-08
# Time:                        10:47:18   Log-Likelihood:                 108.12
# No. Observations:                  52   AIC:                            -212.2
# Df Residuals:                      50   BIC:                            -208.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0042      0.005     -0.877      0.385      -0.014       0.005
# 0              1.3550      0.205      6.619      0.000       0.944       1.766
# ==============================================================================
# Omnibus:                        0.355   Durbin-Watson:                   2.019
# Prob(Omnibus):                  0.837   Jarque-Bera (JB):                0.515
# Skew:                          -0.153   Prob(JB):                        0.773
# Kurtosis:                       2.621   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.729
# Model:                            OLS   Adj. R-squared:                  0.724
# Method:                 Least Squares   F-statistic:                     134.8
# Date:                Sat, 04 May 2024   Prob (F-statistic):           8.41e-16
# Time:                        10:47:18   Log-Likelihood:                 163.38
# No. Observations:                  52   AIC:                            -322.8
# Df Residuals:                      50   BIC:                            -318.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.002      0.938      0.353      -0.002       0.005
# 0              0.8211      0.071     11.609      0.000       0.679       0.963
# ==============================================================================
# Omnibus:                        2.793   Durbin-Watson:                   1.690
# Prob(Omnibus):                  0.247   Jarque-Bera (JB):                1.816
# Skew:                           0.233   Prob(JB):                        0.403
# Kurtosis:                       2.211   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.063
# Method:                 Least Squares   F-statistic:                     4.447
# Date:                Sat, 04 May 2024   Prob (F-statistic):             0.0400
# Time:                        10:47:18   Log-Likelihood:                 119.68
# No. Observations:                  52   AIC:                            -235.4
# Df Residuals:                      50   BIC:                            -231.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0098      0.004      2.551      0.014       0.002       0.018
# 0              0.3457      0.164      2.109      0.040       0.016       0.675
# ==============================================================================
# Omnibus:                        3.842   Durbin-Watson:                   2.580
# Prob(Omnibus):                  0.146   Jarque-Bera (JB):                2.794
# Skew:                           0.442   Prob(JB):                        0.247
# Kurtosis:                       3.712   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.301
# Model:                            OLS   Adj. R-squared:                  0.287
# Method:                 Least Squares   F-statistic:                     21.53
# Date:                Sat, 04 May 2024   Prob (F-statistic):           2.55e-05
# Time:                        10:47:18   Log-Likelihood:                 105.84
# No. Observations:                  52   AIC:                            -207.7
# Df Residuals:                      50   BIC:                            -203.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0028      0.005     -0.564      0.575      -0.013       0.007
# 0              0.9924      0.214      4.640      0.000       0.563       1.422
# ==============================================================================
# Omnibus:                       10.423   Durbin-Watson:                   1.930
# Prob(Omnibus):                  0.005   Jarque-Bera (JB):               14.657
# Skew:                          -0.627   Prob(JB):                     0.000657
# Kurtosis:                       5.279   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.679
# Model:                            OLS   Adj. R-squared:                  0.673
# Method:                 Least Squares   F-statistic:                     106.0
# Date:                Sat, 04 May 2024   Prob (F-statistic):           6.03e-14
# Time:                        10:47:18   Log-Likelihood:                 133.43
# No. Observations:                  52   AIC:                            -262.9
# Df Residuals:                      50   BIC:                            -258.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0041      0.003     -1.387      0.171      -0.010       0.002
# 0              1.2953      0.126     10.293      0.000       1.043       1.548
# ==============================================================================
# Omnibus:                       11.119   Durbin-Watson:                   2.012
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               16.427
# Skew:                          -0.652   Prob(JB):                     0.000271
# Kurtosis:                       5.426   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.016
# Method:                 Least Squares   F-statistic:                    0.1822
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.671
# Time:                        10:47:18   Log-Likelihood:                 106.32
# No. Observations:                  52   AIC:                            -208.6
# Df Residuals:                      50   BIC:                            -204.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0125      0.005      2.516      0.015       0.003       0.023
# 0              0.0905      0.212      0.427      0.671      -0.335       0.516
# ==============================================================================
# Omnibus:                       16.052   Durbin-Watson:                   2.156
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               31.975
# Skew:                           0.832   Prob(JB):                     1.14e-07
# Kurtosis:                       6.463   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.234
# Model:                            OLS   Adj. R-squared:                  0.219
# Method:                 Least Squares   F-statistic:                     15.29
# Date:                Sat, 04 May 2024   Prob (F-statistic):           0.000279
# Time:                        10:47:18   Log-Likelihood:                 133.00
# No. Observations:                  52   AIC:                            -262.0
# Df Residuals:                      50   BIC:                            -258.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.003      0.905      0.370      -0.003       0.009
# 0              0.4961      0.127      3.910      0.000       0.241       0.751
# ==============================================================================
# Omnibus:                        0.044   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.978   Jarque-Bera (JB):                0.189
# Skew:                          -0.058   Prob(JB):                        0.910
# Kurtosis:                       2.728   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.378
# Model:                            OLS   Adj. R-squared:                  0.366
# Method:                 Least Squares   F-statistic:                     30.43
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.22e-06
# Time:                        10:47:18   Log-Likelihood:                 103.70
# No. Observations:                  52   AIC:                            -203.4
# Df Residuals:                      50   BIC:                            -199.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.005     -0.140      0.889      -0.011       0.010
# 0              1.2296      0.223      5.517      0.000       0.782       1.677
# ==============================================================================
# Omnibus:                       26.422   Durbin-Watson:                   2.158
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               56.221
# Skew:                           1.472   Prob(JB):                     6.19e-13
# Kurtosis:                       7.157   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.499
# Model:                            OLS   Adj. R-squared:                  0.489
# Method:                 Least Squares   F-statistic:                     49.84
# Date:                Sat, 04 May 2024   Prob (F-statistic):           4.84e-09
# Time:                        10:47:18   Log-Likelihood:                 126.29
# No. Observations:                  52   AIC:                            -248.6
# Df Residuals:                      50   BIC:                            -244.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0007      0.003      0.207      0.837      -0.006       0.008
# 0              1.0192      0.144      7.060      0.000       0.729       1.309
# ==============================================================================
# Omnibus:                        5.391   Durbin-Watson:                   2.205
# Prob(Omnibus):                  0.067   Jarque-Bera (JB):                6.781
# Skew:                          -0.185   Prob(JB):                       0.0337
# Kurtosis:                       4.730   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.193
# Model:                            OLS   Adj. R-squared:                  0.177
# Method:                 Least Squares   F-statistic:                     11.97
# Date:                Sat, 04 May 2024   Prob (F-statistic):            0.00112
# Time:                        10:47:18   Log-Likelihood:                 96.114
# No. Observations:                  52   AIC:                            -188.2
# Df Residuals:                      50   BIC:                            -184.3
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0034      0.006      0.557      0.580      -0.009       0.016
# 0              0.8922      0.258      3.460      0.001       0.374       1.410
# ==============================================================================
# Omnibus:                        5.249   Durbin-Watson:                   2.583
# Prob(Omnibus):                  0.072   Jarque-Bera (JB):                4.134
# Skew:                           0.598   Prob(JB):                        0.127
# Kurtosis:                       3.691   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# ...
# Df Residuals:                      50   BIC:                            -234.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0041      0.004      1.099      0.277      -0.003       0.012
# 0              0.5339      0.159      3.361      0.001       0.215       0.853
# ==============================================================================
# Omnibus:                        8.575   Durbin-Watson:                   2.243
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):               11.148
# Skew:                          -0.522   Prob(JB):                      0.00379
# Kurtosis:                       5.014   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.410
# Model:                            OLS   Adj. R-squared:                  0.398
# Method:                 Least Squares   F-statistic:                     34.76
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.18e-07
# Time:                        10:47:18   Log-Likelihood:                 94.517
# No. Observations:                  52   AIC:                            -185.0
# Df Residuals:                      50   BIC:                            -181.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0089      0.006     -1.423      0.161      -0.021       0.004
# 0              1.5679      0.266      5.896      0.000       1.034       2.102
# ==============================================================================
# Omnibus:                       19.435   Durbin-Watson:                   2.334
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               63.748
# Skew:                           0.783   Prob(JB):                     1.44e-14
# Kurtosis:                       8.193   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.273
# Model:                            OLS   Adj. R-squared:                  0.259
# Method:                 Least Squares   F-statistic:                     18.81
# Date:                Sat, 04 May 2024   Prob (F-statistic):           6.99e-05
# Time:                        10:47:18   Log-Likelihood:                 83.740
# No. Observations:                  52   AIC:                            -163.5
# Df Residuals:                      50   BIC:                            -159.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0052      0.008      0.677      0.501      -0.010       0.021
# 0              1.4191      0.327      4.337      0.000       0.762       2.076
# ==============================================================================
# Omnibus:                        6.375   Durbin-Watson:                   2.386
# Prob(Omnibus):                  0.041   Jarque-Bera (JB):                9.535
# Skew:                          -0.172   Prob(JB):                      0.00850
# Kurtosis:                       5.070   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.334
# Model:                            OLS   Adj. R-squared:                  0.320
# Method:                 Least Squares   F-statistic:                     25.02
# Date:                Sat, 04 May 2024   Prob (F-statistic):           7.37e-06
# Time:                        10:47:18   Log-Likelihood:                 102.81
# No. Observations:                  52   AIC:                            -201.6
# Df Residuals:                      50   BIC:                            -197.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0029      0.005     -0.549      0.586      -0.014       0.008
# 0              1.1342      0.227      5.002      0.000       0.679       1.590
# ==============================================================================
# Omnibus:                        2.293   Durbin-Watson:                   2.228
# Prob(Omnibus):                  0.318   Jarque-Bera (JB):                1.966
# Skew:                           0.474   Prob(JB):                        0.374
# Kurtosis:                       2.898   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.541
# Method:                 Least Squares   F-statistic:                     61.06
# Date:                Sat, 04 May 2024   Prob (F-statistic):           3.23e-10
# Time:                        10:47:18   Log-Likelihood:                 111.64
# No. Observations:                  52   AIC:                            -219.3
# Df Residuals:                      50   BIC:                            -215.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0083      0.004     -1.859      0.069      -0.017       0.001
# 0              1.4951      0.191      7.814      0.000       1.111       1.879
# ==============================================================================
# Omnibus:                        1.580   Durbin-Watson:                   2.301
# Prob(Omnibus):                  0.454   Jarque-Bera (JB):                1.125
# Skew:                          -0.019   Prob(JB):                        0.570
# Kurtosis:                       2.280   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.189
# Model:                            OLS   Adj. R-squared:                  0.173
# Method:                 Least Squares   F-statistic:                     11.65
# Date:                Sat, 04 May 2024   Prob (F-statistic):            0.00128
# Time:                        10:47:18   Log-Likelihood:                 121.46
# No. Observations:                  52   AIC:                            -238.9
# Df Residuals:                      50   BIC:                            -235.0
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0037      0.004      1.002      0.321      -0.004       0.011
# 0              0.5407      0.158      3.413      0.001       0.222       0.859
# ==============================================================================
# Omnibus:                        1.163   Durbin-Watson:                   2.470
# Prob(Omnibus):                  0.559   Jarque-Bera (JB):                0.494
# Skew:                          -0.157   Prob(JB):                        0.781
# Kurtosis:                       3.360   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.581
# Model:                            OLS   Adj. R-squared:                  0.572
# Method:                 Least Squares   F-statistic:                     69.21
# Date:                Sat, 04 May 2024   Prob (F-statistic):           5.36e-11
# Time:                        10:47:18   Log-Likelihood:                 106.80
# No. Observations:                  52   AIC:                            -209.6
# Df Residuals:                      50   BIC:                            -205.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0066      0.005     -1.343      0.185      -0.017       0.003
# 0              1.7470      0.210      8.319      0.000       1.325       2.169
# ==============================================================================
# Omnibus:                        1.204   Durbin-Watson:                   2.577
# Prob(Omnibus):                  0.548   Jarque-Bera (JB):                0.639
# Skew:                          -0.251   Prob(JB):                        0.726
# Kurtosis:                       3.206   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.581
# Model:                            OLS   Adj. R-squared:                  0.573
# Method:                 Least Squares   F-statistic:                     69.45
# Date:                Sat, 04 May 2024   Prob (F-statistic):           5.09e-11
# Time:                        10:47:18   Log-Likelihood:                 129.65
# No. Observations:                  52   AIC:                            -255.3
# Df Residuals:                      50   BIC:                            -251.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.003      0.493      0.624      -0.005       0.008
# 0              1.1278      0.135      8.334      0.000       0.856       1.400
# ==============================================================================
# Omnibus:                        0.630   Durbin-Watson:                   2.128
# Prob(Omnibus):                  0.730   Jarque-Bera (JB):                0.727
# Skew:                          -0.233   Prob(JB):                        0.695
# Kurtosis:                       2.655   Cond. No.                         47.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#                                           Beta
# FTSEMIB Index                              1.0
# A2A 2019                              0.572608
# Amplifon 2019                         0.142832
# Azimut 2019                           1.129163
# BPER banca 2019                       1.247849
# Banca Mediolanum 2019                 0.824005
# Banca Monte dei Paschi di Siena 2019  1.922966
# Banca pop Sondrio 2019                0.856272
# Banco Bpm 2019                        1.129163
# Brunello cucinelli 2019               0.338281
# Campari 2019                          0.600058
# Diasorin 2019                         0.104282
# Enel 2019                             0.525617
# Eni 2019                              0.981083
# Erg 2019                              0.424123
# Ferrari 2019                          0.578417
# Fineco 2019                           1.354987
# Generali Ass 2019                      0.82114
# Hera 2019                             0.345686
# Interpump 2019                        0.992392
# Intesa San Paolo 2019                 1.295337
# Inwit 2019                            0.090477
# Italgas 2019                          0.496096
# Leonardo 2019                         1.229617
# Mediobanca 2019                       1.019197
# Moncler 2019                          0.892211
# Pirelli 2019                          1.725078
# Poste Italiane 2019                   0.928288
# Prysmian 2019                         1.284706
# Recordati 2019                        0.483568
# Saipem 2019                           1.665453
# Snam 2019                              0.53388
# Stellantis 2019                       1.567915
# Stmicroeletronics 2019                1.419131
# Telecom 2019                           1.13418
# Tenaris 2019                          1.495105
# Terna 2019                            0.540666
# Unicredit 2019                         1.74703
# Unipol 2019                           1.127788

# %%
beta_df.drop(index='FTSEMIB Index', inplace=True)

# %%
beta_df.head()
# Out:
#                            Beta
# A2A 2019               0.572608
# Amplifon 2019          0.142832
# Azimut 2019            1.129163
# BPER banca 2019        1.247849
# Banca Mediolanum 2019  0.824005

# %%
beta_df.sort_values(by="Beta")
# Out:
#                                           Beta
# Inwit 2019                            0.090477
# Diasorin 2019                         0.104282
# Amplifon 2019                         0.142832
# Brunello cucinelli 2019               0.338281
# Hera 2019                             0.345686
# Erg 2019                              0.424123
# Recordati 2019                        0.483568
# Italgas 2019                          0.496096
# Enel 2019                             0.525617
# Snam 2019                              0.53388
# Terna 2019                            0.540666
# A2A 2019                              0.572608
# Ferrari 2019                          0.578417
# Campari 2019                          0.600058
# Generali Ass 2019                      0.82114
# Banca Mediolanum 2019                 0.824005
# Banca pop Sondrio 2019                0.856272
# Moncler 2019                          0.892211
# Poste Italiane 2019                   0.928288
# Eni 2019                              0.981083
# Interpump 2019                        0.992392
# Mediobanca 2019                       1.019197
# Unipol 2019                           1.127788
# Azimut 2019                           1.129163
# Banco Bpm 2019                        1.129163
# Telecom 2019                           1.13418
# Leonardo 2019                         1.229617
# BPER banca 2019                       1.247849
# Prysmian 2019                         1.284706
# Intesa San Paolo 2019                 1.295337
# Fineco 2019                           1.354987
# Stmicroeletronics 2019                1.419131
# Tenaris 2019                          1.495105
# Stellantis 2019                       1.567915
# Saipem 2019                           1.665453
# Pirelli 2019                          1.725078
# Unicredit 2019                         1.74703
# Banca Monte dei Paschi di Siena 2019  1.922966

# %%
# Sort stocks based on beta values
sorted_df = beta_df.sort_values(by='Beta')

# Divide stocks into four portfolios
portfolio_1 = sorted_df.head(10)
portfolio_2 = sorted_df.iloc[10:19]
portfolio_3 = sorted_df.iloc[19:28]
portfolio_4 = sorted_df.tail(10)

# %%
print("Portfolio 1 (Lowest Beta):")
portfolio_1.to_csv("p1-2.csv")
portfolio_1
# Out:
# Portfolio 1 (Lowest Beta):
#                              Beta
# Inwit 2019               0.090477
# Diasorin 2019            0.104282
# Amplifon 2019            0.142832
# Brunello cucinelli 2019  0.338281
# Hera 2019                0.345686
# Erg 2019                 0.424123
# Recordati 2019           0.483568
# Italgas 2019             0.496096
# Enel 2019                0.525617
# Snam 2019                 0.53388

# %%
print("Portfolio 2:")
portfolio_2.to_csv("p2-2.csv")
portfolio_2
# Out:
# Portfolio 2:
#                             Beta
# Terna 2019              0.540666
# A2A 2019                0.572608
# Ferrari 2019            0.578417
# Campari 2019            0.600058
# Generali Ass 2019        0.82114
# Banca Mediolanum 2019   0.824005
# Banca pop Sondrio 2019  0.856272
# Moncler 2019            0.892211
# Poste Italiane 2019     0.928288

# %%
print("Portfolio 3:")
portfolio_3.to_csv("p3-2.csv")
portfolio_3
# Out:
# Portfolio 3:
#                      Beta
# Eni 2019         0.981083
# Interpump 2019   0.992392
# Mediobanca 2019  1.019197
# Unipol 2019      1.127788
# Azimut 2019      1.129163
# Banco Bpm 2019   1.129163
# Telecom 2019      1.13418
# Leonardo 2019    1.229617
# BPER banca 2019  1.247849

# %%
print("Portfolio 4 (Highest Beta):")
portfolio_4.to_csv("p4-2.csv")
portfolio_4
# Out:
# Portfolio 4 (Highest Beta):
#                                           Beta
# Prysmian 2019                         1.284706
# Intesa San Paolo 2019                 1.295337
# Fineco 2019                           1.354987
# Stmicroeletronics 2019                1.419131
# Tenaris 2019                          1.495105
# Stellantis 2019                       1.567915
# Saipem 2019                           1.665453
# Pirelli 2019                          1.725078
# Unicredit 2019                         1.74703
# Banca Monte dei Paschi di Siena 2019  1.922966

# %% [markdown]
# # ESTIMATION #

# %%
# Convert 'Date' column to datetime format
returns_df['Date'] = pd.to_datetime(returns_df['Date'])

# Extract year from 'Date' column
returns_df['Year'] = returns_df['Date'].dt.year

# Filter DataFrame to include only the data from 2020
returns_2020 = returns_df[returns_df['Year'] == 2020].copy()

# Drop the 'Year' column as it's no longer needed
returns_2020.drop(columns='Year', inplace=True)

# %%
returns_2020.head()
# Out:
#           Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 103 2020-01-03      -0.002326      -0.020318           -0.003101
# 104 2020-01-10       0.013461       0.034866            0.021773
# 105 2020-01-17       0.004982       0.035725            0.008371
# 106 2020-01-24      -0.007122       0.011778            0.009811
# 107 2020-01-31      -0.030543      -0.000831           -0.040359
#
#      Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 103          0.000943              0.030980                   -0.017907
# 104          0.114986              0.006113                    0.025641
# 105          0.000845             -0.004765                   -0.013889
# 106         -0.003378             -0.030010                   -0.032113
# 107         -0.059746             -0.069496                   -0.051222
#
#      Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 103                                   0.004322                    -0.014138
# 104                                   0.233857                     0.011472
# 105                                  -0.007556                    -0.000945
# 106                                   0.048621                    -0.041627
# 107                                  -0.053072                    -0.040474
#
#      Banco Bpm 2018-2023  ...  Snam 2018-2023  Stellantis 2018-2023  \
# 103             0.000943  ...       -0.007660             -0.026211
# 104             0.114986  ...        0.023585             -0.018960
# 105             0.000845  ...        0.038961             -0.031027
# 106            -0.003378  ...       -0.016532             -0.023320
# 107            -0.059746  ...       -0.008405             -0.033766
#
#      Stmicroeletronics 2018-2023  Telecom 2018-2023  Tenaris 2018-2023  \
# 103                     0.010686          -0.007828           0.014371
# 104                     0.004880          -0.059172           0.014656
# 105                     0.017807          -0.023633          -0.009148
# 106                     0.103380          -0.015616          -0.005345
# 107                    -0.089009          -0.034702          -0.088617
#
#      Terna 2018-2023  Unicredit 2018-2023  Unipol 2018-2023    BOT 3m  \
# 103        -0.016661             0.016009         -0.034364 -0.007712
# 104         0.025076             0.005402          0.000000 -0.007865
# 105         0.024463            -0.018657         -0.021550 -0.007635
# 106         0.020006            -0.053688         -0.021216 -0.007115
# 107        -0.004113            -0.029090         -0.049752 -0.007192
#
#      Risk Premium
# 103      0.005386
# 104      0.021326
# 105      0.012616
# 106     -0.000007
# 107     -0.023351
#
# [5 rows x 42 columns]

# %%
returns_2020.columns = returns_2020.columns.str.replace('2018-2023', '')

# %%
import numpy as np

# Copy the 2020 data to avoid modifying the original DataFrame
returns_2020_excess = returns_2020.copy()

# Calculate excess returns for each stock by subtracting the risk-free rate
risk_free_rate = returns_2020_excess['BOT 3m'].values  # Convert Series to NumPy array
returns_2020_excess.iloc[:, 2:-2] -= risk_free_rate[:, np.newaxis]

# Set 'Date' column as the index
returns_2020_excess.set_index('Date', inplace=True)

# Display the DataFrame with 'Date' as the index
returns_2020_excess.head()
# Out:
#             FTSEMIB Index      A2A   Amplifon    Azimut   BPER banca   \
# Date
# 2020-01-03      -0.002326 -0.012606   0.004611  0.008655     0.038692
# 2020-01-10       0.013461  0.042732   0.029638  0.122851     0.013978
# 2020-01-17       0.004982  0.043359   0.016006  0.008480     0.002870
# 2020-01-24      -0.007122  0.018893   0.016927  0.003737    -0.022895
# 2020-01-31      -0.030543  0.006361  -0.033166 -0.052553    -0.062303
#
#             Banca Mediolanum   Banca Monte dei Paschi di Siena   \
# Date
# 2020-01-03          -0.010196                          0.012034
# 2020-01-10           0.033506                          0.241722
# 2020-01-17          -0.006254                          0.000079
# 2020-01-24          -0.024997                          0.055737
# 2020-01-31          -0.044030                         -0.045880
#
#             Banca pop Sondrio   Banco Bpm   Brunello cucinelli   ...  \
# Date                                                             ...
# 2020-01-03           -0.006426    0.008655            -0.002763  ...
# 2020-01-10            0.019338    0.122851             0.100642  ...
# 2020-01-17            0.006689    0.008480             0.098233  ...
# 2020-01-24           -0.034512    0.003737            -0.045131  ...
# 2020-01-31           -0.033282   -0.052553            -0.088177  ...
#
#                Snam   Stellantis   Stmicroeletronics   Telecom   Tenaris   \
# Date
# 2020-01-03  0.000052    -0.018499            0.018398 -0.000116  0.022082
# 2020-01-10  0.031450    -0.011094            0.012745 -0.051306  0.022521
# 2020-01-17  0.046596    -0.023393            0.025441 -0.015998 -0.001513
# 2020-01-24 -0.009417    -0.016205            0.110495 -0.008500  0.001770
# 2020-01-31 -0.001213    -0.026574           -0.081817 -0.027509 -0.081425
#
#               Terna   Unicredit    Unipol     BOT 3m  Risk Premium
# Date
# 2020-01-03 -0.008950    0.023720 -0.026653 -0.007712      0.005386
# 2020-01-10  0.032942    0.013268  0.007865 -0.007865      0.021326
# 2020-01-17  0.032097   -0.011022 -0.013915 -0.007635      0.012616
# 2020-01-24  0.027122   -0.046573 -0.014101 -0.007115     -0.000007
# 2020-01-31  0.003080   -0.021898 -0.042560 -0.007192     -0.023351
#
# [5 rows x 41 columns]

# %%
portfolio_1
# Out:
#                              Beta
# Inwit 2019               0.090477
# Diasorin 2019            0.104282
# Amplifon 2019            0.142832
# Brunello cucinelli 2019  0.338281
# Hera 2019                0.345686
# Erg 2019                 0.424123
# Recordati 2019           0.483568
# Italgas 2019             0.496096
# Enel 2019                0.525617
# Snam 2019                 0.53388

# %%
# Remove '2019' from the stock names
portfolio_1.index = portfolio_1.index.str.replace(' 2019', '')

# Rename the index to 'Stock'
portfolio_1.index.name = 'Stock'

# Print the modified DataFrame
portfolio_1
# Out:
#                         Beta
# Stock
# Inwit               0.090477
# Diasorin            0.104282
# Amplifon            0.142832
# Brunello cucinelli  0.338281
# Hera                0.345686
# Erg                 0.424123
# Recordati           0.483568
# Italgas             0.496096
# Enel                0.525617
# Snam                 0.53388

# %%
# Remove '2019' from the stock names
portfolio_2.index = portfolio_2.index.str.replace(' 2019', '')

# Rename the index to 'Stock'
portfolio_2.index.name = 'Stock'

# %%
# Remove '2019' from the stock names
portfolio_3.index = portfolio_3.index.str.replace(' 2019', '')

# Rename the index to 'Stock'
portfolio_3.index.name = 'Stock'

# %%
# Remove '2019' from the stock names
portfolio_4.index = portfolio_4.index.str.replace(' 2019', '')

# Rename the index to 'Stock'
portfolio_4.index.name = 'Stock'

# %%
portfolio_1.index
# Out:
# Index(['Inwit', 'Diasorin', 'Amplifon', 'Brunello cucinelli', 'Hera', 'Erg',
#        'Recordati', 'Italgas', 'Enel', 'Snam'],
#       dtype='object', name='Stock')

# %%
returns_2020_excess.columns = returns_2020_excess.columns.str.strip()

# %%
returns_2020_excess.columns
# Out:
# Index(['FTSEMIB Index', 'A2A', 'Amplifon', 'Azimut', 'BPER banca',
#        'Banca Mediolanum', 'Banca Monte dei Paschi di Siena',
#        'Banca pop Sondrio', 'Banco Bpm', 'Brunello cucinelli', 'Campari',
#        'Diasorin', 'Enel', 'Eni', 'Erg', 'Ferrari', 'Fineco', 'Generali Ass',
#        'Hera', 'Interpump', 'Intesa San Paolo', 'Inwit', 'Italgas', 'Leonardo',
#        'Mediobanca', 'Moncler', 'Pirelli', 'Poste Italiane', 'Prysmian',
#        'Recordati', 'Saipem', 'Snam', 'Stellantis', 'Stmicroeletronics',
#        'Telecom', 'Tenaris', 'Terna', 'Unicredit', 'Unipol', 'BOT 3m',
#        'Risk Premium'],
#       dtype='object')

# %%
returns_2020_excess['Inwit']
# Out:
# Date
# 2020-01-03    0.000901
# 2020-01-10    0.010151
# 2020-01-17    0.073769
# 2020-01-24   -0.010532
# 2020-01-31    0.027878
# 2020-02-07    0.026508
# 2020-02-14    0.074850
# 2020-02-21    0.028953
# 2020-02-28   -0.105669
# 2020-03-06    0.087485
# 2020-03-13   -0.182442
# 2020-03-20    0.116682
# 2020-03-27    0.029707
# 2020-04-03    0.077531
# 2020-04-10   -0.078706
# 2020-04-17    0.179988
# 2020-04-24   -0.134176
# 2020-05-01    0.007306
# 2020-05-08   -0.019231
# 2020-05-15    0.024106
# 2020-05-22   -0.020730
# 2020-05-29   -0.019921
# 2020-06-05   -0.002520
# 2020-06-12   -0.012264
# 2020-06-19    0.022923
# 2020-06-26   -0.018310
# 2020-07-03    0.053913
# 2020-07-10   -0.001774
# 2020-07-17    0.019033
# 2020-07-24   -0.030284
# 2020-07-31   -0.038682
# 2020-08-07    0.005453
# 2020-08-14    0.003338
# 2020-08-21   -0.009744
# 2020-08-28   -0.003726
# 2020-09-04    0.002362
# 2020-09-11    0.099906
# 2020-09-18    0.063460
# 2020-09-25    0.005474
# 2020-10-02    0.017383
# 2020-10-09   -0.010399
# 2020-10-16   -0.001616
# 2020-10-23    0.003643
# 2020-10-30    0.026756
# 2020-11-06    0.114468
# 2020-11-13    0.001008
# 2020-11-20    0.043215
# 2020-11-27    0.033011
# 2020-12-04    0.001824
# 2020-12-11   -0.056075
# 2020-12-18    0.022219
# 2020-12-25    0.000379
# Name: Inwit, dtype: float64

# %%
p_1 = returns_2020_excess[portfolio_1.index]
p_1.head()
# Out:
#                Inwit  Diasorin  Amplifon  Brunello cucinelli      Hera  \
# Date
# 2020-01-03  0.000901  0.009436  0.004611           -0.002763 -0.020989
# 2020-01-10  0.010151  0.017332  0.029638            0.100642  0.018233
# 2020-01-17  0.073769  0.004225  0.016006            0.098233  0.033289
# 2020-01-24 -0.010532 -0.008282  0.016927           -0.045131  0.067145
# 2020-01-31  0.027878 -0.028429 -0.033166           -0.088177 -0.024898
#
#                  Erg  Recordati   Italgas      Enel      Snam
# Date
# 2020-01-03 -0.002534   0.011115 -0.005077  0.017938  0.000052
# 2020-01-10  0.030122   0.019345  0.037013  0.036433  0.031450
# 2020-01-17  0.067888   0.026206  0.016026  0.049161  0.046596
# 2020-01-24  0.030993   0.027374  0.013010  0.019284 -0.009417
# 2020-01-31  0.002528  -0.034009  0.040629  0.011796 -0.001213

# %%
p_2 = returns_2020_excess[portfolio_2.index]
p_2.head()
# Out:
#                Terna       A2A   Ferrari   Campari  Generali Ass  \
# Date
# 2020-01-03 -0.008950 -0.012606 -0.008736 -0.002573     -0.002235
# 2020-01-10  0.032942  0.042732  0.051344 -0.000081      0.014653
# 2020-01-17  0.032097  0.043359  0.014686  0.074178     -0.003153
# 2020-01-24  0.027122  0.018893  0.006479  0.014625     -0.003790
# 2020-01-31  0.003080  0.006361 -0.021470  0.008339     -0.022852
#
#             Banca Mediolanum  Banca pop Sondrio   Moncler  Poste Italiane
# Date
# 2020-01-03         -0.010196          -0.006426 -0.005579       -0.009858
# 2020-01-10          0.033506           0.019338  0.023331        0.022272
# 2020-01-17         -0.006254           0.006689  0.056517        0.014980
# 2020-01-24         -0.024997          -0.034512 -0.043236        0.036284
# 2020-01-31         -0.044030          -0.033282 -0.031032       -0.015009

# %%
p_3 = returns_2020_excess[portfolio_3.index]
p_3.head()
# Out:
#                  Eni  Interpump  Mediobanca    Unipol    Azimut  Banco Bpm  \
# Date
# 2020-01-03  0.015283   0.025417    0.009126 -0.026653  0.008655   0.008655
# 2020-01-10  0.007440  -0.002573    0.006252  0.007865  0.122851   0.122851
# 2020-01-17 -0.005415   0.023106   -0.007318 -0.013915  0.008480   0.008480
# 2020-01-24 -0.024934  -0.011583   -0.012167 -0.014101  0.003737   0.003737
# 2020-01-31 -0.053090  -0.094431   -0.050327 -0.042560 -0.052553  -0.052553
#
#              Telecom  Leonardo  BPER banca
# Date
# 2020-01-03 -0.000116  0.011983    0.038692
# 2020-01-10 -0.051306  0.080172    0.013978
# 2020-01-17 -0.015998 -0.012639    0.002870
# 2020-01-24 -0.008500  0.012513   -0.022895
# 2020-01-31 -0.027509  0.007640   -0.062303

# %%
p_4 = returns_2020_excess[portfolio_4.index]
p_4.head()
# Out:
#             Prysmian  Intesa San Paolo    Fineco  Stmicroeletronics   Tenaris  \
# Date
# 2020-01-03 -0.020130          0.005376  0.002141           0.018398  0.022082
# 2020-01-10  0.014908          0.011058  0.054084           0.012745  0.022521
# 2020-01-17  0.015094         -0.001063 -0.000844           0.025441 -0.001513
# 2020-01-24 -0.011857         -0.017922 -0.004136           0.110495  0.001770
# 2020-01-31 -0.045638         -0.007075 -0.030131          -0.081817 -0.081425
#
#             Stellantis    Saipem   Pirelli  Unicredit  \
# Date
# 2020-01-03   -0.018499  0.016387  0.009249   0.023720
# 2020-01-10   -0.011094  0.014654  0.025140   0.013268
# 2020-01-17   -0.023393 -0.002475 -0.035762  -0.011022
# 2020-01-24   -0.016205 -0.061913 -0.048309  -0.046573
# 2020-01-31   -0.026574 -0.078662 -0.079882  -0.021898
#
#             Banca Monte dei Paschi di Siena
# Date
# 2020-01-03                         0.012034
# 2020-01-10                         0.241722
# 2020-01-17                         0.000079
# 2020-01-24                         0.055737
# 2020-01-31                        -0.045880

# %%
returns_2020.head()
# Out:
#           Date  FTSEMIB Index      A2A   Amplifon    Azimut   BPER banca   \
# 103 2020-01-03      -0.002326 -0.020318  -0.003101  0.000943     0.030980
# 104 2020-01-10       0.013461  0.034866   0.021773  0.114986     0.006113
# 105 2020-01-17       0.004982  0.035725   0.008371  0.000845    -0.004765
# 106 2020-01-24      -0.007122  0.011778   0.009811 -0.003378    -0.030010
# 107 2020-01-31      -0.030543 -0.000831  -0.040359 -0.059746    -0.069496
#
#      Banca Mediolanum   Banca Monte dei Paschi di Siena   Banca pop Sondrio   \
# 103          -0.017907                          0.004322           -0.014138
# 104           0.025641                          0.233857            0.011472
# 105          -0.013889                         -0.007556           -0.000945
# 106          -0.032113                          0.048621           -0.041627
# 107          -0.051222                         -0.053072           -0.040474
#
#      Banco Bpm   ...     Snam   Stellantis   Stmicroeletronics   Telecom   \
# 103    0.000943  ... -0.007660    -0.026211            0.010686 -0.007828
# 104    0.114986  ...  0.023585    -0.018960            0.004880 -0.059172
# 105    0.000845  ...  0.038961    -0.031027            0.017807 -0.023633
# 106   -0.003378  ... -0.016532    -0.023320            0.103380 -0.015616
# 107   -0.059746  ... -0.008405    -0.033766           -0.089009 -0.034702
#
#      Tenaris     Terna   Unicredit    Unipol     BOT 3m  Risk Premium
# 103  0.014371 -0.016661    0.016009 -0.034364 -0.007712      0.005386
# 104  0.014656  0.025076    0.005402  0.000000 -0.007865      0.021326
# 105 -0.009148  0.024463   -0.018657 -0.021550 -0.007635      0.012616
# 106 -0.005345  0.020006   -0.053688 -0.021216 -0.007115     -0.000007
# 107 -0.088617 -0.004113   -0.029090 -0.049752 -0.007192     -0.023351
#
# [5 rows x 42 columns]

# %%
returns_2020 = returns_2020.set_index('Date')

# %% [markdown]
# # P1 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_1.index:
    # Extract market excess return for the date
    x = returns_2020.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_1.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2020-01-03              0.005386                 0.001269
# 2020-01-10              0.021326                 0.033036
# 2020-01-17              0.012616                 0.043140
# 2020-01-24             -0.000007                 0.010137
# 2020-01-31             -0.023351                -0.012706

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.014975120284184434
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.723
# Model:                                 OLS   Adj. R-squared:                  0.631
# Method:                      Least Squares   F-statistic:                     7.831
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0679
# Time:                             10:47:19   Log-Likelihood:                 15.557
# No. Observations:                        5   AIC:                            -27.11
# Df Residuals:                            3   BIC:                            -27.89
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0113      0.006      1.775      0.174      -0.009       0.032
# Market Excess Return     1.1546      0.413      2.798      0.068      -0.158       2.468
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.621
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.103
# Skew:                           0.141   Prob(JB):                        0.950
# Kurtosis:                       2.356   Cond. No.                         66.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.002128623623557705
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.971
# Model:                                 OLS   Adj. R-squared:                  0.957
# Method:                      Least Squares   F-statistic:                     67.70
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0145
# Time:                             10:47:19   Log-Likelihood:                 13.126
# No. Observations:                        4   AIC:                            -22.25
# Df Residuals:                            2   BIC:                            -23.48
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0018      0.006      0.278      0.807      -0.026       0.030
# Market Excess Return     0.8528      0.104      8.228      0.014       0.407       1.299
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.866
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.465
# Skew:                          -0.144   Prob(JB):                        0.793
# Kurtosis:                       1.355   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.02779447328188233
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.931
# Model:                                 OLS   Adj. R-squared:                  0.896
# Method:                      Least Squares   F-statistic:                     26.96
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0351
# Time:                             10:47:19   Log-Likelihood:                 9.6804
# No. Observations:                        4   AIC:                            -15.36
# Df Residuals:                            2   BIC:                            -16.59
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0124      0.017      0.727      0.543      -0.061       0.086
# Market Excess Return     0.7137      0.137      5.193      0.035       0.122       1.305
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.878
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.410
# Skew:                           0.434   Prob(JB):                        0.814
# Kurtosis:                       1.693   Cond. No.                         9.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.018414994136256566
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.006
# Model:                                 OLS   Adj. R-squared:                 -0.491
# Method:                      Least Squares   F-statistic:                   0.01189
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.923
# Time:                             10:47:19   Log-Likelihood:                 13.055
# No. Observations:                        4   AIC:                            -22.11
# Df Residuals:                            2   BIC:                            -23.34
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0184      0.007      2.814      0.107      -0.010       0.047
# Market Excess Return    -0.0167      0.153     -0.109      0.923      -0.674       0.641
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.063
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.431
# Skew:                          -0.665   Prob(JB):                        0.806
# Kurtosis:                       2.093   Cond. No.                         23.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.022008636549461842
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.389
# Model:                                 OLS   Adj. R-squared:                  0.185
# Method:                      Least Squares   F-statistic:                     1.906
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.261
# Time:                             10:47:19   Log-Likelihood:                 15.168
# No. Observations:                        5   AIC:                            -26.34
# Df Residuals:                            3   BIC:                            -27.12
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0167      0.008      2.151      0.121      -0.008       0.041
# Market Excess Return     0.2754      0.199      1.381      0.261      -0.359       0.910
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.279
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.507
# Skew:                           0.038   Prob(JB):                        0.776
# Kurtosis:                       1.443   Cond. No.                         29.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.004566230476492777
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.724
# Model:                                 OLS   Adj. R-squared:                  0.585
# Method:                      Least Squares   F-statistic:                     5.237
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.149
# Time:                             10:47:19   Log-Likelihood:                 10.677
# No. Observations:                        4   AIC:                            -17.35
# Df Residuals:                            2   BIC:                            -18.58
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0036      0.012     -0.295      0.796      -0.057       0.050
# Market Excess Return     0.4144      0.181      2.288      0.149      -0.365       1.194
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.180
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.710
# Skew:                           0.954   Prob(JB):                        0.701
# Kurtosis:                       2.215   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01277115063758078
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.314
# Model:                                 OLS   Adj. R-squared:                  0.086
# Method:                      Least Squares   F-statistic:                     1.375
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.326
# Time:                             10:47:19   Log-Likelihood:                 13.370
# No. Observations:                        5   AIC:                            -22.74
# Df Residuals:                            3   BIC:                            -23.52
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0101      0.010      1.023      0.382      -0.021       0.042
# Market Excess Return     0.3669      0.313      1.173      0.326      -0.629       1.363
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.017
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.475
# Skew:                          -0.568   Prob(JB):                        0.789
# Kurtosis:                       2.005   Cond. No.                         32.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.004200602301612696
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.578
# Model:                                 OLS   Adj. R-squared:                  0.367
# Method:                      Least Squares   F-statistic:                     2.741
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.240
# Time:                             10:47:19   Log-Likelihood:                 12.780
# No. Observations:                        4   AIC:                            -21.56
# Df Residuals:                            2   BIC:                            -22.79
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0084      0.010     -0.810      0.503      -0.053       0.036
# Market Excess Return     0.7009      0.423      1.656      0.240      -1.121       2.523
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.108
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.497
# Skew:                           0.281   Prob(JB):                        0.780
# Kurtosis:                       1.367   Cond. No.                         60.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014988723940896662
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.897
# Model:                                 OLS   Adj. R-squared:                  0.846
# Method:                      Least Squares   F-statistic:                     17.47
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0528
# Time:                             10:47:19   Log-Likelihood:                 14.111
# No. Observations:                        4   AIC:                            -24.22
# Df Residuals:                            2   BIC:                            -25.45
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0201      0.005      3.890      0.060      -0.002       0.042
# Market Excess Return     0.9134      0.219      4.180      0.053      -0.027       1.854
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.993
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.763
# Skew:                          -0.994   Prob(JB):                        0.683
# Kurtosis:                       2.212   Cond. No.                         43.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0050060179345204625
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.924
# Model:                                 OLS   Adj. R-squared:                  0.899
# Method:                      Least Squares   F-statistic:                     36.46
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00911
# Time:                             10:47:19   Log-Likelihood:                 18.315
# No. Observations:                        5   AIC:                            -32.63
# Df Residuals:                            3   BIC:                            -33.41
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0037      0.004      1.037      0.376      -0.008       0.015
# Market Excess Return     0.6340      0.105      6.038      0.009       0.300       0.968
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.706
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.418
# Skew:                           0.329   Prob(JB):                        0.812
# Kurtosis:                       1.746   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.038184958239652095
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.662
# Model:                                 OLS   Adj. R-squared:                  0.493
# Method:                      Least Squares   F-statistic:                     3.917
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.186
# Time:                             10:47:19   Log-Likelihood:                 11.192
# No. Observations:                        4   AIC:                            -18.38
# Df Residuals:                            2   BIC:                            -19.61
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0148      0.029     -0.515      0.658      -0.138       0.109
# Market Excess Return     0.7943      0.401      1.979      0.186      -0.933       2.521
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.179
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.606
# Skew:                          -0.825   Prob(JB):                        0.738
# Kurtosis:                       2.041   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.006523783640344762
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.674
# Model:                                 OLS   Adj. R-squared:                  0.512
# Method:                      Least Squares   F-statistic:                     4.142
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.179
# Time:                             10:47:19   Log-Likelihood:                 14.003
# No. Observations:                        4   AIC:                            -24.01
# Df Residuals:                            2   BIC:                            -25.23
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                -9.919e-05      0.006     -0.016      0.989      -0.026       0.026
# Market Excess Return     0.7998      0.393      2.035      0.179      -0.891       2.491
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.770
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.659
# Skew:                          -0.895   Prob(JB):                        0.719
# Kurtosis:                       2.134   Cond. No.                         76.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.014975  1.154631       1.103087
# 1     02                -0.002129  0.852810       0.901873
# 2     03                -0.027794  0.713683       0.809122
# 3     04                 0.018415 -0.016670       0.322220
# 4     05                 0.022009  0.275446       0.516964
# 5     06                 0.004566  0.414447       0.609631
# 6     07                 0.012771  0.366936       0.577957
# 7     08                 0.004201  0.700923       0.800615
# 8     09                 0.014989  0.913436       0.942291
# 9     10                 0.005006  0.634023       0.756015
# 10    11                 0.038185  0.794314       0.862876
# 11    12                 0.006524  0.799780       0.866520

# %%
coefficients_df.to_csv('coefficients_df_p1_2.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.009646719429769222

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (52, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.733
# Model:                            OLS   Adj. R-squared:                  0.728
# Method:                 Least Squares   F-statistic:                     137.3
# Date:                Sat, 04 May 2024   Prob (F-statistic):           5.95e-16
# Time:                        10:47:20   Log-Likelihood:                 133.25
# No. Observations:                  52   AIC:                            -262.5
# Df Residuals:                      50   BIC:                            -258.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0058      0.003      2.186      0.034       0.000       0.011
# x1             0.5822      0.050     11.718      0.000       0.482       0.682
# ==============================================================================
# Omnibus:                        0.382   Durbin-Watson:                   2.713
# Prob(Omnibus):                  0.826   Jarque-Bera (JB):                0.038
# Skew:                          -0.023   Prob(JB):                        0.981
# Kurtosis:                       3.124   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 0.5822346921874575
# P-value: 5.951007332658541e-16
# Std. error: 0.0496863768706156
# Adj. R-squared: 0.7277329787088034
# F-statistic: 137.31611253591439
# T-statistic for X1: 11.718195788427263

# %% [markdown]
# # P2 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_2.index:
    # Extract market excess return for the date
    x = returns_2020.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_2.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2020-01-03              0.005386                -0.007462
# 2020-01-10              0.021326                 0.026671
# 2020-01-17              0.012616                 0.025900
# 2020-01-24             -0.000007                -0.000348
# 2020-01-31             -0.023351                -0.016655

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# 0.005621149905797061
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.753
# Model:                                 OLS   Adj. R-squared:                  0.670
# Method:                      Least Squares   F-statistic:                     9.125
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0567
# Time:                             10:47:20   Log-Likelihood:                 16.582
# No. Observations:                        5   AIC:                            -29.16
# Df Residuals:                            3   BIC:                            -29.95
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0024      0.005      0.459      0.677      -0.014       0.019
# Market Excess Return     1.0152      0.336      3.021      0.057      -0.054       2.085
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.615
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.470
# Skew:                          -0.667   Prob(JB):                        0.791
# Kurtosis:                       2.313   Cond. No.                         66.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.00856575141849564
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.951
# Model:                                 OLS   Adj. R-squared:                  0.926
# Method:                      Least Squares   F-statistic:                     38.45
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0250
# Time:                             10:47:20   Log-Likelihood:                 11.627
# No. Observations:                        4   AIC:                            -19.25
# Df Residuals:                            2   BIC:                            -20.48
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0043      0.009     -0.455      0.694      -0.045       0.036
# Market Excess Return     0.9351      0.151      6.201      0.025       0.286       1.584
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.023
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.444
# Skew:                          -0.197   Prob(JB):                        0.801
# Kurtosis:                       1.417   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.04233070189556372
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.994
# Model:                                 OLS   Adj. R-squared:                  0.990
# Method:                      Least Squares   F-statistic:                     312.7
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00318
# Time:                             10:47:20   Log-Likelihood:                 13.404
# No. Observations:                        4   AIC:                            -22.81
# Df Residuals:                            2   BIC:                            -24.04
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0116      0.007      1.731      0.226      -0.017       0.041
# Market Excess Return     0.9581      0.054     17.683      0.003       0.725       1.191
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.208
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.452
# Skew:                          -0.088   Prob(JB):                        0.798
# Kurtosis:                       1.362   Cond. No.                         9.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.004429368962087974
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.893
# Model:                                 OLS   Adj. R-squared:                  0.840
# Method:                      Least Squares   F-statistic:                     16.77
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0548
# Time:                             10:47:20   Log-Likelihood:                 11.383
# No. Observations:                        4   AIC:                            -18.77
# Df Residuals:                            2   BIC:                            -19.99
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0047      0.010      0.469      0.685      -0.038       0.047
# Market Excess Return     0.9510      0.232      4.095      0.055      -0.048       1.950
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.294
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.445
# Skew:                           0.506   Prob(JB):                        0.800
# Kurtosis:                       1.716   Cond. No.                         23.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01605502546284306
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.806
# Model:                                 OLS   Adj. R-squared:                  0.742
# Method:                      Least Squares   F-statistic:                     12.49
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0385
# Time:                             10:47:20   Log-Likelihood:                 13.746
# No. Observations:                        5   AIC:                            -23.49
# Df Residuals:                            3   BIC:                            -24.27
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0021      0.010     -0.201      0.853      -0.035       0.031
# Market Excess Return     0.9370      0.265      3.534      0.039       0.093       1.781
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.722
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.151
# Skew:                           0.013   Prob(JB):                        0.927
# Kurtosis:                       2.150   Cond. No.                         29.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014654079124352324
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.984
# Model:                                 OLS   Adj. R-squared:                  0.976
# Method:                      Least Squares   F-statistic:                     122.2
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00808
# Time:                             10:47:20   Log-Likelihood:                 14.616
# No. Observations:                        4   AIC:                            -25.23
# Df Residuals:                            2   BIC:                            -26.46
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0002      0.005     -0.037      0.974      -0.020       0.020
# Market Excess Return     0.7479      0.068     11.055      0.008       0.457       1.039
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.314
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.418
# Skew:                           0.470   Prob(JB):                        0.811
# Kurtosis:                       1.726   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.011110540298490675
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.821
# Model:                                 OLS   Adj. R-squared:                  0.762
# Method:                      Least Squares   F-statistic:                     13.81
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0339
# Time:                             10:47:20   Log-Likelihood:                 17.794
# No. Observations:                        5   AIC:                            -31.59
# Df Residuals:                            3   BIC:                            -32.37
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0077      0.004      1.873      0.158      -0.005       0.021
# Market Excess Return     0.4800      0.129      3.716      0.034       0.069       0.891
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.165
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.444
# Skew:                           0.164   Prob(JB):                        0.801
# Kurtosis:                       1.577   Cond. No.                         32.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.014627303490174649
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.856
# Model:                                 OLS   Adj. R-squared:                  0.784
# Method:                      Least Squares   F-statistic:                     11.89
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0748
# Time:                             10:47:20   Log-Likelihood:                 14.711
# No. Observations:                        4   AIC:                            -25.42
# Df Residuals:                            2   BIC:                            -26.65
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0015      0.006     -0.240      0.833      -0.029       0.026
# Market Excess Return     0.9006      0.261      3.448      0.075      -0.223       2.025
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.987
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.485
# Skew:                           0.160   Prob(JB):                        0.785
# Kurtosis:                       1.325   Cond. No.                         60.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -6.209818205162292e-05
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.872
# Model:                                 OLS   Adj. R-squared:                  0.807
# Method:                      Least Squares   F-statistic:                     13.58
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0664
# Time:                             10:47:20   Log-Likelihood:                 13.671
# No. Observations:                        4   AIC:                            -23.34
# Df Residuals:                            2   BIC:                            -24.57
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0050      0.006      0.865      0.478      -0.020       0.030
# Market Excess Return     0.8991      0.244      3.686      0.066      -0.151       1.949
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.063
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.649
# Skew:                           0.874   Prob(JB):                        0.723
# Kurtosis:                       2.086   Cond. No.                         43.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0008712629295755004
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.983
# Model:                                 OLS   Adj. R-squared:                  0.978
# Method:                      Least Squares   F-statistic:                     176.4
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000923
# Time:                             10:47:20   Log-Likelihood:                 20.516
# No. Observations:                        5   AIC:                            -37.03
# Df Residuals:                            3   BIC:                            -37.81
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0009      0.002     -0.408      0.711      -0.008       0.006
# Market Excess Return     0.8980      0.068     13.280      0.001       0.683       1.113
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.492
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.409
# Skew:                           0.447   Prob(JB):                        0.815
# Kurtosis:                       1.922   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.06344844725857933
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.711
# Model:                                 OLS   Adj. R-squared:                  0.567
# Method:                      Least Squares   F-statistic:                     4.922
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.157
# Time:                             10:47:20   Log-Likelihood:                 11.528
# No. Observations:                        4   AIC:                            -19.06
# Df Residuals:                            2   BIC:                            -20.28
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0089      0.026      0.335      0.769      -0.105       0.122
# Market Excess Return     0.8185      0.369      2.219      0.157      -0.769       2.406
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.144
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.653
# Skew:                           0.877   Prob(JB):                        0.721
# Kurtosis:                       2.085   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.007616439825571506
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.292
# Model:                                 OLS   Adj. R-squared:                 -0.062
# Method:                      Least Squares   F-statistic:                    0.8245
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.460
# Time:                             10:47:20   Log-Likelihood:                 14.425
# No. Observations:                        4   AIC:                            -24.85
# Df Residuals:                            2   BIC:                            -26.08
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0050      0.005      0.903      0.462      -0.019       0.029
# Market Excess Return     0.3210      0.354      0.908      0.460      -1.200       1.842
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.778
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.588
# Skew:                          -0.800   Prob(JB):                        0.745
# Kurtosis:                       2.015   Cond. No.                         76.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                 0.005621  1.015168       1.010112
# 1     02                -0.008566  0.935072       0.956715
# 2     03                -0.042331  0.958086       0.972057
# 3     04                 0.004429  0.950979       0.967319
# 4     05                 0.016055  0.937048       0.958032
# 5     06                 0.014654  0.747917       0.831944
# 6     07                 0.011111  0.479958       0.653305
# 7     08                 0.014627  0.900606       0.933737
# 8     09                -0.000062  0.899107       0.932738
# 9     10                 0.000871  0.898039       0.932026
# 10    11                 0.063448  0.818541       0.879028
# 11    12                 0.007616  0.321035       0.547356

# %%
coefficients_df.to_csv('coefficients_df_p2_2.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.007376120031579821

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (52, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.938
# Model:                            OLS   Adj. R-squared:                  0.937
# Method:                 Least Squares   F-statistic:                     758.5
# Date:                Sat, 04 May 2024   Prob (F-statistic):           7.02e-32
# Time:                        10:47:20   Log-Likelihood:                 156.21
# No. Observations:                  52   AIC:                            -308.4
# Df Residuals:                      50   BIC:                            -304.5
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.002      0.923      0.360      -0.002       0.005
# x1             0.8801      0.032     27.540      0.000       0.816       0.944
# ==============================================================================
# Omnibus:                        0.891   Durbin-Watson:                   2.653
# Prob(Omnibus):                  0.640   Jarque-Bera (JB):                0.879
# Skew:                           0.292   Prob(JB):                        0.644
# Kurtosis:                       2.747   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 0.8800595478403259
# P-value: 7.020407648142793e-32
# Std. error: 0.031955472823999284
# Adj. R-squared: 0.9369172298091967
# F-statistic: 758.4616424697717
# T-statistic for X1: 27.540182324555726

# %% [markdown]
# # P3 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_3.index:
    # Extract market excess return for the date
    x = returns_2020.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_3.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2020-01-03              0.005386                 0.010116
# 2020-01-10              0.021326                 0.034170
# 2020-01-17              0.012616                -0.001372
# 2020-01-24             -0.000007                -0.008244
# 2020-01-31             -0.023351                -0.047521

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# -0.0025701551022021944
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.906
# Model:                                 OLS   Adj. R-squared:                  0.875
# Method:                      Least Squares   F-statistic:                     28.95
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0126
# Time:                             10:47:20   Log-Likelihood:                 16.934
# No. Observations:                        5   AIC:                            -29.87
# Df Residuals:                            3   BIC:                            -30.65
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0080      0.005     -1.647      0.198      -0.023       0.007
# Market Excess Return     1.6853      0.313      5.380      0.013       0.688       2.682
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.944
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.606
# Skew:                          -0.804   Prob(JB):                        0.739
# Kurtosis:                       2.430   Cond. No.                         66.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.010991041671819524
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.964
# Model:                                 OLS   Adj. R-squared:                  0.947
# Method:                      Least Squares   F-statistic:                     54.22
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0179
# Time:                             10:47:20   Log-Likelihood:                 11.701
# No. Observations:                        4   AIC:                            -19.40
# Df Residuals:                            2   BIC:                            -20.63
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0060      0.009     -0.649      0.583      -0.046       0.034
# Market Excess Return     1.0899      0.148      7.364      0.018       0.453       1.727
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.186
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.584
# Skew:                           0.802   Prob(JB):                        0.747
# Kurtosis:                       2.037   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.07180135948043034
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.842
# Model:                                 OLS   Adj. R-squared:                  0.762
# Method:                      Least Squares   F-statistic:                     10.63
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0826
# Time:                             10:47:20   Log-Likelihood:                 6.2098
# No. Observations:                        4   AIC:                            -8.420
# Df Residuals:                            2   BIC:                            -9.647
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0117      0.041     -0.287      0.801      -0.187       0.163
# Market Excess Return     1.0672      0.327      3.261      0.083      -0.341       2.475
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.677
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.557
# Skew:                           0.139   Prob(JB):                        0.757
# Kurtosis:                       1.193   Cond. No.                         9.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.00046827189779287577
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.669
# Model:                                 OLS   Adj. R-squared:                  0.503
# Method:                      Least Squares   F-statistic:                     4.034
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.182
# Time:                             10:47:20   Log-Likelihood:                 8.2069
# No. Observations:                        4   AIC:                            -12.41
# Df Residuals:                            2   BIC:                            -13.64
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0002      0.022     -0.010      0.993      -0.095       0.094
# Market Excess Return     1.0318      0.514      2.008      0.182      -1.179       3.242
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.263
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.266
# Skew:                           0.399   Prob(JB):                        0.876
# Kurtosis:                       2.021   Cond. No.                         23.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.012560240927011534
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.622
# Model:                                 OLS   Adj. R-squared:                  0.497
# Method:                      Least Squares   F-statistic:                     4.945
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.113
# Time:                             10:47:20   Log-Likelihood:                 11.199
# No. Observations:                        5   AIC:                            -18.40
# Df Residuals:                            3   BIC:                            -19.18
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0064      0.017     -0.375      0.733      -0.061       0.048
# Market Excess Return     0.9811      0.441      2.224      0.113      -0.423       2.385
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.175
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.782
# Skew:                          -0.960   Prob(JB):                        0.676
# Kurtosis:                       2.737   Cond. No.                         29.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.01814000526270805
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.968
# Model:                                 OLS   Adj. R-squared:                  0.952
# Method:                      Least Squares   F-statistic:                     60.36
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0162
# Time:                             10:47:20   Log-Likelihood:                 10.726
# No. Observations:                        4   AIC:                            -17.45
# Df Residuals:                            2   BIC:                            -18.68
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0094      0.012     -0.769      0.522      -0.062       0.043
# Market Excess Return     1.3896      0.179      7.769      0.016       0.620       2.159
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.558
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.494
# Skew:                          -0.290   Prob(JB):                        0.781
# Kurtosis:                       1.378   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.010144211774836251
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.877
# Model:                                 OLS   Adj. R-squared:                  0.835
# Method:                      Least Squares   F-statistic:                     21.31
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0191
# Time:                             10:47:20   Log-Likelihood:                 13.426
# No. Observations:                        5   AIC:                            -22.85
# Df Residuals:                            3   BIC:                            -23.63
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0002      0.010     -0.015      0.989      -0.031       0.031
# Market Excess Return     1.4284      0.309      4.617      0.019       0.444       2.413
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.211
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.176
# Skew:                          -0.090   Prob(JB):                        0.916
# Kurtosis:                       2.099   Cond. No.                         32.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.030213149590630838
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.864
# Model:                                 OLS   Adj. R-squared:                  0.796
# Method:                      Least Squares   F-statistic:                     12.70
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0705
# Time:                             10:47:20   Log-Likelihood:                 12.712
# No. Observations:                        4   AIC:                            -21.42
# Df Residuals:                            2   BIC:                            -22.65
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0027      0.011      0.255      0.823      -0.043       0.048
# Market Excess Return     1.5346      0.431      3.564      0.071      -0.318       3.387
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.808
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.403
# Skew:                           0.188   Prob(JB):                        0.818
# Kurtosis:                       1.491   Cond. No.                         60.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.01907428752894516
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.877
# Model:                                 OLS   Adj. R-squared:                  0.816
# Method:                      Least Squares   F-statistic:                     14.32
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0633
# Time:                             10:47:20   Log-Likelihood:                 13.080
# No. Observations:                        4   AIC:                            -22.16
# Df Residuals:                            2   BIC:                            -23.39
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0131      0.007     -1.951      0.190      -0.042       0.016
# Market Excess Return     1.0701      0.283      3.784      0.063      -0.147       2.287
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.757
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.572
# Skew:                          -0.102   Prob(JB):                        0.751
# Kurtosis:                       1.159   Cond. No.                         43.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.010930146337003793
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.931
# Model:                                 OLS   Adj. R-squared:                  0.908
# Method:                      Least Squares   F-statistic:                     40.40
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00788
# Time:                             10:47:20   Log-Likelihood:                 15.644
# No. Observations:                        5   AIC:                            -27.29
# Df Residuals:                            3   BIC:                            -28.07
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0132      0.006     -2.160      0.120      -0.033       0.006
# Market Excess Return     1.1386      0.179      6.356      0.008       0.569       1.709
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.525
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.179
# Skew:                           0.227   Prob(JB):                        0.915
# Kurtosis:                       2.194   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.08312294550040356
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.236
# Model:                                 OLS   Adj. R-squared:                 -0.146
# Method:                      Least Squares   F-statistic:                    0.6188
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.514
# Time:                             10:47:20   Log-Likelihood:                 9.6804
# No. Observations:                        4   AIC:                            -15.36
# Df Residuals:                            2   BIC:                            -16.59
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0524      0.042      1.250      0.338      -0.128       0.233
# Market Excess Return     0.4607      0.586      0.787      0.514      -2.059       2.980
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.908
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.512
# Skew:                          -0.089   Prob(JB):                        0.774
# Kurtosis:                       1.257   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.008687510144961611
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.771
# Model:                                 OLS   Adj. R-squared:                  0.657
# Method:                      Least Squares   F-statistic:                     6.736
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.122
# Time:                             10:47:20   Log-Likelihood:                 14.012
# No. Observations:                        4   AIC:                            -24.02
# Df Residuals:                            2   BIC:                            -25.25
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0003      0.006      0.043      0.970      -0.026       0.026
# Market Excess Return     1.0175      0.392      2.595      0.122      -0.669       2.704
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.836
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.473
# Skew:                           0.434   Prob(JB):                        0.789
# Kurtosis:                       1.556   Cond. No.                         76.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                -0.002570  1.685340       1.456893
# 1     02                -0.010991  1.089887       1.059925
# 2     03                -0.071801  1.067156       1.044771
# 3     04                -0.000468  1.031837       1.021224
# 4     05                 0.012560  0.981128       0.987419
# 5     06                 0.018140  1.389647       1.259765
# 6     07                 0.010144  1.428426       1.285617
# 7     08                 0.030213  1.534628       1.356418
# 8     09                -0.019074  1.070082       1.046721
# 9     10                -0.010930  1.138641       1.092427
# 10    11                 0.083123  0.460669       0.640446
# 11    12                 0.008688  1.017526       1.011684

# %%
coefficients_df.to_csv('coefficients_df_p3_2.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.0037949106921552614

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (52, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.866
# Model:                            OLS   Adj. R-squared:                  0.863
# Method:                 Least Squares   F-statistic:                     321.8
# Date:                Sat, 04 May 2024   Prob (F-statistic):           1.97e-23
# Time:                        10:47:20   Log-Likelihood:                 119.51
# No. Observations:                  52   AIC:                            -235.0
# Df Residuals:                      50   BIC:                            -231.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0039      0.003     -1.113      0.271      -0.011       0.003
# x1             1.1611      0.065     17.940      0.000       1.031       1.291
# ==============================================================================
# Omnibus:                        0.959   Durbin-Watson:                   2.343
# Prob(Omnibus):                  0.619   Jarque-Bera (JB):                0.318
# Skew:                           0.025   Prob(JB):                        0.853
# Kurtosis:                       3.380   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 1.1610948884340335
# P-value: 1.9744215644600715e-23
# Std. error: 0.06472047426561996
# Adj. R-squared: 0.8628475209147414
# F-statistic: 321.848911081634
# T-statistic for X1: 17.94014802284625

# %% [markdown]
# # P4 #

# %%
import pandas as pd

# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_4.index:
    # Extract market excess return for the date
    x = returns_2020.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_4.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2020-01-03              0.005386                 0.007076
# 2020-01-10              0.021326                 0.039900
# 2020-01-17              0.012616                -0.003546
# 2020-01-24             -0.000007                -0.003891
# 2020-01-31             -0.023351                -0.049898

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return': monthly_portfolio_excess_return, 'Beta': x1_coefficient, 'Adjusted Beta': adj})

# Convert the list to a DataFrame
coefficients_df = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df
# Out:
# -0.002071784556268462
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.887
# Model:                                 OLS   Adj. R-squared:                  0.849
# Method:                      Least Squares   F-statistic:                     23.44
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0168
# Time:                             10:47:20   Log-Likelihood:                 16.088
# No. Observations:                        5   AIC:                            -28.18
# Df Residuals:                            3   BIC:                            -28.96
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0078      0.006     -1.365      0.266      -0.026       0.010
# Market Excess Return     1.7961      0.371      4.841      0.017       0.615       2.977
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.781
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.094
# Skew:                          -1.141   Prob(JB):                        0.579
# Kurtosis:                       2.798   Cond. No.                         66.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0008559796258701471
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.990
# Model:                                 OLS   Adj. R-squared:                  0.985
# Method:                      Least Squares   F-statistic:                     193.8
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00512
# Time:                             10:47:20   Log-Likelihood:                 14.478
# No. Observations:                        4   AIC:                            -24.96
# Df Residuals:                            2   BIC:                            -26.18
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0056      0.005      1.216      0.348      -0.014       0.025
# Market Excess Return     1.0291      0.074     13.921      0.005       0.711       1.347
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.685
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.439
# Skew:                          -0.675   Prob(JB):                        0.803
# Kurtosis:                       2.098   Cond. No.                         16.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.07533543962284414
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.948
# Model:                                 OLS   Adj. R-squared:                  0.922
# Method:                      Least Squares   F-statistic:                     36.52
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0263
# Time:                             10:47:20   Log-Likelihood:                 9.5932
# No. Observations:                        4   AIC:                            -15.19
# Df Residuals:                            2   BIC:                            -16.41
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0275      0.017     -1.577      0.256      -0.103       0.048
# Market Excess Return     0.8488      0.140      6.043      0.026       0.244       1.453
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.515
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.656
# Skew:                          -0.888   Prob(JB):                        0.720
# Kurtosis:                       2.114   Cond. No.                         9.06
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.005466314090980043
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.946
# Model:                                 OLS   Adj. R-squared:                  0.919
# Method:                      Least Squares   F-statistic:                     35.08
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0273
# Time:                             10:47:20   Log-Likelihood:                 11.645
# No. Observations:                        4   AIC:                            -19.29
# Df Residuals:                            2   BIC:                            -20.52
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0058      0.009      0.621      0.598      -0.034       0.046
# Market Excess Return     1.2882      0.217      5.923      0.027       0.352       2.224
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.010
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.501
# Skew:                           0.749   Prob(JB):                        0.778
# Kurtosis:                       2.128   Cond. No.                         23.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.024666455441270135
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.892
# Model:                                 OLS   Adj. R-squared:                  0.856
# Method:                      Least Squares   F-statistic:                     24.77
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0156
# Time:                             10:47:20   Log-Likelihood:                 14.192
# No. Observations:                        5   AIC:                            -24.38
# Df Residuals:                            3   BIC:                            -25.16
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0013      0.009      0.140      0.898      -0.029       0.031
# Market Excess Return     1.2069      0.243      4.977      0.016       0.435       1.979
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.677
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.286
# Skew:                          -1.242   Prob(JB):                        0.526
# Kurtosis:                       2.973   Cond. No.                         29.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.02409279801045333
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.988
# Model:                                 OLS   Adj. R-squared:                  0.983
# Method:                      Least Squares   F-statistic:                     169.6
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00584
# Time:                             10:47:21   Log-Likelihood:                 13.354
# No. Observations:                        4   AIC:                            -22.71
# Df Residuals:                            2   BIC:                            -23.94
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0001      0.006      0.023      0.984      -0.027       0.027
# Market Excess Return     1.2079      0.093     13.025      0.006       0.809       1.607
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.346
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.617
# Skew:                          -0.825   Prob(JB):                        0.734
# Kurtosis:                       2.010   Cond. No.                         15.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.0008957480068167795
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.819
# Model:                                 OLS   Adj. R-squared:                  0.758
# Method:                      Least Squares   F-statistic:                     13.54
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0348
# Time:                             10:47:21   Log-Likelihood:                 12.800
# No. Observations:                        5   AIC:                            -21.60
# Df Residuals:                            3   BIC:                            -22.38
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0084      0.011     -0.758      0.504      -0.044       0.027
# Market Excess Return     1.2903      0.351      3.680      0.035       0.174       2.406
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.860
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.734
# Skew:                           0.919   Prob(JB):                        0.693
# Kurtosis:                       2.625   Cond. No.                         32.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.021154600322682977
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.942
# Model:                                 OLS   Adj. R-squared:                  0.912
# Method:                      Least Squares   F-statistic:                     32.20
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0297
# Time:                             10:47:21   Log-Likelihood:                 15.525
# No. Observations:                        4   AIC:                            -27.05
# Df Residuals:                            2   BIC:                            -28.28
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0005      0.005     -0.105      0.926      -0.023       0.022
# Market Excess Return     1.2094      0.213      5.675      0.030       0.292       2.126
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.546
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.724
# Skew:                           0.950   Prob(JB):                        0.696
# Kurtosis:                       2.144   Cond. No.                         60.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# -0.012541003670329523
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.856
# Model:                                 OLS   Adj. R-squared:                  0.785
# Method:                      Least Squares   F-statistic:                     11.93
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0746
# Time:                             10:47:21   Log-Likelihood:                 12.673
# No. Observations:                        4   AIC:                            -21.35
# Df Residuals:                            2   BIC:                            -22.57
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0065      0.007     -0.872      0.475      -0.038       0.025
# Market Excess Return     1.0815      0.313      3.454      0.075      -0.266       2.429
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.136
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.444
# Skew:                           0.518   Prob(JB):                        0.801
# Kurtosis:                       1.740   Cond. No.                         43.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.005051714493032525
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.893
# Model:                                 OLS   Adj. R-squared:                  0.858
# Method:                      Least Squares   F-statistic:                     25.07
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0153
# Time:                             10:47:21   Log-Likelihood:                 14.751
# No. Observations:                        5   AIC:                            -25.50
# Df Residuals:                            3   BIC:                            -26.28
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0029      0.007      0.394      0.720      -0.020       0.026
# Market Excess Return     1.0725      0.214      5.007      0.015       0.391       1.754
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.601
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                1.589
# Skew:                          -1.380   Prob(JB):                        0.452
# Kurtosis:                       3.109   Cond. No.                         29.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.07537387971674654
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.872
# Model:                                 OLS   Adj. R-squared:                  0.808
# Method:                      Least Squares   F-statistic:                     13.59
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0663
# Time:                             10:47:21   Log-Likelihood:                 13.341
# No. Observations:                        4   AIC:                            -22.68
# Df Residuals:                            2   BIC:                            -23.91
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0177      0.017      1.055      0.402      -0.055       0.090
# Market Excess Return     0.8647      0.235      3.687      0.066      -0.144       1.874
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.070
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.740
# Skew:                           0.967   Prob(JB):                        0.691
# Kurtosis:                       2.162   Cond. No.                         38.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 0.008176856008282872
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.528
# Model:                                 OLS   Adj. R-squared:                  0.292
# Method:                      Least Squares   F-statistic:                     2.235
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.274
# Time:                             10:47:21   Log-Likelihood:                 12.145
# No. Observations:                        4   AIC:                            -20.29
# Df Residuals:                            2   BIC:                            -21.52
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0004      0.010      0.045      0.968      -0.041       0.042
# Market Excess Return     0.9346      0.625      1.495      0.274      -1.755       3.625
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.769
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.718
# Skew:                           0.959   Prob(JB):                        0.699
# Kurtosis:                       2.208   Cond. No.                         76.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return      Beta  Adjusted Beta
# 0     01                -0.002072  1.796080       1.530720
# 1     02                 0.000856  1.029093       1.019395
# 2     03                -0.075335  0.848821       0.899214
# 3     04                 0.005466  1.288184       1.192123
# 4     05                 0.024666  1.206874       1.137916
# 5     06                 0.024093  1.207900       1.138600
# 6     07                 0.000896  1.290337       1.193558
# 7     08                 0.021155  1.209400       1.139600
# 8     09                -0.012541  1.081533       1.054355
# 9     10                 0.005052  1.072533       1.048355
# 10    11                 0.075374  0.864706       0.909804
# 11    12                 0.008177  0.934604       0.956402

# %%
coefficients_df.to_csv('coefficients_df_p4_2.csv')

# %%
df['Portfolio Excess Return'].mean()
# Out:
# 0.006378588554838921

# %%
import statsmodels.api as sm
import pandas as pd

x = df['Market Excess Return'].values # Market excess return

y = df['Portfolio Excess Return'].values # Portfolio excess return
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
beta_p = results.params[1]  # Coefficient
p_value = results.pvalues[1]  # P-value
std_error = results.bse[1]  # Standard error
adj_r2 = results.rsquared_adj  # Adjusted R-squared
f_stat = results.fvalue  # F-statistic
t_stat_x1 = results.tvalues[1]

# Print the retrieved values
print("β_p (Coefficient):", beta_p)
print("P-value:", p_value)
print("Std. error:", std_error)
print("Adj. R-squared:", adj_r2)
print("F-statistic:", f_stat)
print("T-statistic for X1:", t_stat_x1)
#
# Out:
# (52, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.920
# Model:                            OLS   Adj. R-squared:                  0.918
# Method:                 Least Squares   F-statistic:                     574.5
# Date:                Sat, 04 May 2024   Prob (F-statistic):           4.51e-29
# Time:                        10:47:21   Log-Likelihood:                 138.87
# No. Observations:                  52   AIC:                            -273.7
# Df Residuals:                      50   BIC:                            -269.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0007      0.002     -0.278      0.782      -0.005       0.004
# x1             1.0689      0.045     23.968      0.000       0.979       1.158
# ==============================================================================
# Omnibus:                        4.672   Durbin-Watson:                   2.792
# Prob(Omnibus):                  0.097   Jarque-Bera (JB):                3.600
# Skew:                          -0.512   Prob(JB):                        0.165
# Kurtosis:                       3.783   Cond. No.                         18.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# β_p (Coefficient): 1.068905871678082
# P-value: 4.509387237617024e-29
# Std. error: 0.04459695893644142
# Adj. R-squared: 0.9183309315061456
# F-statistic: 574.4714301331569
# T-statistic for X1: 23.96813363892059
