# %%
import pandas as pd

returns = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Returns_2018-2023.csv')

portfolio_1 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-4/p1-4.csv', usecols=[0])
portfolio_2 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-4/p2-4.csv', usecols=[0])
portfolio_3 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-4/p3-4.csv', usecols=[0])
portfolio_4 = pd.read_csv('/Users/gloriabagnato/Desktop/TESI/Data-Finance/Period-4/p4-4.csv', usecols=[0])

# %%
# Rename the column
portfolio_1 = portfolio_1.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2021' from the values in the 'Stock' column
portfolio_1['Stock'] = portfolio_1['Stock'].str.replace(' 2021', '')

# %%
portfolio_1
# Out:
#        Stock
# 0   Diasorin
# 1    Telecom
# 2      Inwit
# 3        Erg
# 4  Recordati
# 5       Snam
# 6    Italgas
# 7    Ferrari
# 8      Terna
# 9       Enel

# %%
# Rename the column
portfolio_2 = portfolio_2.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2021' from the values in the 'Stock' column
portfolio_2['Stock'] = portfolio_2['Stock'].str.replace(' 2021', '')

# %%
# Rename the column
portfolio_3 = portfolio_3.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2019' from the values in the 'Stock' column
portfolio_3['Stock'] = portfolio_3['Stock'].str.replace(' 2021', '')

# %%
# Rename the column
portfolio_4 = portfolio_4.rename(columns={'Unnamed: 0': 'Stock'})
# Remove '2019' from the values in the 'Stock' column
portfolio_4['Stock'] = portfolio_4['Stock'].str.replace(' 2021', '')

# %%
# Convert 'Date' column to datetime format
returns['Date'] = pd.to_datetime(returns['Date'])

# Extract year from 'Date' column
returns['Year'] = returns['Date'].dt.year

# Filter DataFrame to include only the data from 2022
returns_2023 = returns[returns['Year'] == 2023].copy()

# Drop the 'Year' column as it's no longer needed
returns_2023.drop(columns='Year', inplace=True)

# %%
returns_2023.drop(columns='Unnamed: 0', inplace=True)

# %%
returns_2023.head()
# Out:
#           Date  FTSEMIB Index  A2A 2018-2023  Amplifon 2018-2023  \
# 260 2023-01-06       0.062150       0.050201           -0.025881
# 261 2023-01-13       0.023952       0.064627           -0.005535
# 262 2023-01-20      -0.000309      -0.039511           -0.046011
# 263 2023-01-27       0.025615       0.052356            0.001167
# 264 2023-02-03       0.019481      -0.019190            0.081585
#
#      Azimut 2018-2023  BPER banca 2018-2023  Banca Mediolanum 2018-2023  \
# 260          0.018156              0.085744                    0.042062
# 261          0.055373              0.051368                    0.045287
# 262          0.013784              0.047032                   -0.007770
# 263          0.011404              0.060183                    0.031799
# 264          0.023417              0.044838                    0.027369
#
#      Banca Monte dei Paschi di Siena 2018-2023  Banca pop Sondrio 2018-2023  \
# 260                                   0.031799                     0.068783
# 261                                   0.110636                     0.018812
# 262                                  -0.080481                     0.000486
# 263                                   0.077170                     0.058281
# 264                                   0.139620                     0.035796
#
#      Banco Bpm 2018-2023  ...  Snam 2018-2023  Stellantis 2018-2023  \
# 260             0.018156  ...        0.055003              0.089113
# 261             0.055373  ...        0.018216             -0.014952
# 262             0.013784  ...        0.004730             -0.014476
# 263             0.011404  ...       -0.029881              0.012265
# 264             0.023417  ...       -0.005485              0.070724
#
#      Stmicroeletronics 2018-2023  Telecom 2018-2023  Tenaris 2018-2023  \
# 260                     0.073928           0.089228          -0.031317
# 261                     0.067852           0.059423           0.024089
# 262                     0.005680           0.022035           0.024451
# 263                     0.146985          -0.003920          -0.005136
# 264                     0.056344           0.115702          -0.073186
#
#      Terna 2018-2023  Unicredit 2018-2023  Unipol 2018-2023    BOT 3m  \
# 260         0.049565             0.108499          0.046292  0.035846
# 261         0.011599             0.002855         -0.002726  0.037173
# 262        -0.003276             0.013827          0.004415  0.040058
# 263        -0.002191             0.062174          0.016538  0.040596
# 264        -0.003843             0.134063          0.005766  0.047385
#
#      Risk Premium
# 260      0.026304
# 261     -0.013221
# 262     -0.040366
# 263     -0.014982
# 264     -0.027904
#
# [5 rows x 42 columns]

# %%
risk_premium_2023 = returns_2023[['Date','Risk Premium']]

# %%
risk_premium_2023.head()
# Out:
#           Date  Risk Premium
# 260 2023-01-06      0.026304
# 261 2023-01-13     -0.013221
# 262 2023-01-20     -0.040366
# 263 2023-01-27     -0.014982
# 264 2023-02-03     -0.027904

# %%
risk_premium_2023['Risk Premium'].mean()
# Out:
# -0.05716634268455696

# %%
returns_2023.columns = returns_2023.columns.str.replace('2018-2023', '')

# %%
import numpy as np

# Copy the 2023 data to avoid modifying the original DataFrame
returns_2023_excess = returns_2023.copy()

# Calculate excess returns for each stock by subtracting the risk-free rate
risk_free_rate = returns_2023_excess['BOT 3m'].values  # Convert Series to NumPy array
returns_2023_excess.iloc[:, 2:-2] -= risk_free_rate[:, np.newaxis]

# Set 'Date' column as the index
returns_2023_excess.set_index('Date', inplace=True)

# Display the DataFrame with 'Date' as the index
returns_2023_excess.head()
# Out:
#             FTSEMIB Index      A2A   Amplifon    Azimut   BPER banca   \
# Date
# 2023-01-06       0.062150  0.014355  -0.061727 -0.017690     0.049898
# 2023-01-13       0.023952  0.027454  -0.042708  0.018200     0.014195
# 2023-01-20      -0.000309 -0.079569  -0.086069 -0.026274     0.006974
# 2023-01-27       0.025615  0.011760  -0.039429 -0.029193     0.019587
# 2023-02-03       0.019481 -0.066574   0.034200 -0.023967    -0.002547
#
#             Banca Mediolanum   Banca Monte dei Paschi di Siena   \
# Date
# 2023-01-06           0.006216                         -0.004047
# 2023-01-13           0.008114                          0.073462
# 2023-01-20          -0.047828                         -0.120538
# 2023-01-27          -0.008797                          0.036573
# 2023-02-03          -0.020016                          0.092235
#
#             Banca pop Sondrio   Banco Bpm   Brunello cucinelli   ...  \
# Date                                                             ...
# 2023-01-06            0.032937   -0.017690            -0.022098  ...
# 2023-01-13           -0.018361    0.018200            -0.057159  ...
# 2023-01-20           -0.039572   -0.026274             0.016024  ...
# 2023-01-27            0.017685   -0.029193             0.030438  ...
# 2023-02-03           -0.011588   -0.023967            -0.005530  ...
#
#                Snam   Stellantis   Stmicroeletronics   Telecom   Tenaris   \
# Date
# 2023-01-06  0.019157     0.053267            0.038082  0.053382 -0.067163
# 2023-01-13 -0.018957    -0.052125            0.030679  0.022250 -0.013084
# 2023-01-20 -0.035328    -0.054534           -0.034377 -0.018022 -0.015607
# 2023-01-27 -0.070477    -0.028331            0.106389 -0.044516 -0.045732
# 2023-02-03 -0.052870     0.023340            0.008960  0.068318 -0.120570
#
#               Terna   Unicredit    Unipol     BOT 3m  Risk Premium
# Date
# 2023-01-06  0.013719    0.072653  0.010446  0.035846      0.026304
# 2023-01-13 -0.025574   -0.034318 -0.039899  0.037173     -0.013221
# 2023-01-20 -0.043334   -0.026231 -0.035642  0.040058     -0.040366
# 2023-01-27 -0.042787    0.021578 -0.024059  0.040596     -0.014982
# 2023-02-03 -0.051228    0.086679 -0.041619  0.047385     -0.027904
#
# [5 rows x 41 columns]

# %%
portfolio_1['Stock']
# Out:
# 0     Diasorin
# 1      Telecom
# 2        Inwit
# 3          Erg
# 4    Recordati
# 5         Snam
# 6      Italgas
# 7      Ferrari
# 8        Terna
# 9         Enel
# Name: Stock, dtype: object

# %%
returns_2023_excess.columns = returns_2023_excess.columns.str.strip()

# %%
p_1 = returns_2023_excess[portfolio_1['Stock'].values]
p_1.head()
# Out:
#             Diasorin   Telecom     Inwit       Erg  Recordati      Snam  \
# Date
# 2023-01-06 -0.065754  0.053382 -0.006103 -0.066924  -0.037653  0.019157
# 2023-01-13 -0.031639  0.022250 -0.020049 -0.022205   0.001348 -0.018957
# 2023-01-20 -0.055781 -0.018022 -0.018760 -0.065339  -0.004459 -0.035328
# 2023-01-27 -0.046587 -0.044516 -0.045065 -0.036994  -0.060788 -0.070477
# 2023-02-03 -0.072294  0.068318 -0.041400 -0.040206  -0.059652 -0.052870
#
#              Italgas   Ferrari     Terna      Enel
# Date
# 2023-01-06  0.003653  0.007610  0.013719  0.077673
# 2023-01-13 -0.030686  0.004474 -0.025574 -0.014499
# 2023-01-20 -0.055711 -0.017080 -0.043334 -0.053675
# 2023-01-27 -0.013468  0.004777 -0.042787 -0.069800
# 2023-02-03 -0.052849 -0.007419 -0.051228 -0.069809

# %%
p_2 = returns_2023_excess[portfolio_2['Stock'].values]
p_2.head()
# Out:
#             Leonardo   Campari      Hera       Eni    Azimut  Banco Bpm  \
# Date
# 2023-01-06 -0.024680 -0.004214  0.009013  0.005701 -0.017690  -0.017690
# 2023-01-13 -0.027848 -0.026543  0.015638  0.005030  0.018200   0.018200
# 2023-01-20  0.043093 -0.038844 -0.082281 -0.037700 -0.026274  -0.026274
# 2023-01-27  0.031009 -0.065445 -0.019873 -0.051941 -0.029193  -0.029193
# 2023-02-03 -0.052831  0.008136 -0.069164 -0.078731 -0.023967  -0.023967
#
#             Generali Ass  Stmicroeletronics       A2A
# Date
# 2023-01-06      0.007789           0.038082  0.014355
# 2023-01-13     -0.036308           0.030679  0.027454
# 2023-01-20     -0.016721          -0.034377 -0.079569
# 2023-01-27     -0.030179           0.106389  0.011760
# 2023-02-03     -0.041533           0.008960 -0.066574

# %%
p_3 = returns_2023_excess[portfolio_3['Stock'].values]
p_3.head()
# Out:
#             Mediobanca  Prysmian   Pirelli  Amplifon  Banca Mediolanum  \
# Date
# 2023-01-06   -0.004680 -0.037866  0.101017 -0.061727          0.006216
# 2023-01-13    0.006005 -0.018671 -0.024651 -0.042708          0.008114
# 2023-01-20   -0.048750  0.009616 -0.055679 -0.086069         -0.047828
# 2023-01-27   -0.006984 -0.026534 -0.030237 -0.039429         -0.008797
# 2023-02-03   -0.033448 -0.050051  0.005626  0.034200         -0.020016
#
#              Tenaris  Poste Italiane   Moncler    Fineco
# Date
# 2023-01-06 -0.067163        0.016751  0.021528  0.026976
# 2023-01-13 -0.013084       -0.024264  0.013266 -0.027776
# 2023-01-20 -0.015607       -0.055268 -0.020778 -0.052971
# 2023-01-27 -0.045732       -0.020350 -0.009547 -0.041205
# 2023-02-03 -0.120570       -0.016288 -0.030424 -0.015117

# %%
p_4 = returns_2023_excess[portfolio_4['Stock'].values]
p_4.head()
# Out:
#             Banca Monte dei Paschi di Siena  Interpump    Saipem  \
# Date
# 2023-01-06                        -0.004047   0.073262  0.046637
# 2023-01-13                         0.073462  -0.002956 -0.050282
# 2023-01-20                        -0.120538  -0.012762  0.102740
# 2023-01-27                         0.036573  -0.059517 -0.029336
# 2023-02-03                         0.092235   0.021553 -0.054569
#
#             Intesa San Paolo    Unipol  Brunello cucinelli  Banca pop Sondrio  \
# Date
# 2023-01-06          0.038985  0.010446           -0.022098           0.032937
# 2023-01-13         -0.012772 -0.039899           -0.057159          -0.018361
# 2023-01-20         -0.087042 -0.035642            0.016024          -0.039572
# 2023-01-27          0.037597 -0.024059            0.030438           0.017685
# 2023-02-03         -0.033773 -0.041619           -0.005530          -0.011588
#
#             Unicredit  BPER banca  Stellantis
# Date
# 2023-01-06   0.072653    0.049898    0.053267
# 2023-01-13  -0.034318    0.014195   -0.052125
# 2023-01-20  -0.026231    0.006974   -0.054534
# 2023-01-27   0.021578    0.019587   -0.028331
# 2023-02-03   0.086679   -0.002547    0.023340

# %%
returns_2023 = returns_2023.set_index('Date')

# %% [markdown]
# # P1 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_1.index:
    # Extract market excess return for the date
    x = returns_2023.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_1.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2023-01-06              0.026304                -0.000124
# 2023-01-13             -0.013221                -0.013554
# 2023-01-20             -0.040366                -0.036749
# 2023-01-27             -0.014982                -0.042571
# 2023-02-03             -0.027904                -0.037941

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 1': monthly_portfolio_excess_return, 'Beta 1': x1_coefficient, 'Adjusted Beta 1': adj, "Residual Variance 1": residual_variance})

# Convert the list to a DataFrame
coefficients_df_port1 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port1
# Out:
# -0.023249278952569598
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.642
# Model:                                 OLS   Adj. R-squared:                  0.462
# Method:                      Least Squares   F-statistic:                     3.580
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.199
# Time:                             18:54:20   Log-Likelihood:                 12.626
# No. Observations:                        4   AIC:                            -21.25
# Df Residuals:                            2   BIC:                            -22.48
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0171      0.008     -2.151      0.164      -0.051       0.017
# Market Excess Return     0.5781      0.306      1.892      0.199      -0.736       1.893
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.331
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.497
# Skew:                          -0.741   Prob(JB):                        0.780
# Kurtosis:                       2.113   Cond. No.                         41.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.6711322196506803e-08
# -0.04847225662772103
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.933
# Model:                                 OLS   Adj. R-squared:                  0.899
# Method:                      Least Squares   F-statistic:                     27.83
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0341
# Time:                             18:54:20   Log-Likelihood:                 16.737
# No. Observations:                        4   AIC:                            -29.47
# Df Residuals:                            2   BIC:                            -30.70
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0183      0.006     -2.917      0.100      -0.045       0.009
# Market Excess Return     0.6830      0.129      5.275      0.034       0.126       1.240
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.977
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.284
# Skew:                           0.445   Prob(JB):                        0.868
# Kurtosis:                       2.044   Cond. No.                         49.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.570736185873732e-10
# -0.04565953268952227
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.896
# Model:                                 OLS   Adj. R-squared:                  0.861
# Method:                      Least Squares   F-statistic:                     25.75
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0148
# Time:                             18:54:20   Log-Likelihood:                 19.703
# No. Observations:                        5   AIC:                            -35.41
# Df Residuals:                            3   BIC:                            -36.19
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0287      0.004     -6.657      0.007      -0.042      -0.015
# Market Excess Return     0.3445      0.068      5.075      0.015       0.128       0.561
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.101
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.565
# Skew:                           0.303   Prob(JB):                        0.754
# Kurtosis:                       1.469   Cond. No.                         25.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.8677547424513386e-10
# -0.04830924356792986
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.005
# Model:                                 OLS   Adj. R-squared:                 -0.492
# Method:                      Least Squares   F-statistic:                   0.01049
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.928
# Time:                             18:54:20   Log-Likelihood:                 11.458
# No. Observations:                        4   AIC:                            -18.92
# Df Residuals:                            2   BIC:                            -20.14
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0514      0.032     -1.599      0.251      -0.190       0.087
# Market Excess Return    -0.0581      0.567     -0.102      0.928      -2.499       2.383
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.516
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.809
# Skew:                           1.030   Prob(JB):                        0.667
# Kurtosis:                       2.221   Cond. No.                         58.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.89864165091902e-08
# -0.06530236242176521
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.894
# Model:                                 OLS   Adj. R-squared:                  0.841
# Method:                      Least Squares   F-statistic:                     16.81
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0547
# Time:                             18:54:20   Log-Likelihood:                 13.873
# No. Observations:                        4   AIC:                            -23.75
# Df Residuals:                            2   BIC:                            -24.97
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0116      0.019      0.594      0.613      -0.072       0.095
# Market Excess Return     1.2193      0.297      4.100      0.055      -0.060       2.499
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.648
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.220
# Skew:                          -0.193   Prob(JB):                        0.896
# Kurtosis:                       1.919   Cond. No.                         56.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.964251611711017e-09
# -0.05977554535980902
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.935
# Model:                                 OLS   Adj. R-squared:                  0.913
# Method:                      Least Squares   F-statistic:                     43.09
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00719
# Time:                             18:54:20   Log-Likelihood:                 19.627
# No. Observations:                        5   AIC:                            -35.25
# Df Residuals:                            3   BIC:                            -36.03
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0122      0.008     -1.569      0.215      -0.037       0.013
# Market Excess Return     0.9069      0.138      6.564      0.007       0.467       1.347
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.591
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.606
# Skew:                           0.145   Prob(JB):                        0.738
# Kurtosis:                       1.319   Cond. No.                         50.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.0732362938035425e-10
# -0.06780244734426619
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.844
# Model:                                 OLS   Adj. R-squared:                  0.765
# Method:                      Least Squares   F-statistic:                     10.79
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0815
# Time:                             18:54:20   Log-Likelihood:                 13.673
# No. Observations:                        4   AIC:                            -23.35
# Df Residuals:                            2   BIC:                            -24.57
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0106      0.018     -0.577      0.622      -0.089       0.068
# Market Excess Return     0.9860      0.300      3.285      0.082      -0.306       2.278
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.460
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.597
# Skew:                           0.815   Prob(JB):                        0.742
# Kurtosis:                       2.037   Cond. No.                         53.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.470004944417745e-09
# -0.07227322221462569
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.834
# Model:                                 OLS   Adj. R-squared:                  0.751
# Method:                      Least Squares   F-statistic:                     10.04
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0869
# Time:                             18:54:20   Log-Likelihood:                 12.000
# No. Observations:                        4   AIC:                            -20.00
# Df Residuals:                            2   BIC:                            -21.23
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0423      0.037      1.138      0.373      -0.118       0.202
# Market Excess Return     1.4867      0.469      3.168      0.087      -0.533       3.506
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.398
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.581
# Skew:                           0.783   Prob(JB):                        0.748
# Kurtosis:                       1.983   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.762082626508625e-08
# -0.07954507971930248
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.542
# Model:                                 OLS   Adj. R-squared:                  0.390
# Method:                      Least Squares   F-statistic:                     3.556
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.156
# Time:                             18:54:20   Log-Likelihood:                 13.663
# No. Observations:                        5   AIC:                            -23.33
# Df Residuals:                            3   BIC:                            -24.11
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0029      0.042     -0.069      0.949      -0.135       0.130
# Market Excess Return     1.0526      0.558      1.886      0.156      -0.724       2.829
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.253
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.592
# Skew:                           0.657   Prob(JB):                        0.744
# Kurtosis:                       1.944   Cond. No.                         61.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 7.242499087954525e-08
# -0.08411090230591003
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.833
# Model:                                 OLS   Adj. R-squared:                  0.750
# Method:                      Least Squares   F-statistic:                     10.00
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0871
# Time:                             18:54:20   Log-Likelihood:                 14.665
# No. Observations:                        4   AIC:                            -25.33
# Df Residuals:                            2   BIC:                            -26.56
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0152      0.022     -0.683      0.565      -0.111       0.080
# Market Excess Return     0.8363      0.264      3.162      0.087      -0.302       1.974
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.002
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.659
# Skew:                           0.008   Prob(JB):                        0.719
# Kurtosis:                       1.011   Cond. No.                         60.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.2422409347681198e-11
# -0.05451695858467506
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.975
# Model:                                 OLS   Adj. R-squared:                  0.962
# Method:                      Least Squares   F-statistic:                     76.69
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0128
# Time:                             18:54:20   Log-Likelihood:                 15.958
# No. Observations:                        4   AIC:                            -27.92
# Df Residuals:                            2   BIC:                            -29.14
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0076      0.008      0.976      0.432      -0.026       0.041
# Market Excess Return     1.1289      0.129      8.757      0.013       0.574       1.684
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.225
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.283
# Skew:                          -0.000   Prob(JB):                        0.868
# Kurtosis:                       1.697   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.7353015128671346e-10
# -0.060821469782125034
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.480
# Model:                                 OLS   Adj. R-squared:                  0.306
# Method:                      Least Squares   F-statistic:                     2.767
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.195
# Time:                             18:54:20   Log-Likelihood:                 18.824
# No. Observations:                        5   AIC:                            -33.65
# Df Residuals:                            3   BIC:                            -34.43
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0159      0.027     -0.583      0.601      -0.102       0.071
# Market Excess Return     0.6970      0.419      1.663      0.195      -0.637       2.031
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.671
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.598
# Skew:                           0.094   Prob(JB):                        0.742
# Kurtosis:                       1.317   Cond. No.                         130.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.9131288791156e-10
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 1    Beta 1  Adjusted Beta 1  \
# 0     01                  -0.023249  0.578055         0.718703
# 1     02                  -0.048472  0.682966         0.788644
# 2     03                  -0.045660  0.344527         0.563018
# 3     04                  -0.048309 -0.058099         0.294601
# 4     05                  -0.065302  1.219324         1.146216
# 5     06                  -0.059776  0.906935         0.937957
# 6     07                  -0.067802  0.986044         0.990696
# 7     08                  -0.072273  1.486689         1.324460
# 8     09                  -0.079545  1.052645         1.035097
# 9     10                  -0.084111  0.836287         0.890858
# 10    11                  -0.054517  1.128934         1.085956
# 11    12                  -0.060821  0.697005         0.798003
#
#     Residual Variance 1
# 0          1.671132e-08
# 1          2.570736e-10
# 2          2.867755e-10
# 3          5.898642e-08
# 4          3.964252e-09
# 5          2.073236e-10
# 6          5.470005e-09
# 7          2.762083e-08
# 8          7.242499e-08
# 9          2.242241e-11
# 10         3.735302e-10
# 11         3.913129e-10

# %% [markdown]
# # P2 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_2.index:
    # Extract market excess return for the date
    x = returns_2023.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_2.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2023-01-06              0.026304                 0.001185
# 2023-01-13             -0.013221                 0.002722
# 2023-01-20             -0.040366                -0.033216
# 2023-01-27             -0.014982                -0.008518
# 2023-02-03             -0.027904                -0.037741

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 2': monthly_portfolio_excess_return, 'Beta 2': x1_coefficient, 'Adjusted Beta 2': adj, "Residual Variance 2": residual_variance})

# Convert the list to a DataFrame
coefficients_df_port2 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port2
# Out:
# -0.009456829298172374
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.602
# Model:                                 OLS   Adj. R-squared:                  0.403
# Method:                      Least Squares   F-statistic:                     3.024
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.224
# Time:                             18:54:45   Log-Likelihood:                 13.135
# No. Observations:                        4   AIC:                            -22.27
# Df Residuals:                            2   BIC:                            -23.50
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0045      0.007     -0.643      0.586      -0.035       0.026
# Market Excess Return     0.4679      0.269      1.739      0.224      -0.690       1.625
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.358
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.430
# Skew:                           0.405   Prob(JB):                        0.807
# Kurtosis:                       1.614   Cond. No.                         41.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 5.543123534747832e-09
# -0.05041596017702527
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.974
# Model:                                 OLS   Adj. R-squared:                  0.961
# Method:                      Least Squares   F-statistic:                     74.57
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0131
# Time:                             18:54:45   Log-Likelihood:                 18.627
# No. Observations:                        4   AIC:                            -33.25
# Df Residuals:                            2   BIC:                            -34.48
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0196      0.004     -5.017      0.038      -0.036      -0.003
# Market Excess Return     0.6970      0.081      8.636      0.013       0.350       1.044
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.044
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.735
# Skew:                          -0.968   Prob(JB):                        0.693
# Kurtosis:                       2.186   Cond. No.                         49.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.412357011563099e-11
# -0.04896307652820392
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.952
# Model:                                 OLS   Adj. R-squared:                  0.936
# Method:                      Least Squares   F-statistic:                     59.34
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00455
# Time:                             18:54:45   Log-Likelihood:                 18.209
# No. Observations:                        5   AIC:                            -32.42
# Df Residuals:                            3   BIC:                            -33.20
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0142      0.006     -2.448      0.092      -0.033       0.004
# Market Excess Return     0.7051      0.092      7.703      0.005       0.414       0.996
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.350
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.437
# Skew:                          -0.415   Prob(JB):                        0.804
# Kurtosis:                       1.814   Cond. No.                         25.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.6440787279702165e-09
# -0.05023237190709479
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.800
# Model:                                 OLS   Adj. R-squared:                  0.701
# Method:                      Least Squares   F-statistic:                     8.024
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.105
# Time:                             18:54:45   Log-Likelihood:                 15.164
# No. Observations:                        4   AIC:                            -26.33
# Df Residuals:                            2   BIC:                            -27.55
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0158      0.013     -1.244      0.339      -0.071       0.039
# Market Excess Return     0.6363      0.225      2.833      0.105      -0.330       1.603
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.658
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.840
# Skew:                           1.062   Prob(JB):                        0.657
# Kurtosis:                       2.273   Cond. No.                         58.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.511116029153266e-09
# -0.06307399135304463
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.756
# Model:                                 OLS   Adj. R-squared:                  0.633
# Method:                      Least Squares   F-statistic:                     6.181
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.131
# Time:                             18:54:45   Log-Likelihood:                 12.151
# No. Observations:                        4   AIC:                            -20.30
# Df Residuals:                            2   BIC:                            -21.53
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0086      0.030      0.287      0.801      -0.120       0.138
# Market Excess Return     1.1371      0.457      2.486      0.131      -0.831       3.105
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.353
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.423
# Skew:                           0.520   Prob(JB):                        0.810
# Kurtosis:                       1.793   Cond. No.                         56.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.9150410478229228e-08
# -0.05777935672379066
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.858
# Model:                                 OLS   Adj. R-squared:                  0.811
# Method:                      Least Squares   F-statistic:                     18.12
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0238
# Time:                             18:54:45   Log-Likelihood:                 17.758
# No. Observations:                        5   AIC:                            -31.52
# Df Residuals:                            3   BIC:                            -32.30
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0129      0.011     -1.146      0.335      -0.049       0.023
# Market Excess Return     0.8547      0.201      4.257      0.024       0.216       1.494
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.614
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.557
# Skew:                           0.108   Prob(JB):                        0.757
# Kurtosis:                       1.379   Cond. No.                         50.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.0988970681071283e-09
# -0.055392733401301394
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.992
# Model:                                 OLS   Adj. R-squared:                  0.988
# Method:                      Least Squares   F-statistic:                     246.5
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00403
# Time:                             18:54:45   Log-Likelihood:                 19.028
# No. Observations:                        4   AIC:                            -34.06
# Df Residuals:                            2   BIC:                            -35.28
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0164      0.005      3.407      0.076      -0.004       0.037
# Market Excess Return     1.2358      0.079     15.702      0.004       0.897       1.574
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.451
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.551
# Skew:                          -0.758   Prob(JB):                        0.759
# Kurtosis:                       1.996   Cond. No.                         53.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.481516159146027e-11
# -0.07058029976916351
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.921
# Model:                                 OLS   Adj. R-squared:                  0.881
# Method:                      Least Squares   F-statistic:                     23.30
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0403
# Time:                             18:54:45   Log-Likelihood:                 15.557
# No. Observations:                        4   AIC:                            -27.11
# Df Residuals:                            2   BIC:                            -28.34
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0011      0.015      0.075      0.947      -0.065       0.067
# Market Excess Return     0.9309      0.193      4.827      0.040       0.101       1.761
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.670
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.357
# Skew:                          -0.537   Prob(JB):                        0.836
# Kurtosis:                       2.004   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.043777260364048e-10
# -0.07331917623432394
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.778
# Model:                                 OLS   Adj. R-squared:                  0.703
# Method:                      Least Squares   F-statistic:                     10.49
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0479
# Time:                             18:54:45   Log-Likelihood:                 16.458
# No. Observations:                        5   AIC:                            -28.92
# Df Residuals:                            3   BIC:                            -29.70
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0020      0.024      0.083      0.939      -0.074       0.078
# Market Excess Return     1.0338      0.319      3.239      0.048       0.018       2.050
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.447
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.248
# Skew:                           0.005   Prob(JB):                        0.883
# Kurtosis:                       1.909   Cond. No.                         61.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 7.457856316689707e-09
# -0.08210963770764124
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.990
# Model:                                 OLS   Adj. R-squared:                  0.985
# Method:                      Least Squares   F-statistic:                     198.8
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00499
# Time:                             18:54:45   Log-Likelihood:                 20.700
# No. Observations:                        4   AIC:                            -37.40
# Df Residuals:                            2   BIC:                            -38.63
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0141      0.005     -2.876      0.103      -0.035       0.007
# Market Excess Return     0.8247      0.058     14.098      0.005       0.573       1.076
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.831
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.622
# Skew:                          -0.833   Prob(JB):                        0.733
# Kurtosis:                       2.020   Cond. No.                         60.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.7689391948674905e-12
# -0.054998804241852245
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.973
# Model:                                 OLS   Adj. R-squared:                  0.960
# Method:                      Least Squares   F-statistic:                     72.72
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0135
# Time:                             18:54:45   Log-Likelihood:                 17.309
# No. Observations:                        4   AIC:                            -30.62
# Df Residuals:                            2   BIC:                            -31.84
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0119      0.006     -2.140      0.166      -0.036       0.012
# Market Excess Return     0.7844      0.092      8.528      0.013       0.389       1.180
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.853
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.369
# Skew:                           0.583   Prob(JB):                        0.831
# Kurtosis:                       2.076   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.4958264975999562e-10
# -0.06523167343519894
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.018
# Model:                                 OLS   Adj. R-squared:                 -0.309
# Method:                      Least Squares   F-statistic:                   0.05614
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.828
# Time:                             18:54:45   Log-Likelihood:                 15.884
# No. Observations:                        5   AIC:                            -27.77
# Df Residuals:                            3   BIC:                            -28.55
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0768      0.049     -1.567      0.215      -0.233       0.079
# Market Excess Return    -0.1788      0.754     -0.237      0.828      -2.580       2.222
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.746
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.884
# Skew:                           1.011   Prob(JB):                        0.643
# Kurtosis:                       2.611   Cond. No.                         130.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 2.0911138223445328e-08
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 2    Beta 2  Adjusted Beta 2  \
# 0     01                  -0.009457  0.467869         0.645246
# 1     02                  -0.050416  0.697047         0.798031
# 2     03                  -0.048963  0.705102         0.803401
# 3     04                  -0.050232  0.636324         0.757549
# 4     05                  -0.063074  1.137066         1.091378
# 5     06                  -0.057779  0.854745         0.903163
# 6     07                  -0.055393  1.235826         1.157218
# 7     08                  -0.070580  0.930891         0.953927
# 8     09                  -0.073319  1.033778         1.022519
# 9     10                  -0.082110  0.824677         0.883118
# 10    11                  -0.054999  0.784365         0.856244
# 11    12                  -0.065232 -0.178756         0.214163
#
#     Residual Variance 2
# 0          5.543124e-09
# 1          4.412357e-11
# 2          1.644079e-09
# 3          1.511116e-09
# 4          1.915041e-08
# 5          1.098897e-09
# 6          2.481516e-11
# 7          8.043777e-10
# 8          7.457856e-09
# 9          4.768939e-12
# 10         1.495826e-10
# 11         2.091114e-08

# %% [markdown]
# # P3 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_3.index:
    # Extract market excess return for the date
    x = returns_2023.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_3.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2023-01-06              0.026304                 0.000117
# 2023-01-13             -0.013221                -0.013752
# 2023-01-20             -0.040366                -0.041482
# 2023-01-27             -0.014982                -0.025424
# 2023-02-03             -0.027904                -0.027343

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 3': monthly_portfolio_excess_return, 'Beta 3': x1_coefficient, 'Adjusted Beta 3': adj, "Residual Variance 3" : residual_variance})

# Convert the list to a DataFrame
coefficients_df_port3 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port3
# Out:
# -0.02013522869300212
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.908
# Model:                                 OLS   Adj. R-squared:                  0.862
# Method:                      Least Squares   F-statistic:                     19.78
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0470
# Time:                             18:55:08   Log-Likelihood:                 15.823
# No. Observations:                        4   AIC:                            -27.65
# Df Residuals:                            2   BIC:                            -28.87
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0137      0.004     -3.819      0.062      -0.029       0.002
# Market Excess Return     0.6109      0.137      4.447      0.047       0.020       1.202
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.682
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.942
# Skew:                           1.139   Prob(JB):                        0.624
# Kurtosis:                       2.322   Cond. No.                         41.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.111457180273602e-10
# -0.04885462396676363
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.658
# Model:                                 OLS   Adj. R-squared:                  0.487
# Method:                      Least Squares   F-statistic:                     3.845
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.189
# Time:                             18:55:08   Log-Likelihood:                 11.003
# No. Observations:                        4   AIC:                            -18.01
# Df Residuals:                            2   BIC:                            -19.23
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0019      0.026     -0.071      0.950      -0.115       0.111
# Market Excess Return     1.0644      0.543      1.961      0.189      -1.271       3.400
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   3.019
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.405
# Skew:                          -0.631   Prob(JB):                        0.817
# Kurtosis:                       2.086   Cond. No.                         49.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.264736782192297e-08
# -0.052985800842674555
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.977
# Model:                                 OLS   Adj. R-squared:                  0.970
# Method:                      Least Squares   F-statistic:                     129.8
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00145
# Time:                             18:55:08   Log-Likelihood:                 17.544
# No. Observations:                        5   AIC:                            -31.09
# Df Residuals:                            3   BIC:                            -31.87
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0057      0.007      0.862      0.452      -0.015       0.027
# Market Excess Return     1.1913      0.105     11.393      0.001       0.859       1.524
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.925
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.459
# Skew:                           0.602   Prob(JB):                        0.795
# Kurtosis:                       2.132   Cond. No.                         25.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.895619077251573e-09
# -0.05138848728654456
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.797
# Model:                                 OLS   Adj. R-squared:                  0.696
# Method:                      Least Squares   F-statistic:                     7.854
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.107
# Time:                             18:55:08   Log-Likelihood:                 13.902
# No. Observations:                        4   AIC:                            -23.80
# Df Residuals:                            2   BIC:                            -25.03
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0048      0.017     -0.273      0.811      -0.080       0.070
# Market Excess Return     0.8629      0.308      2.803      0.107      -0.462       2.188
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.006
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.565
# Skew:                          -0.763   Prob(JB):                        0.754
# Kurtosis:                       1.970   Cond. No.                         58.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.065354837965188e-09
# -0.0660133103248755
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.522
# Model:                                 OLS   Adj. R-squared:                  0.283
# Method:                      Least Squares   F-statistic:                     2.186
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.277
# Time:                             18:55:08   Log-Likelihood:                 12.921
# No. Observations:                        4   AIC:                            -21.84
# Df Residuals:                            2   BIC:                            -23.07
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0308      0.025     -1.247      0.339      -0.137       0.076
# Market Excess Return     0.5578      0.377      1.478      0.277      -1.066       2.181
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.363
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.431
# Skew:                          -0.542   Prob(JB):                        0.806
# Kurtosis:                       1.814   Cond. No.                         56.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 9.09833890536886e-09
# -0.05659011854287175
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.942
# Model:                                 OLS   Adj. R-squared:                  0.922
# Method:                      Least Squares   F-statistic:                     48.50
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00607
# Time:                             18:55:09   Log-Likelihood:                 17.948
# No. Observations:                        5   AIC:                            -31.90
# Df Residuals:                            3   BIC:                            -32.68
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0141      0.011      1.296      0.286      -0.020       0.049
# Market Excess Return     1.3462      0.193      6.965      0.006       0.731       1.961
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   0.568
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.750
# Skew:                           0.461   Prob(JB):                        0.687
# Kurtosis:                       1.343   Cond. No.                         50.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.533665630281235e-10
# -0.05650550510480717
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.996
# Model:                                 OLS   Adj. R-squared:                  0.994
# Method:                      Least Squares   F-statistic:                     503.9
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00198
# Time:                             18:55:09   Log-Likelihood:                 20.501
# No. Observations:                        4   AIC:                            -37.00
# Df Residuals:                            2   BIC:                            -38.23
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0145      0.003      4.355      0.049       0.000       0.029
# Market Excess Return     1.2224      0.054     22.448      0.002       0.988       1.457
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.118
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.343
# Skew:                          -0.069   Prob(JB):                        0.842
# Kurtosis:                       1.572   Cond. No.                         53.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.264022491050071e-12
# -0.07767819668608862
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.997
# Model:                                 OLS   Adj. R-squared:                  0.996
# Method:                      Least Squares   F-statistic:                     678.8
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00147
# Time:                             18:55:09   Log-Likelihood:                 22.750
# No. Observations:                        4   AIC:                            -41.50
# Df Residuals:                            2   BIC:                            -42.73
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0136      0.003     -5.368      0.033      -0.024      -0.003
# Market Excess Return     0.8320      0.032     26.055      0.001       0.695       0.969
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.462
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.775
# Skew:                           1.001   Prob(JB):                        0.679
# Kurtosis:                       2.197   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 7.205614449605023e-13
# -0.07681082821493654
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.899
# Model:                                 OLS   Adj. R-squared:                  0.865
# Method:                      Least Squares   F-statistic:                     26.59
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0141
# Time:                             18:55:09   Log-Likelihood:                 19.475
# No. Observations:                        5   AIC:                            -34.95
# Df Residuals:                            3   BIC:                            -35.73
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0113      0.013     -0.864      0.451      -0.053       0.030
# Market Excess Return     0.9002      0.175      5.157      0.014       0.345       1.456
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.402
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.297
# Skew:                          -0.528   Prob(JB):                        0.862
# Kurtosis:                       2.441   Cond. No.                         61.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.0574265861226062e-09
# -0.09589224076418178
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.620
# Model:                                 OLS   Adj. R-squared:                  0.430
# Method:                      Least Squares   F-statistic:                     3.265
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.213
# Time:                             18:55:09   Log-Likelihood:                 13.905
# No. Observations:                        4   AIC:                            -23.81
# Df Residuals:                            2   BIC:                            -25.04
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0483      0.027     -1.796      0.214      -0.164       0.067
# Market Excess Return     0.5778      0.320      1.807      0.213      -0.798       1.954
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.664
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.464
# Skew:                          -0.580   Prob(JB):                        0.793
# Kurtosis:                       1.800   Cond. No.                         60.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.3406732050727447e-09
# -0.056180161469185946
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.876
# Model:                                 OLS   Adj. R-squared:                  0.814
# Method:                      Least Squares   F-statistic:                     14.09
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0642
# Time:                             18:55:09   Log-Likelihood:                 12.235
# No. Observations:                        4   AIC:                            -20.47
# Df Residuals:                            2   BIC:                            -21.70
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0113      0.020      0.575      0.623      -0.073       0.096
# Market Excess Return     1.2273      0.327      3.753      0.064      -0.180       2.634
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.492
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.417
# Skew:                          -0.334   Prob(JB):                        0.812
# Kurtosis:                       1.567   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.2596813716353445e-08
# -0.05579701825583037
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.011
# Model:                                 OLS   Adj. R-squared:                 -0.319
# Method:                      Least Squares   F-statistic:                   0.03273
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.868
# Time:                             18:55:09   Log-Likelihood:                 14.356
# No. Observations:                        5   AIC:                            -24.71
# Df Residuals:                            3   BIC:                            -25.49
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0438      0.067     -0.659      0.557      -0.256       0.168
# Market Excess Return     0.1853      1.024      0.181      0.868      -3.074       3.444
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.726
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.695
# Skew:                           0.704   Prob(JB):                        0.706
# Kurtosis:                       1.836   Cond. No.                         130.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.6853958868621786e-08
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 3    Beta 3  Adjusted Beta 3  \
# 0     01                  -0.020135  0.610919         0.740613
# 1     02                  -0.048855  1.064450         1.042967
# 2     03                  -0.052986  1.191288         1.127525
# 3     04                  -0.051388  0.862913         0.908609
# 4     05                  -0.066013  0.557799         0.705199
# 5     06                  -0.056590  1.346221         1.230814
# 6     07                  -0.056506  1.222438         1.148292
# 7     08                  -0.077678  0.831971         0.887981
# 8     09                  -0.076811  0.900178         0.933452
# 9     10                  -0.095892  0.577829         0.718553
# 10    11                  -0.056180  1.227319         1.151546
# 11    12                  -0.055797  0.185264         0.456843
#
#     Residual Variance 3
# 0          8.111457e-10
# 1          8.264737e-08
# 2          3.895619e-09
# 3          4.065355e-09
# 4          9.098339e-09
# 5          8.533666e-10
# 6          3.264022e-12
# 7          7.205614e-13
# 8          1.057427e-09
# 9          3.340673e-09
# 10         1.259681e-08
# 11         3.685396e-08

# %% [markdown]
# # P4 #

# %%
# Initialize an empty list to store data
data = []

# Iterate over each date
for date in p_4.index:
    # Extract market excess return for the date
    x = returns_2023.loc[date, 'Risk Premium']  # Market excess return
    
    # Extract portfolio excess return for the date and calculate mean
    y = p_4.loc[date].mean()  # Portfolio excess return
    
    # Append the values to the data list
    data.append({'Date': date, 'Market Excess Return': x, 'Portfolio Excess Return': y})

# Create DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Set Date column as index
df.set_index('Date', inplace=True)

# Display the DataFrame
df.head()
# Out:
#             Market Excess Return  Portfolio Excess Return
# Date
# 2023-01-06              0.026304                 0.035194
# 2023-01-13             -0.013221                -0.018022
# 2023-01-20             -0.040366                -0.025058
# 2023-01-27             -0.014982                 0.002222
# 2023-02-03             -0.027904                 0.007418

# %%
import pandas as pd
import statsmodels.api as sm

# Create an empty list to store the coefficients
coefficients_data = []

# Iterate over each month
for month, group in df.groupby(pd.Grouper(freq='M')):
    # Extract the month's data
    monthly_data = group
    
    # Define independent and dependent variables
    X = monthly_data['Market Excess Return']  # Independent variable
    y = monthly_data['Portfolio Excess Return']  # Dependent variable

    monthly_portfolio_excess_return = monthly_data['Portfolio Excess Return'].values.mean()
    print(monthly_portfolio_excess_return)
    
    # Add constant to independent variables
    X = sm.add_constant(X)
    
    # Fit OLS model
    model = sm.OLS(y, X)
    results = model.fit()

    print(results.summary())

    # Extract the residuals from the regression results
    residuals = results.resid

    # Square the residuals to get the squared residuals
    squared_residuals = residuals ** 2

    # Calculate the variance of the squared residuals
    residual_variance = squared_residuals.var()

    print("Residual Variance:", residual_variance)
    
    
    # Store the coefficient for X1 in the list
    x1_coefficient = results.params['Market Excess Return']
    adj = x1_coefficient * 2/3 + 1/3
    # Extract the month part from the datetime object
    month_str = str(month.month).zfill(2)  # Convert month to string and ensure it's zero-padded
    
    coefficients_data.append({'Month': month_str, 'Portfolio Excess Return 4': monthly_portfolio_excess_return, 'Beta 4': x1_coefficient, 'Adjusted Beta 4': adj, "Residual Variance 4" : residual_variance})

# Convert the list to a DataFrame
coefficients_df_port4 = pd.DataFrame(coefficients_data)

# Display the DataFrame with coefficients
coefficients_df_port4
# Out:
# -0.0014160745847141445
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.871
# Model:                                 OLS   Adj. R-squared:                  0.807
# Method:                      Least Squares   F-statistic:                     13.56
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0665
# Time:                             18:55:23   Log-Likelihood:                 13.449
# No. Observations:                        4   AIC:                            -22.90
# Df Residuals:                            2   BIC:                            -24.13
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0083      0.006      1.273      0.331      -0.020       0.036
# Market Excess Return     0.9157      0.249      3.682      0.066      -0.154       1.986
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.217
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.746
# Skew:                          -0.985   Prob(JB):                        0.689
# Kurtosis:                       2.229   Cond. No.                         41.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.102223914662449e-09
# -0.02843693654938912
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.704
# Model:                                 OLS   Adj. R-squared:                  0.557
# Method:                      Least Squares   F-statistic:                     4.765
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.161
# Time:                             18:55:23   Log-Likelihood:                 11.483
# No. Observations:                        4   AIC:                            -18.97
# Df Residuals:                            2   BIC:                            -20.19
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0180      0.023      0.769      0.522      -0.083       0.118
# Market Excess Return     1.0510      0.481      2.183      0.161      -1.021       3.123
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.341
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.214
# Skew:                          -0.054   Prob(JB):                        0.898
# Kurtosis:                       1.871   Cond. No.                         49.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.102314097220455e-08
# -0.060263090095520847
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.989
# Model:                                 OLS   Adj. R-squared:                  0.985
# Method:                      Least Squares   F-statistic:                     258.0
# Date:                     Sat, 04 May 2024   Prob (F-statistic):           0.000525
# Time:                             18:55:23   Log-Likelihood:                 18.077
# No. Observations:                        5   AIC:                            -32.15
# Df Residuals:                            3   BIC:                            -32.94
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0141      0.006      2.367      0.099      -0.005       0.033
# Market Excess Return     1.5094      0.094     16.061      0.001       1.210       1.809
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.658
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.424
# Skew:                          -0.198   Prob(JB):                        0.809
# Kurtosis:                       1.630   Cond. No.                         25.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.4139438183386365e-09
# -0.0493539605259435
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.919
# Model:                                 OLS   Adj. R-squared:                  0.879
# Method:                      Least Squares   F-statistic:                     22.75
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0413
# Time:                             18:55:23   Log-Likelihood:                 13.139
# No. Observations:                        4   AIC:                            -22.28
# Df Residuals:                            2   BIC:                            -23.51
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0467      0.021      2.209      0.158      -0.044       0.138
# Market Excess Return     1.7773      0.373      4.770      0.041       0.174       3.381
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.653
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.240
# Skew:                          -0.144   Prob(JB):                        0.887
# Kurtosis:                       1.836   Cond. No.                         58.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 7.50984588329088e-09
# -0.06830450247819092
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.926
# Model:                                 OLS   Adj. R-squared:                  0.889
# Method:                      Least Squares   F-statistic:                     25.10
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0376
# Time:                             18:55:23   Log-Likelihood:                 13.966
# No. Observations:                        4   AIC:                            -23.93
# Df Residuals:                            2   BIC:                            -25.16
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0235      0.019      1.233      0.343      -0.058       0.105
# Market Excess Return     1.4558      0.291      5.010      0.038       0.206       2.706
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.062
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.481
# Skew:                          -0.053   Prob(JB):                        0.786
# Kurtosis:                       1.304   Cond. No.                         56.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 1.1961621275358824e-09
# -0.0524515771571676
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.921
# Model:                                 OLS   Adj. R-squared:                  0.895
# Method:                      Least Squares   F-statistic:                     35.11
# Date:                     Sat, 04 May 2024   Prob (F-statistic):            0.00960
# Time:                             18:55:23   Log-Likelihood:                 19.138
# No. Observations:                        5   AIC:                            -34.28
# Df Residuals:                            3   BIC:                            -35.06
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0051      0.009     -0.593      0.595      -0.032       0.022
# Market Excess Return     0.9027      0.152      5.926      0.010       0.418       1.388
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.830
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.403
# Skew:                          -0.446   Prob(JB):                        0.817
# Kurtosis:                       1.932   Cond. No.                         50.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.958699333526405e-10
# -0.049368358091432404
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.947
# Model:                                 OLS   Adj. R-squared:                  0.921
# Method:                      Least Squares   F-statistic:                     35.83
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0268
# Time:                             18:55:23   Log-Likelihood:                 17.857
# No. Observations:                        4   AIC:                            -31.71
# Df Residuals:                            2   BIC:                            -32.94
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0127      0.006     -1.977      0.187      -0.040       0.015
# Market Excess Return     0.6313      0.105      5.986      0.027       0.178       1.085
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.306
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.803
# Skew:                          -1.029   Prob(JB):                        0.669
# Kurtosis:                       2.234   Cond. No.                         53.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 9.913973964225112e-11
# -0.08043322662392571
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.929
# Model:                                 OLS   Adj. R-squared:                  0.893
# Method:                      Least Squares   F-statistic:                     26.09
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0363
# Time:                             18:55:23   Log-Likelihood:                 16.475
# No. Observations:                        4   AIC:                            -28.95
# Df Residuals:                            2   BIC:                            -30.18
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0201      0.012     -1.657      0.239      -0.072       0.032
# Market Excess Return     0.7830      0.153      5.108      0.036       0.123       1.443
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.950
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.577
# Skew:                          -0.052   Prob(JB):                        0.749
# Kurtosis:                       1.142   Cond. No.                         55.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 4.556630610839864e-11
# -0.06659922885618848
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.726
# Model:                                 OLS   Adj. R-squared:                  0.634
# Method:                      Least Squares   F-statistic:                     7.943
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0668
# Time:                             18:55:23   Log-Likelihood:                 14.499
# No. Observations:                        5   AIC:                            -25.00
# Df Residuals:                            3   BIC:                            -25.78
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0303      0.035      0.861      0.453      -0.082       0.142
# Market Excess Return     1.3309      0.472      2.818      0.067      -0.172       2.834
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.422
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.839
# Skew:                           0.982   Prob(JB):                        0.657
# Kurtosis:                       2.584   Cond. No.                         61.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 6.227358084236808e-08
# -0.07735478376954735
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.722
# Model:                                 OLS   Adj. R-squared:                  0.584
# Method:                      Least Squares   F-statistic:                     5.205
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.150
# Time:                             18:55:23   Log-Likelihood:                 14.009
# No. Observations:                        4   AIC:                            -24.02
# Df Residuals:                            2   BIC:                            -25.24
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0188      0.026     -0.716      0.548      -0.131       0.094
# Market Excess Return     0.7110      0.312      2.282      0.150      -0.630       2.052
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.425
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.463
# Skew:                           0.686   Prob(JB):                        0.793
# Kurtosis:                       2.053   Cond. No.                         60.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 3.968678384361664e-09
# -0.04784902229188291
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.972
# Model:                                 OLS   Adj. R-squared:                  0.958
# Method:                      Least Squares   F-statistic:                     69.56
# Date:                     Sat, 04 May 2024   Prob (F-statistic):             0.0141
# Time:                             18:55:23   Log-Likelihood:                 15.704
# No. Observations:                        4   AIC:                            -27.41
# Df Residuals:                            2   BIC:                            -28.63
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                    0.0152      0.008      1.834      0.208      -0.020       0.051
# Market Excess Return     1.1459      0.137      8.340      0.014       0.555       1.737
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   1.341
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.188
# Skew:                          -0.121   Prob(JB):                        0.910
# Kurtosis:                       1.965   Cond. No.                         40.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 6.678597165829666e-10
# -0.06571490442027483
#                                OLS Regression Results
# ===================================================================================
# Dep. Variable:     Portfolio Excess Return   R-squared:                       0.164
# Model:                                 OLS   Adj. R-squared:                 -0.114
# Method:                      Least Squares   F-statistic:                    0.5901
# Date:                     Sat, 04 May 2024   Prob (F-statistic):              0.498
# Time:                             18:55:23   Log-Likelihood:                 16.287
# No. Observations:                        5   AIC:                            -28.57
# Df Residuals:                            3   BIC:                            -29.36
# Df Model:                                1
# Covariance Type:                 nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   -0.0312      0.045     -0.691      0.539      -0.175       0.113
# Market Excess Return     0.5346      0.696      0.768      0.498      -1.680       2.750
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                   2.157
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                0.569
# Skew:                          -0.629   Prob(JB):                        0.752
# Kurtosis:                       1.929   Cond. No.                         130.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Residual Variance: 8.73895662456013e-09
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 4 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/statsmodels/stats/stattools.py:74: ValueWarning: omni_normtest is not valid with less than 8 observations; 5 samples were given.
#   warn("omni_normtest is not valid with less than 8 observations; %i "
#    Month  Portfolio Excess Return 4    Beta 4  Adjusted Beta 4  \
# 0     01                  -0.001416  0.915735         0.943823
# 1     02                  -0.028437  1.050985         1.033990
# 2     03                  -0.060263  1.509426         1.339617
# 3     04                  -0.049354  1.777341         1.518228
# 4     05                  -0.068305  1.455757         1.303838
# 5     06                  -0.052452  0.902745         0.935163
# 6     07                  -0.049368  0.631302         0.754201
# 7     08                  -0.080433  0.782951         0.855301
# 8     09                  -0.066599  1.330923         1.220615
# 9     10                  -0.077355  0.711041         0.807361
# 10    11                  -0.047849  1.145872         1.097248
# 11    12                  -0.065715  0.534634         0.689756
#
#     Residual Variance 4
# 0          8.102224e-09
# 1          4.102314e-08
# 2          1.413944e-09
# 3          7.509846e-09
# 4          1.196162e-09
# 5          8.958699e-10
# 6          9.913974e-11
# 7          4.556631e-11
# 8          6.227358e-08
# 9          3.968678e-09
# 10         6.678597e-10
# 11         8.738957e-09

# %%
merged_df = pd.merge(coefficients_df_port1, coefficients_df_port2, on="Month", how="inner")
merged_df = pd.merge(merged_df, coefficients_df_port3, on="Month", how="inner")
merged_df = pd.merge(merged_df, coefficients_df_port4, on="Month", how="inner")
merged_df
# Out:
#    Month  Portfolio Excess Return 1    Beta 1  Adjusted Beta 1  \
# 0     01                  -0.023249  0.578055         0.718703
# 1     02                  -0.048472  0.682966         0.788644
# 2     03                  -0.045660  0.344527         0.563018
# 3     04                  -0.048309 -0.058099         0.294601
# 4     05                  -0.065302  1.219324         1.146216
# 5     06                  -0.059776  0.906935         0.937957
# 6     07                  -0.067802  0.986044         0.990696
# 7     08                  -0.072273  1.486689         1.324460
# 8     09                  -0.079545  1.052645         1.035097
# 9     10                  -0.084111  0.836287         0.890858
# 10    11                  -0.054517  1.128934         1.085956
# 11    12                  -0.060821  0.697005         0.798003
#
#     Residual Variance 1  Portfolio Excess Return 2    Beta 2  Adjusted Beta 2  \
# 0          1.671132e-08                  -0.009457  0.467869         0.645246
# 1          2.570736e-10                  -0.050416  0.697047         0.798031
# 2          2.867755e-10                  -0.048963  0.705102         0.803401
# 3          5.898642e-08                  -0.050232  0.636324         0.757549
# 4          3.964252e-09                  -0.063074  1.137066         1.091378
# 5          2.073236e-10                  -0.057779  0.854745         0.903163
# 6          5.470005e-09                  -0.055393  1.235826         1.157218
# 7          2.762083e-08                  -0.070580  0.930891         0.953927
# 8          7.242499e-08                  -0.073319  1.033778         1.022519
# 9          2.242241e-11                  -0.082110  0.824677         0.883118
# 10         3.735302e-10                  -0.054999  0.784365         0.856244
# 11         3.913129e-10                  -0.065232 -0.178756         0.214163
#
#     Residual Variance 2  Portfolio Excess Return 3    Beta 3  Adjusted Beta 3  \
# 0          5.543124e-09                  -0.020135  0.610919         0.740613
# 1          4.412357e-11                  -0.048855  1.064450         1.042967
# 2          1.644079e-09                  -0.052986  1.191288         1.127525
# 3          1.511116e-09                  -0.051388  0.862913         0.908609
# 4          1.915041e-08                  -0.066013  0.557799         0.705199
# 5          1.098897e-09                  -0.056590  1.346221         1.230814
# 6          2.481516e-11                  -0.056506  1.222438         1.148292
# 7          8.043777e-10                  -0.077678  0.831971         0.887981
# 8          7.457856e-09                  -0.076811  0.900178         0.933452
# 9          4.768939e-12                  -0.095892  0.577829         0.718553
# 10         1.495826e-10                  -0.056180  1.227319         1.151546
# 11         2.091114e-08                  -0.055797  0.185264         0.456843
#
#     Residual Variance 3  Portfolio Excess Return 4    Beta 4  Adjusted Beta 4  \
# 0          8.111457e-10                  -0.001416  0.915735         0.943823
# 1          8.264737e-08                  -0.028437  1.050985         1.033990
# 2          3.895619e-09                  -0.060263  1.509426         1.339617
# 3          4.065355e-09                  -0.049354  1.777341         1.518228
# 4          9.098339e-09                  -0.068305  1.455757         1.303838
# 5          8.533666e-10                  -0.052452  0.902745         0.935163
# 6          3.264022e-12                  -0.049368  0.631302         0.754201
# 7          7.205614e-13                  -0.080433  0.782951         0.855301
# 8          1.057427e-09                  -0.066599  1.330923         1.220615
# 9          3.340673e-09                  -0.077355  0.711041         0.807361
# 10         1.259681e-08                  -0.047849  1.145872         1.097248
# 11         3.685396e-08                  -0.065715  0.534634         0.689756
#
#     Residual Variance 4
# 0          8.102224e-09
# 1          4.102314e-08
# 2          1.413944e-09
# 3          7.509846e-09
# 4          1.196162e-09
# 5          8.958699e-10
# 6          9.913974e-11
# 7          4.556631e-11
# 8          6.227358e-08
# 9          3.968678e-09
# 10         6.678597e-10
# 11         8.738957e-09

# %%
# Assuming your DataFrame is named df
new_df = merged_df[['Portfolio Excess Return 1', 'Adjusted Beta 1','Beta 1','Residual Variance 1']].copy()  # Selecting columns for Portfolio 1
new_df.columns = ['Portfolio Excess Return', 'Adjusted Beta','Beta','Residual Variance']  # Renaming columns

# Concatenating data for other portfolios
for i in range(2, 5):
    temp_df = merged_df[['Portfolio Excess Return {}'.format(i), 'Adjusted Beta {}'.format(i), 'Beta {}'.format(i), 'Residual Variance {}'.format(i) ]].copy()
    temp_df.columns = ['Portfolio Excess Return', 'Adjusted Beta','Beta', 'Residual Variance']
    new_df = pd.concat([new_df, temp_df], ignore_index=True)

new_df
# Out:
#     Portfolio Excess Return  Adjusted Beta      Beta  Residual Variance
# 0                 -0.023249       0.718703  0.578055       1.671132e-08
# 1                 -0.048472       0.788644  0.682966       2.570736e-10
# 2                 -0.045660       0.563018  0.344527       2.867755e-10
# 3                 -0.048309       0.294601 -0.058099       5.898642e-08
# 4                 -0.065302       1.146216  1.219324       3.964252e-09
# 5                 -0.059776       0.937957  0.906935       2.073236e-10
# 6                 -0.067802       0.990696  0.986044       5.470005e-09
# 7                 -0.072273       1.324460  1.486689       2.762083e-08
# 8                 -0.079545       1.035097  1.052645       7.242499e-08
# 9                 -0.084111       0.890858  0.836287       2.242241e-11
# 10                -0.054517       1.085956  1.128934       3.735302e-10
# 11                -0.060821       0.798003  0.697005       3.913129e-10
# 12                -0.009457       0.645246  0.467869       5.543124e-09
# 13                -0.050416       0.798031  0.697047       4.412357e-11
# 14                -0.048963       0.803401  0.705102       1.644079e-09
# 15                -0.050232       0.757549  0.636324       1.511116e-09
# 16                -0.063074       1.091378  1.137066       1.915041e-08
# 17                -0.057779       0.903163  0.854745       1.098897e-09
# 18                -0.055393       1.157218  1.235826       2.481516e-11
# 19                -0.070580       0.953927  0.930891       8.043777e-10
# 20                -0.073319       1.022519  1.033778       7.457856e-09
# 21                -0.082110       0.883118  0.824677       4.768939e-12
# 22                -0.054999       0.856244  0.784365       1.495826e-10
# 23                -0.065232       0.214163 -0.178756       2.091114e-08
# 24                -0.020135       0.740613  0.610919       8.111457e-10
# 25                -0.048855       1.042967  1.064450       8.264737e-08
# 26                -0.052986       1.127525  1.191288       3.895619e-09
# 27                -0.051388       0.908609  0.862913       4.065355e-09
# 28                -0.066013       0.705199  0.557799       9.098339e-09
# 29                -0.056590       1.230814  1.346221       8.533666e-10
# 30                -0.056506       1.148292  1.222438       3.264022e-12
# 31                -0.077678       0.887981  0.831971       7.205614e-13
# 32                -0.076811       0.933452  0.900178       1.057427e-09
# 33                -0.095892       0.718553  0.577829       3.340673e-09
# 34                -0.056180       1.151546  1.227319       1.259681e-08
# 35                -0.055797       0.456843  0.185264       3.685396e-08
# 36                -0.001416       0.943823  0.915735       8.102224e-09
# 37                -0.028437       1.033990  1.050985       4.102314e-08
# 38                -0.060263       1.339617  1.509426       1.413944e-09
# 39                -0.049354       1.518228  1.777341       7.509846e-09
# 40                -0.068305       1.303838  1.455757       1.196162e-09
# 41                -0.052452       0.935163  0.902745       8.958699e-10
# 42                -0.049368       0.754201  0.631302       9.913974e-11
# 43                -0.080433       0.855301  0.782951       4.556631e-11
# 44                -0.066599       1.220615  1.330923       6.227358e-08
# 45                -0.077355       0.807361  0.711041       3.968678e-09
# 46                -0.047849       1.097248  1.145872       6.678597e-10
# 47                -0.065715       0.689756  0.534634       8.738957e-09

# %%
# Normalize residual variance
residual_variance_mean = new_df['Residual Variance'].mean()
residual_variance_std = new_df['Residual Variance'].std()
normalized_residual_variance = (new_df['Residual Variance'] - residual_variance_mean) / residual_variance_std

# Replace the original column with the normalized values
new_df['Normalized Residual Variance'] = normalized_residual_variance

# %%
merged_df.columns
# Out:
# Index(['Month', 'Portfolio Excess Return 1', 'Beta 1', 'Adjusted Beta 1',
#        'Residual Variance 1', 'Portfolio Excess Return 2', 'Beta 2',
#        'Adjusted Beta 2', 'Residual Variance 2', 'Portfolio Excess Return 3',
#        'Beta 3', 'Adjusted Beta 3', 'Residual Variance 3',
#        'Portfolio Excess Return 4', 'Beta 4', 'Adjusted Beta 4',
#        'Residual Variance 4'],
#       dtype='object')

# %%
new_df.head()
# Out:
#    Portfolio Excess Return  Adjusted Beta      Beta  Residual Variance  \
# 0                -0.023249       0.718703  0.578055       1.671132e-08
# 1                -0.048472       0.788644  0.682966       2.570736e-10
# 2                -0.045660       0.563018  0.344527       2.867755e-10
# 3                -0.048309       0.294601 -0.058099       5.898642e-08
# 4                -0.065302       1.146216  1.219324       3.964252e-09
#
#    Normalized Residual Variance
# 0                      0.275721
# 1                     -0.543180
# 2                     -0.541702
# 3                      2.379681
# 4                     -0.358680

# %% [markdown]
# # SML #

# %%
import statsmodels.api as sm
import pandas as pd

x = new_df['Adjusted Beta'].values # Monthly  est. Adj Beta 2023

y = new_df['Portfolio Excess Return'].values # Monthly Portfolio excess return
    
   
    
# Add a constant to the independent variable (market excess return)
x = sm.add_constant(x)

print(x.shape)
    
# Fit OLS model
model = sm.OLS(y, x)
results = model.fit()
    
print(results.summary())
    
# Retrieve specific values from the model summary
inter = results.params[0]
risk_premium = results.params[1]  # Coefficient
p_value_1 = results.pvalues[1]  # P-value
p_value_2 = results.pvalues[0]
std_error_1 = results.bse[1]  # Standard error
std_error_2 = results.bse[0]
t_stat_x1 = results.tvalues[1]
t_stat_const = results.tvalues[0]

# Print the retrieved values
print("Intercept:", inter)
print("Risk premium (Coefficient):", risk_premium)
print("P-value x1:", p_value_1)
print("P-value const:", p_value_2)
print("Std. error x1:", std_error_1)
print("Std. error const :", std_error_2)
print("T-statistic for X1:", t_stat_x1)
print("T-statistic for const:", t_stat_const)
# Out:
# (48, 2)
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.7008
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.407
# Time:                        18:59:15   Log-Likelihood:                 124.42
# No. Observations:                  48   AIC:                            -244.8
# Df Residuals:                      46   BIC:                            -241.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0493      0.010     -4.900      0.000      -0.069      -0.029
# x1            -0.0088      0.011     -0.837      0.407      -0.030       0.012
# ==============================================================================
# Omnibus:                        8.904   Durbin-Watson:                   1.443
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                8.563
# Skew:                           0.777   Prob(JB):                       0.0138
# Kurtosis:                       4.367   Cond. No.                         7.40
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept: -0.049257941596474834
# Risk premium (Coefficient): -0.00880735642007096
# P-value x1: 0.40684153186793637
# P-value const: 1.2269308818815156e-05
# Std. error x1: 0.01052075439973425
# Std. error const : 0.01005181200971966
# T-statistic for X1: -0.8371411483850845
# T-statistic for const: -4.900404180743191

# %% [markdown]
# # NON-Linearity #

# %%
import statsmodels.api as sm
import pandas as pd

# Assuming new_df contains the required data

# Calculate adjusted beta squared
raw_beta_sqr = new_df['Beta'].values ** 2
adjusted_beta_sqr = 0.67 * raw_beta_sqr + 0.33 * 1.0

# Prepare the data
x = new_df['Adjusted Beta'].values
x_squared = adjusted_beta_sqr
y = new_df['Portfolio Excess Return'].values

# Prepare the independent variables matrix
X = sm.add_constant(pd.DataFrame({'Adjusted Beta': x, 'Adjusted Beta Squared': x_squared}))

# Fit the nonlinear OLS model
model = sm.OLS(y, X)
results = model.fit()

# Print the summary of results
print(results.summary())

# Retrieve specific values from the model summary
intercept = results.params[0]
gamma1 = results.params[1]  # Coefficient for adjusted beta
gamma2 = results.params[2]  # Coefficient for adjusted beta squared
p_value_int = results.pvalues[0]
p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
std_error_int = results.bse[0] 
std_error_gamma1 = results.bse[1]  # Standard error for gamma1
std_error_gamma2 = results.bse[2]  # Standard error for gamma2
t_stat_int = results.tvalues[0]
t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2

# Print the retrieved values
print("Intercept:", intercept)
print("Coefficient for adjusted beta (γ1):", gamma1)
print("Coefficient for adjusted beta squared (γ2):", gamma2)
print("Std. error for intercept:", std_error_int)
print("Std. error for γ1:", std_error_gamma1)
print("Std. error for γ2:", std_error_gamma2)
print("T-statistic for intercept:", t_stat_int)
print("T-statistic for γ1:", t_stat_gamma1)
print("T-statistic for γ2:", t_stat_gamma2)
print("P-value for intercept:", p_value_int)
print("P-value for γ1:", p_value_gamma1)
print("P-value for γ2:", p_value_gamma2)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.029
# Method:                 Least Squares   F-statistic:                    0.3450
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.710
# Time:                        18:59:26   Log-Likelihood:                 124.42
# No. Observations:                  48   AIC:                            -242.8
# Df Residuals:                      45   BIC:                            -237.2
# Df Model:                           2
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.0486      0.014     -3.448      0.001      -0.077      -0.020
# Adjusted Beta            -0.0107      0.031     -0.349      0.729      -0.072       0.051
# Adjusted Beta Squared     0.0012      0.018      0.065      0.948      -0.034       0.037
# ==============================================================================
# Omnibus:                        9.060   Durbin-Watson:                   1.448
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                8.764
# Skew:                           0.787   Prob(JB):                       0.0125
# Kurtosis:                       4.381   Cond. No.                         23.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept: -0.04861863111261046
# Coefficient for adjusted beta (γ1): -0.010685816653110969
# Coefficient for adjusted beta squared (γ2): 0.0011508257279802848
# Std. error for intercept: 0.014098559441134926
# Std. error for γ1: 0.030619905241401835
# Std. error for γ2: 0.017590896647032072
# T-statistic for intercept: -3.4484821882409773
# T-statistic for γ1: -0.34898268197977456
# T-statistic for γ2: 0.06542166389082
# P-value for intercept: 0.001234572118543802
# P-value for γ1: 0.7287300140843568
# P-value for γ2: 0.9481280566312915
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:26: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept = results.params[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma1 = results.params[1]  # Coefficient for adjusted beta
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma2 = results.params[2]  # Coefficient for adjusted beta squared
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_int = results.pvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_int = results.bse[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma1 = results.bse[1]  # Standard error for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma2 = results.bse[2]  # Standard error for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_int = results.tvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/2626776032.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2

# %% [markdown]
# # Non-systematic risk

# %%
import statsmodels.api as sm
import pandas as pd

# Assuming new_df contains the required data

# Calculate adjusted beta squared
raw_beta_sqr = new_df['Beta'].values ** 2
adjusted_beta_sqr = 0.67 * raw_beta_sqr + 0.33 * 1.0

# Prepare the data
x = new_df['Adjusted Beta'].values
x_squared = adjusted_beta_sqr
residual_variance = new_df['Normalized Residual Variance'].values
y = new_df['Portfolio Excess Return'].values

# Prepare the independent variables matrix
X = sm.add_constant(pd.DataFrame({'Adjusted Beta': x, 'Adjusted Beta Squared': x_squared, 'Residual Variance': residual_variance}))

# Fit the nonlinear OLS model
model = sm.OLS(y, X)
results = model.fit()

# Print the summary of results
print(results.summary())

# Retrieve specific values from the model summary
intercept = results.params[0]
gamma1 = results.params[1]  # Coefficient for adjusted beta
gamma2 = results.params[2]  # Coefficient for adjusted beta squared
gamma3 = results.params[3]  # Coefficient for residual variance
p_value_int = results.pvalues[0]
p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
p_value_gamma3 = results.pvalues[3]  # P-value for gamma3
std_error_int = results.bse[0] 
std_error_gamma1 = results.bse[1]  # Standard error for gamma1
std_error_gamma2 = results.bse[2]  # Standard error for gamma2
std_error_gamma3 = results.bse[3]  # Standard error for gamma3
t_stat_int = results.tvalues[0]
t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2
t_stat_gamma3 = results.tvalues[3]  # T-statistic for gamma3

# Function to round the values
def round_to_six_decimals(value):
    return round(value, 6)

# Print the retrieved values rounded to the sixth decimal point
print("Intercept:", round_to_six_decimals(intercept))
print("Coefficient for adjusted beta (γ1):", round_to_six_decimals(gamma1))
print("Coefficient for adjusted beta squared (γ2):", round_to_six_decimals(gamma2))
print("Coefficient for residual variance (γ3):", round_to_six_decimals(gamma3))
print("Std. error for intercept:", round_to_six_decimals(std_error_int))
print("Std. error for γ1:", round_to_six_decimals(std_error_gamma1))
print("Std. error for γ2:", round_to_six_decimals(std_error_gamma2))
print("Std. error for γ3:", round_to_six_decimals(std_error_gamma3))
print("T-statistic for intercept:", round_to_six_decimals(t_stat_int))
print("T-statistic for γ1:", round_to_six_decimals(t_stat_gamma1))
print("T-statistic for γ2:", round_to_six_decimals(t_stat_gamma2))
print("T-statistic for γ3:", round_to_six_decimals(t_stat_gamma3))
print("P-value for intercept:", round_to_six_decimals(p_value_int))
print("P-value for γ1:", round_to_six_decimals(p_value_gamma1))
print("P-value for γ2:", round_to_six_decimals(p_value_gamma2))
print("P-value for γ3:", round_to_six_decimals(p_value_gamma3))
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.052
# Method:                 Least Squares   F-statistic:                    0.2307
# Date:                Sat, 04 May 2024   Prob (F-statistic):              0.875
# Time:                        18:59:34   Log-Likelihood:                 124.43
# No. Observations:                  48   AIC:                            -240.9
# Df Residuals:                      44   BIC:                            -233.4
# Df Model:                           3
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# const                    -0.0490      0.015     -3.355      0.002      -0.079      -0.020
# Adjusted Beta            -0.0096      0.032     -0.298      0.767      -0.074       0.055
# Adjusted Beta Squared     0.0005      0.018      0.027      0.978      -0.037       0.038
# Residual Variance         0.0004      0.003      0.131      0.896      -0.005       0.006
# ==============================================================================
# Omnibus:                        9.039   Durbin-Watson:                   1.451
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                8.734
# Skew:                           0.786   Prob(JB):                       0.0127
# Kurtosis:                       4.377   Cond. No.                         24.2
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# Intercept: -0.049044
# Coefficient for adjusted beta (γ1): -0.009559
# Coefficient for adjusted beta squared (γ2): 0.000504
# Coefficient for residual variance (γ3): 0.000376
# Std. error for intercept: 0.014618
# Std. error for γ1: 0.032127
# Std. error for γ2: 0.018456
# Std. error for γ3: 0.002867
# T-statistic for intercept: -3.355071
# T-statistic for γ1: -0.297534
# T-statistic for γ2: 0.027315
# T-statistic for γ3: 0.131303
# P-value for intercept: 0.001642
# P-value for γ1: 0.767459
# P-value for γ2: 0.978332
# P-value for γ3: 0.896134
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:27: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   intercept = results.params[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:28: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma1 = results.params[1]  # Coefficient for adjusted beta
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:29: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma2 = results.params[2]  # Coefficient for adjusted beta squared
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:30: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   gamma3 = results.params[3]  # Coefficient for residual variance
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:31: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_int = results.pvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:32: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma1 = results.pvalues[1]  # P-value for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:33: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma2 = results.pvalues[2]  # P-value for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:34: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   p_value_gamma3 = results.pvalues[3]  # P-value for gamma3
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:35: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_int = results.bse[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:36: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma1 = results.bse[1]  # Standard error for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:37: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma2 = results.bse[2]  # Standard error for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:38: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   std_error_gamma3 = results.bse[3]  # Standard error for gamma3
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:39: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_int = results.tvalues[0]
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:40: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma1 = results.tvalues[1]  # T-statistic for gamma1
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:41: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma2 = results.tvalues[2]  # T-statistic for gamma2
# /var/folders/gd/ffzqsx5d0dbb4cjdtmxnpsmw0000gn/T/ipykernel_1701/3466800342.py:42: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   t_stat_gamma3 = results.tvalues[3]  # T-statistic for gamma3
